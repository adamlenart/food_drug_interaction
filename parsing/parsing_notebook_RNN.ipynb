# %% [markdown]
# <h1><center>Analyzing food and drug interactions through PubMed abstracts</center></h1>
# <h2><center>PHASE 1: Selection of Parser</center></h2>

# %% [markdown]
# ## Step 1 - Download data

# %%
# To use PubMed API
import pubmed.utils as pb

import json
from pprint import pprint

# Split abstracts to sentences
from nltk.tokenize import sent_tokenize

# UTF-8 support
import codecs

# %% [markdown]
# The _pubmed.utils_ module implements a _PubMedQuery_ class which searches the PubMed database for a search term and returns at most _max_\__results_ abstracts.

# %% [markdown]
# ### Step 1a) Testing search in PubMed - 3 samples

# %%
search_term = 'ACE inhibitor'
max_results = 3
query = pb.PubMedQuery(search_term, max_results)

# %% [markdown]
# After instantiating a _PubMedQuery_ instance, _PubMedQuery.id_\__getter_ should be called to read the ids of the articles of the search results.

# %%
ids = query.id_getter()
print ids
# Out:
# 28687104,28682034,28682025

# %%
query.abstract_getter(ids)
# Out:
# {0: u'Nonsteroidal antiinflammatory agents, \u03b2-lactam antibiotics, non-\u03b2 lactam antibiotics, and angiotensin-converting enzyme inhibitors are the most common classes of drugs that cause angioedema. Drug-induced angioedema is known to occur via mechanisms mediated by histamine, bradykinin, or leukotriene, and an understanding of these mechanisms is crucial in guiding therapeutic decisions. Nonallergic angioedema occurs in patients with genetic variants that affect metabolism or synthesis of bradykinin, substance P, prostaglandins, or leukotrienes, or when patients are taking drugs that have synergistic mechanisms. The mainstay in treatment of nonallergic drug-induced angioedema is cessation of the offending agents.',
#  1: "Fabry's disease (FD) is a severe congenital metabolic disorder characterized by the deficient activity of lysosomal exoglycohydrolase alpha-galactosidase, characterized by glycosphingolipid deposition in several cells, such as capillary endothelial cells, renal, cardiac, and nerve cells. As a systemic disease leading to a contemporaneous myocardial and renal dysfunction, FD might be an example of cardiorenal syndrome type 5 (CRS-5). Kidney damage is commonly characterized by proteinuria, isosthenuria and altered tubular function when occurs at the second-third decade, azotemia and end-stage renal disease in third-fifth decade. Beyond the irreversible glomerular, tubular and vascular damages, the podocytes foot process effacement is the major cause of kidney dysfunction. Myocardial damage is usually observed with right and left ventricular hypertrophy, arrhythmias (due to sinus node and conduction system impairment), diastolic dysfunction, congestive heart failure, myocardial ischemia, fibrosis and cardiac death. The enzymatic replacement therapy is essential for the management of FD, as well as the control of renal (with anti-proteinuric agents such as angiotensin-converting enzyme inhibitors- and/or angiotensin II receptor blockers), brain (coated aspirin, clopidogrel and statins to prevent strokes) and heart complications (calcium channel blockers for ischemic cardiomyopathy, warfarin and amiodarone or cardioverter device for arrhythmias).",
#  2: u'The progression of chronic kidney disease CKD is largely independent of the underlying kidney disorder once renal function has fallen below a critical level. Hypertension is an independent risk factor for disease progression in both adult and pediatric patients with kidney disorders. Optimal blood pressure control (130 /80mm Hg) represents a main goal of conservative therapy in patients with chronic kidney disease CKD but it is rarely achieved in clinical practice. Angiotensin-converting enzyme inhibitors and angiotensin receptor blockers are more effective than other drugs in slowing progression of proteinuric CKD. Dietary salt restriction (\u2264100 mEq/die of NaCl) may be useful to correct the extracellular volume expansion. If this intervention fails, hypertension can be treated by thiazide diuretics in patients with mild CKD, whereas loop diuretics at adequate doses are indicated in patients with more advanced CKD.'}

# %% [markdown]
# Becuase of pairing IDs with abstracts is a little bit tricky as some search result files are differently formatted than others, _abstract_\__getter_ just assigns a generic ID (a counter) to the abstracts.
#
# If we went through the IDs one-by-one, the ids could get paired correctly with the abstracts, and then we would have ID and abstract text pairing...but then it would take very long and we are likely not going to use this information.
#
# ### Step 1b) Downloading abstracts to local jsons

# %% [markdown]
# #### Just to download few queries

# %%
# %%time
# Test: download a few only
# If you don't want to download all abstracts, please do not use the download_all_abstracts() method, 
# but rather the abstract_getter() as below
pb.PubMedQuery.COUNT = 0
max_results = 10

# Specify just few queries
search_term = 'ACE inhibitor'
query = pb.PubMedQuery(search_term, max_results)
ids = query.id_getter()
abstracts = query.abstract_getter(ids)
# Out:
# CPU times: user 102 ms, sys: 10.9 ms, total: 113 ms
# Wall time: 1.05 s

# %%
print abstracts
# Out:
# {0: u'Nonsteroidal antiinflammatory agents, \u03b2-lactam antibiotics, non-\u03b2 lactam antibiotics, and angiotensin-converting enzyme inhibitors are the most common classes of drugs that cause angioedema. Drug-induced angioedema is known to occur via mechanisms mediated by histamine, bradykinin, or leukotriene, and an understanding of these mechanisms is crucial in guiding therapeutic decisions. Nonallergic angioedema occurs in patients with genetic variants that affect metabolism or synthesis of bradykinin, substance P, prostaglandins, or leukotrienes, or when patients are taking drugs that have synergistic mechanisms. The mainstay in treatment of nonallergic drug-induced angioedema is cessation of the offending agents.', 1: "Fabry's disease (FD) is a severe congenital metabolic disorder characterized by the deficient activity of lysosomal exoglycohydrolase alpha-galactosidase, characterized by glycosphingolipid deposition in several cells, such as capillary endothelial cells, renal, cardiac, and nerve cells. As a systemic disease leading to a contemporaneous myocardial and renal dysfunction, FD might be an example of cardiorenal syndrome type 5 (CRS-5). Kidney damage is commonly characterized by proteinuria, isosthenuria and altered tubular function when occurs at the second-third decade, azotemia and end-stage renal disease in third-fifth decade. Beyond the irreversible glomerular, tubular and vascular damages, the podocytes foot process effacement is the major cause of kidney dysfunction. Myocardial damage is usually observed with right and left ventricular hypertrophy, arrhythmias (due to sinus node and conduction system impairment), diastolic dysfunction, congestive heart failure, myocardial ischemia, fibrosis and cardiac death. The enzymatic replacement therapy is essential for the management of FD, as well as the control of renal (with anti-proteinuric agents such as angiotensin-converting enzyme inhibitors- and/or angiotensin II receptor blockers), brain (coated aspirin, clopidogrel and statins to prevent strokes) and heart complications (calcium channel blockers for ischemic cardiomyopathy, warfarin and amiodarone or cardioverter device for arrhythmias).", 2: u'The progression of chronic kidney disease CKD is largely independent of the underlying kidney disorder once renal function has fallen below a critical level. Hypertension is an independent risk factor for disease progression in both adult and pediatric patients with kidney disorders. Optimal blood pressure control (130 /80mm Hg) represents a main goal of conservative therapy in patients with chronic kidney disease CKD but it is rarely achieved in clinical practice. Angiotensin-converting enzyme inhibitors and angiotensin receptor blockers are more effective than other drugs in slowing progression of proteinuric CKD. Dietary salt restriction (\u2264100 mEq/die of NaCl) may be useful to correct the extracellular volume expansion. If this intervention fails, hypertension can be treated by thiazide diuretics in patients with mild CKD, whereas loop diuretics at adequate doses are indicated in patients with more advanced CKD.', 3: 'RAAS, a major pharmacological target in cardiovascular medicine, is inhibited by pharmacological classes including angiotensin converting enzyme (ACE) inhibitors (ACEIs), angiotensin-II type 1 blockers (ARBs) and aldosterone receptors antagonists, in addition to the recently introduced direct renin inhibitors (DRIs). However, currently used RAAS inhibitors still cannot achieve their desired effects and are associated with certain drawbacks, such as adverse side effects, incomplete blockage of the system and poor end-organ protection. In this review, we discuss the efficiency and specificity of the current RAAS inhibitors and propose some recommendations for achieving better treatments with better end-organ protection.Hypertension Research advance online publication, 6 July 2017; doi:10.1038/hr.2017.65.', 4: 'The beneficial effects of an ...

# %%
# Write file with the 10 examples of queries
json_file = 'my_ten_abstracts.json'
print 'Saving to ' + json_file
with open(json_file, 'w') as outfile:
    json.dump(abstracts, outfile, indent=4)
# Out:
# Saving to my_ten_abstracts.json

# %% [markdown]
# #### Download all abstracts
# The _download_\_all_\__abstracts_ method saves _max_\__results_ abstracts to a json file as below.

# %%
# %%time
# reset the counter before calling the download_all_abstracts method as we have already called it once above
pb.PubMedQuery.COUNT = 0
max_results = 500
pb.download_all_abstracts(search_term, max_results)
# Out:
# Saving to pbabstract1.json
# 500/50539 downloaded
# Saving to pbabstract2.json
# 1000/50539 downloaded
# Saving to pbabstract3.json
# 1500/50539 downloaded
# Saving to pbabstract4.json
# 2000/50539 downloaded
# Saving to pbabstract5.json
# 2500/50539 downloaded
# Saving to pbabstract6.json
# 3000/50539 downloaded
# Saving to pbabstract7.json
# 3500/50539 downloaded
# Saving to pbabstract8.json
# 4000/50539 downloaded
# Saving to pbabstract9.json
# 4500/50539 downloaded
# Saving to pbabstract10.json
# 5000/50539 downloaded
# Saving to pbabstract11.json
# 5500/50539 downloaded
# Saving to pbabstract12.json
# 6000/50539 downloaded
# Saving to pbabstract13.json
# 6500/50539 downloaded
# Saving to pbabstract14.json
# 7000/50539 downloaded
# Saving to pbabstract15.json
# 7500/50539 downloaded
# Saving to pbabstract16.json
# 8000/50539 downloaded
# Saving to pbabstract17.json
# 8500/50539 downloaded
# Saving to pbabstract18.json
# 9000/50539 downloaded
# Saving to pbabstract19.json
# 9500/50539 downloaded
# Saving to pbabstract20.json
# 10000/50539 downloaded
# Saving to pbabstract21.json
# 10500/50539 downloaded
# Saving to pbabstract22.json
# 11000/50539 downloaded
# Saving to pbabstract23.json
# 11500/50539 downloaded
# Saving to pbabstract24.json
# 12000/50539 downloaded
# Saving to pbabstract25.json
# 12500/50539 downloaded
# Saving to pbabstract26.json
# 13000/50539 downloaded
# Saving to pbabstract27.json
# 13500/50539 downloaded
# Saving to pbabstract28.json
# 14000/50539 downloaded
# Saving to pbabstract29.json
# 14500/50539 downloaded
# Saving to pbabstract30.json
# 15000/50539 downloaded
# Saving to pbabstract31.json
# 15500/50539 downloaded
# Saving to pbabstract32.json
# 16000/50539 downloaded
# Saving to pbabstract33.json
# 16500/50539 downloaded
# Saving to pbabstract34.json
# 17000/50539 downloaded
# Saving to pbabstract35.json
# 17500/50539 downloaded
# Saving to pbabstract36.json
# 18000/50539 downloaded
# Saving to pbabstract37.json
# 18500/50539 downloaded
# Saving to pbabstract38.json
# 19000/50539 downloaded
# Saving to pbabstract39.json
# 19500/50539 downloaded
# Saving to pbabstract40.json
# 20000/50539 downloaded
# Saving to pbabstract41.json
# 20500/50539 downloaded
# Saving to pbabstract42.json
# 21000/50539 downloaded
# Saving to pbabstract43.json
# 21500/50539 downloaded
# Saving to pbabstract44.json
# 22000/50539 downloaded
# Saving to pbabstract45.json
# 22500/50539 downloaded
# Saving to pbabstract46.json
# 23000/50539 downloaded
# Saving to pbabstract47.json
# 23500/50539 downloaded
# Saving to pbabstract48.json
# 24000/50539 downloaded
# Saving to pbabstract49.json
# 24500/50539 downloaded
# Saving to pbabstract50.json
# 25000/50539 downloaded
# Saving to pbabstract51.json
# 25500/50539 downloaded
# Saving to pbabstract52.json
# 26000/50539 downloaded
# Saving to pbabstract53.json
# 26500/50539 downloaded
# Saving to pbabstract54.json
# 27000/50539 downloaded
# Saving to pbabstract55.json
# 27500/50539 downloaded
# Saving to pbabstract56.json
# 28000/50539 downloaded
# Saving to pbabstract57.json
# 28500/50539 downloaded
# Saving to pbabstract58.json
# 29000/50539 downloaded
# Saving to pbabstract59.json
# 29500/50539 downloaded
# Saving to pbabstract60.json
# 30000/50539 downloaded
# Saving to pbabstract61.json
# 30500/50539 downloaded
# Saving to pbabstract62.json
# 31000/50539 downloaded
# Saving to pbabstract63.json
# 31500/50539 downloaded
# Saving to pbabstract64.json
# 32000/50539 downloaded
# Saving to pbabstract65.json
# 32500/50539 downloaded
# Saving to pbabstract66.json
# 33000/50539 downloaded
# Saving to pbabstract67.json
# 33500/50539 downloaded
# Saving to pbabstract68.json
# 34000/50539 downloaded
# Saving to pbabstract69.json
# 34500/50539 downloaded
# Saving to pbabstract70.json
# 35000/50539 downloaded
# Saving to pbabstract71.json
# 35500/50539 downloaded
# Saving to pbabstract72.json
# 36000/50539 downloaded
# Saving to pbabstract73.json
# 36500/50539 downloaded
# Saving to pbabstract74.json
# 37000/50539 downloaded
# Saving to pbabstract75.json
# 37500/50539 downloaded
# Saving to pbabstract76.json
# 38000/50539 downloaded
# Saving to pbabstract77.json
# 38500/50539 downloaded
# Saving to pbabstract78.json
# 39000/50539 downloaded
# Saving to pbabstract79.json
# 39500/50539 downloaded
# Saving to pbabstract80.json
# 40000/50539 downloaded
# Saving to pbabstract81.json
# 40500/50539 downloaded
# Saving to pbabstract82.json
# 41000/50539 downloaded
# Saving to pbabstract83.json
# 41500/50539 downloaded
# Saving to pbabstract84.json
# 42000/50539 downloaded
# Saving to pbabstract85.json
# 42500/50539 downloaded
# Saving to pbabstract86.json
# 43000/50539 downloaded
# Saving to pbabstract87.json
# 43500/50539 downloaded
# Saving to pbabstract88.json
# 44000/50539 downloaded
# Saving to pbabstract89.json
# 44500/50539 downloaded
# Saving to pbabstract90.json
# 45000/50539 downloaded
# Saving to pbabstract91.json
# 45500/50539 downloaded
# Saving to pbabstract92.json
# 46000/50539 downloaded
# Saving to pbabstract93.json
# 46500/50539 downloaded
# Saving to pbabstract94.json
# 47000/50539 downloaded
# Saving to pbabstract95.json
# 47500/50539 downloaded
# Saving to pbabstract96.json
# 48000/50539 downloaded
# Saving to pbabstract97.json
# 48500/50539 downloaded
# Saving to pbabstract98.json
# 49000/50539 downloaded
# Saving to pbabstract99.json
# 49500/50539 downloaded
# Saving to pbabstract100.json
# 50000/50539 downloaded
# Saving to pbabstract101.json
# 50500/50539 downloaded
# CPU times: user 2min 27s, sys: 2.79 s, total: 2min 30s
# Wall time: 9min 55s

# %% [markdown]
# ## Step 2 - Adding Code for Parser

# %% [markdown]
# 1. Download the parser from https://stanfordnlp.github.io/CoreNLP/
# 2. Unpack into a local dir
# 3. Put the path to englishPCFG.ser.gz as an arg to StanfordParser

# %% [markdown]
# ## Step 2a) Pre-processing of downloaded data

# %% [markdown]
# ### Dictionary of sentences from all abstracts with unique IDs AND filtered if any word related to keyword ACEI

# %%
# Splitting abstracts into sentences AND filtering sentences with words related to keyword "ACEI"
data_dict_ACE = {}
keyword = "ACEI"

for i in range(1, 102):
    name = "pbabstract"+str(i)+".json"
    with codecs.open(name,"r","utf-8") as data_file:
        data = json.load(data_file)  # dictionary type with abstract ID as key
        keys = data.keys()
        for old_key in keys:
            try:
                temp_list = sent_tokenize(data.pop(old_key))  # to convert abstract into a list of sentences
                for j in range(len(temp_list)):
                    new_key = str(i)+"_"+str(old_key)+"_"+str(j)  # add prefix to ID's for unique IDs across different json files
                    transformed_sentence = pb.ace_substitutor(temp_list[j], keyword) 
                    if keyword in transformed_sentence:  # Filtering with keyword
                        data[new_key] = transformed_sentence
            except:
                next
        data_dict_ACE.update(data)

# %%
print len(data_dict_ACE), "sentences in all abstracts with keyword"
# Out:
# 65387 sentences in all abstracts with keyword

# %% [markdown]
# Note: if filtered only with keyword "ACE" instead of related words to ACE inhibitors, we get 54239 sentences.

# %%
# Examples of sentences to check if sent.tokenize() works well
i = 0
for key, sentence in data_dict_ACE.iteritems():
    print key, ": ", sentence
    i += 1
    if i  > 5:
        break
        
# Observations:
# Some sentences with abbreviations does not work well with sent.tokenize() - see second example without keyword above
# Out:
# 4_490_1 :  increase in all-cause mortality was associated with higher age and ACEI prescription.
# 4_490_2 :  higher risk of cardiovascular mortality was associated with increasing age, prescriptions for ACEI, and diagnosis of myocardial infarction or angina as compared with the other diagnoses.
# 21_712_0 :  the clinical benefits of ACEI (ACEI) inhibitors and angiotensin ii receptor blockers (arb) are well established in chronic kidney disease (ckd) patients with diabetic and non-diabetic nephropathies.
# 7_789_0 :  angiotensin ii receptor blockers (arbs), ACEI are some of the most commonly prescribed medications for hypertension.
# 21_712_2 :  given that the single agents can achieve only partial and not durable suppression of the renin-angiotensin system (ras), it has been hypothesized that dual blockage with ACEI and arbs would be most beneficial in the management of progressive ckd than either agent alone.
# 13_206_0 :  to examine the association between ACEI (ACEI) inhibitor use and clinical outcome after primary vascular reconstruction in a population-based follow-up study.

# %% [markdown]
# ## Step 2b) Write text file to run with Stanford RNN parser

# %%
def sample_sentences(sample_size, dictname):
    # Sample of 1,000 sentences for testing
    max_sample = sample_size
    sample = 0
    data_dict_sample = {}
    i= 0

    for id_num, sentence in dictname.iteritems():
        data_dict_sample[id_num] = sentence
        i += 1
        if i >= max_sample:
            break
            
    return data_dict_sample

# %%
data_dict_ACE_sample = sample_sentences(10, data_dict_ACE)

# %%
# Json dump: fast but then keeps the index and json format in text file - we don't want that!
#json.dump(data_dict_ACE_sample, open("ACEsentences_sample.txt",'w'))

# %%
def dict_to_file(filename, dictname):
    with open(filename,'w') as f:
        for value in dictname.values():
            try:
                f.write('{}\n'.format(value))  # some will be dropped from ascii encoding issues?
            except:
                next

# %%
dict_to_file("ACEsentences_sample2.txt", data_dict_ACE_sample)

# %%
# !cat ACEsentences_sample2.txt
# Out:
# Increase in all-cause mortality was associated with higher age and ACE inhibitors prescription.
# Higher risk of cardiovascular mortality was associated with increasing age, prescriptions for ACE inhibitor, and diagnosis of myocardial infarction or angina as compared with the other diagnoses.
# The clinical benefits of angiotensin-converting enzyme (ACE) inhibitors and angiotensin II receptor blockers (ARB) are well established in chronic kidney disease (CKD) patients with diabetic and non-diabetic nephropathies.
# Angiotensin II receptor blockers (ARBs), angiotensin-converting enzyme inhibitors (ACEIs) are some of the most commonly prescribed medications for hypertension.
# Given that the single agents can achieve only partial and not durable suppression of the renin-angiotensin system (RAS), it has been hypothesized that dual blockage with ACE inhibitors and ARBs would be most beneficial in the management of progressive CKD than either agent alone.
# To examine the association between angiotensin-converting enzyme (ACE) inhibitor use and clinical outcome after primary vascular reconstruction in a population-based follow-up study.
# These results suggest that potentiation of bradykinin-induced skin reaction by cilazapril is due to a tissular (and not systemic) inhibition of ACE and does not occur with Ro 42-5892.
# We contacted patients General Practitioners for current patient data including MACE, which was supplemented by using the hospital patient records.
# ACEIs, specifically benazepril hydrochloride (BH), will delay the onset of overt DCM in Doberman Pinschers.
# ACE inhibitors were associated with a slightly increased recurrence hazard, whereas ARBs were not associated with recurrence (adjusted ACE inhibitor HR = 1.2, 95% CI, 0.97 to 1.4; adjusted ARBs HR = 1.1, 95% CI, 0.85 to 1.3).

# %% [markdown]
# ## Step 2c) Run Stanford parser models with sample set

# %% [markdown]
# ### Stanford models API download instructions:

# %% [markdown]
# We first downloaded the files from this link <http://nlp.stanford.edu/software/stanford-corenlp-full-2017-06-09.zip>
#
# Then we dragged the pubmed folder into that same folder, with the copied abstracts (if you don't want to re-download them all again).
#
# There are a few files you will need to make sure are present:
#
# `lexparser-gui.bat
# lexparser-gui.command
# lexparser-gui.sh
# lexparser-lang-train-test.sh
# lexparser-lang.sh
# lexparser.bat
# lexparser.sh                       `
#
# You will also need to add the `edu` folder that can be found here:
# <https://www.dropbox.com/s/t9uk4z1xznpo0jz/jars.zip?dl=0>
#
# Add the .zip extension to the `stanford-corenlp-3.8.0-models.jar` file, and unzip it. Copy that `edu` folder and paste it in to your home directory.

# %% [markdown]
# ### Testing with default parser (lexical parser)

# %%
# !chmod a+x lexparser.sh

# %%
! ./lexparser.sh ACEsentences_sample2.txt
# Out:
# [main] INFO edu.stanford.nlp.parser.lexparser.LexicalizedParser - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ... done [0.5 sec].
# Parsing file: ACEsentences_sample2.txt
# Parsing [sent. 1 len. 14]: Increase in all-cause mortality was associated with higher age and ACE inhibitors prescription .
# (ROOT
#   (S
#     (NP
#       (NP (NNP Increase))
#       (PP (IN in)
#         (NP (JJ all-cause) (NN mortality))))
#     (VP (VBD was)
#       (VP (VBN associated)
#         (PP (IN with)
#           (NP
#             (NP (JJR higher) (NN age))
#             (CC and)
#             (NP (NNP ACE) (NNS inhibitors) (NN prescription))))))
#     (. .)))
#
# nsubjpass(associated-6, Increase-1)
# case(mortality-4, in-2)
# amod(mortality-4, all-cause-3)
# nmod:in(Increase-1, mortality-4)
# auxpass(associated-6, was-5)
# root(ROOT-0, associated-6)
# case(age-9, with-7)
# amod(age-9, higher-8)
# nmod:with(associated-6, age-9)
# cc(age-9, and-10)
# compound(prescription-13, ACE-11)
# compound(prescription-13, inhibitors-12)
# nmod:with(associated-6, prescription-13)
# conj:and(age-9, prescription-13)
#
# Parsing [sent. 2 len. 30]: Higher risk of cardiovascular mortality was associated with increasing age , prescriptions for ACE inhibitor , and diagnosis of myocardial infarction or angina as compared with the other diagnoses .
# (ROOT
#   (S
#     (NP
#       (NP (JJR Higher) (NN risk))
#       (PP (IN of)
#         (NP (JJ cardiovascular) (NN mortality))))
#     (VP (VBD was)
#       (VP (VBN associated)
#         (PP (IN with)
#           (S
#             (VP (VBG increasing)
#               (NP
#                 (NP (NN age))
#                 (, ,)
#                 (NP
#                   (NP (NNS prescriptions))
#                   (PP (IN for)
#                     (NP (NNP ACE) (NN inhibitor))))
#                 (, ,)
#                 (CC and)
#                 (NP
#                   (NP (NN diagnosis))
#                   (PP (IN of)
#                     (NP (JJ myocardial) (NN infarction)
#                       (CC or)
#                       (NN angina)))))
#               (PP (IN as))
#               (PP (VBN compared)
#                 (PP (IN with)
#                   (NP (DT the) (JJ other) (NNS diagnoses)))))))))
#     (. .)))
#
# amod(risk-2, Higher-1)
# nsubjpass(associated-7, risk-2)
# case(mortality-5, of-3)
# amod(mortality-5, cardiovascular-4)
# nmod:of(risk-2, mortality-5)
# auxpass(associated-7, was-6)
# root(ROOT-0, associated-7)
# mark(increasing-9, with-8)
# advcl(associated-7, increasing-9)
# dobj(increasing-9, age-10)
# dobj(increasing-9, prescriptions-12)
# conj:and(age-10, prescriptions-12)
# case(inhibitor-15, for-13)
# compound(inhibitor-15, ACE-14)
# nmod:for(prescriptions-12, inhibitor-15)
# cc(age-10, and-17)
# dobj(increasing-9, diagnosis-18)
# conj:and(age-10, diagnosis-18)
# case(infarction-21, of-19)
# amod(infarction-21, myocardial-20)
# nmod:of(diagnosis-18, infarction-21)
# cc(infarction-21, or-22)
# nmod:of(diagnosis-18, angina-23)
# conj:or(infarction-21, angina-23)
# nmod(increasing-9, as-24)
# case(diagnoses-29, compared-25)
# mwe(compared-25, with-26)
# det(diagnoses-29, the-27)
# amod(diagnoses-29, other-28)
# advcl(increasing-9, diagnoses-29)
#
# Parsing [sent. 3 len. 35]: The clinical benefits of angiotensin-converting enzyme -LRB- ACE -RRB- inhibitors and angiotensin II receptor blockers -LRB- ARB -RRB- are well established in chronic kidney disease -LRB- CKD -RRB- patients with diabetic and non-diabetic nephropathies .
# (ROOT
#   (S
#     (NP
#       (NP (DT The) (JJ clinical) (NNS benefits))
#       (PP (IN of)
#         (NP
#           (NP (JJ angiotensin-converting) (NN enzyme)
#             (PRN (-LRB- -LRB-)
#               (NP (NNP ACE))
#               (-RRB- -RRB-))
#             (NNS inhibitors))
#           (CC and)
#           (NP
#             (NP (JJ angiotensin) (NNP II) (NN receptor) (NNS blockers))
#             (PRN (-LRB- -LRB-)
#               (NP (NNP ARB))
#               (-RRB- -RRB-))))))
#     (VP (VBP are)
#       (ADVP (RB well))
#       (VP (VBN established)
#         (PP (IN in)
#           (NP
#             (NP (JJ chronic) (NN kidney) (NN disease)
#               (PRN (-LRB- -LRB-)
#                 (NP (NNP CKD))
#                 (-RRB- -RRB-))
#               (NNS patients))
#             (PP (IN with)
#               (NP
#                 (ADJP (JJ diabetic)
#                   (CC and)
#                   (JJ non-diabetic))
#                 (NNS nephropathies)))))))
#     (. .)))
#
# det(benefits-3, The-1)
# amod(benefits-3, clinical-2)
# nsubjpass(established-21, benefits-3)
# case(inhibitors-10, of-4)
# amod(inhibitors-10, angiotensin-converting-5)
# compound(inhibitors-10, enzyme-6)
# appos(inhibitors-10, ACE-8)
# nmod:of(benefits-3, inhibitors-10)
# cc(inhibitors-10, and-11)
# amod(blockers-15, angiotensin-12)
# compound(blockers-15, II-13)
# compound(blockers-15, receptor-14)
# nmod:of(benefits-3, blockers-15)
# conj:and(inhibitors-10, blockers-15)
# appos(blockers-15, ARB-17)
# auxpass(established-21, are-19)
# advmod(established-21, well-20)
# root(ROOT-0, established-21)
# case(patients-29, in-22)
# amod(patients-29, chronic-23)
# compound(patients-29, kidney-24)
# compound(patients-29, disease-25)
# appos(patients-29, CKD-27)
# nmod:in(established-21, patients-29)
# case(nephropathies-34, with-30)
# amod(nephropathies-34, diabetic-31)
# cc(diabetic-31, and-32)
# conj:and(diabetic-31, non-diabetic-33)
# amod(nephropathies-34, non-diabetic-33)
# nmod:with(patients-29, nephropathies-34)
#
# Parsing [sent. 4 len. 25]: Angiotensin II receptor blockers -LRB- ARBs -RRB- , angiotensin-converting enzyme inhibitors -LRB- ACEIs -RRB- are some of the most commonly prescribed medications for hypertension .
# (ROOT
#   (S
#     (NP
#       (NP
#         (NP (JJ Angiotensin) (NNP II) (NN receptor) (NNS blockers))
#         (PRN (-LRB- -LRB-)
#           (NP (NNP ARBs))
#           (-RRB- -RRB-)))
#       (, ,)
#       (NP
#         (NP (JJ angiotensin-converting) (NN enzyme) (NNS inhibitors))
#         (PRN (-LRB- -LRB-)
#           (NP (NNP ACEIs))
#           (-RRB- -RRB-))))
#     (VP (VBP are)
#       (NP
#         (NP (DT some))
#         (PP (IN of)
#           (NP
#             (NP (DT the)
#               (ADJP (RBS most) (RB commonly) (VBN prescribed))
#               (NNS medications))
#             (PP (IN for)
#               (NP (NN hypertension)))))))
#     (. .)))
#
# amod(blockers-4, Angiotensin-1)
# compound(blockers-4, II-2)
# compound(blockers-4, receptor-3)
# nsubj(some-16, blockers-4)
# appos(blockers-4, ARBs-6)
# amod(inhibitors-11, angiotensin-converting-9)
# compound(inhibitors-11, enzyme-10)
# appos(blockers-4, inhibitors-11)
# appos(inhibitors-11, ACEIs-13)
# cop(some-16, are-15)
# root(ROOT-0, some-16)
# case(medications-22, of-17)
# det(medications-22, the-18)
# advmod(prescribed-21, most-19)
# advmod(prescribed-21, commonly-20)
# amod(medications-22, prescribed-21)
# nmod:of(some-16, medications-22)
# case(hypertension-24, for-23)
# nmod:for(medications-22, hypertension-24)
#
# Parsing [sent. 5 len. 48]: Given that the single agents can achieve only partial and not durable suppression of the renin-angiotensin system -LRB- RAS -RRB- , it has been hypothesized that dual blockage with ACE inhibitors and ARBs would be most beneficial in the management of progressive CKD than either agent alone .
# (ROOT
#   (S
#     (PP (VBN Given)
#       (SBAR (IN that)
#         (S
#           (NP (DT the) (JJ single) (NNS agents))
#           (VP (MD can)
#             (VP (VB achieve)
#               (NP
#                 (NP (RB only) (JJ partial))
#                 (CC and)
#                 (RB not)
#                 (NP
#                   (NP (JJ durable) (NN suppression))
#                   (PP (IN of)
#                     (NP
#                       (NP (DT the) (JJ renin-angiotensin) (NN system))
#                       (PRN (-LRB- -LRB-)
#                         (NP (NNP RAS))
#                         (-RRB- -RRB-)))))))))))
#     (, ,)
#     (NP (PRP it))
#     (VP (VBZ has)
#       (VP (VBN been)
#         (VP (VBN hypothesized)
#           (SBAR (IN that)
#             (S
#               (NP
#                 (NP (JJ dual) (NN blockage))
#                 (PP (IN with)
#                   (NP (NNP ACE) (NNS inhibitors)
#                     (CC and)
#                     (NNS ARBs))))
#               (VP (MD would)
#                 (VP (VB be)
#                   (ADJP
#                     (ADJP (RBS most) (JJ beneficial))
#                     (PP (IN in)
#                       (NP
#                         (NP (DT the) (NN management))
#                         (PP (IN of)
#                           (NP (JJ progressive) (NNP CKD)))))
#                     (PP (IN than)
#                       (NP (DT either) (NN agent))))
#                   (ADVP (RB alone)))))))))
#     (. .)))
#
# mark(achieve-7, Given-1)
# mark(achieve-7, that-2)
# det(agents-5, the-3)
# amod(agents-5, single-4)
# nsubj(achieve-7, agents-5)
# aux(achieve-7, can-6)
# advcl(hypothesized-25, achieve-7)
# advmod(partial-9, only-8)
# dobj(achieve-7, partial-9)
# cc(partial-9, and-10)
# neg(suppression-13, not-11)
# amod(suppression-13, durable-12)
# dobj(achieve-7, suppression-13)
# conj:and(partial-9, suppression-13)
# case(system-17, of-14)
# det(system-17, the-15)
# amod(system-17, renin-angiotensin-16)
# nmod:of(suppression-13, system-17)
# appos(system-17, RAS-19)
# nsubjpass(hypothesized-25, it-22)
# aux(hypothesized-25, has-23)
# auxpass(hypothesized-25, been-24)
# root(ROOT-0, hypothesized-25)
# mark(beneficial-37, that-26)
# amod(blockage-28, dual-27)
# nsubj(beneficial-37, blockage-28)
# case(inhibitors-31, with-29)
# compound(inhibitors-31, ACE-30)
# nmod:with(blockage-28, inhibitors-31)
# cc(inhibitors-31, and-32)
# nmod:with(blockage-28, ARBs-33)
# conj:and(inhibitors-31, ARBs-33)
# aux(beneficial-37, would-34)
# cop(beneficial-37, be-35)
# advmod(beneficial-37, most-36)
# ccomp(hypothesized-25, beneficial-37)
# case(management-40, in-38)
# det(management-40, the-39)
# nmod:in(beneficial-37, management-40)
# case(CKD-43, of-41)
# amod(CKD-43, progressive-42)
# nmod:of(management-40, CKD-43)
# case(agent-46, than-44)
# det(agent-46, either-45)
# nmod:than(beneficial-37, agent-46)
# advmod(beneficial-37, alone-47)
#
# Parsing [sent. 6 len. 25]: To examine the association between angiotensin-converting enzyme -LRB- ACE -RRB- inhibitor use and clinical outcome after primary vascular reconstruction in a population-based follow-up study .
# (ROOT
#   (S
#     (S
#       (VP (TO To)
#         (VP (VB examine)
#           (NP
#             (NP (DT the) (NN association))
#             (PP (IN between)
#               (NP
#                 (NP (JJ angiotensin-converting) (NN enzyme))
#                 (PRN (-LRB- -LRB-)
#                   (NP (NNP ACE))
#                   (-RRB- -RRB-))))))))
#     (VP (VBP inhibitor)
#       (NP (NN use)
#         (CC and)
#         (JJ clinical) (NN outcome))
#       (PP (IN after)
#         (NP
#           (NP (JJ primary) (NN vascular) (NN reconstruction))
#           (PP (IN in)
#             (NP (DT a) (JJ population-based) (NN follow-up) (NN study))))))
#     (. .)))
#
# mark(examine-2, To-1)
# csubj(inhibitor-11, examine-2)
# det(association-4, the-3)
# dobj(examine-2, association-4)
# case(enzyme-7, between-5)
# amod(enzyme-7, angiotensin-converting-6)
# nmod:between(association-4, enzyme-7)
# appos(enzyme-7, ACE-9)
# root(ROOT-0, inhibitor-11)
# compound(outcome-15, use-12)
# cc(use-12, and-13)
# conj:and(use-12, clinical-14)
# compound(outcome-15, clinical-14)
# dobj(inhibitor-11, outcome-15)
# case(reconstruction-19, after-16)
# amod(reconstruction-19, primary-17)
# compound(reconstruction-19, vascular-18)
# nmod:after(inhibitor-11, reconstruction-19)
# case(study-24, in-20)
# det(study-24, a-21)
# amod(study-24, population-based-22)
# compound(study-24, follow-up-23)
# nmod:in(reconstruction-19, study-24)
#
# Parsing [sent. 7 len. 32]: These results suggest that potentiation of bradykinin-induced skin reaction by cilazapril is due to a tissular -LRB- and not systemic -RRB- inhibition of ACE and does not occur with Ro 42-5892 .
# (ROOT
#   (S
#     (NP (DT These) (NNS results))
#     (VP
#       (VP (VBP suggest)
#         (SBAR (IN that)
#           (S
#             (NP
#               (NP (NN potentiation))
#               (PP (IN of)
#                 (NP
#                   (NP (JJ bradykinin-induced) (NN skin) (NN reaction))
#                   (PP (IN by)
#                     (NP (NN cilazapril))))))
#             (VP (VBZ is)
#               (ADJP (JJ due)
#                 (PP (TO to)
#                   (NP
#                     (NP (DT a) (NN tissular)
#                       (PRN (-LRB- -LRB-)
#                         (CC and)
#                         (RB not)
#                         (NP (NNP systemic))
#                         (-RRB- -RRB-))
#                       (NN inhibition))
#                     (PP (IN of)
#                       (NP (NNP ACE))))))))))
#       (CC and)
#       (VP (VBZ does) (RB not)
#         (VP (VB occur)
#           (PP (IN with)
#             (NP (NNP Ro) (CD 42-5892))))))
#     (. .)))
#
# det(results-2, These-1)
# nsubj(suggest-3, results-2)
# nsubj(occur-28, results-2)
# root(ROOT-0, suggest-3)
# mark(due-13, that-4)
# nsubj(due-13, potentiation-5)
# case(reaction-9, of-6)
# amod(reaction-9, bradykinin-induced-7)
# compound(reaction-9, skin-8)
# nmod:of(potentiation-5, reaction-9)
# case(cilazapril-11, by-10)
# nmod:by(reaction-9, cilazapril-11)
# cop(due-13, is-12)
# ccomp(suggest-3, due-13)
# case(inhibition-22, to-14)
# det(inhibition-22, a-15)
# compound(inhibition-22, tissular-16)
# cc(systemic-20, and-18)
# dep(systemic-20, not-19)
# appos(inhibition-22, systemic-20)
# nmod:to(due-13, inhibition-22)
# case(ACE-24, of-23)
# nmod:of(inhibition-22, ACE-24)
# cc(suggest-3, and-25)
# aux(occur-28, does-26)
# neg(occur-28, not-27)
# conj:and(suggest-3, occur-28)
# case(Ro-30, with-29)
# nmod:with(occur-28, Ro-30)
# nummod(Ro-30, 42-5892-31)
#
# Parsing [sent. 8 len. 22]: We contacted patients General Practitioners for current patient data including MACE , which was supplemented by using the hospital patient records .
# (ROOT
#   (S
#     (NP (PRP We))
#     (VP (VBD contacted)
#       (NP
#         (NP (NNP patients) (NNP General) (NNP Practitioners))
#         (PP (IN for)
#           (NP (JJ current) (NN patient) (NNS data))))
#       (PP (VBG including)
#         (NP
#           (NP (NNP MACE))
#           (, ,)
#           (SBAR
#             (WHNP (WDT which))
#             (S
#               (VP (VBD was)
#                 (VP (VBN supplemented)
#                   (PP (IN by)
#                     (S
#                       (VP (VBG using)
#                         (NP (DT the) (NN hospital) (NN patient) (NNS records))))))))))))
#     (. .)))
#
# nsubj(contacted-2, We-1)
# root(ROOT-0, contacted-2)
# compound(Practitioners-5, patients-3)
# compound(Practitioners-5, General-4)
# dobj(contacted-2, Practitioners-5)
# case(data-9, for-6)
# amod(data-9, current-7)
# compound(data-9, patient-8)
# nmod:for(Practitioners-5, data-9)
# case(MACE-11, including-10)
# nmod:including(contacted-2, MACE-11)
# nsubjpass(supplemented-15, MACE-11)
# ref(MACE-11, which-13)
# auxpass(supplemented-15, was-14)
# acl:relcl(MACE-11, supplemented-15)
# mark(using-17, by-16)
# advcl(supplemented-15, using-17)
# det(records-21, the-18)
# compound(records-21, hospital-19)
# compound(records-21, patient-20)
# dobj(using-17, records-21)
#
# Parsing [sent. 9 len. 20]: ACEIs , specifically benazepril hydrochloride -LRB- BH -RRB- , will delay the onset of overt DCM in Doberman Pinschers .
# (ROOT
#   (S
#     (NP
#       (NP (NNS ACEIs))
#       (, ,)
#       (NP
#         (NP
#           (ADJP (RB specifically) (JJ benazepril))
#           (NN hydrochloride))
#         (PRN (-LRB- -LRB-)
#           (NP (NNP BH))
#           (-RRB- -RRB-)))
#       (, ,))
#     (VP (MD will)
#       (VP (VB delay)
#         (NP
#           (NP (DT the) (NN onset))
#           (PP (IN of)
#             (NP
#               (NP (NNP overt) (NNP DCM))
#               (PP (IN in)
#                 (NP (NNP Doberman) (NNPS Pinschers))))))))
#     (. .)))
#
# nsubj(delay-11, ACEIs-1)
# advmod(benazepril-4, specifically-3)
# amod(hydrochloride-5, benazepril-4)
# appos(ACEIs-1, hydrochloride-5)
# appos(hydrochloride-5, BH-7)
# aux(delay-11, will-10)
# root(ROOT-0, delay-11)
# det(onset-13, the-12)
# dobj(delay-11, onset-13)
# case(DCM-16, of-14)
# compound(DCM-16, overt-15)
# nmod:of(onset-13, DCM-16)
# case(Pinschers-19, in-17)
# compound(Pinschers-19, Doberman-18)
# nmod:in(DCM-16, Pinschers-19)
#
# Parsing [sent. 10 len. 49]: ACE inhibitors were associated with a slightly increased recurrence hazard , whereas ARBs were not associated with recurrence -LRB- adjusted ACE inhibitor HR = 1.2 , 95 % CI , 0.97 to 1.4 ; adjusted ARBs HR = 1.1 , 95 % CI , 0.85 to 1.3 -RRB- .
# (ROOT
#   (S
#     (NP (NNP ACE) (NNS inhibitors))
#     (VP (VBD were)
#       (VP (VBN associated)
#         (PP (IN with)
#           (NP
#             (NP (DT a) (RB slightly) (VBN increased) (NN recurrence) (NN hazard))
#             (, ,)
#             (SBAR (IN whereas)
#               (S
#                 (NP (NNP ARBs))
#                 (VP (VBD were) (RB not)
#                   (VP (VBN associated)
#                     (PP (IN with)
#                       (NP
#                         (NP (NN recurrence))
#                         (PRN (-LRB- -LRB-)
#                           (VP (VBN adjusted)
#                             (NP
#                               (NP
#                                 (NP (NNP ACE) (NNP inhibitor) (NNP HR))
#                                 (SBAR
#                                   (S
#                                     (VP (SYM =)
#                                       (NP (CD 1.2))))))
#                               (, ,)
#                               (NP
#                                 (NP (CD 95) (NN %))
#                                 (NP (NNP CI)))
#                               (, ,)
#                               (NP
#                                 (NP
#                                   (QP (CD 0.97) (TO to) (CD 1.4)))
#                                 (: ;)
#                                 (NP
#                                   (NP (JJ adjusted) (NNP ARBs) (NNP HR))
#                                   (SBAR
#                                     (S
#                                       (VP (SYM =)
#                                         (NP (CD 1.1)))))))
#                               (, ,)
#                               (NP
#                                 (NP (CD 95) (NN %))
#                                 (NP (NNP CI))
#                                 (, ,)
#                                 (ADVP (RB 0.85)
#                                   (PP (TO to)
#                                     (NP (CD 1.3)))))))
#                           (-RRB- -RRB-))))))))))))
#     (. .)))
#
# compound(inhibitors-2, ACE-1)
# nsubjpass(associated-4, inhibitors-2)
# auxpass(associated-4, were-3)
# root(ROOT-0, associated-4)
# case(hazard-10, with-5)
# det(hazard-10, a-6)
# advmod(hazard-10, slightly-7)
# amod(hazard-10, increased-8)
# compound(hazard-10, recurrence-9)
# nmod:with(associated-4, hazard-10)
# mark(associated-16, whereas-12)
# nsubjpass(associated-16, ARBs-13)
# auxpass(associated-16, were-14)
# neg(associated-16, not-15)
# dep(hazard-10, associated-16)
# case(recurrence-18, with-17)
# nmod:with(associated-16, recurrence-18)
# dep(recurrence-18, adjusted-20)
# compound(HR-23, ACE-21)
# compound(HR-23, inhibitor-22)
# dobj(adjusted-20, HR-23)
# dep(1.2-25, =-24)
# acl:relcl(HR-23, 1.2-25)
# nummod(%-28, 95-27)
# appos(HR-23, %-28)
# appos(%-28, CI-29)
# compound(1.4-33, 0.97-31)
# dep(1.4-33, to-32)
# appos(HR-23, 1.4-33)
# amod(HR-37, adjusted-35)
# compound(HR-37, ARBs-36)
# dep(1.4-33, HR-37)
# dep(1.1-39, =-38)
# acl:relcl(HR-37, 1.1-39)
# nummod(%-42, 95-41)
# appos(HR-23, %-42)
# appos(%-42, CI-43)
# advmod(%-42, 0.85-45)
# case(1.3-47, to-46)
# nmod:to(0.85-45, 1.3-47)
#
# Parsed file: ACEsentences_sample2.txt [10 sentences].
# Parsed 300 words in 10 sentences (58.20 wds/sec; 1.94 sents/sec).

# %% [markdown]
# ### Testing with RNN parser

# %% [markdown]
# Make sure to create a new script for RNN model from making a copy of the `lexparser.sh` and update both memory (increase needed) and model (the ser.gz filename)

# %%
# !chmod a+x lexparserRNN.sh
! ./lexparserRNN.sh ACEsentences_sample2.txt
# Out:
# [main] INFO edu.stanford.nlp.parser.lexparser.LexicalizedParser - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishRNN.ser.gz ... done [1.9 sec].
# Parsing file: ACEsentences_sample2.txt
# Parsing [sent. 1 len. 14]: Increase in all-cause mortality was associated with higher age and ACE inhibitors prescription .
# (ROOT
#   (S
#     (NP
#       (NP (JJ Increase))
#       (PP (IN in)
#         (NP (JJ all-cause) (NN mortality))))
#     (VP (VBD was)
#       (VP (VBN associated)
#         (PP (IN with)
#           (NP
#             (NP (JJR higher) (NN age))
#             (CC and)
#             (NP (NNP ACE) (NN inhibitors) (NN prescription))))))
#     (. .)))
#
# nsubjpass(associated-6, Increase-1)
# case(mortality-4, in-2)
# amod(mortality-4, all-cause-3)
# nmod:in(Increase-1, mortality-4)
# auxpass(associated-6, was-5)
# root(ROOT-0, associated-6)
# case(age-9, with-7)
# amod(age-9, higher-8)
# nmod:with(associated-6, age-9)
# cc(age-9, and-10)
# compound(prescription-13, ACE-11)
# compound(prescription-13, inhibitors-12)
# nmod:with(associated-6, prescription-13)
# conj:and(age-9, prescription-13)
#
# Parsing [sent. 2 len. 30]: Higher risk of cardiovascular mortality was associated with increasing age , prescriptions for ACE inhibitor , and diagnosis of myocardial infarction or angina as compared with the other diagnoses .
# (ROOT
#   (S
#     (NP
#       (NP (JJR Higher) (NN risk))
#       (PP (IN of)
#         (NP (JJ cardiovascular) (NN mortality))))
#     (VP (VBD was)
#       (VP (VBN associated)
#         (PP (IN with)
#           (NP (VBG increasing) (NN age)))
#         (, ,)
#         (PP
#           (ADVP
#             (NP
#               (NP (NNS prescriptions))
#               (PP (IN for)
#                 (NP (NNP ACE) (NN inhibitor)))
#               (, ,)
#               (CC and)
#               (NP
#                 (NP (NN diagnosis))
#                 (PP (IN of)
#                   (NP (JJ myocardial) (NN infarction)
#                     (CC or)
#                     (NN angina)))))
#             (RB as))
#           (VBN compared)
#           (PP (IN with)
#             (NP (DT the) (JJ other) (NNS diagnoses))))))
#     (. .)))
#
# amod(risk-2, Higher-1)
# nsubjpass(associated-7, risk-2)
# case(mortality-5, of-3)
# amod(mortality-5, cardiovascular-4)
# nmod:of(risk-2, mortality-5)
# auxpass(associated-7, was-6)
# root(ROOT-0, associated-7)
# case(age-10, with-8)
# amod(age-10, increasing-9)
# nmod:with(associated-7, age-10)
# nmod:npmod(as-24, prescriptions-12)
# case(inhibitor-15, for-13)
# compound(inhibitor-15, ACE-14)
# nmod:for(prescriptions-12, inhibitor-15)
# cc(prescriptions-12, and-17)
# conj:and(prescriptions-12, diagnosis-18)
# nmod:npmod(as-24, diagnosis-18)
# case(infarction-21, of-19)
# amod(infarction-21, myocardial-20)
# nmod:of(diagnosis-18, infarction-21)
# cc(infarction-21, or-22)
# nmod:of(diagnosis-18, angina-23)
# conj:or(infarction-21, angina-23)
# advcl(associated-7, as-24)
# case(as-24, compared-25)
# case(diagnoses-29, with-26)
# det(diagnoses-29, the-27)
# amod(diagnoses-29, other-28)
# dep(as-24, diagnoses-29)
#
# Parsing [sent. 3 len. 35]: The clinical benefits of angiotensin-converting enzyme -LRB- ACE -RRB- inhibitors and angiotensin II receptor blockers -LRB- ARB -RRB- are well established in chronic kidney disease -LRB- CKD -RRB- patients with diabetic and non-diabetic nephropathies .
# (ROOT
#   (S
#     (NP
#       (NP (DT The) (JJ clinical) (NNS benefits))
#       (PP (IN of)
#         (NP
#           (NP (JJ angiotensin-converting) (NN enzyme)
#             (PRN (-LRB- -LRB-)
#               (NP (NNP ACE))
#               (-RRB- -RRB-))
#             (NNS inhibitors))
#           (CC and)
#           (NP (JJ angiotensin) (NNP II) (NN receptor) (NNS blockers))
#           (PRN (-LRB- -LRB-)
#             (NP (NNP ARB))
#             (-RRB- -RRB-)))))
#     (VP (VBP are)
#       (ADVP (RB well))
#       (VP (VBN established)
#         (PP (IN in)
#           (NP
#             (NP (JJ chronic) (NN kidney) (NN disease)
#               (PRN (-LRB- -LRB-)
#                 (NP (NNP CKD))
#                 (-RRB- -RRB-))
#               (NNS patients))
#             (PP (IN with)
#               (NP
#                 (ADJP (JJ diabetic)
#                   (CC and)
#                   (JJ non-diabetic))
#                 (NNS nephropathies)))))))
#     (. .)))
#
# det(benefits-3, The-1)
# amod(benefits-3, clinical-2)
# nsubjpass(established-21, benefits-3)
# case(inhibitors-10, of-4)
# amod(inhibitors-10, angiotensin-converting-5)
# compound(inhibitors-10, enzyme-6)
# appos(inhibitors-10, ACE-8)
# nmod:of(benefits-3, inhibitors-10)
# cc(inhibitors-10, and-11)
# amod(blockers-15, angiotensin-12)
# compound(blockers-15, II-13)
# compound(blockers-15, receptor-14)
# nmod:of(benefits-3, blockers-15)
# conj:and(inhibitors-10, blockers-15)
# appos(inhibitors-10, ARB-17)
# auxpass(established-21, are-19)
# advmod(established-21, well-20)
# root(ROOT-0, established-21)
# case(patients-29, in-22)
# amod(patients-29, chronic-23)
# compound(patients-29, kidney-24)
# compound(patients-29, disease-25)
# appos(patients-29, CKD-27)
# nmod:in(established-21, patients-29)
# case(nephropathies-34, with-30)
# amod(nephropathies-34, diabetic-31)
# cc(diabetic-31, and-32)
# conj:and(diabetic-31, non-diabetic-33)
# amod(nephropathies-34, non-diabetic-33)
# nmod:with(patients-29, nephropathies-34)
#
# Parsing [sent. 4 len. 25]: Angiotensin II receptor blockers -LRB- ARBs -RRB- , angiotensin-converting enzyme inhibitors -LRB- ACEIs -RRB- are some of the most commonly prescribed medications for hypertension .
# (ROOT
#   (S
#     (NP
#       (NP
#         (NP (NNP Angiotensin) (NNP II) (NN receptor) (NNS blockers))
#         (PRN (-LRB- -LRB-)
#           (NP (NNP ARBs))
#           (-RRB- -RRB-)))
#       (, ,)
#       (NP (JJ angiotensin-converting) (NN enzyme) (NNS inhibitors))
#       (PRN (-LRB- -LRB-)
#         (NP (NNP ACEIs))
#         (-RRB- -RRB-)))
#     (VP (VBP are)
#       (NP
#         (NP (DT some))
#         (PP (IN of)
#           (NP
#             (NP (DT the)
#               (ADJP (RBS most) (RB commonly) (JJ prescribed))
#               (NNS medications))
#             (PP (IN for)
#               (NP (NN hypertension)))))))
#     (. .)))
#
# compound(blockers-4, Angiotensin-1)
# compound(blockers-4, II-2)
# compound(blockers-4, receptor-3)
# nsubj(some-16, blockers-4)
# appos(blockers-4, ARBs-6)
# amod(inhibitors-11, angiotensin-converting-9)
# compound(inhibitors-11, enzyme-10)
# appos(blockers-4, inhibitors-11)
# appos(blockers-4, ACEIs-13)
# cop(some-16, are-15)
# root(ROOT-0, some-16)
# case(medications-22, of-17)
# det(medications-22, the-18)
# advmod(prescribed-21, most-19)
# advmod(prescribed-21, commonly-20)
# amod(medications-22, prescribed-21)
# nmod:of(some-16, medications-22)
# case(hypertension-24, for-23)
# nmod:for(medications-22, hypertension-24)
#
# Parsing [sent. 5 len. 48]: Given that the single agents can achieve only partial and not durable suppression of the renin-angiotensin system -LRB- RAS -RRB- , it has been hypothesized that dual blockage with ACE inhibitors and ARBs would be most beneficial in the management of progressive CKD than either agent alone .
# (ROOT
#   (S
#     (PP (VBN Given)
#       (SBAR (IN that)
#         (S
#           (NP (DT the) (JJ single) (NNS agents))
#           (VP (MD can)
#             (VP (VB achieve)
#               (NP
#                 (NP
#                   (ADJP
#                     (ADJP (RB only) (JJ partial))
#                     (CC and)
#                     (ADJP (RB not) (JJ durable)))
#                   (NN suppression))
#                 (PP (IN of)
#                   (NP
#                     (NP (DT the) (JJ renin-angiotensin) (NN system))
#                     (PRN (-LRB- -LRB-)
#                       (NP (NNP RAS))
#                       (-RRB- -RRB-))))))))))
#     (, ,)
#     (NP (PRP it))
#     (VP (VBZ has)
#       (VP (VBN been)
#         (VP (VBN hypothesized)
#           (SBAR (IN that)
#             (S
#               (NP
#                 (NP (JJ dual) (NN blockage))
#                 (PP (IN with)
#                   (NP (NNP ACE) (NNS inhibitors)
#                     (CC and)
#                     (NNS ARBs))))
#               (VP (MD would)
#                 (VP (VB be)
#                   (ADJP (RBS most) (JJ beneficial)
#                     (PP (IN in)
#                       (NP
#                         (NP (DT the) (NN management))
#                         (PP (IN of)
#                           (NP (JJ progressive) (NNP CKD)))))
#                     (PP (IN than)
#                       (NP
#                         (NP (DT either) (NN agent))
#                         (ADVP (RB alone))))))))))))
#     (. .)))
#
# mark(achieve-7, Given-1)
# mark(achieve-7, that-2)
# det(agents-5, the-3)
# amod(agents-5, single-4)
# nsubj(achieve-7, agents-5)
# aux(achieve-7, can-6)
# advcl(hypothesized-25, achieve-7)
# advmod(partial-9, only-8)
# amod(suppression-13, partial-9)
# cc(partial-9, and-10)
# neg(durable-12, not-11)
# conj:and(partial-9, durable-12)
# amod(suppression-13, durable-12)
# dobj(achieve-7, suppression-13)
# case(system-17, of-14)
# det(system-17, the-15)
# amod(system-17, renin-angiotensin-16)
# nmod:of(suppression-13, system-17)
# appos(system-17, RAS-19)
# nsubjpass(hypothesized-25, it-22)
# aux(hypothesized-25, has-23)
# auxpass(hypothesized-25, been-24)
# root(ROOT-0, hypothesized-25)
# mark(beneficial-37, that-26)
# amod(blockage-28, dual-27)
# nsubj(beneficial-37, blockage-28)
# case(inhibitors-31, with-29)
# compound(inhibitors-31, ACE-30)
# nmod:with(blockage-28, inhibitors-31)
# cc(inhibitors-31, and-32)
# nmod:with(blockage-28, ARBs-33)
# conj:and(inhibitors-31, ARBs-33)
# aux(beneficial-37, would-34)
# cop(beneficial-37, be-35)
# advmod(beneficial-37, most-36)
# ccomp(hypothesized-25, beneficial-37)
# case(management-40, in-38)
# det(management-40, the-39)
# nmod:in(beneficial-37, management-40)
# case(CKD-43, of-41)
# amod(CKD-43, progressive-42)
# nmod:of(management-40, CKD-43)
# case(agent-46, than-44)
# det(agent-46, either-45)
# nmod:than(beneficial-37, agent-46)
# advmod(agent-46, alone-47)
#
# Parsing [sent. 6 len. 25]: To examine the association between angiotensin-converting enzyme -LRB- ACE -RRB- inhibitor use and clinical outcome after primary vascular reconstruction in a population-based follow-up study .
# (ROOT
#   (S
#     (VP (TO To)
#       (VP (VB examine)
#         (NP (DT the) (NN association))
#         (PP (IN between)
#           (S
#             (VP (VBG angiotensin-converting)
#               (NP
#                 (NP (JJ enzyme)
#                   (PRN (-LRB- -LRB-)
#                     (NP (NNP ACE))
#                     (-RRB- -RRB-))
#                   (NN inhibitor) (NN use))
#                 (CC and)
#                 (NP (JJ clinical) (NN outcome)))
#               (PP (IN after)
#                 (NP
#                   (NP (JJ primary) (NN vascular) (NN reconstruction))
#                   (PP (IN in)
#                     (NP (DT a) (JJ population-based) (NN follow-up) (NN study))))))))))
#     (. .)))
#
# mark(examine-2, To-1)
# root(ROOT-0, examine-2)
# det(association-4, the-3)
# dobj(examine-2, association-4)
# mark(angiotensin-converting-6, between-5)
# advcl(examine-2, angiotensin-converting-6)
# amod(use-12, enzyme-7)
# appos(use-12, ACE-9)
# compound(use-12, inhibitor-11)
# dobj(angiotensin-converting-6, use-12)
# cc(use-12, and-13)
# amod(outcome-15, clinical-14)
# dobj(angiotensin-converting-6, outcome-15)
# conj:and(use-12, outcome-15)
# case(reconstruction-19, after-16)
# amod(reconstruction-19, primary-17)
# compound(reconstruction-19, vascular-18)
# nmod:after(angiotensin-converting-6, reconstruction-19)
# case(study-24, in-20)
# det(study-24, a-21)
# amod(study-24, population-based-22)
# compound(study-24, follow-up-23)
# nmod:in(reconstruction-19, study-24)
#
# Parsing [sent. 7 len. 32]: These results suggest that potentiation of bradykinin-induced skin reaction by cilazapril is due to a tissular -LRB- and not systemic -RRB- inhibition of ACE and does not occur with Ro 42-5892 .
# (ROOT
#   (S
#     (NP (DT These) (NNS results))
#     (VP (VBP suggest)
#       (SBAR (IN that)
#         (S
#           (NP
#             (NP (NN potentiation))
#             (PP (IN of)
#               (NP
#                 (NP (JJ bradykinin-induced) (NN skin) (NN reaction))
#                 (PP (IN by)
#                   (NP (NN cilazapril))))))
#           (VP
#             (VP (VBZ is)
#               (ADJP (JJ due)
#                 (PP (TO to)
#                   (NP
#                     (NP (DT a)
#                       (ADJP
#                         (ADJP (JJ tissular))
#                         (PRN (-LRB- -LRB-)
#                           (CC and)
#                           (FRAG (RB not) (JJ systemic))
#                           (-RRB- -RRB-)))
#                       (NN inhibition))
#                     (PP (IN of)
#                       (NP (NNP ACE)))))))
#             (CC and)
#             (VP (VBZ does) (RB not)
#               (VP (VB occur)
#                 (PP (IN with)
#                   (NP (NNP Ro) (CD 42-5892)))))))))
#     (. .)))
#
# det(results-2, These-1)
# nsubj(suggest-3, results-2)
# root(ROOT-0, suggest-3)
# mark(due-13, that-4)
# nsubj(due-13, potentiation-5)
# nsubj(occur-28, potentiation-5)
# case(reaction-9, of-6)
# amod(reaction-9, bradykinin-induced-7)
# compound(reaction-9, skin-8)
# nmod:of(potentiation-5, reaction-9)
# case(cilazapril-11, by-10)
# nmod:by(reaction-9, cilazapril-11)
# cop(due-13, is-12)
# ccomp(suggest-3, due-13)
# case(inhibition-22, to-14)
# det(inhibition-22, a-15)
# amod(inhibition-22, tissular-16)
# dep(tissular-16, and-18)
# dep(and-18, not-19)
# dep(not-19, systemic-20)
# nmod:to(due-13, inhibition-22)
# case(ACE-24, of-23)
# nmod:of(inhibition-22, ACE-24)
# cc(due-13, and-25)
# aux(occur-28, does-26)
# neg(occur-28, not-27)
# ccomp(suggest-3, occur-28)
# conj:and(due-13, occur-28)
# case(Ro-30, with-29)
# nmod:with(occur-28, Ro-30)
# nummod(Ro-30, 42-5892-31)
#
# Parsing [sent. 8 len. 22]: We contacted patients General Practitioners for current patient data including MACE , which was supplemented by using the hospital patient records .
# (ROOT
#   (S
#     (NP (PRP We))
#     (VP (VBD contacted)
#       (NP
#         (NP (NNS patients))
#         (NP (NNP General) (NNP Practitioners)))
#       (PP (IN for)
#         (NP
#           (NP (JJ current) (NN patient) (NNS data))
#           (PP (VBG including)
#             (NP
#               (NP (NNP MACE))
#               (, ,)
#               (SBAR
#                 (WHNP (WDT which))
#                 (S
#                   (VP (VBD was)
#                     (VP (VBN supplemented)
#                       (PP (IN by)
#                         (S
#                           (VP (VBG using)
#                             (NP (DT the) (NN hospital) (NN patient) (NNS records))))))))))))))
#     (. .)))
#
# nsubj(contacted-2, We-1)
# root(ROOT-0, contacted-2)
# dobj(contacted-2, patients-3)
# compound(Practitioners-5, General-4)
# dep(patients-3, Practitioners-5)
# case(data-9, for-6)
# amod(data-9, current-7)
# compound(data-9, patient-8)
# nmod:for(contacted-2, data-9)
# case(MACE-11, including-10)
# nmod:including(data-9, MACE-11)
# nsubjpass(supplemented-15, MACE-11)
# ref(MACE-11, which-13)
# auxpass(supplemented-15, was-14)
# acl:relcl(MACE-11, supplemented-15)
# mark(using-17, by-16)
# advcl(supplemented-15, using-17)
# det(records-21, the-18)
# compound(records-21, hospital-19)
# compound(records-21, patient-20)
# dobj(using-17, records-21)
#
# Parsing [sent. 9 len. 20]: ACEIs , specifically benazepril hydrochloride -LRB- BH -RRB- , will delay the onset of overt DCM in Doberman Pinschers .
# (ROOT
#   (S
#     (NP
#       (NP (NNS ACEIs))
#       (, ,)
#       (ADVP (RB specifically))
#       (NP
#         (NP (NN benazepril) (NN hydrochloride))
#         (PRN (-LRB- -LRB-)
#           (NP (NNP BH))
#           (-RRB- -RRB-)))
#       (, ,))
#     (VP (MD will)
#       (VP (VB delay)
#         (NP
#           (NP (DT the) (NN onset))
#           (PP (IN of)
#             (NP (JJ overt) (NNP DCM))))
#         (PP (IN in)
#           (NP (NNP Doberman) (NNP Pinschers)))))
#     (. .)))
#
# nsubj(delay-11, ACEIs-1)
# advmod(hydrochloride-5, specifically-3)
# compound(hydrochloride-5, benazepril-4)
# appos(ACEIs-1, hydrochloride-5)
# appos(hydrochloride-5, BH-7)
# aux(delay-11, will-10)
# root(ROOT-0, delay-11)
# det(onset-13, the-12)
# dobj(delay-11, onset-13)
# case(DCM-16, of-14)
# amod(DCM-16, overt-15)
# nmod:of(onset-13, DCM-16)
# case(Pinschers-19, in-17)
# compound(Pinschers-19, Doberman-18)
# nmod:in(delay-11, Pinschers-19)
#
# Parsing [sent. 10 len. 49]: ACE inhibitors were associated with a slightly increased recurrence hazard , whereas ARBs were not associated with recurrence -LRB- adjusted ACE inhibitor HR = 1.2 , 95 % CI , 0.97 to 1.4 ; adjusted ARBs HR = 1.1 , 95 % CI , 0.85 to 1.3 -RRB- .
# (ROOT
#   (S
#     (NP (NNP ACE) (NNS inhibitors))
#     (VP (VBD were)
#       (VP (VBN associated)
#         (PP (IN with)
#           (NP
#             (NP (DT a) (RB slightly) (VBN increased) (NN recurrence) (NN hazard))
#             (, ,)
#             (SBAR (IN whereas)
#               (S
#                 (NP (NNP ARBs))
#                 (VP (VBD were) (RB not)
#                   (VP (VBN associated)
#                     (PP (IN with)
#                       (NP
#                         (NP (NN recurrence))
#                         (PRN (-LRB- -LRB-)
#                           (NP
#                             (NP (JJ adjusted) (NN ACE) (NN inhibitor))
#                             (SBAR
#                               (S
#                                 (NP (NNP HR))
#                                 (VP (SYM =)
#                                   (NP (CD 1.2))))))
#                           (, ,)
#                           (NP
#                             (NP (CD 95) (NN %))
#                             (SBAR
#                               (S
#                                 (NP
#                                   (NP (NNP CI))
#                                   (, ,)
#                                   (NP
#                                     (QP (CD 0.97) (TO to) (CD 1.4)))
#                                   (: ;))
#                                 (VP (VBD adjusted)
#                                   (S
#                                     (NP (NNP ARBs) (NNP HR))
#                                     (VP (SYM =)
#                                       (NP (CD 1.1))))))))
#                           (, ,)
#                           (NP
#                             (NP
#                               (ADJP (CD 95) (NN %))
#                               (NNP CI))
#                             (, ,)
#                             (NP (CD 0.85) (TO to) (CD 1.3)))
#                           (-RRB- -RRB-))))))))))))
#     (. .)))
#
# compound(inhibitors-2, ACE-1)
# nsubjpass(associated-4, inhibitors-2)
# auxpass(associated-4, were-3)
# root(ROOT-0, associated-4)
# case(hazard-10, with-5)
# det(hazard-10, a-6)
# advmod(hazard-10, slightly-7)
# amod(hazard-10, increased-8)
# compound(hazard-10, recurrence-9)
# nmod:with(associated-4, hazard-10)
# mark(associated-16, whereas-12)
# nsubjpass(associated-16, ARBs-13)
# auxpass(associated-16, were-14)
# neg(associated-16, not-15)
# dep(hazard-10, associated-16)
# case(recurrence-18, with-17)
# nmod:with(associated-16, recurrence-18)
# amod(inhibitor-22, adjusted-20)
# compound(inhibitor-22, ACE-21)
# dep(recurrence-18, inhibitor-22)
# nsubj(1.2-25, HR-23)
# dep(1.2-25, =-24)
# acl:relcl(inhibitor-22, 1.2-25)
# nummod(%-28, 95-27)
# dep(inhibitor-22, %-28)
# nsubj(adjusted-35, CI-29)
# compound(1.4-33, 0.97-31)
# dep(1.4-33, to-32)
# appos(CI-29, 1.4-33)
# acl:relcl(%-28, adjusted-35)
# compound(HR-37, ARBs-36)
# nsubj(1.1-39, HR-37)
# dep(1.1-39, =-38)
# ccomp(adjusted-35, 1.1-39)
# compound(%-42, 95-41)
# amod(CI-43, %-42)
# dep(inhibitor-22, CI-43)
# nummod(1.3-47, 0.85-45)
# dep(1.3-47, to-46)
# appos(CI-43, 1.3-47)
#
# Parsed file: ACEsentences_sample2.txt [10 sentences].
# Parsed 300 words in 10 sentences (34.53 wds/sec; 1.15 sents/sec).

# %%
# !java -version
# Out:
# java version "1.8.0_131"
# Java(TM) SE Runtime Environment (build 1.8.0_131-b11)
# Java HotSpot(TM) 64-Bit Server VM (build 25.131-b11, mixed mode)

# %% [markdown]
# ## Step 2d) Run Stanford parser models with entire set

# %%
dict_to_file("ACEsentences_full.txt", data_dict_ACE)

# %%
! ./lexparserRNN.sh ACEsentences.txt
