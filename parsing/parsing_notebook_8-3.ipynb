# %% [markdown]
# ## Instructions
#
# We first downloaded the files from this link <http://nlp.stanford.edu/software/stanford-corenlp-full-2017-06-09.zip>
#
# Then we dragged the pubmed folder into that same folder, with the copied abstracts (if you don't want to re-download them all again).
#
# There are a few files you will need to make sure are present:
#
# `lexparser-gui.bat
# lexparser-gui.command
# lexparser-gui.sh
# lexparser-lang-train-test.sh
# lexparser-lang.sh
# lexparser.bat
# lexparser.sh                       `
#
# You will also need to add the `edu` folder that can be found here:
# <https://www.dropbox.com/s/t9uk4z1xznpo0jz/jars.zip?dl=0>
#
# Add the .zip extension to the `stanford-corenlp-3.8.0-models.jar` file, and unzip it. Copy that `edu` folder and paste it in to your home directory.

# %% [markdown]
# ## Here is a list of some of the files you should see in your home folder...

# %%
# !ls
# Out:
# CoreNLP-to-HTML.xsl                pbabstract311.json
# KeywordSentences.py                pbabstract312.json
# KeywordSentences.txt               pbabstract313.json
# KeywordSentences.txt.out           pbabstract314.json
# KeywordSentences.txt.xml           pbabstract315.json
# KeywordSentences2.py               pbabstract316.json
# KeywordSentences2.txt              pbabstract317.json
# KeywordSentences2.txt.out          pbabstract318.json
# KeywordSentences_output.txt        pbabstract319.json
# LIBRARY-LICENSES                   pbabstract32.json
# LICENSE.txt                        pbabstract320.json
# Makefile                           pbabstract321.json
# README.txt                         pbabstract322.json
# SemgrexDemo.java                   pbabstract323.json
# ShiftReduceDemo.java               pbabstract324.json
# StanfordCoreNlpDemo.java           pbabstract325.json
# StanfordDependenciesManual.pdf     pbabstract326.json
# baseline-sparkless.ipynb           pbabstract327.json
# baseline_v1.ipynb                  pbabstract328.json
# baseline_v2.ipynb                  pbabstract329.json
# build.xml                          pbabstract33.json
# compound_food_id.ipynb             pbabstract330.json
# corenlp.sh                         pbabstract331.json
# data                               pbabstract332.json
# driver.sh                          pbabstract333.json
# edu                                pbabstract334.json
# ejml-0.23-src.zip                  pbabstract335.json
# ejml-0.23.jar                      pbabstract336.json
# foodlist.txt                       pbabstract337.json
# foodlist2.txt                      pbabstract338.json
# input.txt                          pbabstract339.json
# input.txt.xml                      pbabstract34.json
# javax.json-api-1.0-sources.jar     pbabstract340.json
# javax.json.jar                     pbabstract341.json
# joda-time-2.9-sources.jar          pbabstract342.json
# joda-time.jar                      pbabstract343.json
# jollyday-0.4.9-sources.jar         pbabstract344.json
# jollyday.jar                       pbabstract345.json
# lexparser-gui.bat                  pbabstract346.json
# lexparser-gui.command              pbabstract347.json
# lexparser-gui.sh                   pbabstract348.json
# lexparser-lang-train-test.sh       pbabstract349.json
# lexparser-lang.sh                  pbabstract35.json
# lexparser.bat                      pbabstract350.json
# lexparser.sh                       pbabstract351.json
# lexparser2.sh                      pbabstract352.json
# lexparserRNN.sh                    pbabstract353.json
# lexparser_caseless.sh              pbabstract354.json
# lexparser_rnn.sh                   pbabstract355.json
# mapper.py                          pbabstract356.json
# more_abstracts.json                pbabstract357.json
# more_abstracts2.json               pbabstract358.json
# my_ten_abstracts.json              pbabstract359.json
# output_file.json                   pbabstract36.json
# parsing_notebook.ipynb             pbabstract360.json
# parsing_notebook_RNN.ipynb         pbabstract361.json
# patterns                           pbabstract362.json
# pbabstract1.json                   pbabstract363.json
# pbabstract10.json                  pbabstract364.json
# pbabstract100.json                 pbabstract365.json
# pbabstract101.json                 pbabstract366.json
# pbabstract102.json                 pbabstract367.json
# pbabstract103.json                 pbabstract368.json
# pbabstract104.json                 pbabstract369.json
# pbabstract105.json                 pbabstract37.json
# pbabstract106.json                 pbabstract370.json
# pbabstract107.json                 pbabstract371.json
# pbabstract108.json                 pbabstract372.json
# pbabstract109.json                 pbabstract373.json
# pbabstract11.json                  pbabstract374.json
# pbabstract110.json                 pbabstract375.json
# pbabstract111.json                 pbabstract376.json
# pbabstract112.json                 pbabstract377.json
# pbabstract113.json                 pbabstract378.json
# pbabstract114.json                 pbabstract379.json
# pbabstract115.json                 pbabstract38.json
# pbabstract116.json                 pbabstract380.json
# pbabstract117.json                 pbabstract381.json
# pbabstract118.json                 pbabstract382.json
# pbabstract119.json                 pbabstract383.json
# pbabstract12.json                  pbabstract384.json
# pbabstract120.json                 pbabstract385.json
# pbabstract121.json                 pbabstract386.json
# pbabstract122.json                 pbabstract387.json
# pbabstract123.json                 pbabstract388.json
# pbabstract124.json                 pbabstract389.json
# pbabstract125.json                 pbabstract39.json
# pbabstract126.json                 pbabstract390.json
# pbabstract127.json                 pbabstract391.json
# pbabstract128.json                 pbabstract392.json
# pbabstract129.json                 pbabstract393.json
# pbabstract13.json                  pbabstract394.json
# pbabstract130.json                 pbabstract395.json
# pbabstract131.json                 pbabstract396.json
# pbabstract132.json                 pbabstract397.json
# pbabstract133.json                 pbabstract398.json
# pbabstract134.json                 pbabstract399.json
# pbabstract135.json                 pbabstract4.json
# pbabstract136.json                 pbabstract40.json
# pbabstract137.json                 pbabstract400.json
# pbabstract138.json                 pbabstract401.json
# pbabstract139.json                 pbabstract402.json
# pbabstract14.json                  pbabstract403.json
# pbabstract140.json                 pbabstract404.json
# pbabstract141.json                 pbabstract405.json
# pbabstract142.json                 pbabstract406.json
# pbabstract143.json                 pbabstract407.json
# pbabstract144.json                 pbabstract408.json
# pbabstract145.json                 pbabstract409.json
# pbabstract146.json                 pbabstract41.json
# pbabstract147.json                 pbabstract410.json
# pbabstract148.json                 pbabstract411.json
# pbabstract149.json                 pbabstract412.json
# pbabstract15.json                  pbabstract413.json
# pbabstract150.json                 pbabstract414.json
# pbabstract151.json                 pbabstract415.json
# pbabstract152.json                 pbabstract416.json
# pbabstract153.json                 pbabstract417.json
# pbabstract154.json                 pbabstract418.json
# pbabstract155.json                 pbabstract419.json
# pbabstract156.json                 pbabstract42.json
# pbabstract157.json                 pbabstract420.json
# pbabstract158.json                 pbabstract421.json
# pbabstract159.json                 pbabstract422.json
# pbabstract16.json                  pbabstract423.json
# pbabstract160.json                 pbabstract424.json
# pbabstract161.json                 pbabstract425.json
# pbabstract162.json                 pbabstract426.json
# pbabstract163.json                 pbabstract427.json
# pbabstract164.json                 pbabstract428.json
# pbabstract165.json                 pbabstract429.json
# pbabstract166.json                 pbabstract43.json
# pbabstract167.json                 pbabstract430.json
# pbabstract168.json                 pbabstract431.json
# pbabstract169.json                 pbabstract432.json
# pbabstract17.json                  pbabstract433.json
# pbabstract170.json                 pbabstract434.json
# pbabstract171.json                 pbabstract435.json
# pbabstract172.json                 pbabstract436.json
# pbabstract173.json                 pbabstract437.json
# pbabstract174.json                 pbabstract438.json
# pbabstract175.json                 pbabstract439.json
# pbabstract176.json                 pbabstract44.json
# pbabstract177.json                 pbabstract440.json
# pbabstract178.json                 pbabstract441.json
# pbabstract179.json                 pbabstract442.json
# pbabstract18.json                  pbabstract443.json
# pbabstract180.json                 pbabstract444.json
# pbabstract181.json                 pbabstract445.json
# pbabstract182.json                 pbabstract446.json
# pbabstract183.json                 pbabstract447.json
# pbabstract184.json                 pbabstract448.json
# pbabstract185.json                 pbabstract449.json
# pbabstract186.json                 pbabstract45.json
# pbabstract187.json                 pbabstract450.json
# pbabstract188.json                 pbabstract451.json
# pbabstract189.json                 pbabstract452.json
# pbabstract19.json                  pbabstract453.json
# pbabstract190.json                 pbabstract454.json
# pbabstract191.json                 pbabstract455.json
# pbabstract192.json                 pbabstract456.json
# pbabstract193.json                 pbabstract457.json
# pbabstract194.json                 pbabstract458.json
# pbabstract195.json                 pbabstract459.json
# pbabstract196.json                 pbabstract46.json
# pbabstract197.json                 pbabstract460.json
# pbabstract198.json                 pbabstract461.json
# pbabstract199.json                 pbabstract462.json
# pbabstract2.json                   pbabstract463.json
# pbabstract20.json                  pbabstract464.json
# pbabstract200.json                 pbabstract465.json
# pbabstract201.json                 pbabstract466.json
# pbabstract202.json                 pbabstract467.json
# pbabstract203.json                 pbabstract468.json
# pbabstract204.json                 pbabstract469.json
# pbabstract205.json                 pbabstract47.json
# pbabstract206.json                 pbabstract470.json
# pbabstract207.json                 pbabstract471.json
# pbabstract208.json                 pbabstract472.json
# pbabstract209.json                 pbabstract473.json
# pbabstract21.json                  pbabstract474.json
# pbabstract210.json                 pbabstract475.json
# pbabstract211.json                 pbabstract476.json
# pbabstract212.json                 pbabstract477.json
# pbabstract213.json                 pbabstract478.json
# pbabstract214.json                 pbabstract479.json
# pbabstract215.json                 pbabstract48.json
# pbabstract216.json                 pbabstract480.json
# pbabstract217.json                 pbabstract481.json
# pbabstract218.json                 pbabstract482.json
# pbabstract219.json                 pbabstract483.json
# pbabstract22.json                  pbabstract484.json
# pbabstract220.json                 pbabstract485.json
# pbabstract221.json                 pbabstract486.json
# pbabstract222.json                 pbabstract487.json
# pbabstract223.json                 pbabstract488.json
# pbabstract224.json                 pbabstract489.json
# pbabstract225.json                 pbabstract49.json
# pbabstract226.json                 pbabstract490.json
# pbabstract227.json                 pbabstract491.json
# pbabstract228.json                 pbabstract492.json
# pbabstract229.json                 pbabstract493.json
# pbabstract23.json                  pbabstract494.json
# pbabstract230.json                 pbabstract495.json
# pbabstract231.json                 pbabstract496.json
# pbabstract232.json                 pbabstract497.json
# pbabstract233.json                 pbabstract498.json
# pbabstract234.json                 pbabstract499.json
# pbabstract235.json                 pbabstract5.json
# pbabstract236.json                 pbabstract50.json
# pbabstract237.json                 pbabstract500.json
# pbabstract238.json                 pbabstract501.json
# pbabstract239.json                 pbabstract502.json
# pbabstract24.json                  pbabstract503.json
# pbabstract240.json                 pbabstract504.json
# pbabstract241.json                 pbabstract505.json
# pbabstract242.json                 pbabstract51.json
# pbabstract243.json                 pbabstract52.json
# pbabstract244.json                 pbabstract53.json
# pbabstract245.json                 pbabstract54.json
# pbabstract246.json                 pbabstract55.json
# pbabstract247.json                 pbabstract56.json
# pbabstract248.json                 pbabstract57.json
# pbabstract249.json                 pbabstract58.json
# pbabstract25.json                  pbabstract59.json
# pbabstract250.json                 pbabstract6.json
# pbabstract251.json                 pbabstract60.json
# pbabstract252.json                 pbabstract61.json
# pbabstract253.json                 pbabstract62.json
# pbabstract254.json                 pbabstract63.json
# pbabstract255.json                 pbabstract64.json
# pbabstract256.json                 pbabstract65.json
# pbabstract257.json                 pbabstract66.json
# pbabstract258.json                 pbabstract67.json
# pbabstract259.json                 pbabstract68.json
# pbabstract26.json                  pbabstract69.json
# pbabstract260.json                 pbabstract7.json
# pbabstract261.json                 pbabstract70.json
# pbabstract262.json                 pbabstract71.json
# pbabstract263.json                 pbabstract72.json
# pbabstract264.json                 pbabstract73.json
# pbabstract265.json                 pbabstract74.json
# pbabstract266.json                 pbabstract75.json
# pbabstract267.json                 pbabstract76.json
# pbabstract268.json                 pbabstract77.json
# pbabstract269.json                 pbabstract78.json
# pbabstract27.json                  pbabstract79.json
# pbabstract270.json                 pbabstract8.json
# pbabstract271.json                 pbabstract80.json
# pbabstract272.json                 pbabstract81.json
# pbabstract273.json                 pbabstract82.json
# pbabstract274.json                 pbabstract83.json
# pbabstract275.json                 pbabstract84.json
# pbabstract276.json                 pbabstract85.json
# pbabstract277.json                 pbabstract86.json
# pbabstract278.json                 pbabstract87.json
# pbabstract279.json                 pbabstract88.json
# pbabstract28.json                  pbabstract89.json
# pbabstract280.json                 pbabstract9.json
# pbabstract281.json                 pbabstract90.json
# pbabstract282.json                 pbabstract91.json
# pbabstract283.json                 pbabstract92.json
# pbabstract284.json                 pbabstract93.json
# pbabstract285.json                 pbabstract94.json
# pbabstract286.json                 pbabstract95.json
# pbabstract287.json                 pbabstract96.json
# pbabstract288.json                 pbabstract97.json
# pbabstract289.json                 pbabstract98.json
# pbabstract29.json                  pbabstract99.json
# pbabstract290.json                 pom.xml
# pbabstract291.json                 protobuf.jar
# pbabstract292.json                 pubmed
# pbabstract293.json                 sample_abstract.txt
# pbabstract294.json                 sample_abstract.txt.out
# pbabstract295.json                 sample_sentence.txt
# pbabstract296.json                 sample_sentence.txt.out
# pbabstract297.json                 sample_sentence_output.txt
# pbabstract298.json                 sample_viz.html
# pbabstract299.json                 sample_viz2.html
# pbabstract3.json                   slf4j-api.jar
# pbabstract30.json                  slf4j-simple.jar
# pbabstract300.json                 stanford-corenlp-3.8.0-javadoc.jar
# pbabstract301.json                 stanford-corenlp-3.8.0-models.jar
# pbabstract302.json                 stanford-corenlp-3.8.0-sources.jar
# pbabstract303.json                 stanford-corenlp-3.8.0.jar
# pbabstract304.json                 sutime
# pbabstract305.json                 test_file.txt
# pbabstract306.json                 text.txt
# pbabstract307.json                 tokensregex
# pbabstract308.json                 viz_data_file.json
# pbabstract309.json                 xom-1.2.10-src.jar
# pbabstract31.json                  xom.jar
# pbabstract310.json

# %% [markdown]
# # Parsing the Pubmed Abstracts

# %%
import pubmed.utils as pb
import json
import re
from collections import defaultdict
from pprint import pprint
import string
# utf-8 support
import codecs
# spit abstracts to sentences
from nltk.tokenize import sent_tokenize

# %%
#search_term = 'ACE inhibitor'
search_term = 'statin'
max_results = 100
query = pb.PubMedQuery(search_term, max_results)

# %%
ids = query.id_getter()
print "Num abstracts: ", len(ids)
# Out:
# Num abstracts:  899

# %% [markdown]
# ## This is to just download a few of the abstracts

# %%
# %%time
#I just tried to download a few 
# if you don't want to download all abstracts, please do not use the download_all_abstracts() method, but rather the 
# abstract_getter() as below
pb.PubMedQuery.COUNT = 0
max_results = 25
query = pb.PubMedQuery(search_term, max_results)
ids = query.id_getter()
abstracts = query.abstract_getter(ids)
# Out:
# CPU times: user 160 ms, sys: 0 ns, total: 160 ms
# Wall time: 2.12 s

# %% [markdown]
# ## This is to download a TON of the abstracts

# %%
# %%time
# pb.PubMedQuery.COUNT = 0
# max_results = 100
#full_query = pb.download_all_abstracts(search_term, max_results)
#ids = full_query.id_getter()
#abstracts = full_query.id_getter(ids)

# %% [markdown]
# ## Save abstracts to JSON file

# %%
json_file = 'my_ten_abstracts.json'
#json_file = 'more_abstracts.json'
print 'Saving to ' + json_file
with codecs.open(json_file, 'w','utf-8') as outfile:
    json.dump(abstracts, outfile, indent=4)
# Out:
# Saving to my_ten_abstracts.json

# %% [markdown]
# ## We might not need all the sentences in the abstract, so I am seeing what would happen if we just parse out the ones with key words, and write them to a textfile, and then parse the resulting file.
#
# Keyword selection could happen here in the sentence tokenizer.

# %%
sentences = []
with codecs.open('my_ten_abstracts.json','r','utf-8') as data_file:    
    data = json.load(data_file)
    for abstract in data.itervalues():
        sentences.append(sent_tokenize(abstract))
    # flatten the list of abstracts into one long list of sentences
    sentences = [sent for s in sentences for sent in s]
    print "Sentences: ",len(sentences)
# Out:
# Sentences:  234

# %%
keyword = 'ACEI'
key_sentences = []
transformed_sentences = pb.ace_substitutor(sentences, 'ACEI')
for sent in transformed_sentences:
    if keyword in sent:
        key_sentences.append(sent)

# %%
# %%writefile KeywordSentences.py
import json
import codecs
import pubmed.utils as pb

#change keyword to ACE
keyword = 'ACEI'
with codecs.open('my_ten_abstracts.json','r','utf-8') as data_file:    
    data = json.load(data_file)
    #pick snippets related to ACE inhibitors
    for abstract in data.itervalues():
        transformed_abstract = pb.ace_substitutor(abstract, 'ACEI') 
        if keyword in transformed_abstract:
            print transformed_abstract.encode('utf-8') + '\n'
# Out:
# Overwriting KeywordSentences.py

# %%
# !python2 KeywordSentences.py > KeywordSentences.txt

# %%
#This mimics the format that the example parser file has
# !head KeywordSentences.txt
# Out:
# renin-angiotensin-aldosterone system (raas) antagonists, including ACEI, angiotensin receptor blockers (arb), and mineralocorticoid receptor antagonists (mra) decrease mortality and morbidity in heart failure but increase the risk of hyperkalemia, especially when used in combination. prevention of hyperkalemia and its associated complications requires careful patient selection, counseling regarding dietary potassium intake, awareness of drug interactions, and regular laboratory surveillance. recent data suggests that the risk of hyperkalemia may be further moderated through the use of combined angiotensin-neprilysin inhibitors, novel mras, and novel potassium binding agents. clinicians should be mindful of the risk of hyperkalemia when prescribing raas inhibitors to patients with heart failure. in patients at highest risk, such as those with diabetes, the elderly, and advanced chronic kidney disease, more intensive laboratory surveillance of potassium and creatinine may be required. novel therapies hold promise for reducing the risk of hyperkalemia and enhancing the tolerability of raas antagonists.
#
# heart failure is a disease with a high prevalence and incidence. new therapeutic approaches are needed to prevent the onset of heart failure and to reduce the high morbidity and mortality associated with this disease. an optimized therapy of arterial hypertension in patients with risk factors and the use of the sglt2 inhibitor empagliflozin in type 2 diabetics are proven strategies to prevent heart failure. the therapeutic options in heart failure with preserved ejection fraction are still insufficient. in heart failure with reduced ejection fraction sacubitril/valsartan, the first approved angiotensin receptor-neprilysin inhibitor, is superior to an ACEI (ACEI) inhibitor. whether digitalis affects the prognosis in heart failure remains unclear; however, serum concentration should be targeted at the lower therapeutic range. iron supplementation in heart failure with reduced systolic function and iron deficiency improves symptoms and quality of life.
#
# participants (n=418) underwent one of the following 3 conditions: i) multicomponent exercise training 3times/week (mex; n=116); ii) ACEI used mono-dose daily (ACEI; n=70); iii) combined exercise and ACEI drugs (aceimex; n=232). the trial was completed by 82% of the participants (n=342): mex (n=90); ACEI (n=66); aceimex (n=186). baseline and 2-year follow-up evaluations included the senior fitness test battery, short form health survey 36 (sf-36), the health history questionnaires, anthropometric and hemodynamic profile.
#
# heart failure (hf) prevalence continues to rise and remains a significant burden to patients, caregivers, providers, and the healthcare system. guideline-directed medical therapy with standard neurohormonal blockade has been the cornerstone of medical management for many years. despite aggressive utilization of ACEI, angiotensin receptor blockers, beta-blockers, and aldosterone antagonists, hf hospitalizations and readmissions are common and residual mortality remains high. with the development of two novel medical therapies (sacubitril/valsartan and ivabradine), the american college of cardiology, american heart association, and heart failure society of america released a pharmacologic update to provide guidelines for incorporation of these agents into clinical practice. although effective via different mechanisms of action, both agents now have a prominent role in risk reduction. hf medical regimens often become quite complex, especially when associated with comorbid conditions, and require frequent follow-up. providers must be proficient in patient monitoring, medication dose titration, and therapy optimization. individualized patient care strategies such as guideline-directed therapy can promote long-term adherence and quality of life.
#
# we included a group with no dd (n=649), a group with grade 1 dd (n=2875), and those with grades 2 and 3 (n=1357) who had normal ejection fraction. the prevalence of grade 2 or 3 dd with preserved ejection fraction was 25%; 95% ci: 24-26. the absolute change of ACEI-inhibitor use before and after the echocardiogram increased by 14, 19, 23, 27 in patients without dd, those with grade 1, grade 2 or 3 asymptomatic and grade 2 or 3 symptomatic, respectively. the use of β-blocker, statin, and diuretic had similar trends.

# %%
# !chmod a+x lexparser.sh

# %% [markdown]
# # Testing with PCFG Model*
#
# *notice I made a change to the lexparser file to allow for more memory

# %%
# !cat ./lexparser.sh
# Out:
# #!/usr/bin/env bash
# #
# # Runs the English PCFG parser on one or more files, printing trees only
#
# if [ ! $# -ge 1 ]; then
#   echo Usage: `basename $0` 'file(s)'
#   echo
#   exit
# fi
#
# scriptdir=`dirname $0`
#
# java -mx500m -cp "$scriptdir/*:" edu.stanford.nlp.parser.lexparser.LexicalizedParser \
#  -outputFormat "penn,typedDependencies" edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz $*

# %%
# %%timeit
! ./lexparser.sh  KeywordSentences.txt
# Out:
# [main] INFO edu.stanford.nlp.parser.lexparser.LexicalizedParser - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ... done [0.6 sec].
# Parsing file: KeywordSentences.txt
# Parsing [sent. 1 len. 52]: RAAS , a major pharmacological target in cardiovascular medicine , is inhibited by pharmacological classes including angiotensin converting enzyme -LRB- ACE -RRB- inhibitors -LRB- ACEIs -RRB- , angiotensin-II type 1 blockers -LRB- ARBs -RRB- and aldosterone receptors antagonists , in addition to the recently introduced direct renin inhibitors -LRB- DRIs -RRB- .
# (ROOT
#   (S
#     (NP
#       (NP (NNS RAAS))
#       (, ,)
#       (NP
#         (NP (DT a) (JJ major) (JJ pharmacological) (NN target))
#         (PP (IN in)
#           (NP (JJ cardiovascular) (NN medicine))))
#       (, ,))
#     (VP (VBZ is)
#       (ADJP (JJ inhibited)
#         (PP (IN by)
#           (NP
#             (NP (JJ pharmacological) (NNS classes))
#             (PP (VBG including)
#               (NP
#                 (NP
#                   (NP (NN angiotensin))
#                   (S
#                     (VP (VBG converting)
#                       (NP (JJ enzyme)
#                         (PRN (-LRB- -LRB-)
#                           (NP (NNP ACE))
#                           (-RRB- -RRB-))
#                         (NNS inhibitors))))
#                   (PRN (-LRB- -LRB-)
#                     (NP (NNP ACEIs))
#                     (-RRB- -RRB-)))
#                 (, ,)
#                 (NP
#                   (ADJP (RB angiotensin-II) (NN type)
#                     (PRN
#                       (NP (CD 1))
#                       (PP
#                         (NP
#                           (NP (NNS blockers))
#                           (PRN (-LRB- -LRB-)
#                             (NP (NNP ARBs))
#                             (-RRB- -RRB-))
#                           (CC and)
#                           (NP (JJ aldosterone) (NNS receptors) (NNS antagonists))
#                           (, ,))
#                         (IN in)
#                         (NP (NN addition))))
#                     (PP (TO to)
#                       (NP (DT the)
#                         (ADJP (RB recently) (VBN introduced))
#                         (JJ direct) (NN renin))))
#                   (NNS inhibitors))))
#             (PRN (-LRB- -LRB-)
#               (NP (NNP DRIs))
#               (-RRB- -RRB-))))))
#     (. .)))
#
# nsubj(inhibited-12, RAAS-1)
# det(target-6, a-3)
# amod(target-6, major-4)
# amod(target-6, pharmacological-5)
# appos(RAAS-1, target-6)
# case(medicine-9, in-7)
# amod(medicine-9, cardiovascular-8)
# nmod:in(target-6, medicine-9)
# cop(inhibited-12, is-11)
# root(ROOT-0, inhibited-12)
# case(classes-15, by-13)
# amod(classes-15, pharmacological-14)
# nmod:by(inhibited-12, classes-15)
# case(angiotensin-17, including-16)
# nmod:including(classes-15, angiotensin-17)
# dep(angiotensin-17, converting-18)
# amod(inhibitors-23, enzyme-19)
# appos(inhibitors-23, ACE-21)
# dobj(converting-18, inhibitors-23)
# appos(angiotensin-17, ACEIs-25)
# advmod(type-29, angiotensin-II-28)
# amod(inhibitors-48, type-29)
# dep(type-29, 1-30)
# nmod:in(1-30, blockers-31)
# appos(blockers-31, ARBs-33)
# cc(blockers-31, and-35)
# amod(antagonists-38, aldosterone-36)
# compound(antagonists-38, receptors-37)
# nmod:in(1-30, antagonists-38)
# conj:and(blockers-31, antagonists-38)
# case(blockers-31, in-40)
# dep(blockers-31, addition-41)
# case(renin-47, to-42)
# det(renin-47, the-43)
# advmod(introduced-45, recently-44)
# amod(renin-47, introduced-45)
# amod(renin-47, direct-46)
# nmod:to(type-29, renin-47)
# appos(angiotensin-17, inhibitors-48)
# appos(classes-15, DRIs-50)
#
# Parsing [sent. 2 len. 36]: However , currently used RAAS inhibitors still can not achieve their desired effects and are associated with certain drawbacks , such as adverse side effects , incomplete blockage of the system and poor end-organ protection .
# (ROOT
#   (S
#     (ADVP (RB However))
#     (, ,)
#     (ADVP (RB currently))
#     (VP (VBD used)
#       (SBAR
#         (S
#           (NP (NNP RAAS) (NNS inhibitors))
#           (ADVP (RB still))
#           (VP
#             (VP (MD can) (RB not)
#               (VP (VB achieve)
#                 (NP (PRP$ their) (VBN desired) (NNS effects))))
#             (CC and)
#             (VP (VBP are)
#               (VP (VBN associated)
#                 (PP (IN with)
#                   (NP
#                     (NP (JJ certain) (NNS drawbacks))
#                     (, ,)
#                     (PP (JJ such) (IN as)
#                       (NP (JJ adverse) (NN side) (NNS effects)))
#                     (, ,)
#                     (ADJP (JJ incomplete) (JJ blockage))
#                     (PP (IN of)
#                       (NP
#                         (NP (DT the) (NN system))
#                         (CC and)
#                         (NP (JJ poor) (JJ end-organ) (NN protection))))))))))))
#     (. .)))
#
# advmod(used-4, However-1)
# advmod(used-4, currently-3)
# root(ROOT-0, used-4)
# compound(inhibitors-6, RAAS-5)
# nsubj(achieve-10, inhibitors-6)
# nsubjpass(associated-16, inhibitors-6)
# advmod(achieve-10, still-7)
# aux(achieve-10, can-8)
# neg(achieve-10, not-9)
# ccomp(used-4, achieve-10)
# nmod:poss(effects-13, their-11)
# amod(effects-13, desired-12)
# dobj(achieve-10, effects-13)
# cc(achieve-10, and-14)
# auxpass(associated-16, are-15)
# ccomp(used-4, associated-16)
# conj:and(achieve-10, associated-16)
# case(drawbacks-19, with-17)
# amod(drawbacks-19, certain-18)
# nmod:with(associated-16, drawbacks-19)
# case(effects-25, such-21)
# mwe(such-21, as-22)
# amod(effects-25, adverse-23)
# compound(effects-25, side-24)
# nmod:such_as(drawbacks-19, effects-25)
# amod(blockage-28, incomplete-27)
# amod(drawbacks-19, blockage-28)
# case(system-31, of-29)
# det(system-31, the-30)
# nmod:of(drawbacks-19, system-31)
# cc(system-31, and-32)
# amod(protection-35, poor-33)
# amod(protection-35, end-organ-34)
# nmod:of(drawbacks-19, protection-35)
# conj:and(system-31, protection-35)
#
# Parsing [sent. 3 len. 42]: In this review , we discuss the efficiency and specificity of the current RAAS inhibitors and propose some recommendations for achieving better treatments with better end-organ protection.Hypertension Research advance online publication , 6 July 2017 ; doi :10.1038 / hr .2017.65 .
# (ROOT
#   (S
#     (PP (IN In)
#       (NP (DT this) (NN review)))
#     (, ,)
#     (S
#       (NP (PRP we))
#       (VP
#         (VP (VB discuss)
#           (NP
#             (NP (DT the) (NN efficiency)
#               (CC and)
#               (NN specificity))
#             (PP (IN of)
#               (NP (DT the) (JJ current) (NNS RAAS) (NNS inhibitors)))))
#         (CC and)
#         (VP (VB propose)
#           (NP (DT some) (NNS recommendations))
#           (PP (IN for)
#             (S
#               (VP (VBG achieving)
#                 (NP (JJR better) (NNS treatments))
#                 (PP (IN with)
#                   (NP (JJR better) (JJ end-organ) (NN protection.Hypertension) (NNP Research) (NN advance) (JJ online) (NN publication) (, ,) (CD 6) (NNP July) (NNS 2017)))))))))
#     (: ;)
#     (FRAG
#       (X
#         (X (SYM doi))
#         (NP (CD :10.1038)))
#       (: /)
#       (NP (CD hr) (CD .2017.65)))
#     (. .)))
#
# case(review-3, In-1)
# det(review-3, this-2)
# nmod:in(discuss-6, review-3)
# nsubj(discuss-6, we-5)
# nsubj(propose-17, we-5)
# root(ROOT-0, discuss-6)
# det(efficiency-8, the-7)
# dobj(discuss-6, efficiency-8)
# cc(efficiency-8, and-9)
# dobj(discuss-6, specificity-10)
# conj:and(efficiency-8, specificity-10)
# case(inhibitors-15, of-11)
# det(inhibitors-15, the-12)
# amod(inhibitors-15, current-13)
# compound(inhibitors-15, RAAS-14)
# nmod:of(efficiency-8, inhibitors-15)
# cc(discuss-6, and-16)
# conj:and(discuss-6, propose-17)
# det(recommendations-19, some-18)
# dobj(propose-17, recommendations-19)
# mark(achieving-21, for-20)
# advcl(propose-17, achieving-21)
# amod(treatments-23, better-22)
# dobj(achieving-21, treatments-23)
# case(2017-35, with-24)
# amod(2017-35, better-25)
# amod(2017-35, end-organ-26)
# compound(2017-35, protection.Hypertension-27)
# compound(2017-35, Research-28)
# compound(2017-35, advance-29)
# amod(2017-35, online-30)
# compound(2017-35, publication-31)
# nummod(2017-35, 6-33)
# compound(2017-35, July-34)
# nmod:with(achieving-21, 2017-35)
# dep(:10.1038-38, doi-37)
# dep(.2017.65-41, :10.1038-38)
# nummod(.2017.65-41, hr-40)
# dep(discuss-6, .2017.65-41)
#
# Parsing [sent. 4 len. 51]: The beneficial effects of angiotensin converting enzyme -LRB- ACE -RRB- inhibitors and angiotensin II -LRB- AII -RRB- receptor antagonists in patients with heart failure secondary to reduced ejection fraction -LRB- HFrEF -RRB- are felt to result from prevention of the adverse effects of AII on systemic afterload and renal homeostasis .
# (ROOT
#   (S
#     (NP
#       (NP (DT The) (JJ beneficial) (NNS effects))
#       (PP (IN of)
#         (NP
#           (NP (NN angiotensin))
#           (VP (VBG converting)
#             (NP
#               (NP (JJ enzyme)
#                 (PRN (-LRB- -LRB-)
#                   (NP (NNP ACE))
#                   (-RRB- -RRB-))
#                 (NN inhibitors))
#               (CC and)
#               (NP
#                 (NP (NNP angiotensin) (NNP II))
#                 (PRN (-LRB- -LRB-)
#                   (NP (NNP AII))
#                   (-RRB- -RRB-)))
#               (NP
#                 (NP (NN receptor) (NNS antagonists))
#                 (PP (IN in)
#                   (NP (NNS patients)))))
#             (PP (IN with)
#               (NP
#                 (NP (NN heart) (NN failure))
#                 (ADJP (JJ secondary)
#                   (PP (TO to)
#                     (NP
#                       (NP (VBN reduced) (NN ejection) (NN fraction))
#                       (PRN (-LRB- -LRB-)
#                         (NP (NNP HFrEF))
#                         (-RRB- -RRB-)))))))))))
#     (VP (VBP are)
#       (VP (VBN felt)
#         (S
#           (VP (TO to)
#             (VP (VB result)
#               (PP (IN from)
#                 (NP
#                   (NP (NN prevention))
#                   (PP (IN of)
#                     (NP
#                       (NP (DT the) (JJ adverse) (NNS effects))
#                       (PP (IN of)
#                         (NP (NNP AII)))))))
#               (PP (IN on)
#                 (NP (JJ systemic) (JJ afterload)
#                   (CC and)
#                   (JJ renal) (NNS homeostasis))))))))
#     (. .)))
#
# det(effects-3, The-1)
# amod(effects-3, beneficial-2)
# nsubjpass(felt-34, effects-3)
# nsubj:xsubj(result-36, effects-3)
# case(angiotensin-5, of-4)
# nmod:of(effects-3, angiotensin-5)
# acl(angiotensin-5, converting-6)
# amod(inhibitors-11, enzyme-7)
# appos(inhibitors-11, ACE-9)
# dobj(converting-6, inhibitors-11)
# cc(inhibitors-11, and-12)
# compound(II-14, angiotensin-13)
# dobj(converting-6, II-14)
# conj:and(inhibitors-11, II-14)
# appos(II-14, AII-16)
# compound(antagonists-19, receptor-18)
# dep(inhibitors-11, antagonists-19)
# case(patients-21, in-20)
# nmod:in(antagonists-19, patients-21)
# case(failure-24, with-22)
# compound(failure-24, heart-23)
# nmod:with(converting-6, failure-24)
# amod(failure-24, secondary-25)
# case(fraction-29, to-26)
# amod(fraction-29, reduced-27)
# compound(fraction-29, ejection-28)
# nmod:to(secondary-25, fraction-29)
# appos(fraction-29, HFrEF-31)
# auxpass(felt-34, are-33)
# root(ROOT-0, felt-34)
# mark(result-36, to-35)
# xcomp(felt-34, result-36)
# case(prevention-38, from-37)
# nmod:from(result-36, prevention-38)
# case(effects-42, of-39)
# det(effects-42, the-40)
# amod(effects-42, adverse-41)
# nmod:of(prevention-38, effects-42)
# case(AII-44, of-43)
# nmod:of(effects-42, AII-44)
# case(afterload-47, on-45)
# amod(afterload-47, systemic-46)
# nmod:on(result-36, afterload-47)
# cc(afterload-47, and-48)
# amod(homeostasis-50, renal-49)
# nmod:on(result-36, homeostasis-50)
# conj:and(afterload-47, homeostasis-50)
#
# Parsing [sent. 5 len. 31]: However , AII can activate the sympathetic nervous system and part of the beneficial effects of ACE inhibitors and AII antagonists may result from their ability to inhibit such activation .
# (ROOT
#   (S
#     (ADVP (RB However))
#     (, ,)
#     (S
#       (NP (NNP AII))
#       (VP (MD can)
#         (VP (VB activate)
#           (NP
#             (NP (DT the)
#               (ADJP (JJ sympathetic) (JJ nervous))
#               (NN system))
#             (CC and)
#             (NP
#               (NP (NN part))
#               (PP (IN of)
#                 (NP
#                   (NP (DT the) (JJ beneficial) (NNS effects))
#                   (PP (IN of)
#                     (NP (NNP ACE) (NNS inhibitors))))))))))
#     (CC and)
#     (S
#       (NP (NNP AII) (NNS antagonists))
#       (VP (MD may)
#         (VP (VB result)
#           (PP (IN from)
#             (NP (PRP$ their) (NN ability)
#               (S
#                 (VP (TO to)
#                   (VP (VB inhibit)
#                     (NP (JJ such) (NN activation))))))))))
#     (. .)))
#
# advmod(activate-5, However-1)
# nsubj(activate-5, AII-3)
# aux(activate-5, can-4)
# root(ROOT-0, activate-5)
# det(system-9, the-6)
# amod(nervous-8, sympathetic-7)
# amod(system-9, nervous-8)
# dobj(activate-5, system-9)
# cc(system-9, and-10)
# dobj(activate-5, part-11)
# conj:and(system-9, part-11)
# case(effects-15, of-12)
# det(effects-15, the-13)
# amod(effects-15, beneficial-14)
# nmod:of(part-11, effects-15)
# case(inhibitors-18, of-16)
# compound(inhibitors-18, ACE-17)
# nmod:of(effects-15, inhibitors-18)
# cc(activate-5, and-19)
# compound(antagonists-21, AII-20)
# nsubj(result-23, antagonists-21)
# aux(result-23, may-22)
# conj:and(activate-5, result-23)
# case(ability-26, from-24)
# nmod:poss(ability-26, their-25)
# nmod:from(result-23, ability-26)
# mark(inhibit-28, to-27)
# acl(ability-26, inhibit-28)
# amod(activation-30, such-29)
# dobj(inhibit-28, activation-30)
#
# Parsing [sent. 6 len. 49]: We examined the acute effects of the ACE inhibitor captopril -LRB- 25 mg , n = 9 -RRB- and the AII receptor antagonist losartan -LRB- 50 mg , n = 10 -RRB- on hemodynamics as well as total body and cardiac norepinephrine spillover in patients with chronic HFrEF .
# (ROOT
#   (S
#     (NP (PRP We))
#     (VP (VBD examined)
#       (NP
#         (NP (DT the) (JJ acute) (NNS effects))
#         (PP (IN of)
#           (NP
#             (NP (DT the) (NNP ACE) (NN inhibitor) (NN captopril))
#             (PRN (-LRB- -LRB-)
#               (NP
#                 (NP (CD 25) (NN mg))
#                 (, ,)
#                 (NP
#                   (NP (NN n))
#                   (SBAR
#                     (S
#                       (VP (SYM =)
#                         (NP (CD 9)))))))
#               (-RRB- -RRB-))
#             (CC and)
#             (NP (DT the) (NNP AII) (NN receptor) (NN antagonist) (NN losartan))
#             (PRN (-LRB- -LRB-)
#               (NP
#                 (NP (CD 50) (NN mg))
#                 (, ,)
#                 (NP
#                   (NP (NN n))
#                   (SBAR
#                     (S
#                       (VP (SYM =)
#                         (NP (CD 10)))))))
#               (-RRB- -RRB-)))))
#       (PP (IN on)
#         (NP
#           (NP (NNS hemodynamics))
#           (CONJP (RB as) (RB well) (IN as))
#           (NP (JJ total) (NN body)
#             (CC and)
#             (JJ cardiac) (NN norepinephrine) (NN spillover))))
#       (PP (IN in)
#         (NP
#           (NP (NNS patients))
#           (PP (IN with)
#             (NP (JJ chronic) (NNP HFrEF))))))
#     (. .)))
#
# nsubj(examined-2, We-1)
# root(ROOT-0, examined-2)
# det(effects-5, the-3)
# amod(effects-5, acute-4)
# dobj(examined-2, effects-5)
# case(captopril-10, of-6)
# det(captopril-10, the-7)
# compound(captopril-10, ACE-8)
# compound(captopril-10, inhibitor-9)
# nmod:of(effects-5, captopril-10)
# nummod(mg-13, 25-12)
# dep(captopril-10, mg-13)
# appos(mg-13, n-15)
# dep(9-17, =-16)
# acl:relcl(n-15, 9-17)
# cc(captopril-10, and-19)
# det(losartan-24, the-20)
# compound(losartan-24, AII-21)
# compound(losartan-24, receptor-22)
# compound(losartan-24, antagonist-23)
# nmod:of(effects-5, losartan-24)
# conj:and(captopril-10, losartan-24)
# nummod(mg-27, 50-26)
# dep(captopril-10, mg-27)
# appos(mg-27, n-29)
# dep(10-31, =-30)
# acl:relcl(n-29, 10-31)
# case(hemodynamics-34, on-33)
# nmod:on(examined-2, hemodynamics-34)
# cc(hemodynamics-34, as-35)
# mwe(as-35, well-36)
# mwe(as-35, as-37)
# amod(body-39, total-38)
# nmod:on(examined-2, body-39)
# conj:and(hemodynamics-34, body-39)
# cc(body-39, and-40)
# amod(spillover-43, cardiac-41)
# compound(spillover-43, norepinephrine-42)
# conj:and(hemodynamics-34, spillover-43)
# conj:and(body-39, spillover-43)
# case(patients-45, in-44)
# nmod:in(examined-2, patients-45)
# case(HFrEF-48, with-46)
# amod(HFrEF-48, chronic-47)
# nmod:with(patients-45, HFrEF-48)
#
# Parsing [sent. 7 len. 20]: Hemodynamic and neurochemical measurements were made at baseline and at 1 , 2 and 4 hours after oral dosing .
# (ROOT
#   (S
#     (NP (JJ Hemodynamic)
#       (CC and)
#       (JJ neurochemical) (NNS measurements))
#     (VP (VBD were)
#       (VP (VBN made)
#         (PP
#           (PP (IN at)
#             (NP (NN baseline)))
#           (CC and)
#           (PP (IN at)
#             (NP (CD 1) (, ,) (CD 2)
#               (CC and)
#               (CD 4)))
#           (NP (NNS hours)))
#         (PP (IN after)
#           (NP (JJ oral) (NN dosing)))))
#     (. .)))
#
# amod(measurements-4, Hemodynamic-1)
# cc(Hemodynamic-1, and-2)
# conj:and(Hemodynamic-1, neurochemical-3)
# amod(measurements-4, neurochemical-3)
# nsubjpass(made-6, measurements-4)
# auxpass(made-6, were-5)
# root(ROOT-0, made-6)
# case(baseline-8, at-7)
# nmod:at(hours-16, baseline-8)
# cc(hours-16, and-9)
# case(1-11, at-10)
# nmod(made-6, 1-11)
# conj:and(hours-16, 1-11)
# nummod(1-11, 2-13)
# cc(1-11, and-14)
# conj:and(1-11, 4-15)
# conj:and(hours-16, 4-15)
# nmod(made-6, hours-16)
# case(dosing-19, after-17)
# amod(dosing-19, oral-18)
# nmod:after(made-6, dosing-19)
#
# Parsing [sent. 8 len. 25]: Administration of both drugs caused significant reductions in systemic arterial , cardiac filling and pulmonary artery pressures -LRB- P < 0.05 vs baseline -RRB- .
# (ROOT
#   (S
#     (NP
#       (NP (NNP Administration))
#       (PP (IN of)
#         (NP (DT both) (NNS drugs))))
#     (VP (VBD caused)
#       (NP (JJ significant) (NNS reductions))
#       (PP (IN in)
#         (NP
#           (NP (JJ systemic) (NN arterial))
#           (, ,)
#           (NP (JJ cardiac) (NN filling))
#           (CC and)
#           (NP (JJ pulmonary) (NN artery) (NNS pressures))))
#       (PRN (-LRB- -LRB-)
#         (NP
#           (NP (NNP P) (NNP <))
#           (NP (CD 0.05) (NN vs) (NN baseline)))
#         (-RRB- -RRB-)))
#     (. .)))
#
# nsubj(caused-5, Administration-1)
# case(drugs-4, of-2)
# det(drugs-4, both-3)
# nmod:of(Administration-1, drugs-4)
# root(ROOT-0, caused-5)
# amod(reductions-7, significant-6)
# dobj(caused-5, reductions-7)
# case(arterial-10, in-8)
# amod(arterial-10, systemic-9)
# nmod:in(caused-5, arterial-10)
# amod(filling-13, cardiac-12)
# nmod:in(caused-5, filling-13)
# conj:and(arterial-10, filling-13)
# cc(arterial-10, and-14)
# amod(pressures-17, pulmonary-15)
# compound(pressures-17, artery-16)
# nmod:in(caused-5, pressures-17)
# conj:and(arterial-10, pressures-17)
# compound(<-20, P-19)
# dep(caused-5, <-20)
# nummod(baseline-23, 0.05-21)
# compound(baseline-23, vs-22)
# dep(<-20, baseline-23)
#
# Parsing [sent. 9 len. 13]: There was no significant difference in the magnitude of those hemodynamic effects .
# (ROOT
#   (S
#     (NP (EX There))
#     (VP (VBD was)
#       (NP
#         (NP (DT no) (JJ significant) (NN difference))
#         (PP (IN in)
#           (NP
#             (NP (DT the) (NN magnitude))
#             (PP (IN of)
#               (NP (DT those) (JJ hemodynamic) (NNS effects)))))))
#     (. .)))
#
# expl(was-2, There-1)
# root(ROOT-0, was-2)
# neg(difference-5, no-3)
# amod(difference-5, significant-4)
# nsubj(was-2, difference-5)
# case(magnitude-8, in-6)
# det(magnitude-8, the-7)
# nmod:in(difference-5, magnitude-8)
# case(effects-12, of-9)
# det(effects-12, those-10)
# amod(effects-12, hemodynamic-11)
# nmod:of(magnitude-8, effects-12)
#
# Parsing [sent. 10 len. 23]: Plasma concentrations of AII were significantly decreased by captopril and increased by losartan -LRB- P < 0.05 vs baseline for both -RRB- .
# (ROOT
#   (S
#     (NP
#       (NP (NNP Plasma) (NNS concentrations))
#       (PP (IN of)
#         (NP (NNP AII))))
#     (VP (VBD were)
#       (ADVP (RB significantly))
#       (VP
#         (VP (VBN decreased)
#           (PP (IN by)
#             (NP (NN captopril))))
#         (CC and)
#         (VP (VBN increased)
#           (PP (IN by)
#             (NP
#               (NP (NN losartan))
#               (PRN (-LRB- -LRB-)
#                 (NP
#                   (NP (NNP P) (NNP <))
#                   (NP
#                     (NP (CD 0.05) (NN vs) (NN baseline))
#                     (PP (IN for)
#                       (NP (DT both)))))
#                 (-RRB- -RRB-)))))))
#     (. .)))
#
# compound(concentrations-2, Plasma-1)
# nsubjpass(decreased-7, concentrations-2)
# nsubjpass(increased-11, concentrations-2)
# case(AII-4, of-3)
# nmod:of(concentrations-2, AII-4)
# auxpass(decreased-7, were-5)
# advmod(decreased-7, significantly-6)
# root(ROOT-0, decreased-7)
# case(captopril-9, by-8)
# nmod:by(decreased-7, captopril-9)
# cc(decreased-7, and-10)
# conj:and(decreased-7, increased-11)
# case(losartan-13, by-12)
# nmod:by(increased-11, losartan-13)
# compound(<-16, P-15)
# dep(losartan-13, <-16)
# nummod(baseline-19, 0.05-17)
# compound(baseline-19, vs-18)
# dep(<-16, baseline-19)
# case(both-21, for-20)
# nmod:for(baseline-19, both-21)
#
# Parsing [sent. 11 len. 37]: Total body sympathetic activity increased in response to both captopril and losartan -LRB- P < 0.05 vs baseline for both -RRB- , however there was no change in cardiac sympathetic activity in response to either drug .
# (ROOT
#   (S
#     (NP
#       (NP (JJ Total) (NN body) (JJ sympathetic) (NN activity))
#       (VP (VBN increased)
#         (PP (IN in)
#           (NP (NN response)))
#         (PP (TO to)
#           (NP
#             (NP (DT both) (NN captopril)
#               (CC and)
#               (NN losartan))
#             (PRN (-LRB- -LRB-)
#               (NP
#                 (NP (NNP P) (NNP <))
#                 (NP
#                   (NP (CD 0.05) (NN vs) (NN baseline))
#                   (PP (IN for)
#                     (NP (DT both)))))
#               (-RRB- -RRB-))))))
#     (, ,)
#     (ADVP (RB however))
#     (NP (EX there))
#     (VP (VBD was)
#       (NP
#         (NP (DT no) (NN change))
#         (PP (IN in)
#           (NP
#             (NP (JJ cardiac) (JJ sympathetic) (NN activity))
#             (PP (IN in)
#               (NP (NN response))))))
#       (PP (TO to)
#         (NP (DT either) (NN drug))))
#     (. .)))
#
# amod(activity-4, Total-1)
# compound(activity-4, body-2)
# amod(activity-4, sympathetic-3)
# nsubj(was-25, activity-4)
# acl(activity-4, increased-5)
# case(response-7, in-6)
# nmod:in(increased-5, response-7)
# case(captopril-10, to-8)
# cc:preconj(captopril-10, both-9)
# nmod:to(increased-5, captopril-10)
# cc(captopril-10, and-11)
# nmod:to(increased-5, losartan-12)
# conj:and(captopril-10, losartan-12)
# compound(<-15, P-14)
# dep(captopril-10, <-15)
# nummod(baseline-18, 0.05-16)
# compound(baseline-18, vs-17)
# dep(<-15, baseline-18)
# case(both-20, for-19)
# nmod:for(baseline-18, both-20)
# expl(was-25, however-23)
# dep(however-23, there-24)
# root(ROOT-0, was-25)
# neg(change-27, no-26)
# nsubj(was-25, change-27)
# case(activity-31, in-28)
# amod(activity-31, cardiac-29)
# amod(activity-31, sympathetic-30)
# nmod:in(change-27, activity-31)
# case(response-33, in-32)
# nmod:in(activity-31, response-33)
# case(drug-36, to-34)
# det(drug-36, either-35)
# nmod:to(was-25, drug-36)
#
# Parsing [sent. 12 len. 29]: The results of the current study do not support the hypothesis that the acute inhibition of the renin angiotensin system has sympathoinhibitory effects in patients with chronic HFrEF .
# (ROOT
#   (S
#     (NP
#       (NP (DT The) (NNS results))
#       (PP (IN of)
#         (NP (DT the) (JJ current) (NN study))))
#     (VP (VBP do) (RB not)
#       (VP (VB support)
#         (NP (DT the) (NNS hypothesis))
#         (SBAR (IN that)
#           (S
#             (NP
#               (NP (DT the) (JJ acute) (NN inhibition))
#               (PP (IN of)
#                 (NP (DT the) (NN renin) (NN angiotensin) (NN system))))
#             (VP (VBZ has)
#               (NP
#                 (NP (JJ sympathoinhibitory) (NNS effects))
#                 (PP (IN in)
#                   (NP
#                     (NP (NNS patients))
#                     (PP (IN with)
#                       (NP (JJ chronic) (NNP HFrEF)))))))))))
#     (. .)))
#
# det(results-2, The-1)
# nsubj(support-9, results-2)
# case(study-6, of-3)
# det(study-6, the-4)
# amod(study-6, current-5)
# nmod:of(results-2, study-6)
# aux(support-9, do-7)
# neg(support-9, not-8)
# root(ROOT-0, support-9)
# det(hypothesis-11, the-10)
# dobj(support-9, hypothesis-11)
# mark(has-21, that-12)
# det(inhibition-15, the-13)
# amod(inhibition-15, acute-14)
# nsubj(has-21, inhibition-15)
# case(system-20, of-16)
# det(system-20, the-17)
# compound(system-20, renin-18)
# compound(system-20, angiotensin-19)
# nmod:of(inhibition-15, system-20)
# ccomp(support-9, has-21)
# amod(effects-23, sympathoinhibitory-22)
# dobj(has-21, effects-23)
# case(patients-25, in-24)
# nmod:in(effects-23, patients-25)
# case(HFrEF-28, with-26)
# amod(HFrEF-28, chronic-27)
# nmod:with(patients-25, HFrEF-28)
#
# Parsed file: KeywordSentences.txt [12 sentences].
# Parsed 408 words in 12 sentences (35.25 wds/sec; 1.04 sents/sec).
# [main] INFO edu.stanford.nlp.parser.lexparser.LexicalizedParser - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ... done [0.9 sec].
# Parsing file: KeywordSentences.txt
# Parsing [sent. 1 len. 52]: RAAS , a major pharmacological target in cardiovascular medicine , is inhibited by pharmacological classes including angiotensin converting enzyme -LRB- ACE -RRB- inhibitors -LRB- ACEIs -RRB- , angiotensin-II type 1 blockers -LRB- ARBs -RRB- and aldosterone receptors antagonists , in addition to the recently introduced direct renin inhibitors -LRB- DRIs -RRB- .
# (ROOT
#   (S
#     (NP
#       (NP (NNS RAAS))
#       (, ,)
#       (NP
#         (NP (DT a) (JJ major) (JJ pharmacological) (NN target))
#         (PP (IN in)
#           (NP (JJ cardiovascular) (NN medicine))))
#       (, ,))
#     (VP (VBZ is)
#       (ADJP (JJ inhibited)
#         (PP (IN by)
#           (NP
#             (NP (JJ pharmacological) (NNS classes))
#             (PP (VBG including)
#               (NP
#                 (NP
#                   (NP (NN angiotensin))
#                   (S
#                     (VP (VBG converting)
#                       (NP (JJ enzyme)
#                         (PRN (-LRB- -LRB-)
#                           (NP (NNP ACE))
#                           (-RRB- -RRB-))
#                         (NNS inhibitors))))
#                   (PRN (-LRB- -LRB-)
#                     (NP (NNP ACEIs))
#                     (-RRB- -RRB-)))
#                 (, ,)
#                 (NP
#                   (ADJP (RB angiotensin-II) (NN type)
#                     (PRN
#                       (NP (CD 1))
#                       (PP
#                         (NP
#                           (NP (NNS blockers))
#                           (PRN (-LRB- -LRB-)
#                             (NP (NNP ARBs))
#                             (-RRB- -RRB-))
#                           (CC and)
#                           (NP (JJ aldosterone) (NNS receptors) (NNS antagonists))
#                           (, ,))
#                         (IN in)
#                         (NP (NN addition))))
#                     (PP (TO to)
#                       (NP (DT the)
#                         (ADJP (RB recently) (VBN introduced))
#                         (JJ direct) (NN renin))))
#                   (NNS inhibitors))))
#             (PRN (-LRB- -LRB-)
#               (NP (NNP DRIs))
#               (-RRB- -RRB-))))))
#     (. .)))
#
# nsubj(inhibited-12, RAAS-1)
# det(target-6, a-3)
# amod(target-6, major-4)
# amod(target-6, pharmacological-5)
# appos(RAAS-1, target-6)
# case(medicine-9, in-7)
# amod(medicine-9, cardiovascular-8)
# nmod:in(target-6, medicine-9)
# cop(inhibited-12, is-11)
# root(ROOT-0, inhibited-12)
# case(classes-15, by-13)
# amod(classes-15, pharmacological-14)
# nmod:by(inhibited-12, classes-15)
# case(angiotensin-17, including-16)
# nmod:including(classes-15, angiotensin-17)
# dep(angiotensin-17, converting-18)
# amod(inhibitors-23, enzyme-19)
# appos(inhibitors-23, ACE-21)
# dobj(converting-18, inhibitors-23)
# appos(angiotensin-17, ACEIs-25)
# advmod(type-29, angiotensin-II-28)
# amod(inhibitors-48, type-29)
# dep(type-29, 1-30)
# nmod:in(1-30, blockers-31)
# appos(blockers-31, ARBs-33)
# cc(blockers-31, and-35)
# amod(antagonists-38, aldosterone-36)
# compound(antagonists-38, receptors-37)
# nmod:in(1-30, antagonists-38)
# conj:and(blockers-31, antagonists-38)
# case(blockers-31, in-40)
# dep(blockers-31, addition-41)
# case(renin-47, to-42)
# det(renin-47, the-43)
# advmod(introduced-45, recently-44)
# amod(renin-47, introduced-45)
# amod(renin-47, direct-46)
# nmod:to(type-29, renin-47)
# appos(angiotensin-17, inhibitors-48)
# appos(classes-15, DRIs-50)
#
# Parsing [sent. 2 len. 36]: However , currently used RAAS inhibitors still can not achieve their desired effects and are associated with certain drawbacks , such as adverse side effects , incomplete blockage of the system and poor end-organ protection .
# (ROOT
#   (S
#     (ADVP (RB However))
#     (, ,)
#     (ADVP (RB currently))
#     (VP (VBD used)
#       (SBAR
#         (S
#           (NP (NNP RAAS) (NNS inhibitors))
#           (ADVP (RB still))
#           (VP
#             (VP (MD can) (RB not)
#               (VP (VB achieve)
#                 (NP (PRP$ their) (VBN desired) (NNS effects))))
#             (CC and)
#             (VP (VBP are)
#               (VP (VBN associated)
#                 (PP (IN with)
#                   (NP
#                     (NP (JJ certain) (NNS drawbacks))
#                     (, ,)
#                     (PP (JJ such) (IN as)
#                       (NP (JJ adverse) (NN side) (NNS effects)))
#                     (, ,)
#                     (ADJP (JJ incomplete) (JJ blockage))
#                     (PP (IN of)
#                       (NP
#                         (NP (DT the) (NN system))
#                         (CC and)
#                         (NP (JJ poor) (JJ end-organ) (NN protection))))))))))))
#     (. .)))
#
# advmod(used-4, However-1)
# advmod(used-4, currently-3)
# root(ROOT-0, used-4)
# compound(inhibitors-6, RAAS-5)
# nsubj(achieve-10, inhibitors-6)
# nsubjpass(associated-16, inhibitors-6)
# advmod(achieve-10, still-7)
# aux(achieve-10, can-8)
# neg(achieve-10, not-9)
# ccomp(used-4, achieve-10)
# nmod:poss(effects-13, their-11)
# amod(effects-13, desired-12)
# dobj(achieve-10, effects-13)
# cc(achieve-10, and-14)
# auxpass(associated-16, are-15)
# ccomp(used-4, associated-16)
# conj:and(achieve-10, associated-16)
# case(drawbacks-19, with-17)
# amod(drawbacks-19, certain-18)
# nmod:with(associated-16, drawbacks-19)
# case(effects-25, such-21)
# mwe(such-21, as-22)
# amod(effects-25, adverse-23)
# compound(effects-25, side-24)
# nmod:such_as(drawbacks-19, effects-25)
# amod(blockage-28, incomplete-27)
# amod(drawbacks-19, blockage-28)
# case(system-31, of-29)
# det(system-31, the-30)
# nmod:of(drawbacks-19, system-31)
# cc(system-31, and-32)
# amod(protection-35, poor-33)
# amod(protection-35, end-organ-34)
# nmod:of(drawbacks-19, protection-35)
# conj:and(system-31, protection-35)
#
# Parsing [sent. 3 len. 42]: In this review , we discuss the efficiency and specificity of the current RAAS inhibitors and propose some recommendations for achieving better treatments with better end-organ protection.Hypertension Research advance online publication , 6 July 2017 ; doi :10.1038 / hr .2017.65 .
# (ROOT
#   (S
#     (PP (IN In)
#       (NP (DT this) (NN review)))
#     (, ,)
#     (S
#       (NP (PRP we))
#       (VP
#         (VP (VB discuss)
#           (NP
#             (NP (DT the) (NN efficiency)
#               (CC and)
#               (NN specificity))
#             (PP (IN of)
#               (NP (DT the) (JJ current) (NNS RAAS) (NNS inhibitors)))))
#         (CC and)
#         (VP (VB propose)
#           (NP (DT some) (NNS recommendations))
#           (PP (IN for)
#             (S
#               (VP (VBG achieving)
#                 (NP (JJR better) (NNS treatments))
#                 (PP (IN with)
#                   (NP (JJR better) (JJ end-organ) (NN protection.Hypertension) (NNP Research) (NN advance) (JJ online) (NN publication) (, ,) (CD 6) (NNP July) (NNS 2017)))))))))
#     (: ;)
#     (FRAG
#       (X
#         (X (SYM doi))
#         (NP (CD :10.1038)))
#       (: /)
#       (NP (CD hr) (CD .2017.65)))
#     (. .)))
#
# case(review-3, In-1)
# det(review-3, this-2)
# nmod:in(discuss-6, review-3)
# nsubj(discuss-6, we-5)
# nsubj(propose-17, we-5)
# root(ROOT-0, discuss-6)
# det(efficiency-8, the-7)
# dobj(discuss-6, efficiency-8)
# cc(efficiency-8, and-9)
# dobj(discuss-6, specificity-10)
# conj:and(efficiency-8, specificity-10)
# case(inhibitors-15, of-11)
# det(inhibitors-15, the-12)
# amod(inhibitors-15, current-13)
# compound(inhibitors-15, RAAS-14)
# nmod:of(efficiency-8, inhibitors-15)
# cc(discuss-6, and-16)
# conj:and(discuss-6, propose-17)
# det(recommendations-19, some-18)
# dobj(propose-17, recommendations-19)
# mark(achieving-21, for-20)
# advcl(propose-17, achieving-21)
# amod(treatments-23, better-22)
# dobj(achieving-21, treatments-23)
# case(2017-35, with-24)
# amod(2017-35, better-25)
# amod(2017-35, end-organ-26)
# compound(2017-35, protection.Hypertension-27)
# compound(2017-35, Research-28)
# compound(2017-35, advance-29)
# amod(2017-35, online-30)
# compound(2017-35, publication-31)
# nummod(2017-35, 6-33)
# compound(2017-35, July-34)
# nmod:with(achieving-21, 2017-35)
# dep(:10.1038-38, doi-37)
# dep(.2017.65-41, :10.1038-38)
# nummod(.2017.65-41, hr-40)
# dep(discuss-6, .2017.65-41)
#
# Parsing [sent. 4 len. 51]: The beneficial effects of angiotensin converting enzyme -LRB- ACE -RRB- inhibitors and angiotensin II -LRB- AII -RRB- receptor antagonists in patients with heart failure secondary to reduced ejection fraction -LRB- HFrEF -RRB- are felt to result from prevention of the adverse effects of AII on systemic afterload and renal homeostasis .
# (ROOT
#   (S
#     (NP
#       (NP (DT The) (JJ beneficial) (NNS effects))
#       (PP (IN of)
#         (NP
#           (NP (NN angiotensin))
#           (VP (VBG converting)
#             (NP
#               (NP (JJ enzyme)
#                 (PRN (-LRB- -LRB-)
#                   (NP (NNP ACE))
#                   (-RRB- -RRB-))
#                 (NN inhibitors))
#               (CC and)
#               (NP
#                 (NP (NNP angiotensin) (NNP II))
#                 (PRN (-LRB- -LRB-)
#                   (NP (NNP AII))
#                   (-RRB- -RRB-)))
#               (NP
#                 (NP (NN receptor) (NNS antagonists))
#                 (PP (IN in)
#                   (NP (NNS patients)))))
#             (PP (IN with)
#               (NP
#                 (NP (NN heart) (NN failure))
#                 (ADJP (JJ secondary)
#                   (PP (TO to)
#                     (NP
#                       (NP (VBN reduced) (NN ejection) (NN fraction))
#                       (PRN (-LRB- -LRB-)
#                         (NP (NNP HFrEF))
#                         (-RRB- -RRB-)))))))))))
#     (VP (VBP are)
#       (VP (VBN felt)
#         (S
#           (VP (TO to)
#             (VP (VB result)
#               (PP (IN from)
#                 (NP
#                   (NP (NN prevention))
#                   (PP (IN of)
#                     (NP
#                       (NP (DT the) (JJ adverse) (NNS effects))
#                       (PP (IN of)
#                         (NP (NNP AII)))))))
#               (PP (IN on)
#                 (NP (JJ systemic) (JJ afterload)
#                   (CC and)
#                   (JJ renal) (NNS homeostasis))))))))
#     (. .)))
#
# det(effects-3, The-1)
# amod(effects-3, beneficial-2)
# nsubjpass(felt-34, effects-3)
# nsubj:xsubj(result-36, effects-3)
# case(angiotensin-5, of-4)
# nmod:of(effects-3, angiotensin-5)
# acl(angiotensin-5, converting-6)
# amod(inhibitors-11, enzyme-7)
# appos(inhibitors-11, ACE-9)
# dobj(converting-6, inhibitors-11)
# cc(inhibitors-11, and-12)
# compound(II-14, angiotensin-13)
# dobj(converting-6, II-14)
# conj:and(inhibitors-11, II-14)
# appos(II-14, AII-16)
# compound(antagonists-19, receptor-18)
# dep(inhibitors-11, antagonists-19)
# case(patients-21, in-20)
# nmod:in(antagonists-19, patients-21)
# case(failure-24, with-22)
# compound(failure-24, heart-23)
# nmod:with(converting-6, failure-24)
# amod(failure-24, secondary-25)
# case(fraction-29, to-26)
# amod(fraction-29, reduced-27)
# compound(fraction-29, ejection-28)
# nmod:to(secondary-25, fraction-29)
# appos(fraction-29, HFrEF-31)
# auxpass(felt-34, are-33)
# root(ROOT-0, felt-34)
# mark(result-36, to-35)
# xcomp(felt-34, result-36)
# case(prevention-38, from-37)
# nmod:from(result-36, prevention-38)
# case(effects-42, of-39)
# det(effects-42, the-40)
# amod(effects-42, adverse-41)
# nmod:of(prevention-38, effects-42)
# case(AII-44, of-43)
# nmod:of(effects-42, AII-44)
# case(afterload-47, on-45)
# amod(afterload-47, systemic-46)
# nmod:on(result-36, afterload-47)
# cc(afterload-47, and-48)
# amod(homeostasis-50, renal-49)
# nmod:on(result-36, homeostasis-50)
# conj:and(afterload-47, homeostasis-50)
#
# Parsing [sent. 5 len. 31]: However , AII can activate the sympathetic nervous system and part of the beneficial effects of ACE inhibitors and AII antagonists may result from their ability to inhibit such activation .
# (ROOT
#   (S
#     (ADVP (RB However))
#     (, ,)
#     (S
#       (NP (NNP AII))
#       (VP (MD can)
#         (VP (VB activate)
#           (NP
#             (NP (DT the)
#               (ADJP (JJ sympathetic) (JJ nervous))
#               (NN system))
#             (CC and)
#             (NP
#               (NP (NN part))
#               (PP (IN of)
#                 (NP
#                   (NP (DT the) (JJ beneficial) (NNS effects))
#                   (PP (IN of)
#                     (NP (NNP ACE) (NNS inhibitors))))))))))
#     (CC and)
#     (S
#       (NP (NNP AII) (NNS antagonists))
#       (VP (MD may)
#         (VP (VB result)
#           (PP (IN from)
#             (NP (PRP$ their) (NN ability)
#               (S
#                 (VP (TO to)
#                   (VP (VB inhibit)
#                     (NP (JJ such) (NN activation))))))))))
#     (. .)))
#
# advmod(activate-5, However-1)
# nsubj(activate-5, AII-3)
# aux(activate-5, can-4)
# root(ROOT-0, activate-5)
# det(system-9, the-6)
# amod(nervous-8, sympathetic-7)
# amod(system-9, nervous-8)
# dobj(activate-5, system-9)
# cc(system-9, and-10)
# dobj(activate-5, part-11)
# conj:and(system-9, part-11)
# case(effects-15, of-12)
# det(effects-15, the-13)
# amod(effects-15, beneficial-14)
# nmod:of(part-11, effects-15)
# case(inhibitors-18, of-16)
# compound(inhibitors-18, ACE-17)
# nmod:of(effects-15, inhibitors-18)
# cc(activate-5, and-19)
# compound(antagonists-21, AII-20)
# nsubj(result-23, antagonists-21)
# aux(result-23, may-22)
# conj:and(activate-5, result-23)
# case(ability-26, from-24)
# nmod:poss(ability-26, their-25)
# nmod:from(result-23, ability-26)
# mark(inhibit-28, to-27)
# acl(ability-26, inhibit-28)
# amod(activation-30, such-29)
# dobj(inhibit-28, activation-30)
#
# Parsing [sent. 6 len. 49]: We examined the acute effects of the ACE inhibitor captopril -LRB- 25 mg , n = 9 -RRB- and the AII receptor antagonist losartan -LRB- 50 mg , n = 10 -RRB- on hemodynamics as well as total body and cardiac norepinephrine spillover in patients with chronic HFrEF .
# (ROOT
#   (S
#     (NP (PRP We))
#     (VP (VBD examined)
#       (NP
#         (NP (DT the) (JJ acute) (NNS effects))
#         (PP (IN of)
#           (NP
#             (NP (DT the) (NNP ACE) (NN inhibitor) (NN captopril))
#             (PRN (-LRB- -LRB-)
#               (NP
#                 (NP (CD 25) (NN mg))
#                 (, ,)
#                 (NP
#                   (NP (NN n))
#                   (SBAR
#                     (S
#                       (VP (SYM =)
#                         (NP (CD 9)))))))
#               (-RRB- -RRB-))
#             (CC and)
#             (NP (DT the) (NNP AII) (NN receptor) (NN antagonist) (NN losartan))
#             (PRN (-LRB- -LRB-)
#               (NP
#                 (NP (CD 50) (NN mg))
#                 (, ,)
#                 (NP
#                   (NP (NN n))
#                   (SBAR
#                     (S
#                       (VP (SYM =)
#                         (NP (CD 10)))))))
#               (-RRB- -RRB-)))))
#       (PP (IN on)
#         (NP
#           (NP (NNS hemodynamics))
#           (CONJP (RB as) (RB well) (IN as))
#           (NP (JJ total) (NN body)
#             (CC and)
#             (JJ cardiac) (NN norepinephrine) (NN spillover))))
#       (PP (IN in)
#         (NP
#           (NP (NNS patients))
#           (PP (IN with)
#             (NP (JJ chronic) (NNP HFrEF))))))
#     (. .)))
#
# nsubj(examined-2, We-1)
# root(ROOT-0, examined-2)
# det(effects-5, the-3)
# amod(effects-5, acute-4)
# dobj(examined-2, effects-5)
# case(captopril-10, of-6)
# det(captopril-10, the-7)
# compound(captopril-10, ACE-8)
# compound(captopril-10, inhibitor-9)
# nmod:of(effects-5, captopril-10)
# nummod(mg-13, 25-12)
# dep(captopril-10, mg-13)
# appos(mg-13, n-15)
# dep(9-17, =-16)
# acl:relcl(n-15, 9-17)
# cc(captopril-10, and-19)
# det(losartan-24, the-20)
# compound(losartan-24, AII-21)
# compound(losartan-24, receptor-22)
# compound(losartan-24, antagonist-23)
# nmod:of(effects-5, losartan-24)
# conj:and(captopril-10, losartan-24)
# nummod(mg-27, 50-26)
# dep(captopril-10, mg-27)
# appos(mg-27, n-29)
# dep(10-31, =-30)
# acl:relcl(n-29, 10-31)
# case(hemodynamics-34, on-33)
# nmod:on(examined-2, hemodynamics-34)
# cc(hemodynamics-34, as-35)
# mwe(as-35, well-36)
# mwe(as-35, as-37)
# amod(body-39, total-38)
# nmod:on(examined-2, body-39)
# conj:and(hemodynamics-34, body-39)
# cc(body-39, and-40)
# amod(spillover-43, cardiac-41)
# compound(spillover-43, norepinephrine-42)
# conj:and(hemodynamics-34, spillover-43)
# conj:and(body-39, spillover-43)
# case(patients-45, in-44)
# nmod:in(examined-2, patients-45)
# case(HFrEF-48, with-46)
# amod(HFrEF-48, chronic-47)
# nmod:with(patients-45, HFrEF-48)
#
# Parsing [sent. 7 len. 20]: Hemodynamic and neurochemical measurements were made at baseline and at 1 , 2 and 4 hours after oral dosing .
# (ROOT
#   (S
#     (NP (JJ Hemodynamic)
#       (CC and)
#       (JJ neurochemical) (NNS measurements))
#     (VP (VBD were)
#       (VP (VBN made)
#         (PP
#           (PP (IN at)
#             (NP (NN baseline)))
#           (CC and)
#           (PP (IN at)
#             (NP (CD 1) (, ,) (CD 2)
#               (CC and)
#               (CD 4)))
#           (NP (NNS hours)))
#         (PP (IN after)
#           (NP (JJ oral) (NN dosing)))))
#     (. .)))
#
# amod(measurements-4, Hemodynamic-1)
# cc(Hemodynamic-1, and-2)
# conj:and(Hemodynamic-1, neurochemical-3)
# amod(measurements-4, neurochemical-3)
# nsubjpass(made-6, measurements-4)
# auxpass(made-6, were-5)
# root(ROOT-0, made-6)
# case(baseline-8, at-7)
# nmod:at(hours-16, baseline-8)
# cc(hours-16, and-9)
# case(1-11, at-10)
# nmod(made-6, 1-11)
# conj:and(hours-16, 1-11)
# nummod(1-11, 2-13)
# cc(1-11, and-14)
# conj:and(1-11, 4-15)
# conj:and(hours-16, 4-15)
# nmod(made-6, hours-16)
# case(dosing-19, after-17)
# amod(dosing-19, oral-18)
# nmod:after(made-6, dosing-19)
#
# Parsing [sent. 8 len. 25]: Administration of both drugs caused significant reductions in systemic arterial , cardiac filling and pulmonary artery pressures -LRB- P < 0.05 vs baseline -RRB- .
# (ROOT
#   (S
#     (NP
#       (NP (NNP Administration))
#       (PP (IN of)
#         (NP (DT both) (NNS drugs))))
#     (VP (VBD caused)
#       (NP (JJ significant) (NNS reductions))
#       (PP (IN in)
#         (NP
#           (NP (JJ systemic) (NN arterial))
#           (, ,)
#           (NP (JJ cardiac) (NN filling))
#           (CC and)
#           (NP (JJ pulmonary) (NN artery) (NNS pressures))))
#       (PRN (-LRB- -LRB-)
#         (NP
#           (NP (NNP P) (NNP <))
#           (NP (CD 0.05) (NN vs) (NN baseline)))
#         (-RRB- -RRB-)))
#     (. .)))
#
# nsubj(caused-5, Administration-1)
# case(drugs-4, of-2)
# det(drugs-4, both-3)
# nmod:of(Administration-1, drugs-4)
# root(ROOT-0, caused-5)
# amod(reductions-7, significant-6)
# dobj(caused-5, reductions-7)
# case(arterial-10, in-8)
# amod(arterial-10, systemic-9)
# nmod:in(caused-5, arterial-10)
# amod(filling-13, cardiac-12)
# nmod:in(caused-5, filling-13)
# conj:and(arterial-10, filling-13)
# cc(arterial-10, and-14)
# amod(pressures-17, pulmonary-15)
# compound(pressures-17, artery-16)
# nmod:in(caused-5, pressures-17)
# conj:and(arterial-10, pressures-17)
# compound(<-20, P-19)
# dep(caused-5, <-20)
# nummod(baseline-23, 0.05-21)
# compound(baseline-23, vs-22)
# dep(<-20, baseline-23)
#
# Parsing [sent. 9 len. 13]: There was no significant difference in the magnitude of those hemodynamic effects .
# (ROOT
#   (S
#     (NP (EX There))
#     (VP (VBD was)
#       (NP
#         (NP (DT no) (JJ significant) (NN difference))
#         (PP (IN in)
#           (NP
#             (NP (DT the) (NN magnitude))
#             (PP (IN of)
#               (NP (DT those) (JJ hemodynamic) (NNS effects)))))))
#     (. .)))
#
# expl(was-2, There-1)
# root(ROOT-0, was-2)
# neg(difference-5, no-3)
# amod(difference-5, significant-4)
# nsubj(was-2, difference-5)
# case(magnitude-8, in-6)
# det(magnitude-8, the-7)
# nmod:in(difference-5, magnitude-8)
# case(effects-12, of-9)
# det(effects-12, those-10)
# amod(effects-12, hemodynamic-11)
# nmod:of(magnitude-8, effects-12)
#
# Parsing [sent. 10 len. 23]: Plasma concentrations of AII were significantly decreased by captopril and increased by losartan -LRB- P < 0.05 vs baseline for both -RRB- .
# (ROOT
#   (S
#     (NP
#       (NP (NNP Plasma) (NNS concentrations))
#       (PP (IN of)
#         (NP (NNP AII))))
#     (VP (VBD were)
#       (ADVP (RB significantly))
#       (VP
#         (VP (VBN decreased)
#           (PP (IN by)
#             (NP (NN captopril))))
#         (CC and)
#         (VP (VBN increased)
#           (PP (IN by)
#             (NP
#               (NP (NN losartan))
#               (PRN (-LRB- -LRB-)
#                 (NP
#                   (NP (NNP P) (NNP <))
#                   (NP
#                     (NP (CD 0.05) (NN vs) (NN baseline))
#                     (PP (IN for)
#                       (NP (DT both)))))
#                 (-RRB- -RRB-)))))))
#     (. .)))
#
# compound(concentrations-2, Plasma-1)
# nsubjpass(decreased-7, concentrations-2)
# nsubjpass(increased-11, concentrations-2)
# case(AII-4, of-3)
# nmod:of(concentrations-2, AII-4)
# auxpass(decreased-7, were-5)
# advmod(decreased-7, significantly-6)
# root(ROOT-0, decreased-7)
# case(captopril-9, by-8)
# nmod:by(decreased-7, captopril-9)
# cc(decreased-7, and-10)
# conj:and(decreased-7, increased-11)
# case(losartan-13, by-12)
# nmod:by(increased-11, losartan-13)
# compound(<-16, P-15)
# dep(losartan-13, <-16)
# nummod(baseline-19, 0.05-17)
# compound(baseline-19, vs-18)
# dep(<-16, baseline-19)
# case(both-21, for-20)
# nmod:for(baseline-19, both-21)
#
# Parsing [sent. 11 len. 37]: Total body sympathetic activity increased in response to both captopril and losartan -LRB- P < 0.05 vs baseline for both -RRB- , however there was no change in cardiac sympathetic activity in response to either drug .
# (ROOT
#   (S
#     (NP
#       (NP (JJ Total) (NN body) (JJ sympathetic) (NN activity))
#       (VP (VBN increased)
#         (PP (IN in)
#           (NP (NN response)))
#         (PP (TO to)
#           (NP
#             (NP (DT both) (NN captopril)
#               (CC and)
#               (NN losartan))
#             (PRN (-LRB- -LRB-)
#               (NP
#                 (NP (NNP P) (NNP <))
#                 (NP
#                   (NP (CD 0.05) (NN vs) (NN baseline))
#                   (PP (IN for)
#                     (NP (DT both)))))
#               (-RRB- -RRB-))))))
#     (, ,)
#     (ADVP (RB however))
#     (NP (EX there))
#     (VP (VBD was)
#       (NP
#         (NP (DT no) (NN change))
#         (PP (IN in)
#           (NP
#             (NP (JJ cardiac) (JJ sympathetic) (NN activity))
#             (PP (IN in)
#               (NP (NN response))))))
#       (PP (TO to)
#         (NP (DT either) (NN drug))))
#     (. .)))
#
# amod(activity-4, Total-1)
# compound(activity-4, body-2)
# amod(activity-4, sympathetic-3)
# nsubj(was-25, activity-4)
# acl(activity-4, increased-5)
# case(response-7, in-6)
# nmod:in(increased-5, response-7)
# case(captopril-10, to-8)
# cc:preconj(captopril-10, both-9)
# nmod:to(increased-5, captopril-10)
# cc(captopril-10, and-11)
# nmod:to(increased-5, losartan-12)
# conj:and(captopril-10, losartan-12)
# compound(<-15, P-14)
# dep(captopril-10, <-15)
# nummod(baseline-18, 0.05-16)
# compound(baseline-18, vs-17)
# dep(<-15, baseline-18)
# case(both-20, for-19)
# nmod:for(baseline-18, both-20)
# expl(was-25, however-23)
# dep(however-23, there-24)
# root(ROOT-0, was-25)
# neg(change-27, no-26)
# nsubj(was-25, change-27)
# case(activity-31, in-28)
# amod(activity-31, cardiac-29)
# amod(activity-31, sympathetic-30)
# nmod:in(change-27, activity-31)
# case(response-33, in-32)
# nmod:in(activity-31, response-33)
# case(drug-36, to-34)
# det(drug-36, either-35)
# nmod:to(was-25, drug-36)
#
# Parsing [sent. 12 len. 29]: The results of the current study do not support the hypothesis that the acute inhibition of the renin angiotensin system has sympathoinhibitory effects in patients with chronic HFrEF .
# (ROOT
#   (S
#     (NP
#       (NP (DT The) (NNS results))
#       (PP (IN of)
#         (NP (DT the) (JJ current) (NN study))))
# ...
#                   (-RRB- -RRB-))
#                 (NN inhibitors))
#               (CC and)
#               (NP
#                 (NP (NNP angiotensin) (NNP II))
#                 (PRN (-LRB- -LRB-)
#                   (NP (NNP AII))
#                   (-RRB- -RRB-)))
#               (NP
#                 (NP (NN receptor) (NNS antagonists))
#                 (PP (IN in)
#                   (NP (NNS patients)))))
#             (PP (IN with)
#               (NP
#                 (NP (NN heart) (NN failure))
#                 (ADJP (JJ secondary)
#                   (PP (TO to)
#                     (NP
#                       (NP (VBN reduced) (NN ejection) (NN fraction))
#                       (PRN (-LRB- -LRB-)
#                         (NP (NNP HFrEF))
#                         (-RRB- -RRB-)))))))))))
#     (VP (VBP are)
#       (VP (VBN felt)
#         (S
#           (VP (TO to)
#             (VP (VB result)
#               (PP (IN from)
#                 (NP
#                   (NP (NN prevention))
#                   (PP (IN of)
#                     (NP
#                       (NP (DT the) (JJ adverse) (NNS effects))
#                       (PP (IN of)
#                         (NP (NNP AII)))))))
#               (PP (IN on)
#                 (NP (JJ systemic) (JJ afterload)
#                   (CC and)
#                   (JJ renal) (NNS homeostasis))))))))
#     (. .)))
#
# det(effects-3, The-1)
# amod(effects-3, beneficial-2)
# nsubjpass(felt-34, effects-3)
# nsubj:xsubj(result-36, effects-3)
# case(angiotensin-5, of-4)
# nmod:of(effects-3, angiotensin-5)
# acl(angiotensin-5, converting-6)
# amod(inhibitors-11, enzyme-7)
# appos(inhibitors-11, ACE-9)
# dobj(converting-6, inhibitors-11)
# cc(inhibitors-11, and-12)
# compound(II-14, angiotensin-13)
# dobj(converting-6, II-14)
# conj:and(inhibitors-11, II-14)
# appos(II-14, AII-16)
# compound(antagonists-19, receptor-18)
# dep(inhibitors-11, antagonists-19)
# case(patients-21, in-20)
# nmod:in(antagonists-19, patients-21)
# case(failure-24, with-22)
# compound(failure-24, heart-23)
# nmod:with(converting-6, failure-24)
# amod(failure-24, secondary-25)
# case(fraction-29, to-26)
# amod(fraction-29, reduced-27)
# compound(fraction-29, ejection-28)
# nmod:to(secondary-25, fraction-29)
# appos(fraction-29, HFrEF-31)
# auxpass(felt-34, are-33)
# root(ROOT-0, felt-34)
# mark(result-36, to-35)
# xcomp(felt-34, result-36)
# case(prevention-38, from-37)
# nmod:from(result-36, prevention-38)
# case(effects-42, of-39)
# det(effects-42, the-40)
# amod(effects-42, adverse-41)
# nmod:of(prevention-38, effects-42)
# case(AII-44, of-43)
# nmod:of(effects-42, AII-44)
# case(afterload-47, on-45)
# amod(afterload-47, systemic-46)
# nmod:on(result-36, afterload-47)
# cc(afterload-47, and-48)
# amod(homeostasis-50, renal-49)
# nmod:on(result-36, homeostasis-50)
# conj:and(afterload-47, homeostasis-50)
#
# Parsing [sent. 5 len. 31]: However , AII can activate the sympathetic nervous system and part of the beneficial effects of ACE inhibitors and AII antagonists may result from their ability to inhibit such activation .
# (ROOT
#   (S
#     (ADVP (RB However))
#     (, ,)
#     (S
#       (NP (NNP AII))
#       (VP (MD can)
#         (VP (VB activate)
#           (NP
#             (NP (DT the)
#               (ADJP (JJ sympathetic) (JJ nervous))
#               (NN system))
#             (CC and)
#             (NP
#               (NP (NN part))
#               (PP (IN of)
#                 (NP
#                   (NP (DT the) (JJ beneficial) (NNS effects))
#                   (PP (IN of)
#                     (NP (NNP ACE) (NNS inhibitors))))))))))
#     (CC and)
#     (S
#       (NP (NNP AII) (NNS antagonists))
#       (VP (MD may)
#         (VP (VB result)
#           (PP (IN from)
#             (NP (PRP$ their) (NN ability)
#               (S
#                 (VP (TO to)
#                   (VP (VB inhibit)
#                     (NP (JJ such) (NN activation))))))))))
#     (. .)))
#
# advmod(activate-5, However-1)
# nsubj(activate-5, AII-3)
# aux(activate-5, can-4)
# root(ROOT-0, activate-5)
# det(system-9, the-6)
# amod(nervous-8, sympathetic-7)
# amod(system-9, nervous-8)
# dobj(activate-5, system-9)
# cc(system-9, and-10)
# dobj(activate-5, part-11)
# conj:and(system-9, part-11)
# case(effects-15, of-12)
# det(effects-15, the-13)
# amod(effects-15, beneficial-14)
# nmod:of(part-11, effects-15)
# case(inhibitors-18, of-16)
# compound(inhibitors-18, ACE-17)
# nmod:of(effects-15, inhibitors-18)
# cc(activate-5, and-19)
# compound(antagonists-21, AII-20)
# nsubj(result-23, antagonists-21)
# aux(result-23, may-22)
# conj:and(activate-5, result-23)
# case(ability-26, from-24)
# nmod:poss(ability-26, their-25)
# nmod:from(result-23, ability-26)
# mark(inhibit-28, to-27)
# acl(ability-26, inhibit-28)
# amod(activation-30, such-29)
# dobj(inhibit-28, activation-30)
#
# Parsing [sent. 6 len. 49]: We examined the acute effects of the ACE inhibitor captopril -LRB- 25 mg , n = 9 -RRB- and the AII receptor antagonist losartan -LRB- 50 mg , n = 10 -RRB- on hemodynamics as well as total body and cardiac norepinephrine spillover in patients with chronic HFrEF .
# (ROOT
#   (S
#     (NP (PRP We))
#     (VP (VBD examined)
#       (NP
#         (NP (DT the) (JJ acute) (NNS effects))
#         (PP (IN of)
#           (NP
#             (NP (DT the) (NNP ACE) (NN inhibitor) (NN captopril))
#             (PRN (-LRB- -LRB-)
#               (NP
#                 (NP (CD 25) (NN mg))
#                 (, ,)
#                 (NP
#                   (NP (NN n))
#                   (SBAR
#                     (S
#                       (VP (SYM =)
#                         (NP (CD 9)))))))
#               (-RRB- -RRB-))
#             (CC and)
#             (NP (DT the) (NNP AII) (NN receptor) (NN antagonist) (NN losartan))
#             (PRN (-LRB- -LRB-)
#               (NP
#                 (NP (CD 50) (NN mg))
#                 (, ,)
#                 (NP
#                   (NP (NN n))
#                   (SBAR
#                     (S
#                       (VP (SYM =)
#                         (NP (CD 10)))))))
#               (-RRB- -RRB-)))))
#       (PP (IN on)
#         (NP
#           (NP (NNS hemodynamics))
#           (CONJP (RB as) (RB well) (IN as))
#           (NP (JJ total) (NN body)
#             (CC and)
#             (JJ cardiac) (NN norepinephrine) (NN spillover))))
#       (PP (IN in)
#         (NP
#           (NP (NNS patients))
#           (PP (IN with)
#             (NP (JJ chronic) (NNP HFrEF))))))
#     (. .)))
#
# nsubj(examined-2, We-1)
# root(ROOT-0, examined-2)
# det(effects-5, the-3)
# amod(effects-5, acute-4)
# dobj(examined-2, effects-5)
# case(captopril-10, of-6)
# det(captopril-10, the-7)
# compound(captopril-10, ACE-8)
# compound(captopril-10, inhibitor-9)
# nmod:of(effects-5, captopril-10)
# nummod(mg-13, 25-12)
# dep(captopril-10, mg-13)
# appos(mg-13, n-15)
# dep(9-17, =-16)
# acl:relcl(n-15, 9-17)
# cc(captopril-10, and-19)
# det(losartan-24, the-20)
# compound(losartan-24, AII-21)
# compound(losartan-24, receptor-22)
# compound(losartan-24, antagonist-23)
# nmod:of(effects-5, losartan-24)
# conj:and(captopril-10, losartan-24)
# nummod(mg-27, 50-26)
# dep(captopril-10, mg-27)
# appos(mg-27, n-29)
# dep(10-31, =-30)
# acl:relcl(n-29, 10-31)
# case(hemodynamics-34, on-33)
# nmod:on(examined-2, hemodynamics-34)
# cc(hemodynamics-34, as-35)
# mwe(as-35, well-36)
# mwe(as-35, as-37)
# amod(body-39, total-38)
# nmod:on(examined-2, body-39)
# conj:and(hemodynamics-34, body-39)
# cc(body-39, and-40)
# amod(spillover-43, cardiac-41)
# compound(spillover-43, norepinephrine-42)
# conj:and(hemodynamics-34, spillover-43)
# conj:and(body-39, spillover-43)
# case(patients-45, in-44)
# nmod:in(examined-2, patients-45)
# case(HFrEF-48, with-46)
# amod(HFrEF-48, chronic-47)
# nmod:with(patients-45, HFrEF-48)
#
# Parsing [sent. 7 len. 20]: Hemodynamic and neurochemical measurements were made at baseline and at 1 , 2 and 4 hours after oral dosing .
# (ROOT
#   (S
#     (NP (JJ Hemodynamic)
#       (CC and)
#       (JJ neurochemical) (NNS measurements))
#     (VP (VBD were)
#       (VP (VBN made)
#         (PP
#           (PP (IN at)
#             (NP (NN baseline)))
#           (CC and)
#           (PP (IN at)
#             (NP (CD 1) (, ,) (CD 2)
#               (CC and)
#               (CD 4)))
#           (NP (NNS hours)))
#         (PP (IN after)
#           (NP (JJ oral) (NN dosing)))))
#     (. .)))
#
# amod(measurements-4, Hemodynamic-1)
# cc(Hemodynamic-1, and-2)
# conj:and(Hemodynamic-1, neurochemical-3)
# amod(measurements-4, neurochemical-3)
# nsubjpass(made-6, measurements-4)
# auxpass(made-6, were-5)
# root(ROOT-0, made-6)
# case(baseline-8, at-7)
# nmod:at(hours-16, baseline-8)
# cc(hours-16, and-9)
# case(1-11, at-10)
# nmod(made-6, 1-11)
# conj:and(hours-16, 1-11)
# nummod(1-11, 2-13)
# cc(1-11, and-14)
# conj:and(1-11, 4-15)
# conj:and(hours-16, 4-15)
# nmod(made-6, hours-16)
# case(dosing-19, after-17)
# amod(dosing-19, oral-18)
# nmod:after(made-6, dosing-19)
#
# Parsing [sent. 8 len. 25]: Administration of both drugs caused significant reductions in systemic arterial , cardiac filling and pulmonary artery pressures -LRB- P < 0.05 vs baseline -RRB- .
# (ROOT
#   (S
#     (NP
#       (NP (NNP Administration))
#       (PP (IN of)
#         (NP (DT both) (NNS drugs))))
#     (VP (VBD caused)
#       (NP (JJ significant) (NNS reductions))
#       (PP (IN in)
#         (NP
#           (NP (JJ systemic) (NN arterial))
#           (, ,)
#           (NP (JJ cardiac) (NN filling))
#           (CC and)
#           (NP (JJ pulmonary) (NN artery) (NNS pressures))))
#       (PRN (-LRB- -LRB-)
#         (NP
#           (NP (NNP P) (NNP <))
#           (NP (CD 0.05) (NN vs) (NN baseline)))
#         (-RRB- -RRB-)))
#     (. .)))
#
# nsubj(caused-5, Administration-1)
# case(drugs-4, of-2)
# det(drugs-4, both-3)
# nmod:of(Administration-1, drugs-4)
# root(ROOT-0, caused-5)
# amod(reductions-7, significant-6)
# dobj(caused-5, reductions-7)
# case(arterial-10, in-8)
# amod(arterial-10, systemic-9)
# nmod:in(caused-5, arterial-10)
# amod(filling-13, cardiac-12)
# nmod:in(caused-5, filling-13)
# conj:and(arterial-10, filling-13)
# cc(arterial-10, and-14)
# amod(pressures-17, pulmonary-15)
# compound(pressures-17, artery-16)
# nmod:in(caused-5, pressures-17)
# conj:and(arterial-10, pressures-17)
# compound(<-20, P-19)
# dep(caused-5, <-20)
# nummod(baseline-23, 0.05-21)
# compound(baseline-23, vs-22)
# dep(<-20, baseline-23)
#
# Parsing [sent. 9 len. 13]: There was no significant difference in the magnitude of those hemodynamic effects .
# (ROOT
#   (S
#     (NP (EX There))
#     (VP (VBD was)
#       (NP
#         (NP (DT no) (JJ significant) (NN difference))
#         (PP (IN in)
#           (NP
#             (NP (DT the) (NN magnitude))
#             (PP (IN of)
#               (NP (DT those) (JJ hemodynamic) (NNS effects)))))))
#     (. .)))
#
# expl(was-2, There-1)
# root(ROOT-0, was-2)
# neg(difference-5, no-3)
# amod(difference-5, significant-4)
# nsubj(was-2, difference-5)
# case(magnitude-8, in-6)
# det(magnitude-8, the-7)
# nmod:in(difference-5, magnitude-8)
# case(effects-12, of-9)
# det(effects-12, those-10)
# amod(effects-12, hemodynamic-11)
# nmod:of(magnitude-8, effects-12)
#
# Parsing [sent. 10 len. 23]: Plasma concentrations of AII were significantly decreased by captopril and increased by losartan -LRB- P < 0.05 vs baseline for both -RRB- .
# (ROOT
#   (S
#     (NP
#       (NP (NNP Plasma) (NNS concentrations))
#       (PP (IN of)
#         (NP (NNP AII))))
#     (VP (VBD were)
#       (ADVP (RB significantly))
#       (VP
#         (VP (VBN decreased)
#           (PP (IN by)
#             (NP (NN captopril))))
#         (CC and)
#         (VP (VBN increased)
#           (PP (IN by)
#             (NP
#               (NP (NN losartan))
#               (PRN (-LRB- -LRB-)
#                 (NP
#                   (NP (NNP P) (NNP <))
#                   (NP
#                     (NP (CD 0.05) (NN vs) (NN baseline))
#                     (PP (IN for)
#                       (NP (DT both)))))
#                 (-RRB- -RRB-)))))))
#     (. .)))
#
# compound(concentrations-2, Plasma-1)
# nsubjpass(decreased-7, concentrations-2)
# nsubjpass(increased-11, concentrations-2)
# case(AII-4, of-3)
# nmod:of(concentrations-2, AII-4)
# auxpass(decreased-7, were-5)
# advmod(decreased-7, significantly-6)
# root(ROOT-0, decreased-7)
# case(captopril-9, by-8)
# nmod:by(decreased-7, captopril-9)
# cc(decreased-7, and-10)
# conj:and(decreased-7, increased-11)
# case(losartan-13, by-12)
# nmod:by(increased-11, losartan-13)
# compound(<-16, P-15)
# dep(losartan-13, <-16)
# nummod(baseline-19, 0.05-17)
# compound(baseline-19, vs-18)
# dep(<-16, baseline-19)
# case(both-21, for-20)
# nmod:for(baseline-19, both-21)
#
# Parsing [sent. 11 len. 37]: Total body sympathetic activity increased in response to both captopril and losartan -LRB- P < 0.05 vs baseline for both -RRB- , however there was no change in cardiac sympathetic activity in response to either drug .
# (ROOT
#   (S
#     (NP
#       (NP (JJ Total) (NN body) (JJ sympathetic) (NN activity))
#       (VP (VBN increased)
#         (PP (IN in)
#           (NP (NN response)))
#         (PP (TO to)
#           (NP
#             (NP (DT both) (NN captopril)
#               (CC and)
#               (NN losartan))
#             (PRN (-LRB- -LRB-)
#               (NP
#                 (NP (NNP P) (NNP <))
#                 (NP
#                   (NP (CD 0.05) (NN vs) (NN baseline))
#                   (PP (IN for)
#                     (NP (DT both)))))
#               (-RRB- -RRB-))))))
#     (, ,)
#     (ADVP (RB however))
#     (NP (EX there))
#     (VP (VBD was)
#       (NP
#         (NP (DT no) (NN change))
#         (PP (IN in)
#           (NP
#             (NP (JJ cardiac) (JJ sympathetic) (NN activity))
#             (PP (IN in)
#               (NP (NN response))))))
#       (PP (TO to)
#         (NP (DT either) (NN drug))))
#     (. .)))
#
# amod(activity-4, Total-1)
# compound(activity-4, body-2)
# amod(activity-4, sympathetic-3)
# nsubj(was-25, activity-4)
# acl(activity-4, increased-5)
# case(response-7, in-6)
# nmod:in(increased-5, response-7)
# case(captopril-10, to-8)
# cc:preconj(captopril-10, both-9)
# nmod:to(increased-5, captopril-10)
# cc(captopril-10, and-11)
# nmod:to(increased-5, losartan-12)
# conj:and(captopril-10, losartan-12)
# compound(<-15, P-14)
# dep(captopril-10, <-15)
# nummod(baseline-18, 0.05-16)
# compound(baseline-18, vs-17)
# dep(<-15, baseline-18)
# case(both-20, for-19)
# nmod:for(baseline-18, both-20)
# expl(was-25, however-23)
# dep(however-23, there-24)
# root(ROOT-0, was-25)
# neg(change-27, no-26)
# nsubj(was-25, change-27)
# case(activity-31, in-28)
# amod(activity-31, cardiac-29)
# amod(activity-31, sympathetic-30)
# nmod:in(change-27, activity-31)
# case(response-33, in-32)
# nmod:in(activity-31, response-33)
# case(drug-36, to-34)
# det(drug-36, either-35)
# nmod:to(was-25, drug-36)
#
# Parsing [sent. 12 len. 29]: The results of the current study do not support the hypothesis that the acute inhibition of the renin angiotensin system has sympathoinhibitory effects in patients with chronic HFrEF .
# (ROOT
#   (S
#     (NP
#       (NP (DT The) (NNS results))
#       (PP (IN of)
#         (NP (DT the) (JJ current) (NN study))))
#     (VP (VBP do) (RB not)
#       (VP (VB support)
#         (NP (DT the) (NNS hypothesis))
#         (SBAR (IN that)
#           (S
#             (NP
#               (NP (DT the) (JJ acute) (NN inhibition))
#               (PP (IN of)
#                 (NP (DT the) (NN renin) (NN angiotensin) (NN system))))
#             (VP (VBZ has)
#               (NP
#                 (NP (JJ sympathoinhibitory) (NNS effects))
#                 (PP (IN in)
#                   (NP
#                     (NP (NNS patients))
#                     (PP (IN with)
#                       (NP (JJ chronic) (NNP HFrEF)))))))))))
#     (. .)))
#
# det(results-2, The-1)
# nsubj(support-9, results-2)
# case(study-6, of-3)
# det(study-6, the-4)
# amod(study-6, current-5)
# nmod:of(results-2, study-6)
# aux(support-9, do-7)
# neg(support-9, not-8)
# root(ROOT-0, support-9)
# det(hypothesis-11, the-10)
# dobj(support-9, hypothesis-11)
# mark(has-21, that-12)
# det(inhibition-15, the-13)
# amod(inhibition-15, acute-14)
# nsubj(has-21, inhibition-15)
# case(system-20, of-16)
# det(system-20, the-17)
# compound(system-20, renin-18)
# compound(system-20, angiotensin-19)
# nmod:of(inhibition-15, system-20)
# ccomp(support-9, has-21)
# amod(effects-23, sympathoinhibitory-22)
# dobj(has-21, effects-23)
# case(patients-25, in-24)
# nmod:in(effects-23, patients-25)
# case(HFrEF-28, with-26)
# amod(HFrEF-28, chronic-27)
# nmod:with(patients-25, HFrEF-28)
#
# Parsed file: KeywordSentences.txt [12 sentences].
# Parsed 408 words in 12 sentences (44.31 wds/sec; 1.30 sents/sec).
# 1 loop, best of 3: 9.81 s per loop

# %% [markdown]
# ## Testing with RNN Model

# %%
# !cat ./lexparser_rnn.sh
# Out:
# #!/usr/bin/env bash
# #
# # Runs the English PCFG parser on one or more files, printing trees only
#
# if [ ! $# -ge 1 ]; then
#   echo Usage: `basename $0` 'file(s)'
#   echo
#   exit
# fi
#
# scriptdir=`dirname $0`
#
# java -mx500m -cp "$scriptdir/*:" edu.stanford.nlp.parser.lexparser.LexicalizedParser \
#  -outputFormat "penn,typedDependencies" edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz $*

# %%
# %%timeit
! ./lexparser_rnn.sh  KeywordSentences.txt
# Out:
# [main] INFO edu.stanford.nlp.parser.lexparser.LexicalizedParser - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ... done [0.5 sec].
# Parsing file: KeywordSentences.txt
# Parsed file: KeywordSentences.txt [0 sentences].
# Parsed 0 words in 0 sentences (0.00 wds/sec; 0.00 sents/sec).
# [main] INFO edu.stanford.nlp.parser.lexparser.LexicalizedParser - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ... done [0.5 sec].
# Parsing file: KeywordSentences.txt
# Parsed file: KeywordSentences.txt [0 sentences].
# Parsed 0 words in 0 sentences (0.00 wds/sec; 0.00 sents/sec).
# [main] INFO edu.stanford.nlp.parser.lexparser.LexicalizedParser - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ... done [0.5 sec].
# Parsing file: KeywordSentences.txt
# Parsed file: KeywordSentences.txt [0 sentences].
# Parsed 0 words in 0 sentences (0.00 wds/sec; 0.00 sents/sec).
# [main] INFO edu.stanford.nlp.parser.lexparser.LexicalizedParser - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ... done [0.5 sec].
# Parsing file: KeywordSentences.txt
# Parsed file: KeywordSentences.txt [0 sentences].
# Parsed 0 words in 0 sentences (0.00 wds/sec; 0.00 sents/sec).
# 1 loop, best of 3: 989 ms per loop

# %% [markdown]
# ## Test with Caseless PCFG  Model

# %%
# !cat ./lexparser_caseless.sh
# Out:
# #!/usr/bin/env bash
# #
# # Runs the English PCFG parser on one or more files, printing trees only
#
# if [ ! $# -ge 1 ]; then
#   echo Usage: `basename $0` 'file(s)'
#   echo
#   exit
# fi
#
# scriptdir=`dirname $0`
#
# java -mx500m -cp "$scriptdir/*:" edu.stanford.nlp.parser.lexparser.LexicalizedParser \
#  -outputFormat "penn,typedDependencies" edu/stanford/nlp/models/lexparser/englishPCFG.caseless.ser.gz $*

# %%
# %%timeit
! ./lexparser_caseless.sh  KeywordSentences.txt
# Out:
# [main] INFO edu.stanford.nlp.parser.lexparser.LexicalizedParser - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.caseless.ser.gz ... done [0.5 sec].
# Parsing file: KeywordSentences.txt
# Parsed file: KeywordSentences.txt [0 sentences].
# Parsed 0 words in 0 sentences (0.00 wds/sec; 0.00 sents/sec).
# [main] INFO edu.stanford.nlp.parser.lexparser.LexicalizedParser - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.caseless.ser.gz ... done [0.5 sec].
# Parsing file: KeywordSentences.txt
# Parsed file: KeywordSentences.txt [0 sentences].
# Parsed 0 words in 0 sentences (0.00 wds/sec; 0.00 sents/sec).
# [main] INFO edu.stanford.nlp.parser.lexparser.LexicalizedParser - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.caseless.ser.gz ... done [0.6 sec].
# Parsing file: KeywordSentences.txt
# Parsed file: KeywordSentences.txt [0 sentences].
# Parsed 0 words in 0 sentences (0.00 wds/sec; 0.00 sents/sec).
# [main] INFO edu.stanford.nlp.parser.lexparser.LexicalizedParser - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.caseless.ser.gz ... done [0.5 sec].
# Parsing file: KeywordSentences.txt
# Parsed file: KeywordSentences.txt [0 sentences].
# Parsed 0 words in 0 sentences (0.00 wds/sec; 0.00 sents/sec).
# 1 loop, best of 3: 1.03 s per loop

# %% [markdown]
# ## Command Line Sentiment Analysis
#
# This creates an output file with tuples and sentiments! We can modify which annotators we use. I think maybe just the sentiment and the ner is all we need.

# %%
# !java -cp "*" -Xmx2g edu.stanford.nlp.pipeline.StanfordCoreNLP -annotators tokenize,ssplit,pos,lemma,ner,parse,dcoref,sentiment -file KeywordSentences.txt -outputFormat text
# Out:
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator pos
# [main] INFO edu.stanford.nlp.tagger.maxent.MaxentTagger - Loading POS tagger from edu/stanford/nlp/models/pos-tagger/english-left3words/english-left3words-distsim.tagger ... done [0.8 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [2.2 sec].
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [1.3 sec].
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.6 sec].
# [main] INFO edu.stanford.nlp.time.JollyDayHolidays - Initializing JollyDayHoliday for SUTime from classpath edu/stanford/nlp/models/sutime/jollyday/Holidays_sutime.xml as sutime.binder.1.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ... done [0.6 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator dcoref
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator sentiment
#
# Processing file /home/adam/Documents/MIDS/W266/Project/parsing/KeywordSentences.txt ... writing to /home/adam/Documents/MIDS/W266/Project/parsing/KeywordSentences.txt.out
# Annotating file /home/adam/Documents/MIDS/W266/Project/parsing/KeywordSentences.txt ... done [0.1 sec].
#
# Annotation pipeline timing information:
# TokenizerAnnotator: 0.1 sec.
# WordsToSentencesAnnotator: 0.0 sec.
# POSTaggerAnnotator: 0.0 sec.
# MorphaAnnotator: 0.0 sec.
# NERCombinerAnnotator: 0.0 sec.
# ParserAnnotator: 0.0 sec.
# DeterministicCorefAnnotator: 0.0 sec.
# SentimentAnnotator: 0.0 sec.
# TOTAL: 0.1 sec. for 0 tokens at 0.0 tokens/sec.
# Pipeline setup: 7.5 sec.
# Total time for StanfordCoreNLP pipeline: 7.6 sec.

# %%
# !cat *.out >> output_file.json

# %%
# !cat output_file.json

# %% [markdown]
# ## Sentences of note:
#
# `Plasma concentrations of AII were significantly decreased by captopril and increased by losartan`.
# `nmod:of(concentrations-2, AII-4)`
# `nmod:agent(decreased-7, captopril-9)`
# `nmod:by(increased-11, losartan-13)`

# %% [markdown]
# ## Experimenting with Selected Abstracts

# %%
#From <https://www.ncbi.nlm.nih.gov/pubmed/28656517>

# !echo "Renin-angiotensin-aldosterone system (RAAS) antagonists, including angiotensin-converting enzyme inhibitors (ACEI), angiotensin receptor blockers (ARB), and mineralocorticoid receptor antagonists (MRA) decrease mortality and morbidity in heart failure but increase the risk of hyperkalemia, especially when used in combination. Prevention of hyperkalemia and its associated complications requires careful patient selection, counseling regarding dietary potassium intake, awareness of drug interactions, and regular laboratory surveillance. Recent data suggests that the risk of hyperkalemia may be further moderated through the use of combined angiotensin-neprilysin inhibitors, novel MRAs, and novel potassium binding agents. Clinicians should be mindful of the risk of hyperkalemia when prescribing RAAS inhibitors to patients with heart failure. In patients at highest risk, such as those with diabetes, the elderly, and advanced chronic kidney disease, more intensive laboratory surveillance of potassium and creatinine may be required. Novel therapies hold promise for reducing the risk of hyperkalemia and enhancing the tolerability of RAAS antagonists." > sample_abstract.txt

# %%
# !head sample_abstract.txt
# Out:
# Renin-angiotensin-aldosterone system (RAAS) antagonists, including angiotensin-converting enzyme inhibitors (ACEI), angiotensin receptor blockers (ARB), and mineralocorticoid receptor antagonists (MRA) decrease mortality and morbidity in heart failure but increase the risk of hyperkalemia, especially when used in combination. Prevention of hyperkalemia and its associated complications requires careful patient selection, counseling regarding dietary potassium intake, awareness of drug interactions, and regular laboratory surveillance. Recent data suggests that the risk of hyperkalemia may be further moderated through the use of combined angiotensin-neprilysin inhibitors, novel MRAs, and novel potassium binding agents. Clinicians should be mindful of the risk of hyperkalemia when prescribing RAAS inhibitors to patients with heart failure. In patients at highest risk, such as those with diabetes, the elderly, and advanced chronic kidney disease, more intensive laboratory surveillance of potassium and creatinine may be required. Novel therapies hold promise for reducing the risk of hyperkalemia and enhancing the tolerability of RAAS antagonists.

# %%
# !java -cp "*" -Xmx2g edu.stanford.nlp.pipeline.StanfordCoreNLP -annotators tokenize,ssplit,pos,lemma,ner,parse,dcoref,sentiment -file sample_abstract.txt -outputFormat text
# Out:
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator pos
# [main] INFO edu.stanford.nlp.tagger.maxent.MaxentTagger - Loading POS tagger from edu/stanford/nlp/models/pos-tagger/english-left3words/english-left3words-distsim.tagger ... done [1.4 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [2.2 sec].
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [1.8 sec].
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.8 sec].
# [main] INFO edu.stanford.nlp.time.JollyDayHolidays - Initializing JollyDayHoliday for SUTime from classpath edu/stanford/nlp/models/sutime/jollyday/Holidays_sutime.xml as sutime.binder.1.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ... done [0.4 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator dcoref
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator sentiment
#
# Processing file /Users/lisabarcelo/Desktop/W266/food_drug_interaction/drafts/sample_abstract.txt ... writing to /Users/lisabarcelo/Desktop/W266/food_drug_interaction/drafts/sample_abstract.txt.out
# Annotating file /Users/lisabarcelo/Desktop/W266/food_drug_interaction/drafts/sample_abstract.txt ... done [6.7 sec].
#
# Annotation pipeline timing information:
# TokenizerAnnotator: 0.2 sec.
# WordsToSentencesAnnotator: 0.0 sec.
# POSTaggerAnnotator: 0.1 sec.
# MorphaAnnotator: 0.1 sec.
# NERCombinerAnnotator: 0.7 sec.
# ParserAnnotator: 5.1 sec.
# DeterministicCorefAnnotator: 0.3 sec.
# SentimentAnnotator: 0.2 sec.
# TOTAL: 6.7 sec. for 176 tokens at 26.4 tokens/sec.
# Pipeline setup: 11.5 sec.
# Total time for StanfordCoreNLP pipeline: 18.3 sec.

# %%
# !cat sample_abstract.txt.out
# Out:
# Sentence #1 (49 tokens, sentiment: Very negative):
# Renin-angiotensin-aldosterone system (RAAS) antagonists, including angiotensin-converting enzyme inhibitors (ACEI), angiotensin receptor blockers (ARB), and mineralocorticoid receptor antagonists (MRA) decrease mortality and morbidity in heart failure but increase the risk of hyperkalemia, especially when used in combination.
# [Text=Renin-angiotensin-aldosterone CharacterOffsetBegin=0 CharacterOffsetEnd=29 PartOfSpeech=NN Lemma=renin-angiotensin-aldosterone NamedEntityTag=O SentimentClass=Neutral]
# [Text=system CharacterOffsetBegin=30 CharacterOffsetEnd=36 PartOfSpeech=NN Lemma=system NamedEntityTag=O SentimentClass=Neutral]
# [Text=-LRB- CharacterOffsetBegin=37 CharacterOffsetEnd=38 PartOfSpeech=-LRB- Lemma=-lrb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=RAAS CharacterOffsetBegin=38 CharacterOffsetEnd=42 PartOfSpeech=NN Lemma=raas NamedEntityTag=O SentimentClass=Neutral]
# [Text=-RRB- CharacterOffsetBegin=42 CharacterOffsetEnd=43 PartOfSpeech=-RRB- Lemma=-rrb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=antagonists CharacterOffsetBegin=44 CharacterOffsetEnd=55 PartOfSpeech=NNS Lemma=antagonist NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=55 CharacterOffsetEnd=56 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=including CharacterOffsetBegin=57 CharacterOffsetEnd=66 PartOfSpeech=VBG Lemma=include NamedEntityTag=O SentimentClass=Neutral]
# [Text=angiotensin-converting CharacterOffsetBegin=67 CharacterOffsetEnd=89 PartOfSpeech=JJ Lemma=angiotensin-converting NamedEntityTag=O SentimentClass=Neutral]
# [Text=enzyme CharacterOffsetBegin=90 CharacterOffsetEnd=96 PartOfSpeech=NN Lemma=enzyme NamedEntityTag=O SentimentClass=Neutral]
# [Text=inhibitors CharacterOffsetBegin=97 CharacterOffsetEnd=107 PartOfSpeech=NNS Lemma=inhibitor NamedEntityTag=O SentimentClass=Neutral]
# [Text=-LRB- CharacterOffsetBegin=108 CharacterOffsetEnd=109 PartOfSpeech=-LRB- Lemma=-lrb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=ACEI CharacterOffsetBegin=109 CharacterOffsetEnd=113 PartOfSpeech=NN Lemma=acei NamedEntityTag=O SentimentClass=Neutral]
# [Text=-RRB- CharacterOffsetBegin=113 CharacterOffsetEnd=114 PartOfSpeech=-RRB- Lemma=-rrb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=114 CharacterOffsetEnd=115 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=angiotensin CharacterOffsetBegin=116 CharacterOffsetEnd=127 PartOfSpeech=NN Lemma=angiotensin NamedEntityTag=O SentimentClass=Neutral]
# [Text=receptor CharacterOffsetBegin=128 CharacterOffsetEnd=136 PartOfSpeech=NN Lemma=receptor NamedEntityTag=O SentimentClass=Neutral]
# [Text=blockers CharacterOffsetBegin=137 CharacterOffsetEnd=145 PartOfSpeech=NNS Lemma=blocker NamedEntityTag=O SentimentClass=Neutral]
# [Text=-LRB- CharacterOffsetBegin=146 CharacterOffsetEnd=147 PartOfSpeech=-LRB- Lemma=-lrb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=ARB CharacterOffsetBegin=147 CharacterOffsetEnd=150 PartOfSpeech=NN Lemma=arb NamedEntityTag=O SentimentClass=Neutral]
# [Text=-RRB- CharacterOffsetBegin=150 CharacterOffsetEnd=151 PartOfSpeech=-RRB- Lemma=-rrb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=151 CharacterOffsetEnd=152 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=and CharacterOffsetBegin=153 CharacterOffsetEnd=156 PartOfSpeech=CC Lemma=and NamedEntityTag=O SentimentClass=Neutral]
# [Text=mineralocorticoid CharacterOffsetBegin=157 CharacterOffsetEnd=174 PartOfSpeech=NN Lemma=mineralocorticoid NamedEntityTag=O SentimentClass=Neutral]
# [Text=receptor CharacterOffsetBegin=175 CharacterOffsetEnd=183 PartOfSpeech=NN Lemma=receptor NamedEntityTag=O SentimentClass=Neutral]
# [Text=antagonists CharacterOffsetBegin=184 CharacterOffsetEnd=195 PartOfSpeech=NNS Lemma=antagonist NamedEntityTag=O SentimentClass=Neutral]
# [Text=-LRB- CharacterOffsetBegin=196 CharacterOffsetEnd=197 PartOfSpeech=-LRB- Lemma=-lrb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=MRA CharacterOffsetBegin=197 CharacterOffsetEnd=200 PartOfSpeech=NN Lemma=mra NamedEntityTag=ORGANIZATION SentimentClass=Neutral]
# [Text=-RRB- CharacterOffsetBegin=200 CharacterOffsetEnd=201 PartOfSpeech=-RRB- Lemma=-rrb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=decrease CharacterOffsetBegin=202 CharacterOffsetEnd=210 PartOfSpeech=NN Lemma=decrease NamedEntityTag=O SentimentClass=Neutral]
# [Text=mortality CharacterOffsetBegin=211 CharacterOffsetEnd=220 PartOfSpeech=NN Lemma=mortality NamedEntityTag=O SentimentClass=Neutral]
# [Text=and CharacterOffsetBegin=221 CharacterOffsetEnd=224 PartOfSpeech=CC Lemma=and NamedEntityTag=O SentimentClass=Neutral]
# [Text=morbidity CharacterOffsetBegin=225 CharacterOffsetEnd=234 PartOfSpeech=NN Lemma=morbidity NamedEntityTag=O SentimentClass=Neutral]
# [Text=in CharacterOffsetBegin=235 CharacterOffsetEnd=237 PartOfSpeech=IN Lemma=in NamedEntityTag=O SentimentClass=Neutral]
# [Text=heart CharacterOffsetBegin=238 CharacterOffsetEnd=243 PartOfSpeech=NN Lemma=heart NamedEntityTag=O SentimentClass=Neutral]
# [Text=failure CharacterOffsetBegin=244 CharacterOffsetEnd=251 PartOfSpeech=NN Lemma=failure NamedEntityTag=O SentimentClass=Very negative]
# [Text=but CharacterOffsetBegin=252 CharacterOffsetEnd=255 PartOfSpeech=CC Lemma=but NamedEntityTag=O SentimentClass=Neutral]
# [Text=increase CharacterOffsetBegin=256 CharacterOffsetEnd=264 PartOfSpeech=VBP Lemma=increase NamedEntityTag=O SentimentClass=Neutral]
# [Text=the CharacterOffsetBegin=265 CharacterOffsetEnd=268 PartOfSpeech=DT Lemma=the NamedEntityTag=O SentimentClass=Neutral]
# [Text=risk CharacterOffsetBegin=269 CharacterOffsetEnd=273 PartOfSpeech=NN Lemma=risk NamedEntityTag=O SentimentClass=Neutral]
# [Text=of CharacterOffsetBegin=274 CharacterOffsetEnd=276 PartOfSpeech=IN Lemma=of NamedEntityTag=O SentimentClass=Neutral]
# [Text=hyperkalemia CharacterOffsetBegin=277 CharacterOffsetEnd=289 PartOfSpeech=NN Lemma=hyperkalemia NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=289 CharacterOffsetEnd=290 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=especially CharacterOffsetBegin=291 CharacterOffsetEnd=301 PartOfSpeech=RB Lemma=especially NamedEntityTag=O SentimentClass=Neutral]
# [Text=when CharacterOffsetBegin=302 CharacterOffsetEnd=306 PartOfSpeech=WRB Lemma=when NamedEntityTag=O SentimentClass=Neutral]
# [Text=used CharacterOffsetBegin=307 CharacterOffsetEnd=311 PartOfSpeech=VBN Lemma=use NamedEntityTag=O SentimentClass=Neutral]
# [Text=in CharacterOffsetBegin=312 CharacterOffsetEnd=314 PartOfSpeech=IN Lemma=in NamedEntityTag=O SentimentClass=Neutral]
# [Text=combination CharacterOffsetBegin=315 CharacterOffsetEnd=326 PartOfSpeech=NN Lemma=combination NamedEntityTag=O SentimentClass=Neutral]
# [Text=. CharacterOffsetBegin=326 CharacterOffsetEnd=327 PartOfSpeech=. Lemma=. NamedEntityTag=O SentimentClass=Neutral]
# (ROOT
#   (NP
#     (NP
#       (NP (NN Renin-angiotensin-aldosterone) (NN system))
#       (PRN (-LRB- -LRB-)
#         (NP (NN RAAS))
#         (-RRB- -RRB-)))
#     (NP
#       (NP
#         (NP
#           (NP (NNS antagonists))
#           (, ,)
#           (PP (VBG including)
#             (NP (JJ angiotensin-converting) (NN enzyme) (NNS inhibitors))))
#         (PRN (-LRB- -LRB-)
#           (NP (NN ACEI))
#           (-RRB- -RRB-)))
#       (, ,)
#       (NP
#         (NP (NN angiotensin) (NN receptor) (NNS blockers))
#         (PRN (-LRB- -LRB-)
#           (NP (NN ARB))
#           (-RRB- -RRB-)))
#       (, ,)
#       (CC and)
#       (NP
#         (NP (NN mineralocorticoid) (NN receptor) (NNS antagonists))
#         (PRN (-LRB- -LRB-)
#           (NP (NN MRA))
#           (-RRB- -RRB-))
#         (SBAR
#           (S
#             (NP
#               (NP (NN decrease) (NN mortality)
#                 (CC and)
#                 (NN morbidity))
#               (PP (IN in)
#                 (NP (NN heart) (NN failure))))
#             (ADVP (CC but))
#             (VP (VBP increase)
#               (NP
#                 (NP (DT the) (NN risk))
#                 (PP (IN of)
#                   (NP (NN hyperkalemia))))
#               (, ,)
#               (SBAR
#                 (WHADVP (RB especially) (WRB when))
#                 (S
#                   (VP (VBN used)
#                     (PP (IN in)
#                       (NP (NN combination)))))))))))
#     (. .)))
#
# root(ROOT-0, system-2)
# compound(system-2, Renin-angiotensin-aldosterone-1)
# punct(RAAS-4, -LRB--3)
# appos(system-2, RAAS-4)
# punct(RAAS-4, -RRB--5)
# dep(system-2, antagonists-6)
# punct(antagonists-6, ,-7)
# case(inhibitors-11, including-8)
# amod(inhibitors-11, angiotensin-converting-9)
# compound(inhibitors-11, enzyme-10)
# nmod:including(antagonists-6, inhibitors-11)
# punct(ACEI-13, -LRB--12)
# appos(antagonists-6, ACEI-13)
# punct(ACEI-13, -RRB--14)
# punct(antagonists-6, ,-15)
# compound(blockers-18, angiotensin-16)
# compound(blockers-18, receptor-17)
# dep(system-2, blockers-18)
# conj:and(antagonists-6, blockers-18)
# punct(ARB-20, -LRB--19)
# appos(blockers-18, ARB-20)
# punct(ARB-20, -RRB--21)
# punct(antagonists-6, ,-22)
# cc(antagonists-6, and-23)
# compound(antagonists-26, mineralocorticoid-24)
# compound(antagonists-26, receptor-25)
# dep(system-2, antagonists-26)
# conj:and(antagonists-6, antagonists-26)
# punct(MRA-28, -LRB--27)
# appos(antagonists-26, MRA-28)
# punct(MRA-28, -RRB--29)
# compound(mortality-31, decrease-30)
# nsubj(increase-38, mortality-31)
# cc(mortality-31, and-32)
# conj:and(mortality-31, morbidity-33)
# nsubj(increase-38, morbidity-33)
# case(failure-36, in-34)
# compound(failure-36, heart-35)
# nmod:in(mortality-31, failure-36)
# advmod(increase-38, but-37)
# acl:relcl(antagonists-26, increase-38)
# det(risk-40, the-39)
# dobj(increase-38, risk-40)
# case(hyperkalemia-42, of-41)
# nmod:of(risk-40, hyperkalemia-42)
# punct(increase-38, ,-43)
# advmod(when-45, especially-44)
# advmod(used-46, when-45)
# advcl(increase-38, used-46)
# case(combination-48, in-47)
# nmod:in(used-46, combination-48)
# punct(system-2, .-49)
#
# Sentence #2 (28 tokens, sentiment: Negative):
# Prevention of hyperkalemia and its associated complications requires careful patient selection, counseling regarding dietary potassium intake, awareness of drug interactions, and regular laboratory surveillance.
# [Text=Prevention CharacterOffsetBegin=328 CharacterOffsetEnd=338 PartOfSpeech=NNP Lemma=Prevention NamedEntityTag=O SentimentClass=Neutral]
# [Text=of CharacterOffsetBegin=339 CharacterOffsetEnd=341 PartOfSpeech=IN Lemma=of NamedEntityTag=O SentimentClass=Neutral]
# [Text=hyperkalemia CharacterOffsetBegin=342 CharacterOffsetEnd=354 PartOfSpeech=NN Lemma=hyperkalemia NamedEntityTag=O SentimentClass=Neutral]
# [Text=and CharacterOffsetBegin=355 CharacterOffsetEnd=358 PartOfSpeech=CC Lemma=and NamedEntityTag=O SentimentClass=Neutral]
# [Text=its CharacterOffsetBegin=359 CharacterOffsetEnd=362 PartOfSpeech=PRP$ Lemma=its NamedEntityTag=O SentimentClass=Neutral]
# [Text=associated CharacterOffsetBegin=363 CharacterOffsetEnd=373 PartOfSpeech=VBN Lemma=associate NamedEntityTag=O SentimentClass=Neutral]
# [Text=complications CharacterOffsetBegin=374 CharacterOffsetEnd=387 PartOfSpeech=NNS Lemma=complication NamedEntityTag=O SentimentClass=Negative]
# [Text=requires CharacterOffsetBegin=388 CharacterOffsetEnd=396 PartOfSpeech=VBZ Lemma=require NamedEntityTag=O SentimentClass=Neutral]
# [Text=careful CharacterOffsetBegin=397 CharacterOffsetEnd=404 PartOfSpeech=JJ Lemma=careful NamedEntityTag=O SentimentClass=Neutral]
# [Text=patient CharacterOffsetBegin=405 CharacterOffsetEnd=412 PartOfSpeech=NN Lemma=patient NamedEntityTag=O SentimentClass=Neutral]
# [Text=selection CharacterOffsetBegin=413 CharacterOffsetEnd=422 PartOfSpeech=NN Lemma=selection NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=422 CharacterOffsetEnd=423 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=counseling CharacterOffsetBegin=424 CharacterOffsetEnd=434 PartOfSpeech=VBG Lemma=counsel NamedEntityTag=O SentimentClass=Neutral]
# [Text=regarding CharacterOffsetBegin=435 CharacterOffsetEnd=444 PartOfSpeech=VBG Lemma=regard NamedEntityTag=O SentimentClass=Neutral]
# [Text=dietary CharacterOffsetBegin=445 CharacterOffsetEnd=452 PartOfSpeech=JJ Lemma=dietary NamedEntityTag=O SentimentClass=Neutral]
# [Text=potassium CharacterOffsetBegin=453 CharacterOffsetEnd=462 PartOfSpeech=NN Lemma=potassium NamedEntityTag=O SentimentClass=Neutral]
# [Text=intake CharacterOffsetBegin=463 CharacterOffsetEnd=469 PartOfSpeech=NN Lemma=intake NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=469 CharacterOffsetEnd=470 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=awareness CharacterOffsetBegin=471 CharacterOffsetEnd=480 PartOfSpeech=NN Lemma=awareness NamedEntityTag=O SentimentClass=Neutral]
# [Text=of CharacterOffsetBegin=481 CharacterOffsetEnd=483 PartOfSpeech=IN Lemma=of NamedEntityTag=O SentimentClass=Neutral]
# [Text=drug CharacterOffsetBegin=484 CharacterOffsetEnd=488 PartOfSpeech=NN Lemma=drug NamedEntityTag=O SentimentClass=Neutral]
# [Text=interactions CharacterOffsetBegin=489 CharacterOffsetEnd=501 PartOfSpeech=NNS Lemma=interaction NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=501 CharacterOffsetEnd=502 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=and CharacterOffsetBegin=503 CharacterOffsetEnd=506 PartOfSpeech=CC Lemma=and NamedEntityTag=O SentimentClass=Neutral]
# [Text=regular CharacterOffsetBegin=507 CharacterOffsetEnd=514 PartOfSpeech=JJ Lemma=regular NamedEntityTag=O SentimentClass=Neutral]
# [Text=laboratory CharacterOffsetBegin=515 CharacterOffsetEnd=525 PartOfSpeech=NN Lemma=laboratory NamedEntityTag=O SentimentClass=Neutral]
# [Text=surveillance CharacterOffsetBegin=526 CharacterOffsetEnd=538 PartOfSpeech=NN Lemma=surveillance NamedEntityTag=O SentimentClass=Neutral]
# [Text=. CharacterOffsetBegin=538 CharacterOffsetEnd=539 PartOfSpeech=. Lemma=. NamedEntityTag=O SentimentClass=Neutral]
# (ROOT
#   (S
#     (NP
#       (NP (NNP Prevention))
#       (PP (IN of)
#         (NP
#           (NP (NN hyperkalemia))
#           (CC and)
#           (NP (PRP$ its) (VBN associated) (NNS complications)))))
#     (VP (VBZ requires)
#       (NP (JJ careful) (NN patient) (NN selection))
#       (, ,)
#       (S
#         (VP (VBG counseling)
#           (PP (VBG regarding)
#             (NP
#               (NP (JJ dietary) (NN potassium) (NN intake))
#               (, ,)
#               (NP
#                 (NP (NN awareness))
#                 (PP (IN of)
#                   (NP (NN drug) (NNS interactions))))
#               (, ,)
#               (CC and)
#               (NP (JJ regular) (NN laboratory) (NN surveillance)))))))
#     (. .)))
#
# root(ROOT-0, requires-8)
# nsubj(requires-8, Prevention-1)
# case(hyperkalemia-3, of-2)
# nmod:of(Prevention-1, hyperkalemia-3)
# cc(hyperkalemia-3, and-4)
# nmod:poss(complications-7, its-5)
# amod(complications-7, associated-6)
# nmod:of(Prevention-1, complications-7)
# conj:and(hyperkalemia-3, complications-7)
# amod(selection-11, careful-9)
# compound(selection-11, patient-10)
# dobj(requires-8, selection-11)
# punct(requires-8, ,-12)
# advcl(requires-8, counseling-13)
# case(intake-17, regarding-14)
# amod(intake-17, dietary-15)
# compound(intake-17, potassium-16)
# nmod:regarding(counseling-13, intake-17)
# punct(intake-17, ,-18)
# nmod:regarding(counseling-13, awareness-19)
# conj:and(intake-17, awareness-19)
# case(interactions-22, of-20)
# compound(interactions-22, drug-21)
# nmod:of(awareness-19, interactions-22)
# punct(intake-17, ,-23)
# cc(intake-17, and-24)
# amod(surveillance-27, regular-25)
# compound(surveillance-27, laboratory-26)
# nmod:regarding(counseling-13, surveillance-27)
# conj:and(intake-17, surveillance-27)
# punct(requires-8, .-28)
#
# Sentence #3 (29 tokens, sentiment: Negative):
# Recent data suggests that the risk of hyperkalemia may be further moderated through the use of combined angiotensin-neprilysin inhibitors, novel MRAs, and novel potassium binding agents.
# [Text=Recent CharacterOffsetBegin=540 CharacterOffsetEnd=546 PartOfSpeech=JJ Lemma=recent NamedEntityTag=O SentimentClass=Neutral]
# [Text=data CharacterOffsetBegin=547 CharacterOffsetEnd=551 PartOfSpeech=NNS Lemma=datum NamedEntityTag=O SentimentClass=Neutral]
# [Text=suggests CharacterOffsetBegin=552 CharacterOffsetEnd=560 PartOfSpeech=VBZ Lemma=suggest NamedEntityTag=O SentimentClass=Neutral]
# [Text=that CharacterOffsetBegin=561 CharacterOffsetEnd=565 PartOfSpeech=IN Lemma=that NamedEntityTag=O SentimentClass=Neutral]
# [Text=the CharacterOffsetBegin=566 CharacterOffsetEnd=569 PartOfSpeech=DT Lemma=the NamedEntityTag=O SentimentClass=Neutral]
# [Text=risk CharacterOffsetBegin=570 CharacterOffsetEnd=574 PartOfSpeech=NN Lemma=risk NamedEntityTag=O SentimentClass=Neutral]
# [Text=of CharacterOffsetBegin=575 CharacterOffsetEnd=577 PartOfSpeech=IN Lemma=of NamedEntityTag=O SentimentClass=Neutral]
# [Text=hyperkalemia CharacterOffsetBegin=578 CharacterOffsetEnd=590 PartOfSpeech=NN Lemma=hyperkalemia NamedEntityTag=O SentimentClass=Neutral]
# [Text=may CharacterOffsetBegin=591 CharacterOffsetEnd=594 PartOfSpeech=MD Lemma=may NamedEntityTag=O SentimentClass=Neutral]
# [Text=be CharacterOffsetBegin=595 CharacterOffsetEnd=597 PartOfSpeech=VB Lemma=be NamedEntityTag=O SentimentClass=Neutral]
# [Text=further CharacterOffsetBegin=598 CharacterOffsetEnd=605 PartOfSpeech=JJ Lemma=further NamedEntityTag=O SentimentClass=Neutral]
# [Text=moderated CharacterOffsetBegin=606 CharacterOffsetEnd=615 PartOfSpeech=VBN Lemma=moderate NamedEntityTag=O SentimentClass=Neutral]
# [Text=through CharacterOffsetBegin=616 CharacterOffsetEnd=623 PartOfSpeech=IN Lemma=through NamedEntityTag=O SentimentClass=Neutral]
# [Text=the CharacterOffsetBegin=624 CharacterOffsetEnd=627 PartOfSpeech=DT Lemma=the NamedEntityTag=O SentimentClass=Neutral]
# [Text=use CharacterOffsetBegin=628 CharacterOffsetEnd=631 PartOfSpeech=NN Lemma=use NamedEntityTag=O SentimentClass=Neutral]
# [Text=of CharacterOffsetBegin=632 CharacterOffsetEnd=634 PartOfSpeech=IN Lemma=of NamedEntityTag=O SentimentClass=Neutral]
# [Text=combined CharacterOffsetBegin=635 CharacterOffsetEnd=643 PartOfSpeech=JJ Lemma=combined NamedEntityTag=O SentimentClass=Neutral]
# [Text=angiotensin-neprilysin CharacterOffsetBegin=644 CharacterOffsetEnd=666 PartOfSpeech=NN Lemma=angiotensin-neprilysin NamedEntityTag=O SentimentClass=Neutral]
# [Text=inhibitors CharacterOffsetBegin=667 CharacterOffsetEnd=677 PartOfSpeech=NNS Lemma=inhibitor NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=677 CharacterOffsetEnd=678 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=novel CharacterOffsetBegin=679 CharacterOffsetEnd=684 PartOfSpeech=JJ Lemma=novel NamedEntityTag=O SentimentClass=Positive]
# [Text=MRAs CharacterOffsetBegin=685 CharacterOffsetEnd=689 PartOfSpeech=NNS Lemma=mra NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=689 CharacterOffsetEnd=690 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=and CharacterOffsetBegin=691 CharacterOffsetEnd=694 PartOfSpeech=CC Lemma=and NamedEntityTag=O SentimentClass=Neutral]
# [Text=novel CharacterOffsetBegin=695 CharacterOffsetEnd=700 PartOfSpeech=JJ Lemma=novel NamedEntityTag=O SentimentClass=Positive]
# [Text=potassium CharacterOffsetBegin=701 CharacterOffsetEnd=710 PartOfSpeech=NN Lemma=potassium NamedEntityTag=O SentimentClass=Neutral]
# [Text=binding CharacterOffsetBegin=711 CharacterOffsetEnd=718 PartOfSpeech=VBG Lemma=bind NamedEntityTag=O SentimentClass=Neutral]
# [Text=agents CharacterOffsetBegin=719 CharacterOffsetEnd=725 PartOfSpeech=NNS Lemma=agent NamedEntityTag=O SentimentClass=Neutral]
# [Text=. CharacterOffsetBegin=725 CharacterOffsetEnd=726 PartOfSpeech=. Lemma=. NamedEntityTag=O SentimentClass=Neutral]
# (ROOT
#   (S
#     (NP (JJ Recent) (NNS data))
#     (VP (VBZ suggests)
#       (SBAR (IN that)
#         (S
#           (NP
#             (NP (DT the) (NN risk))
#             (PP (IN of)
#               (NP (NN hyperkalemia))))
#           (VP (MD may)
#             (VP (VB be)
#               (NP
#                 (NP
#                   (NP (JJ further))
#                   (VP (VBN moderated)
#                     (PP (IN through)
#                       (NP
#                         (NP (DT the) (NN use))
#                         (PP (IN of)
#                           (NP (JJ combined) (NN angiotensin-neprilysin) (NNS inhibitors)))))))
#                 (, ,)
#                 (NP (JJ novel) (NNS MRAs))
#                 (, ,)
#                 (CC and)
#                 (NP
#                   (ADJP (JJ novel))
#                   (NN potassium) (VBG binding) (NNS agents))))))))
#     (. .)))
#
# root(ROOT-0, suggests-3)
# amod(data-2, Recent-1)
# nsubj(suggests-3, data-2)
# mark(further-11, that-4)
# det(risk-6, the-5)
# nsubj(further-11, risk-6)
# case(hyperkalemia-8, of-7)
# nmod:of(risk-6, hyperkalemia-8)
# aux(further-11, may-9)
# cop(further-11, be-10)
# ccomp(suggests-3, further-11)
# acl(further-11, moderated-12)
# case(use-15, through-13)
# det(use-15, the-14)
# nmod:through(moderated-12, use-15)
# case(inhibitors-19, of-16)
# amod(inhibitors-19, combined-17)
# compound(inhibitors-19, angiotensin-neprilysin-18)
# nmod:of(use-15, inhibitors-19)
# punct(further-11, ,-20)
# amod(MRAs-22, novel-21)
# ccomp(suggests-3, MRAs-22)
# conj:and(further-11, MRAs-22)
# punct(further-11, ,-23)
# cc(further-11, and-24)
# amod(agents-28, novel-25)
# compound(agents-28, potassium-26)
# amod(agents-28, binding-27)
# ccomp(suggests-3, agents-28)
# conj:and(further-11, agents-28)
# punct(suggests-3, .-29)
#
# Sentence #4 (19 tokens, sentiment: Negative):
# Clinicians should be mindful of the risk of hyperkalemia when prescribing RAAS inhibitors to patients with heart failure.
# [Text=Clinicians CharacterOffsetBegin=727 CharacterOffsetEnd=737 PartOfSpeech=NNS Lemma=clinician NamedEntityTag=MISC SentimentClass=Neutral]
# [Text=should CharacterOffsetBegin=738 CharacterOffsetEnd=744 PartOfSpeech=MD Lemma=should NamedEntityTag=O SentimentClass=Neutral]
# [Text=be CharacterOffsetBegin=745 CharacterOffsetEnd=747 PartOfSpeech=VB Lemma=be NamedEntityTag=O SentimentClass=Neutral]
# [Text=mindful CharacterOffsetBegin=748 CharacterOffsetEnd=755 PartOfSpeech=JJ Lemma=mindful NamedEntityTag=O SentimentClass=Neutral]
# [Text=of CharacterOffsetBegin=756 CharacterOffsetEnd=758 PartOfSpeech=IN Lemma=of NamedEntityTag=O SentimentClass=Neutral]
# [Text=the CharacterOffsetBegin=759 CharacterOffsetEnd=762 PartOfSpeech=DT Lemma=the NamedEntityTag=O SentimentClass=Neutral]
# [Text=risk CharacterOffsetBegin=763 CharacterOffsetEnd=767 PartOfSpeech=NN Lemma=risk NamedEntityTag=O SentimentClass=Neutral]
# [Text=of CharacterOffsetBegin=768 CharacterOffsetEnd=770 PartOfSpeech=IN Lemma=of NamedEntityTag=O SentimentClass=Neutral]
# [Text=hyperkalemia CharacterOffsetBegin=771 CharacterOffsetEnd=783 PartOfSpeech=NN Lemma=hyperkalemia NamedEntityTag=O SentimentClass=Neutral]
# [Text=when CharacterOffsetBegin=784 CharacterOffsetEnd=788 PartOfSpeech=WRB Lemma=when NamedEntityTag=O SentimentClass=Neutral]
# [Text=prescribing CharacterOffsetBegin=789 CharacterOffsetEnd=800 PartOfSpeech=VBG Lemma=prescribe NamedEntityTag=O SentimentClass=Neutral]
# [Text=RAAS CharacterOffsetBegin=801 CharacterOffsetEnd=805 PartOfSpeech=NN Lemma=raas NamedEntityTag=O SentimentClass=Neutral]
# [Text=inhibitors CharacterOffsetBegin=806 CharacterOffsetEnd=816 PartOfSpeech=NNS Lemma=inhibitor NamedEntityTag=O SentimentClass=Neutral]
# [Text=to CharacterOffsetBegin=817 CharacterOffsetEnd=819 PartOfSpeech=TO Lemma=to NamedEntityTag=O SentimentClass=Neutral]
# [Text=patients CharacterOffsetBegin=820 CharacterOffsetEnd=828 PartOfSpeech=NNS Lemma=patient NamedEntityTag=O SentimentClass=Neutral]
# [Text=with CharacterOffsetBegin=829 CharacterOffsetEnd=833 PartOfSpeech=IN Lemma=with NamedEntityTag=O SentimentClass=Neutral]
# [Text=heart CharacterOffsetBegin=834 CharacterOffsetEnd=839 PartOfSpeech=NN Lemma=heart NamedEntityTag=O SentimentClass=Neutral]
# [Text=failure CharacterOffsetBegin=840 CharacterOffsetEnd=847 PartOfSpeech=NN Lemma=failure NamedEntityTag=O SentimentClass=Very negative]
# [Text=. CharacterOffsetBegin=847 CharacterOffsetEnd=848 PartOfSpeech=. Lemma=. NamedEntityTag=O SentimentClass=Neutral]
# (ROOT
#   (S
#     (NP (NNS Clinicians))
#     (VP (MD should)
#       (VP (VB be)
#         (ADJP (JJ mindful)
#           (PP (IN of)
#             (NP
#               (NP (DT the) (NN risk))
#               (PP (IN of)
#                 (NP (NN hyperkalemia))))))
#         (SBAR
#           (WHADVP (WRB when))
#           (S
#             (VP (VBG prescribing)
#               (NP (NN RAAS) (NNS inhibitors))
#               (PP (TO to)
#                 (NP
#                   (NP (NNS patients))
#                   (PP (IN with)
#                     (NP (NN heart) (NN failure))))))))))
#     (. .)))
#
# root(ROOT-0, mindful-4)
# nsubj(mindful-4, Clinicians-1)
# aux(mindful-4, should-2)
# cop(mindful-4, be-3)
# case(risk-7, of-5)
# det(risk-7, the-6)
# nmod:of(mindful-4, risk-7)
# case(hyperkalemia-9, of-8)
# nmod:of(risk-7, hyperkalemia-9)
# advmod(prescribing-11, when-10)
# advcl(mindful-4, prescribing-11)
# compound(inhibitors-13, RAAS-12)
# dobj(prescribing-11, inhibitors-13)
# case(patients-15, to-14)
# nmod:to(prescribing-11, patients-15)
# case(failure-18, with-16)
# compound(failure-18, heart-17)
# nmod:with(patients-15, failure-18)
# punct(mindful-4, .-19)
#
# Sentence #5 (33 tokens, sentiment: Negative):
# In patients at highest risk, such as those with diabetes, the elderly, and advanced chronic kidney disease, more intensive laboratory surveillance of potassium and creatinine may be required.
# [Text=In CharacterOffsetBegin=849 CharacterOffsetEnd=851 PartOfSpeech=IN Lemma=in NamedEntityTag=O SentimentClass=Neutral]
# [Text=patients CharacterOffsetBegin=852 CharacterOffsetEnd=860 PartOfSpeech=NNS Lemma=patient NamedEntityTag=O SentimentClass=Neutral]
# [Text=at CharacterOffsetBegin=861 CharacterOffsetEnd=863 PartOfSpeech=IN Lemma=at NamedEntityTag=O SentimentClass=Neutral]
# [Text=highest CharacterOffsetBegin=864 CharacterOffsetEnd=871 PartOfSpeech=JJS Lemma=highest NamedEntityTag=O SentimentClass=Neutral]
# [Text=risk CharacterOffsetBegin=872 CharacterOffsetEnd=876 PartOfSpeech=NN Lemma=risk NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=876 CharacterOffsetEnd=877 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=such CharacterOffsetBegin=878 CharacterOffsetEnd=882 PartOfSpeech=JJ Lemma=such NamedEntityTag=O SentimentClass=Neutral]
# [Text=as CharacterOffsetBegin=883 CharacterOffsetEnd=885 PartOfSpeech=IN Lemma=as NamedEntityTag=O SentimentClass=Neutral]
# [Text=those CharacterOffsetBegin=886 CharacterOffsetEnd=891 PartOfSpeech=DT Lemma=those NamedEntityTag=O SentimentClass=Neutral]
# [Text=with CharacterOffsetBegin=892 CharacterOffsetEnd=896 PartOfSpeech=IN Lemma=with NamedEntityTag=O SentimentClass=Neutral]
# [Text=diabetes CharacterOffsetBegin=897 CharacterOffsetEnd=905 PartOfSpeech=NN Lemma=diabetes NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=905 CharacterOffsetEnd=906 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=the CharacterOffsetBegin=907 CharacterOffsetEnd=910 PartOfSpeech=DT Lemma=the NamedEntityTag=O SentimentClass=Neutral]
# [Text=elderly CharacterOffsetBegin=911 CharacterOffsetEnd=918 PartOfSpeech=JJ Lemma=elderly NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=918 CharacterOffsetEnd=919 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=and CharacterOffsetBegin=920 CharacterOffsetEnd=923 PartOfSpeech=CC Lemma=and NamedEntityTag=O SentimentClass=Neutral]
# [Text=advanced CharacterOffsetBegin=924 CharacterOffsetEnd=932 PartOfSpeech=VBD Lemma=advance NamedEntityTag=O SentimentClass=Neutral]
# [Text=chronic CharacterOffsetBegin=933 CharacterOffsetEnd=940 PartOfSpeech=JJ Lemma=chronic NamedEntityTag=O SentimentClass=Neutral]
# [Text=kidney CharacterOffsetBegin=941 CharacterOffsetEnd=947 PartOfSpeech=NN Lemma=kidney NamedEntityTag=O SentimentClass=Neutral]
# [Text=disease CharacterOffsetBegin=948 CharacterOffsetEnd=955 PartOfSpeech=NN Lemma=disease NamedEntityTag=O SentimentClass=Negative]
# [Text=, CharacterOffsetBegin=955 CharacterOffsetEnd=956 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=more CharacterOffsetBegin=957 CharacterOffsetEnd=961 PartOfSpeech=JJR Lemma=more NamedEntityTag=O SentimentClass=Neutral]
# [Text=intensive CharacterOffsetBegin=962 CharacterOffsetEnd=971 PartOfSpeech=JJ Lemma=intensive NamedEntityTag=O SentimentClass=Neutral]
# [Text=laboratory CharacterOffsetBegin=972 CharacterOffsetEnd=982 PartOfSpeech=NN Lemma=laboratory NamedEntityTag=O SentimentClass=Neutral]
# [Text=surveillance CharacterOffsetBegin=983 CharacterOffsetEnd=995 PartOfSpeech=NN Lemma=surveillance NamedEntityTag=O SentimentClass=Neutral]
# [Text=of CharacterOffsetBegin=996 CharacterOffsetEnd=998 PartOfSpeech=IN Lemma=of NamedEntityTag=O SentimentClass=Neutral]
# [Text=potassium CharacterOffsetBegin=999 CharacterOffsetEnd=1008 PartOfSpeech=NN Lemma=potassium NamedEntityTag=O SentimentClass=Neutral]
# [Text=and CharacterOffsetBegin=1009 CharacterOffsetEnd=1012 PartOfSpeech=CC Lemma=and NamedEntityTag=O SentimentClass=Neutral]
# [Text=creatinine CharacterOffsetBegin=1013 CharacterOffsetEnd=1023 PartOfSpeech=NN Lemma=creatinine NamedEntityTag=O SentimentClass=Neutral]
# [Text=may CharacterOffsetBegin=1024 CharacterOffsetEnd=1027 PartOfSpeech=MD Lemma=may NamedEntityTag=O SentimentClass=Neutral]
# [Text=be CharacterOffsetBegin=1028 CharacterOffsetEnd=1030 PartOfSpeech=VB Lemma=be NamedEntityTag=O SentimentClass=Neutral]
# [Text=required CharacterOffsetBegin=1031 CharacterOffsetEnd=1039 PartOfSpeech=VBN Lemma=require NamedEntityTag=O SentimentClass=Neutral]
# [Text=. CharacterOffsetBegin=1039 CharacterOffsetEnd=1040 PartOfSpeech=. Lemma=. NamedEntityTag=O SentimentClass=Neutral]
# (ROOT
#   (S
#     (PP (IN In)
#       (NP
#         (NP
#           (NP (NNS patients))
#           (PP (IN at)
#             (NP (JJS highest) (NN risk))))
#         (, ,)
#         (UCP
#           (PP (JJ such) (IN as)
#             (NP
#               (NP (DT those))
#               (PP (IN with)
#                 (NP
#                   (NP (NN diabetes))
#                   (, ,)
#                   (NP (DT the) (JJ elderly))
#                   (, ,)))))
#           (CC and)
#           (S
#             (VP (VBD advanced)
#               (NP (JJ chronic) (NN kidney) (NN disease)))))))
#     (, ,)
#     (NP
#       (NP (JJR more) (JJ intensive) (NN laboratory) (NN surveillance))
#       (PP (IN of)
#         (NP (NN potassium)
#           (CC and)
#           (NN creatinine))))
#     (VP (MD may)
#       (VP (VB be)
#         (VP (VBN required))))
#     (. .)))
#
# root(ROOT-0, required-32)
# case(patients-2, In-1)
# nmod:in(required-32, patients-2)
# case(risk-5, at-3)
# amod(risk-5, highest-4)
# nmod:at(patients-2, risk-5)
# punct(patients-2, ,-6)
# case(those-9, such-7)
# mwe(such-7, as-8)
# nmod:such_as(patients-2, those-9)
# case(diabetes-11, with-10)
# nmod:with(those-9, diabetes-11)
# punct(diabetes-11, ,-12)
# det(elderly-14, the-13)
# appos(diabetes-11, elderly-14)
# punct(diabetes-11, ,-15)
# cc(those-9, and-16)
# nmod:such_as(patients-2, advanced-17)
# conj:and(those-9, advanced-17)
# amod(disease-20, chronic-18)
# compound(disease-20, kidney-19)
# dobj(advanced-17, disease-20)
# punct(required-32, ,-21)
# amod(surveillance-25, more-22)
# amod(surveillance-25, intensive-23)
# compound(surveillance-25, laboratory-24)
# nsubjpass(required-32, surveillance-25)
# case(potassium-27, of-26)
# nmod:of(surveillance-25, potassium-27)
# cc(potassium-27, and-28)
# nmod:of(surveillance-25, creatinine-29)
# conj:and(potassium-27, creatinine-29)
# aux(required-32, may-30)
# auxpass(required-32, be-31)
# punct(required-32, .-33)
#
# Sentence #6 (18 tokens, sentiment: Negative):
# Novel therapies hold promise for reducing the risk of hyperkalemia and enhancing the tolerability of RAAS antagonists.
# [Text=Novel CharacterOffsetBegin=1041 CharacterOffsetEnd=1046 PartOfSpeech=JJ Lemma=novel NamedEntityTag=O SentimentClass=Neutral]
# [Text=therapies CharacterOffsetBegin=1047 CharacterOffsetEnd=1056 PartOfSpeech=NNS Lemma=therapy NamedEntityTag=O SentimentClass=Neutral]
# [Text=hold CharacterOffsetBegin=1057 CharacterOffsetEnd=1061 PartOfSpeech=VBP Lemma=hold NamedEntityTag=O SentimentClass=Neutral]
# [Text=promise CharacterOffsetBegin=1062 CharacterOffsetEnd=1069 PartOfSpeech=NN Lemma=promise NamedEntityTag=O SentimentClass=Positive]
# [Text=for CharacterOffsetBegin=1070 CharacterOffsetEnd=1073 PartOfSpeech=IN Lemma=for NamedEntityTag=O SentimentClass=Neutral]
# [Text=reducing CharacterOffsetBegin=1074 CharacterOffsetEnd=1082 PartOfSpeech=VBG Lemma=reduce NamedEntityTag=O SentimentClass=Neutral]
# [Text=the CharacterOffsetBegin=1083 CharacterOffsetEnd=1086 PartOfSpeech=DT Lemma=the NamedEntityTag=O SentimentClass=Neutral]
# [Text=risk CharacterOffsetBegin=1087 CharacterOffsetEnd=1091 PartOfSpeech=NN Lemma=risk NamedEntityTag=O SentimentClass=Neutral]
# [Text=of CharacterOffsetBegin=1092 CharacterOffsetEnd=1094 PartOfSpeech=IN Lemma=of NamedEntityTag=O SentimentClass=Neutral]
# [Text=hyperkalemia CharacterOffsetBegin=1095 CharacterOffsetEnd=1107 PartOfSpeech=NN Lemma=hyperkalemia NamedEntityTag=O SentimentClass=Neutral]
# [Text=and CharacterOffsetBegin=1108 CharacterOffsetEnd=1111 PartOfSpeech=CC Lemma=and NamedEntityTag=O SentimentClass=Neutral]
# [Text=enhancing CharacterOffsetBegin=1112 CharacterOffsetEnd=1121 PartOfSpeech=VBG Lemma=enhance NamedEntityTag=O SentimentClass=Positive]
# [Text=the CharacterOffsetBegin=1122 CharacterOffsetEnd=1125 PartOfSpeech=DT Lemma=the NamedEntityTag=O SentimentClass=Neutral]
# [Text=tolerability CharacterOffsetBegin=1126 CharacterOffsetEnd=1138 PartOfSpeech=NN Lemma=tolerability NamedEntityTag=O SentimentClass=Neutral]
# [Text=of CharacterOffsetBegin=1139 CharacterOffsetEnd=1141 PartOfSpeech=IN Lemma=of NamedEntityTag=O SentimentClass=Neutral]
# [Text=RAAS CharacterOffsetBegin=1142 CharacterOffsetEnd=1146 PartOfSpeech=NN Lemma=raas NamedEntityTag=O SentimentClass=Neutral]
# [Text=antagonists CharacterOffsetBegin=1147 CharacterOffsetEnd=1158 PartOfSpeech=NNS Lemma=antagonist NamedEntityTag=O SentimentClass=Neutral]
# [Text=. CharacterOffsetBegin=1158 CharacterOffsetEnd=1159 PartOfSpeech=. Lemma=. NamedEntityTag=O SentimentClass=Neutral]
# (ROOT
#   (S
#     (NP (JJ Novel) (NNS therapies))
#     (VP (VBP hold)
#       (NP (NN promise))
#       (PP (IN for)
#         (S
#           (VP
#             (VP (VBG reducing)
#               (NP
#                 (NP (DT the) (NN risk))
#                 (PP (IN of)
#                   (NP (NN hyperkalemia)))))
#             (CC and)
#             (VP (VBG enhancing)
#               (NP
#                 (NP (DT the) (NN tolerability))
#                 (PP (IN of)
#                   (NP (NN RAAS) (NNS antagonists)))))))))
#     (. .)))
#
# root(ROOT-0, hold-3)
# amod(therapies-2, Novel-1)
# nsubj(hold-3, therapies-2)
# dobj(hold-3, promise-4)
# mark(reducing-6, for-5)
# advcl:for(hold-3, reducing-6)
# det(risk-8, the-7)
# dobj(reducing-6, risk-8)
# case(hyperkalemia-10, of-9)
# nmod:of(risk-8, hyperkalemia-10)
# cc(reducing-6, and-11)
# advcl:for(hold-3, enhancing-12)
# conj:and(reducing-6, enhancing-12)
# det(tolerability-14, the-13)
# dobj(enhancing-12, tolerability-14)
# case(antagonists-17, of-15)
# compound(antagonists-17, RAAS-16)
# nmod:of(tolerability-14, antagonists-17)
# punct(hold-3, .-18)
#
# Coreference set:
# 	(2,5,[5,6]) -> (1,2,[1,50]), that is: "its" -> "Renin-angiotensin-aldosterone system -LRB- RAAS -RRB- antagonists , including angiotensin-converting enzyme inhibitors -LRB- ACEI -RRB- , angiotensin receptor blockers -LRB- ARB -RRB- , and mineralocorticoid receptor antagonists -LRB- MRA -RRB- decrease mortality and morbidity in heart failure but increase the risk of hyperkalemia , especially when used in combination ."
# Coreference set:
# 	(1,26,[24,49]) -> (1,6,[6,7]), that is: "mineralocorticoid receptor antagonists -LRB- MRA -RRB- decrease mortality and morbidity in heart failure but increase the risk of hyperkalemia , especially when used in combination" -> "antagonists"
# Coreference set:
# 	(4,18,[17,19]) -> (1,36,[35,37]), that is: "heart failure" -> "heart failure"
# Coreference set:
# 	(3,6,[5,9]) -> (1,40,[39,43]), that is: "the risk of hyperkalemia" -> "the risk of hyperkalemia"
# 	(3,11,[11,20]) -> (1,40,[39,43]), that is: "further moderated through the use of combined angiotensin-neprilysin inhibitors" -> "the risk of hyperkalemia"
# 	(4,7,[6,10]) -> (1,40,[39,43]), that is: "the risk of hyperkalemia" -> "the risk of hyperkalemia"
# 	(6,8,[7,11]) -> (1,40,[39,43]), that is: "the risk of hyperkalemia" -> "the risk of hyperkalemia"

# %% [markdown]
# Our takeaway sentence is that "ACE Inhibitors (ACEI) [...] decrease mortality and morbidity in heart failure but increase the risk of hyperkalemia...".
#
# `amod(inhibitors-11, angiotensin-converting-9)`
#
# `dobj(increase-38, risk-40)`
#
# `nmod:of(risk-40, hyperkalemia-42)`

# %% [markdown]
# ## Experimenting with specific drug names instead of a drug class
#
# It didn't look like we had a lot of interactions between drugs and molecules, so I wonder if we change our serach terms a little bit to include the drug names. The search terms are not case sensitive.
#
# `Drugs in class: Captopril, Lisinopril, Ramipril, Benazepril`

# %%
search_term = ['Captopril', 'Lisinopril','Ramipril','Benazepril']
max_results = 100
for i in search_term:
    query2 = pb.PubMedQuery(i, max_results)
    
ids2 = query2.id_getter()
print "Num abstracts: ", len(ids2)

abstracts2 = query.abstract_getter(ids2)

json_file2 = 'more_abstracts2.json'
print 'Saving to ' + json_file2
with open(json_file2, 'w') as outfile:
    json.dump(abstracts2, outfile, indent=4)
    
    
sentences2 = []
with open('more_abstracts2.json') as data_file:    
    data = json.load(data_file)
    for abstract in data.itervalues():
        sentences2.append(sent_tokenize(abstract))
    # flatten the list of abstracts into one long list of sentences
    sentences2 = [sent for s in sentences2 for sent in s]
    print "Sentences: ",len(sentences2)
# Out:
# Num abstracts:  899
# Saving to more_abstracts2.json
# Sentences:  938

# %%
#Just looking at some sentences
sentences2[:5]
# Out:
# [u'Benazepril plays an important role in down-regulating the expression of TGFbeta1 and decreasing the accumulation of ECM by blocking intrarenal renin-angiotensin system.',
#  u'To study the expression of type I transforming growth factor beta receptor (TGFbetaRI) in renal cortex in streptozotocin-induced diabetic rats and the regulation of benazepril.',
#  u'Experimental glomerulosclerosis in rats was induced by adriamycin.',
#  u'The treated group was given benazepril (4 mg x kg(-1) x d(-1)).',
#  u'Intrarenal angiotensin converting enzyme (ACE) activity and angiotensin II (AngII) concentration were measured with colorimetry and radioimmunoassay respectively.']

# %%
# %%writefile KeywordSentences2.py
import json

#change keyword to ACE
keywords = ['Captopril', 'Lisinopril','Ramipril','Benazepril']
with open('more_abstracts2.json') as data_file:    
    data = json.load(data_file)
    #pick snippets related to ACE inhibitors
    for i in range(len(data.keys())):
        try:
            if any(k in data[str(i)] for k in keywords):
                print data[str(i)] + '\n'
            else:
                next
        except:
            next
# Out:
# Overwriting KeywordSentences2.py

# %%
# !python KeywordSentences2.py > KeywordSentences2.txt

# %%
# !cat KeywordSentences2.txt
# Out:
# A number of experimental and clinical investigations support the notion that angiotensin-converting enzyme inhibitor (ACEi) and angiotensin II type 1 receptor blocker (ARB) compounds attenuate renal fibrosis. Fibrosis can be attenuated by either suppressing matrix formation or facilitating matrix degradation. In this study, drugs of ACEi and ARB classes were tested for their ability to facilitate matrix degradation in the kidney. A murine model system in which cyclosporin A (CsA) treatment for a specified period caused interstitial matrix deposition in the kidney was used. CsA was then discontinued, and experimental procedures were initiated to investigate matrix degradation. Benazepril, an ACEi, facilitated matrix degradation via the bradykinin (BK) B2 receptor on tubular epithelial cells in the kidney, whereas CGP-48933, an ARB, did not. In this murine model of CsA nephropathy under ACE blockade, plasminogen activator inhibitor-1 (PAI-1) expression was decreased in tubular epithelial cells, possibly leading to conversion of plasminogen to plasmin by plasminogen activator and subsequent activation of matrix metalloproteinases. These findings were confirmed in this study by measurements of plasmin activity, collagenolytic activity, and matrix metalloproteinase activities in the kidneys. In tubular epithelial cells stimulated in vitro, BK suppressed PAI-1 gene expression. All of these results suggest that ACEi can decrease PAI-1 expression via BK, thereby facilitating matrix degradation via activation of degradative enzymes to reduce interstitial matrix deposition.
#
# Plasmin is an important factor in the degradation of extracellular matrix. In the study reported here we examined the expression of plasminogen-activator inhibitor-1 (PAI-1), urokinase-type plasminogen activator (uPA), and uPA receptor (uPAR), as well as the relevance of such expression to the production of type IV collagen, a major component of extracellular matrix, in the renal tissue of rats with streptozotocin-induced diabetes. Because angiotensin II is involved in the synthesis of PAI-1 and uPA, we also examined the effect of benazepril, an angiotensin-converting-enzyme inhibitor, on the expression of PAI-1, uPA, and uPAR messenger RNAs (mRNAs) and type IV collagen protein. Rats with streptozocin-induced diabetes-some untreated and some treated with 30 mg/L benazepril-and nondiabetic control rats were sacrificed at 4, 12, or 24 weeks after induction of diabetes. We examined the expression of PAI-1, uPA, and uPAR mRNAs through the use of in situ hybridization and that of type IV collagen by means of immunohistochemical methods. In control rats, we detected weak signals for PAI-1, uPA, and uPAR mRNAs in glomeruli. Diabetic rats exhibited high levels of expression of PAI-1, uPA, and uPAR mRNAs and type IV collagen protein, mainly in mesangial cells. These mRNAs were synthesized in various renal cells (epithelial, mesangial, and endothelial cells and Bowman's capsule). Benazepril inhibited increases in all 3 mRNAs, especially in the mesangium; reduced type IV collagen expression; and attenuated mesangial expansion. Our results indicated that altered expression of PAI-1, uPA, and uPAR in diabetic nephropathy was associated with mesangial expansion and that the beneficial effects of ACE-I may be at least associated with such expression.
#
# The effects of the combined use of angiotensin converting enzyme inhibitor (ACEI) benazepril and angiotensin II type 1 receptor antagonist (AT1RA) valsartan on apoptosis and the expression of apoptosis-related proteins Fas and FasL in the kidney of rats with adriamycin-induced nephritic glomerulosclerosis was investigated. Uninephrectomy and the injection of adriamycin induced the rat model of glomerulosclerosis. Benazepril (6 mg/kg), valsantan (20 mg/kg), or benazepril (3 mg/kg) plus valsantan (20 mg/kg) was respectively delivered daily by gavage to the rats in three treatment groups for 12 weeks. Apoptosis was examined by means of terminal-deoxynucleotidyl transferase mediated d-UTP nick end labeling (TUNEL). Immunohistochemistry was adopted to detect the expression of Fas and FasL. Software of pathological analysis quantitated the levels of Fas and FasL. The results showed that as compared with those in the control group, the kidneys in the model group had more severe glomerulosclerosis, much more apoptotic cells and higher levels of expression of Fas and FasL. The degree of glomerulosclerosis, the number of apoptotic cells and the levels of expression of Fas and FasL were reduced by benazepril and valsartan. The combined use of benazepril and valsartan had the best therapeutic effect. It was concluded that benazepril and valsartan could suppress the excessive apoptosis of kidney cells by lowering the expression of the apoptosis-related proteins Fas and FasL, so as to postpone the process of glomerulosclerosis. The combined use of benazepril and valsartan has better therapeutic effect.
#
# Benazepril was safe and tolerable when applied in hypertensive patients.
#
# Benazepril increases the microvessel density and collateral flow, promotes the creation of collateral circulation in ischemic area, but captopril has not such effects.
#
# Benazepril hydrochloride is an angiotensin-converting enzyme inhibitor. Previous clinical trials show that antihypertensive treatment with benazepril provides effective blood pressure (BP) control and is generally well tolerated by patients with hypertension. However, the long-term antihypertensive effects and tolerability of benazepril remain to be established in Chinese patients with hypertension.
#
# The study was a prospective, randomized, double-blinded, placebo-controlled clinical trial. A total of 162 dogs with New York Heart Association (NYHA) class II-IV heart failure caused by chronic valvular disease (CVD) or dilated cardiomyopathy (DCM) were enrolled. Benazepril (minimum dosage, 0.25 mg/kg) or placebo were administered orally once daily for up to 34 months. In this paper, we report results of plasma alanine aminotransferase (ALT), creatinine, potassium and urea.
#
# Benazepril was well tolerated during long-term therapy in dogs with CHF and no specific precautions appear to be necessary regarding plasma ALT, creatinine, potassium or urea. The possible action of benazepril in improving renal function (evidenced via lower plasma creatinine) merits further investigation.
#
# To study the effect of the Compound of traditional Chinese drugs and Benazepril on gene expression of renal endothelin and its receptor of experimental diabetic nephropathy(DN). To discove the mechanism of the compound of traditional Chinese drugs in treating DN.
#
# Streptozotocin DN model was built and influenced with the compound of traditional Chinese drugs and Benazepril. The changes of Upro, Glu, HbA1C and (PT-PCR) mRNA expression levels of ET-1, ETA-R of the renal cortex were tested, and thus the histopathological character of the kidney was analysed.
#
# The compound of traditional Chinese drugs and Benazepril have significant difference from normal saline in the improvement of Upro, Glu, HbA1C. The compound of traditional Chinese drugs have significant difference from Benazepril in the improvement of Glu, HbA1C. The mRNA expression level of ET-1, ETA-R of the renal cortex of DN model was raised. After influenced by the compound of traditional Chinese drugs and Benazepril, the over-expression level de-creased (still higher than normal control ones). The compound of traditional Chinese drugs were more effective than Benazepril to inhibit the proliferation of the stalk region and the third cells.
#
# ET takes part in the process of diabetic glo-Merulosclerosis. Both the compound of traditional Chinese drugs and Benazepril can influence the expression quantity from the level of gene transcription of ET and its receptor. The compound of traditional Chinese drugs can not only reduce urinary albumin of DN, but also improve blood glucose, glycosylated hemoglubin. And it can inhibit nonenzymatic glucosylation of protein as well as the proliferation of the stalk region and the third cells.
#
# Both benazepril and amlodipine were similarly effective in reducing systolic blood pressure (SBP) (-17.6 mmHg with benazepril and -19.8 mmHg with amlodipine; P<0.001 versus placebo), and diastolic blood pressure (DBP) (-11.1 mmHg, -13.2 mmHg, respectively). Combination therapy produced greater reduction in SBP/DBP values (-28.3/-20.5 mmHg; P<0.001 versus placebo, P<0.01 versus benazepril and amlodipine). Benazepril monotherapy significantly decreased plasma PAI-1 activity (-8.4 IU/ml, P<0.05) while it did not influence t-PA activity (+0.02 IU/ml). Amlodipine monotherapy produced a significant increase in t-PA activity (+0.27 IU/ml, P<0.05) while it did not influence PAI-1 activity (+0.8 IU/ml). The amlodipine/benazepril combination produced both a significant decrease in plasma PAI-1 activity (-8.7 IU, P<0.05) and a significant increase in t-PA activity (+0.26 IU/ml, P<0.05).
#
# The disposition and effect of benazepril and its active metabolite, benazeprilat, were evaluated in cats using a pharmacokinetic/pharmacodynamic model. Cats received single 1 mg/kg doses of intravenous 14C-benazeprilat and oral 14C-benazepril.HCl, and single and repeat (eight daily) oral administrations of 0.25, 0.5 and 1.0 mg/kg nonlabelled benazepril.HCl. The pharmacokinetic endpoints were plasma concentrations of benazepril and benazeprilat, and recovery of radioactivity in faeces and urine. The pharmacodynamic endpoint was plasma angiotensin-converting enzyme (ACE) activity. Benazeprilat data were fitted to an equation corresponding to a single-compartment model with a volume equal to the blood space (Vc = 0.093 L/kg). Within this space, benazeprilat was bound nonlinearly to ACE, which was mainly tissular (89.4%) rather than circulating (10.6%). Free benazeprilat was eliminated quickly from the central compartment (t1/2 approximately 1.0 h; Cl approximately 0.125 L/kg/h), elimination being principally biliary ( approximately 85%) rather than urinary ( approximately 15%). Nevertheless, inhibition of ACE was long-lasting (t1/2 16-23 h) due to high affinity binding of benazeprilat to ACE (Kd approximately 3.5 mmol/L, IC50 approximately 4.3 mmol/L). Simulations using the model predict a lack of proportionality between dose of benazepril, plasma benazeprilat concentrations and effect due to the nonlinear binding of benazeprilat to ACE. For example, increasing the dose of benazepril (e.g. above 0.125 mg/kg q24 h) produced only small incremental inhibition of ACE (either peak effect or duration of action).
#
# Albuminuria and hypertension are predictors of poor renal and cardiovascular outcome in diabetic patients. This study tested whether dual blockade of the renin-angiotensin system (RAS) with both an angiotensin-converting enzyme (ACE) inhibitor (ACE-I) and an Angiotensin-II receptor blocker (ARB) is superior to either drug alone in type I diabetic patients with diabetic nephropathy (DN). A randomized double-blind crossover trial was performed with 8-wk treatment with placebo, 20 mg of benazepril once daily, 80 mg of valsartan once daily, and the combination of 20 mg of benazepril and 80 mg of valsartan. Twenty type I diabetic patients with DN were included. At the end of each treatment period, albuminuria, 24-h BP, and GFR were measured. Eighteen patients completed the study. Placebo values were: albuminuria [mean (95% CI)], 701 (490 to 1002) mg/24 h; BP [mean (SEM)], 144 (4)/79 (2) mmHg, and GFR [mean (SEM)], 82 (7) ml/min per 1.73 m(2). Treatment with benazepril, valsartan, or dual blockade significantly reduced albuminuria and BP compared with placebo. Benazepril and valsartan were equally effective. Dual blockade induced an additional reduction in albuminuria of 43 % (29 to 54 %) compared with any type of monotherapy, and a reduction in systolic BP of 6 (0 to 13) mmHg and 7 (1 to 14) mmHg (versus benazepril and valsartan, respectively) and a reduction of 7 (4 to 10) mmHg diastolic compared with both monotherapies. GFR was reversibly reduced on dual blockade compared with monotherapy and placebo. All treatments were safe and well tolerated. In conclusion, dual blockade of the RAS may offer additional renal and cardiovascular protection in type I diabetic patients with DN.
#
# Eighty-nine patients with essential hypertension and 102 normotensive subjects were included in this study. All subjects were genotyped by polymerase chain reaction for the insertion/deletion polymorphism of the angiotensin-converting enzyme gene. Blood pressure was measured before and after taking Benazepril 10 mg, once daily, for 2 months.
#
# Uninephrectomized Spraque-Dawley rats were used to induce diabetes by intraperitoneal injection of streptozotocin (65 mg.kg-1). Benazepril (10 mg.kg-1) was given daily by gavage from the next day of the induction to diabetes for 12 weeks. Apoptosis was evaluated by means of terminal-deoxynucleotidyl transferase mediated d-UTP nick end labeling (TUNEL). Flow cytometry and immunohistochemistry were used to detect the expression of Fas and Fas-L.
#
# The angiotensin converting enzyme (ACE) inhibitors are widely used in the management of essential hypertension, stable chronic heart failure, myocardial infarction (MI) and diabetic nephropathy. There is an increasing number of new agents to add to the nine ACE inhibitors (benazepril, cilazapril, delapril, fosinopril, lisinopril, pentopril, perindopril, quinapril and ramipril) reviewed in this journal in 1990. The pharmacokinetic properties of five newer ACE inhibitors (trandolapril, moexipril, spirapril, temocapril and imidapril) are reviewed in this update. All of these new agents are characterised by having a carboxyl functional groups and requiring hepatic activation to form pharmacologically active metabolites. They achieve peak plasma concentrations at similar times (t(max)) to those of established agents. Three of these agents (trandolapril, moexipril and imidapril) require dosage reductions in patients with renal impairment. Dosage reductions of moexipril and temocapril are recommended for elderly patients, and dosages of moexipril should be lower in patients who are hepatically impaired. Moexipril should be taken 1 hour before meals, whereas other ACE inhibitors can be taken without regard to meals. The pharmacokinetics of warfarin are not altered by concomitant administration with trandolapril or moexipril. Although imidapril and spirapril have no effect on digoxin pharmacokinetics, the area under the concentration-time curve of imidapril and the peak plasma concentration of the active metabolite imidaprilat are decreased when imidapril is given together with digoxin. Although six ACE inhibitors (captopril, enalapril, fosinopril, lisinopril, quinapril and ramipril) have been approved for use in heart failure by the US Food and Drug Administration, an overview of 32 clinical trials of ACE inhibitors in heart failure showed that no significant heterogeneity in mortality was found among enalapril, ramipril, quinapril, captopril, lisinopril, benazepril, perindopril and cilazapril. Initiation of therapy with captopril, ramipril, and trandolapril at least 3 days after an acute MI resulted in all-cause mortality risk reductions of 18 to 27%. Captopril has been shown to have similar morbidity and mortality benefits to those of diuretics and beta-blockers in hypertensive patients. Captopril has been shown to delay the progression of diabetic nephropathy, and enalapril and lisinopril prevent the development of nephropathy in normoalbuminuric patients with diabetes. ACE inhibitors are generally characterised by flat dose-response curves. Lisinopril is the only ACE inhibitor that exhibits a linear dose-response curve. Despite the fact that most ACE inhibitors are recommended for once-daily administration, only fosinopril, ramipril, and trandolapril have trough-to-peak effect ratios in excess of 50%.
#
# To evaluate the efficacy and safety of Benazepril used among the essential hypertensives.
#
# 1 831 essential hypertensive patients aged 35 to 75 were randomly selected from a community and followed for 18 months. The level of blood pressure, status of taking Benazepril and side effects were sequencially collected.
#
# 1/3 of the patients had taken antihypertensive drug before the study and the rate of compliance was over 96%. The effective rate of Benazepril was 73.6% at three months and increased to 84.7% at 18 months. Comparing with the baseline data, SBP and DBP declined 10.8 mmHg and 6.7 mmHg respectively. The rate of side effect was 22.7%. Cough was most commonly seen among side effects. The peak of first recording on side effect occurred at three months including 60% of them mild.
#
# Results showed that Benazepril had good efficacy and safety for the essential hypertension patients in a long-term observation.
#
# Captopril, enalapril, and lisinopril are angiotensin-converting enzyme (ACE) inhibitors widely prescribed for hypertension and heart failure. Cutaneous side effects of captopril include angio-edema, anaphylactoid reactions, maculopapular eruptions, pitiryasis rosea-like rash, toxic erythema, and exfoliative dermatitis. Some of the immunological captopril-induced cutaneous adverse reactions have been diagnosed in recent years by patch tests. A case of a cutaneous immune adverse reaction to captopril with tolerance to enalapril and lisinopril demonstrated both by patch tests and double-blind challenge tests is reported for the first time. A 71-year-old nonatopic woman suffered a generalized pruriginous maculopapular rash. Two months earlier, she had started oral treatment with captopril 50 mg t.i.d and glibenclamide 5 mg daily. After the rash appeared, she stopped both drugs and the reaction cleared. A skin biopsy from one of the lesions showed perivascular lymphocytic infiltrate of the upper dermis. Skin prick tests with captopril and glibenclamide and patch tests with enalapril, lisinopril, and glibenclamide at 1% and 10% pet., and with mercaptobenzothiazole (a sulfhydryl group-containing chemical at 1% pet were negative. Only patch tests with captopril at 1% and 10% concentrations were positive at 48 h. Oral double-blind challenge tests with glibenclamide, enalapril, lisinopril, and placebo showed good tolerance. The patient was advised to avoid only captopril. Because captopril is the only ACE inhibitor containing a sulfhydryl group and has occasionally been implicated in complex immunological diseases, this chemical group has been considered the culprit of allergic reactions to captopril. The lack of cross-reactivity between captopril, enalapril, and benazepril has been demonstrated in a few patients by patch tests. In our patient, patch tests identified captopril as the drug responsible for a probably immune adverse reaction not due to the sulfhydryl group. Patch tests are useful and safe in the diagnostic work-up of allergic drug reactions and in studies of cross-sensitivity among ACE inhibitors.
#
# Benazepril therapy as a component of antihypertensive treatment of persons with chronic renal insufficiency initially costs money, but investment costs are recouped quickly and return on investment continues to grow. The impact of end-stage renal disease on patient health and healthcare costs is great. Thus, the quality-adjusted survival benefits and overall cost savings seen in benazepril recipients over a prolonged period (2 to 7 years) indicate that the strategy of prescribing benazepril to reduce progression of renal disease in patients with renal insufficiency is both clinically and economically beneficial compared with current antihypertensive regimens without ACE inhibition.
#
# Benazepril plays an important role in down-regulating the expression of TGFbeta1 and decreasing the accumulation of ECM by blocking intrarenal renin-angiotensin system.
#
# It is suggested that there is an interaction between TGFbetaR I and the pathogenesis of diabetic nephropathy. Benazepril can supress the expression of TGFbetaR I in renal cortex.
#
# To explore the intensity of inhibition of Shenkang Injection (SKI) and Benazepril on various ingredients of human glomerular mesangial extracellular matrix (ECM).
#
# Effect of SKI, a herbal preparation for lowering adverse Qi, despelling turbidness, supplementing Qi and activating circulation, and Benazepril were observed by cultured glomerular mesangial cell technique in vitro.
#
# SKI could inhibit the fibronetin, laminin, and type IV collagen of ECM, and the action was dose-dependent. Benazepril could also inhibit the fibronetin and type IV collagen of ECM but was weaker in intensity.
#
# The effect of SKI was superior to Benazepril in inhibiting ECM.
#
# A reversed-phase high-performance liquid chromatographic (HPLC) method was developed and validated for the kinetic investigation of the chemical and enzymatic hydrolysis of benazepril hydrochloride. Kinetic studies on the acidic hydrolysis of benazepril hydrochloride were carried out in 0.1 M hydrochloric acid solution at 50, 53, 58 and 63 degrees C. Benazepril hydrochloride appeared stable in a pH 7.4 phosphate buffered solution at 37 degrees C and showed susceptibility to undergoing in vitro enzymatic hydrolysis with porcine liver esterase (PLE) in a pH 7.4 buffered solution at 37 degrees C. Benazeprilat appeared to be the major degradation product in both (chemical and enzymatic) studies of hydrolysis. Statistical evaluation of the proposed HPLC methods revealed their good linearity and reproducibility. Relative standard deviation (R.S.D.) was less than 4.76, while detection limits for benazepril hydrochloride and benazeprilat were 13.0 x 10(-7) and 9.0 x 10(-7) M, respectively. Treatment of the kinetic data of the acidic hydrolysis was carried out by non-linear regression analysis and k values were determined. The kinetic parameters of the enzymatic hydrolysis were determined by non-linear regression analysis of the data using the equation of Michaelis-Menten.
#
# Combination therapy is required in many patients to achieve goal blood pressure (BP). Calcium antagonists are highly effective antihypertensive drugs in a broad range of demographic groups. Yet, higher doses are associated with an increased frequency of lower extremity edema. The purpose of our open label, single-center clinical trial was to evaluate the use of concomitant pharmacologic therapies to attenuate the lower extremity edema associated with dihydropyridine calcium antagonists therapy using a water displacement technique. Forty-seven patients received 5 mg/day of oral amlodipine for a period of 6 weeks after a 4-week wash-out off of all antihypertensive medications to establish baseline BP. They were then randomized to receive either an additional 5 mg of amlodipine, 25 mg of hydrochlorothiazide (HCTZ), or 20 mg of benazepril for an additional 6 weeks. Blood pressure determinations and water displacement measurements were obtained at the end of the 4-week placebo wash-out period, after 6 weeks of 5 mg/day of oral amlodipine therapy, and after an additional 6 weeks of 5 mg of amlodipine and randomized drug therapy. Adjusted BP reductions (based on pretreatment BP) were -6.8/-3.8 mm Hg for the 10-mg amlodipine group, -9.9/-8.2 mm Hg for the amlodipine (5 mg)/HCTZ (25 mg) group, and -26.2/-16.4 mm Hg for the amlodipine (5 mg)/benazepril (20 mg) group (P < .0167, group 3 v group 1 diastolic BP, which was statistically significant by the improved Bonferroni method). Seventeen of the 47 patients developed at least a 10% increase in lower extremity edema water displacement in response to 5 mg/day of oral amlodipine therapy (36.2%). Adding 5 mg of amlodipine to a baseline of 5 mg of amlodipine resulted in no net change in lower extremity edema (+58.0 mL,+ 0.6% change, n=5). Adding 25 mg of HCTZ reduced lower extremity edema by a mean of 136.3 mL (-11.1% change, n=4). Benazepril reduced water displacement by 204.4 mL (-14.3% change, n=8). Our pilot study indicates that adding an angiotensin converting enzyme inhibitor to a dihydropyridine calcium channel blocker is the most effective way to not only reduce systolic and diastolic BP but also attenuate lower extremity edema. Due to the inherent daily variability of lower extremity edema, power calculations indicate many patients (n=702, 356 in each group) would be needed to compare the antiedema efficacy of the angiotensin converting enzyme inhibitor and the thiazide diuretic.
#
# Prescribing trends and the cost of antihypertensive drugs were studied in 300 patients attending an internal medicine clinic. Beta-blockers were the most frequently used group of drugs (46.7%), followed by calcium-channel antagonists (34.3%) and angiotensin-converting enzyme inhibitors (30%). Diuretics were used in only 13.2% of the prescriptions. Atenolol (36%), amlodipine (29.3%) and enalapril (19%) were the most frequently used individual drugs. Propranolol, furosemide, amlodipine and atenolol were the least expensive drugs used, with annual drug acquisition costs of Rs 80, 102, 182 and 318, respectively. Benazepril (Rs 1778), diltiazem SR (Rs 1777), lisinopril (Rs 1660), prazosin (Rs 1416) and losartan (Rs 1365) were the most expensive drugs in terms of annual drug acquisition costs.

# %% [markdown]
# ## Experimenting with Sentiment Analysis

# %%
# !java -cp "*" -Xmx2g edu.stanford.nlp.pipeline.StanfordCoreNLP -annotators tokenize,ssplit,pos,lemma,ner,parse,dcoref,sentiment -file KeywordSentences2.txt -outputFormat text
# Out:
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator pos
# [main] INFO edu.stanford.nlp.tagger.maxent.MaxentTagger - Loading POS tagger from edu/stanford/nlp/models/pos-tagger/english-left3words/english-left3words-distsim.tagger ... done [1.4 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [2.0 sec].
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [1.8 sec].
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.8 sec].
# [main] INFO edu.stanford.nlp.time.JollyDayHolidays - Initializing JollyDayHoliday for SUTime from classpath edu/stanford/nlp/models/sutime/jollyday/Holidays_sutime.xml as sutime.binder.1.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ... done [0.5 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator dcoref
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator sentiment
#
# Processing file /Users/lisabarcelo/Desktop/W266/food_drug_interaction/drafts/KeywordSentences2.txt ... writing to /Users/lisabarcelo/Desktop/W266/food_drug_interaction/drafts/KeywordSentences2.txt.out
# Annotating file /Users/lisabarcelo/Desktop/W266/food_drug_interaction/drafts/KeywordSentences2.txt ... done [74.5 sec].
#
# Annotation pipeline timing information:
# TokenizerAnnotator: 0.1 sec.
# WordsToSentencesAnnotator: 0.0 sec.
# POSTaggerAnnotator: 0.5 sec.
# MorphaAnnotator: 0.1 sec.
# NERCombinerAnnotator: 6.4 sec.
# ParserAnnotator: 55.9 sec.
# DeterministicCorefAnnotator: 11.1 sec.
# SentimentAnnotator: 0.4 sec.
# TOTAL: 74.5 sec. for 4353 tokens at 58.4 tokens/sec.
# Pipeline setup: 10.7 sec.
# Total time for StanfordCoreNLP pipeline: 85.4 sec.

# %%
# !cat KeywordSentences2.txt.out
# Out:
# Sentence #1 (32 tokens, sentiment: Negative):
# A number of experimental and clinical investigations support the notion that angiotensin-converting enzyme inhibitor (ACEi) and angiotensin II type 1 receptor blocker (ARB) compounds attenuate renal fibrosis.
# [Text=A CharacterOffsetBegin=0 CharacterOffsetEnd=1 PartOfSpeech=DT Lemma=a NamedEntityTag=O SentimentClass=Neutral]
# [Text=number CharacterOffsetBegin=2 CharacterOffsetEnd=8 PartOfSpeech=NN Lemma=number NamedEntityTag=O SentimentClass=Neutral]
# [Text=of CharacterOffsetBegin=9 CharacterOffsetEnd=11 PartOfSpeech=IN Lemma=of NamedEntityTag=O SentimentClass=Neutral]
# [Text=experimental CharacterOffsetBegin=12 CharacterOffsetEnd=24 PartOfSpeech=JJ Lemma=experimental NamedEntityTag=O SentimentClass=Neutral]
# [Text=and CharacterOffsetBegin=25 CharacterOffsetEnd=28 PartOfSpeech=CC Lemma=and NamedEntityTag=O SentimentClass=Neutral]
# [Text=clinical CharacterOffsetBegin=29 CharacterOffsetEnd=37 PartOfSpeech=JJ Lemma=clinical NamedEntityTag=O SentimentClass=Neutral]
# [Text=investigations CharacterOffsetBegin=38 CharacterOffsetEnd=52 PartOfSpeech=NNS Lemma=investigation NamedEntityTag=O SentimentClass=Neutral]
# [Text=support CharacterOffsetBegin=53 CharacterOffsetEnd=60 PartOfSpeech=VBP Lemma=support NamedEntityTag=O SentimentClass=Neutral]
# [Text=the CharacterOffsetBegin=61 CharacterOffsetEnd=64 PartOfSpeech=DT Lemma=the NamedEntityTag=O SentimentClass=Neutral]
# [Text=notion CharacterOffsetBegin=65 CharacterOffsetEnd=71 PartOfSpeech=NN Lemma=notion NamedEntityTag=O SentimentClass=Neutral]
# [Text=that CharacterOffsetBegin=72 CharacterOffsetEnd=76 PartOfSpeech=IN Lemma=that NamedEntityTag=O SentimentClass=Neutral]
# [Text=angiotensin-converting CharacterOffsetBegin=77 CharacterOffsetEnd=99 PartOfSpeech=JJ Lemma=angiotensin-converting NamedEntityTag=O SentimentClass=Neutral]
# [Text=enzyme CharacterOffsetBegin=100 CharacterOffsetEnd=106 PartOfSpeech=NN Lemma=enzyme NamedEntityTag=O SentimentClass=Neutral]
# [Text=inhibitor CharacterOffsetBegin=107 CharacterOffsetEnd=116 PartOfSpeech=NN Lemma=inhibitor NamedEntityTag=O SentimentClass=Neutral]
# [Text=-LRB- CharacterOffsetBegin=117 CharacterOffsetEnd=118 PartOfSpeech=-LRB- Lemma=-lrb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=ACEi CharacterOffsetBegin=118 CharacterOffsetEnd=122 PartOfSpeech=NN Lemma=acei NamedEntityTag=O SentimentClass=Neutral]
# [Text=-RRB- CharacterOffsetBegin=122 CharacterOffsetEnd=123 PartOfSpeech=-RRB- Lemma=-rrb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=and CharacterOffsetBegin=124 CharacterOffsetEnd=127 PartOfSpeech=CC Lemma=and NamedEntityTag=O SentimentClass=Neutral]
# [Text=angiotensin CharacterOffsetBegin=128 CharacterOffsetEnd=139 PartOfSpeech=NN Lemma=angiotensin NamedEntityTag=O SentimentClass=Neutral]
# [Text=II CharacterOffsetBegin=140 CharacterOffsetEnd=142 PartOfSpeech=CD Lemma=ii NamedEntityTag=NUMBER NormalizedNamedEntityTag=0.0 SentimentClass=Neutral]
# [Text=type CharacterOffsetBegin=143 CharacterOffsetEnd=147 PartOfSpeech=NN Lemma=type NamedEntityTag=O SentimentClass=Neutral]
# [Text=1 CharacterOffsetBegin=148 CharacterOffsetEnd=149 PartOfSpeech=CD Lemma=1 NamedEntityTag=NUMBER NormalizedNamedEntityTag=1.0 SentimentClass=Neutral]
# [Text=receptor CharacterOffsetBegin=150 CharacterOffsetEnd=158 PartOfSpeech=NN Lemma=receptor NamedEntityTag=O SentimentClass=Neutral]
# [Text=blocker CharacterOffsetBegin=159 CharacterOffsetEnd=166 PartOfSpeech=NN Lemma=blocker NamedEntityTag=O SentimentClass=Neutral]
# [Text=-LRB- CharacterOffsetBegin=167 CharacterOffsetEnd=168 PartOfSpeech=-LRB- Lemma=-lrb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=ARB CharacterOffsetBegin=168 CharacterOffsetEnd=171 PartOfSpeech=NN Lemma=arb NamedEntityTag=O SentimentClass=Neutral]
# [Text=-RRB- CharacterOffsetBegin=171 CharacterOffsetEnd=172 PartOfSpeech=-RRB- Lemma=-rrb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=compounds CharacterOffsetBegin=173 CharacterOffsetEnd=182 PartOfSpeech=NNS Lemma=compound NamedEntityTag=O SentimentClass=Neutral]
# [Text=attenuate CharacterOffsetBegin=183 CharacterOffsetEnd=192 PartOfSpeech=VBP Lemma=attenuate NamedEntityTag=O SentimentClass=Neutral]
# [Text=renal CharacterOffsetBegin=193 CharacterOffsetEnd=198 PartOfSpeech=JJ Lemma=renal NamedEntityTag=O SentimentClass=Neutral]
# [Text=fibrosis CharacterOffsetBegin=199 CharacterOffsetEnd=207 PartOfSpeech=NN Lemma=fibrosis NamedEntityTag=O SentimentClass=Neutral]
# [Text=. CharacterOffsetBegin=207 CharacterOffsetEnd=208 PartOfSpeech=. Lemma=. NamedEntityTag=O SentimentClass=Neutral]
# (ROOT
#   (S
#     (NP
#       (NP (DT A) (NN number))
#       (PP (IN of)
#         (NP (JJ experimental)
#           (CC and)
#           (JJ clinical) (NNS investigations))))
#     (VP (VBP support)
#       (NP (DT the) (NN notion))
#       (SBAR (IN that)
#         (S
#           (NP
#             (NP
#               (NP (JJ angiotensin-converting) (NN enzyme) (NN inhibitor))
#               (PRN (-LRB- -LRB-)
#                 (NP (NN ACEi))
#                 (-RRB- -RRB-)))
#             (CC and)
#             (NP
#               (NP (NN angiotensin) (CD II))
#               (NP
#                 (ADJP (NN type) (CD 1))
#                 (NN receptor) (NN blocker)
#                 (PRN (-LRB- -LRB-)
#                   (NP (NN ARB))
#                   (-RRB- -RRB-))
#                 (NNS compounds))))
#           (VP (VBP attenuate)
#             (NP (JJ renal) (NN fibrosis))))))
#     (. .)))
#
# root(ROOT-0, support-8)
# det:qmod(investigations-7, A-1)
# mwe(A-1, number-2)
# mwe(A-1, of-3)
# amod(investigations-7, experimental-4)
# cc(experimental-4, and-5)
# conj:and(experimental-4, clinical-6)
# amod(investigations-7, clinical-6)
# nsubj(support-8, investigations-7)
# det(notion-10, the-9)
# dobj(support-8, notion-10)
# mark(attenuate-29, that-11)
# amod(inhibitor-14, angiotensin-converting-12)
# compound(inhibitor-14, enzyme-13)
# nsubj(attenuate-29, inhibitor-14)
# punct(ACEi-16, -LRB--15)
# appos(inhibitor-14, ACEi-16)
# punct(ACEi-16, -RRB--17)
# cc(inhibitor-14, and-18)
# conj:and(inhibitor-14, angiotensin-19)
# nsubj(attenuate-29, angiotensin-19)
# nummod(angiotensin-19, II-20)
# amod(compounds-28, type-21)
# compound(type-21, 1-22)
# compound(compounds-28, receptor-23)
# compound(compounds-28, blocker-24)
# punct(ARB-26, -LRB--25)
# appos(compounds-28, ARB-26)
# punct(ARB-26, -RRB--27)
# dep(angiotensin-19, compounds-28)
# ccomp(support-8, attenuate-29)
# amod(fibrosis-31, renal-30)
# dobj(attenuate-29, fibrosis-31)
# punct(support-8, .-32)
#
# Sentence #2 (14 tokens, sentiment: Negative):
# Fibrosis can be attenuated by either suppressing matrix formation or facilitating matrix degradation.
# [Text=Fibrosis CharacterOffsetBegin=209 CharacterOffsetEnd=217 PartOfSpeech=NN Lemma=fibrosis NamedEntityTag=O SentimentClass=Neutral]
# [Text=can CharacterOffsetBegin=218 CharacterOffsetEnd=221 PartOfSpeech=MD Lemma=can NamedEntityTag=O SentimentClass=Neutral]
# [Text=be CharacterOffsetBegin=222 CharacterOffsetEnd=224 PartOfSpeech=VB Lemma=be NamedEntityTag=O SentimentClass=Neutral]
# [Text=attenuated CharacterOffsetBegin=225 CharacterOffsetEnd=235 PartOfSpeech=VBN Lemma=attenuate NamedEntityTag=O SentimentClass=Neutral]
# [Text=by CharacterOffsetBegin=236 CharacterOffsetEnd=238 PartOfSpeech=IN Lemma=by NamedEntityTag=O SentimentClass=Neutral]
# [Text=either CharacterOffsetBegin=239 CharacterOffsetEnd=245 PartOfSpeech=CC Lemma=either NamedEntityTag=O SentimentClass=Neutral]
# [Text=suppressing CharacterOffsetBegin=246 CharacterOffsetEnd=257 PartOfSpeech=VBG Lemma=suppress NamedEntityTag=O SentimentClass=Neutral]
# [Text=matrix CharacterOffsetBegin=258 CharacterOffsetEnd=264 PartOfSpeech=NN Lemma=matrix NamedEntityTag=O SentimentClass=Neutral]
# [Text=formation CharacterOffsetBegin=265 CharacterOffsetEnd=274 PartOfSpeech=NN Lemma=formation NamedEntityTag=O SentimentClass=Neutral]
# [Text=or CharacterOffsetBegin=275 CharacterOffsetEnd=277 PartOfSpeech=CC Lemma=or NamedEntityTag=O SentimentClass=Neutral]
# [Text=facilitating CharacterOffsetBegin=278 CharacterOffsetEnd=290 PartOfSpeech=VBG Lemma=facilitate NamedEntityTag=O SentimentClass=Neutral]
# [Text=matrix CharacterOffsetBegin=291 CharacterOffsetEnd=297 PartOfSpeech=NN Lemma=matrix NamedEntityTag=O SentimentClass=Neutral]
# [Text=degradation CharacterOffsetBegin=298 CharacterOffsetEnd=309 PartOfSpeech=NN Lemma=degradation NamedEntityTag=O SentimentClass=Neutral]
# [Text=. CharacterOffsetBegin=309 CharacterOffsetEnd=310 PartOfSpeech=. Lemma=. NamedEntityTag=O SentimentClass=Neutral]
# (ROOT
#   (S
#     (NP (NN Fibrosis))
#     (VP (MD can)
#       (VP (VB be)
#         (VP (VBN attenuated)
#           (PP (IN by)
#             (S
#               (VP (CC either)
#                 (VP (VBG suppressing)
#                   (NP (NN matrix) (NN formation)))
#                 (CC or)
#                 (VP (VBG facilitating)
#                   (NP (NN matrix) (NN degradation)))))))))
#     (. .)))
#
# root(ROOT-0, attenuated-4)
# nsubjpass(attenuated-4, Fibrosis-1)
# aux(attenuated-4, can-2)
# auxpass(attenuated-4, be-3)
# mark(suppressing-7, by-5)
# cc:preconj(suppressing-7, either-6)
# advcl:by(attenuated-4, suppressing-7)
# compound(formation-9, matrix-8)
# dobj(suppressing-7, formation-9)
# cc(suppressing-7, or-10)
# advcl:by(attenuated-4, facilitating-11)
# conj:or(suppressing-7, facilitating-11)
# compound(degradation-13, matrix-12)
# dobj(facilitating-11, degradation-13)
# punct(attenuated-4, .-14)
#
# Sentence #3 (23 tokens, sentiment: Negative):
# In this study, drugs of ACEi and ARB classes were tested for their ability to facilitate matrix degradation in the kidney.
# [Text=In CharacterOffsetBegin=311 CharacterOffsetEnd=313 PartOfSpeech=IN Lemma=in NamedEntityTag=O SentimentClass=Neutral]
# [Text=this CharacterOffsetBegin=314 CharacterOffsetEnd=318 PartOfSpeech=DT Lemma=this NamedEntityTag=O SentimentClass=Neutral]
# [Text=study CharacterOffsetBegin=319 CharacterOffsetEnd=324 PartOfSpeech=NN Lemma=study NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=324 CharacterOffsetEnd=325 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=drugs CharacterOffsetBegin=326 CharacterOffsetEnd=331 PartOfSpeech=NNS Lemma=drug NamedEntityTag=O SentimentClass=Neutral]
# [Text=of CharacterOffsetBegin=332 CharacterOffsetEnd=334 PartOfSpeech=IN Lemma=of NamedEntityTag=O SentimentClass=Neutral]
# [Text=ACEi CharacterOffsetBegin=335 CharacterOffsetEnd=339 PartOfSpeech=NN Lemma=acei NamedEntityTag=O SentimentClass=Neutral]
# [Text=and CharacterOffsetBegin=340 CharacterOffsetEnd=343 PartOfSpeech=CC Lemma=and NamedEntityTag=O SentimentClass=Neutral]
# [Text=ARB CharacterOffsetBegin=344 CharacterOffsetEnd=347 PartOfSpeech=NN Lemma=arb NamedEntityTag=O SentimentClass=Neutral]
# [Text=classes CharacterOffsetBegin=348 CharacterOffsetEnd=355 PartOfSpeech=NNS Lemma=class NamedEntityTag=O SentimentClass=Neutral]
# [Text=were CharacterOffsetBegin=356 CharacterOffsetEnd=360 PartOfSpeech=VBD Lemma=be NamedEntityTag=O SentimentClass=Neutral]
# [Text=tested CharacterOffsetBegin=361 CharacterOffsetEnd=367 PartOfSpeech=VBN Lemma=test NamedEntityTag=O SentimentClass=Neutral]
# [Text=for CharacterOffsetBegin=368 CharacterOffsetEnd=371 PartOfSpeech=IN Lemma=for NamedEntityTag=O SentimentClass=Neutral]
# [Text=their CharacterOffsetBegin=372 CharacterOffsetEnd=377 PartOfSpeech=PRP$ Lemma=they NamedEntityTag=O SentimentClass=Neutral]
# [Text=ability CharacterOffsetBegin=378 CharacterOffsetEnd=385 PartOfSpeech=NN Lemma=ability NamedEntityTag=O SentimentClass=Neutral]
# [Text=to CharacterOffsetBegin=386 CharacterOffsetEnd=388 PartOfSpeech=TO Lemma=to NamedEntityTag=O SentimentClass=Neutral]
# [Text=facilitate CharacterOffsetBegin=389 CharacterOffsetEnd=399 PartOfSpeech=VB Lemma=facilitate NamedEntityTag=O SentimentClass=Neutral]
# [Text=matrix CharacterOffsetBegin=400 CharacterOffsetEnd=406 PartOfSpeech=NN Lemma=matrix NamedEntityTag=O SentimentClass=Neutral]
# [Text=degradation CharacterOffsetBegin=407 CharacterOffsetEnd=418 PartOfSpeech=NN Lemma=degradation NamedEntityTag=O SentimentClass=Neutral]
# [Text=in CharacterOffsetBegin=419 CharacterOffsetEnd=421 PartOfSpeech=IN Lemma=in NamedEntityTag=O SentimentClass=Neutral]
# [Text=the CharacterOffsetBegin=422 CharacterOffsetEnd=425 PartOfSpeech=DT Lemma=the NamedEntityTag=O SentimentClass=Neutral]
# [Text=kidney CharacterOffsetBegin=426 CharacterOffsetEnd=432 PartOfSpeech=NN Lemma=kidney NamedEntityTag=O SentimentClass=Neutral]
# [Text=. CharacterOffsetBegin=432 CharacterOffsetEnd=433 PartOfSpeech=. Lemma=. NamedEntityTag=O SentimentClass=Neutral]
# (ROOT
#   (S
#     (PP (IN In)
#       (NP (DT this) (NN study)))
#     (, ,)
#     (NP
#       (NP (NNS drugs))
#       (PP (IN of)
#         (NP (NN ACEi)
#           (CC and)
#           (NN ARB) (NNS classes))))
#     (VP (VBD were)
#       (VP (VBN tested)
#         (PP (IN for)
#           (NP (PRP$ their) (NN ability)
#             (S
#               (VP (TO to)
#                 (VP (VB facilitate)
#                   (NP (NN matrix) (NN degradation))
#                   (PP (IN in)
#                     (NP (DT the) (NN kidney))))))))))
#     (. .)))
#
# root(ROOT-0, tested-12)
# case(study-3, In-1)
# det(study-3, this-2)
# nmod:in(tested-12, study-3)
# punct(tested-12, ,-4)
# nsubjpass(tested-12, drugs-5)
# case(classes-10, of-6)
# compound(classes-10, ACEi-7)
# cc(ACEi-7, and-8)
# conj:and(ACEi-7, ARB-9)
# compound(classes-10, ARB-9)
# nmod:of(drugs-5, classes-10)
# auxpass(tested-12, were-11)
# case(ability-15, for-13)
# nmod:poss(ability-15, their-14)
# nmod:for(tested-12, ability-15)
# mark(facilitate-17, to-16)
# acl:to(ability-15, facilitate-17)
# compound(degradation-19, matrix-18)
# dobj(facilitate-17, degradation-19)
# case(kidney-22, in-20)
# det(kidney-22, the-21)
# nmod:in(facilitate-17, kidney-22)
# punct(tested-12, .-23)
#
# Sentence #4 (26 tokens, sentiment: Negative):
# A murine model system in which cyclosporin A (CsA) treatment for a specified period caused interstitial matrix deposition in the kidney was used.
# [Text=A CharacterOffsetBegin=434 CharacterOffsetEnd=435 PartOfSpeech=DT Lemma=a NamedEntityTag=O SentimentClass=Neutral]
# [Text=murine CharacterOffsetBegin=436 CharacterOffsetEnd=442 PartOfSpeech=JJ Lemma=murine NamedEntityTag=O SentimentClass=Neutral]
# [Text=model CharacterOffsetBegin=443 CharacterOffsetEnd=448 PartOfSpeech=NN Lemma=model NamedEntityTag=O SentimentClass=Positive]
# [Text=system CharacterOffsetBegin=449 CharacterOffsetEnd=455 PartOfSpeech=NN Lemma=system NamedEntityTag=O SentimentClass=Neutral]
# [Text=in CharacterOffsetBegin=456 CharacterOffsetEnd=458 PartOfSpeech=IN Lemma=in NamedEntityTag=O SentimentClass=Neutral]
# [Text=which CharacterOffsetBegin=459 CharacterOffsetEnd=464 PartOfSpeech=WDT Lemma=which NamedEntityTag=O SentimentClass=Neutral]
# [Text=cyclosporin CharacterOffsetBegin=465 CharacterOffsetEnd=476 PartOfSpeech=NN Lemma=cyclosporin NamedEntityTag=O SentimentClass=Neutral]
# [Text=A CharacterOffsetBegin=477 CharacterOffsetEnd=478 PartOfSpeech=NN Lemma=a NamedEntityTag=O SentimentClass=Neutral]
# [Text=-LRB- CharacterOffsetBegin=479 CharacterOffsetEnd=480 PartOfSpeech=-LRB- Lemma=-lrb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=CsA CharacterOffsetBegin=480 CharacterOffsetEnd=483 PartOfSpeech=NN Lemma=csa NamedEntityTag=O SentimentClass=Neutral]
# [Text=-RRB- CharacterOffsetBegin=483 CharacterOffsetEnd=484 PartOfSpeech=-RRB- Lemma=-rrb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=treatment CharacterOffsetBegin=485 CharacterOffsetEnd=494 PartOfSpeech=NN Lemma=treatment NamedEntityTag=O SentimentClass=Neutral]
# [Text=for CharacterOffsetBegin=495 CharacterOffsetEnd=498 PartOfSpeech=IN Lemma=for NamedEntityTag=O SentimentClass=Neutral]
# [Text=a CharacterOffsetBegin=499 CharacterOffsetEnd=500 PartOfSpeech=DT Lemma=a NamedEntityTag=O SentimentClass=Neutral]
# [Text=specified CharacterOffsetBegin=501 CharacterOffsetEnd=510 PartOfSpeech=JJ Lemma=specified NamedEntityTag=O SentimentClass=Neutral]
# [Text=period CharacterOffsetBegin=511 CharacterOffsetEnd=517 PartOfSpeech=NN Lemma=period NamedEntityTag=O SentimentClass=Neutral]
# [Text=caused CharacterOffsetBegin=518 CharacterOffsetEnd=524 PartOfSpeech=VBD Lemma=cause NamedEntityTag=O SentimentClass=Neutral]
# [Text=interstitial CharacterOffsetBegin=525 CharacterOffsetEnd=537 PartOfSpeech=JJ Lemma=interstitial NamedEntityTag=O SentimentClass=Neutral]
# [Text=matrix CharacterOffsetBegin=538 CharacterOffsetEnd=544 PartOfSpeech=NN Lemma=matrix NamedEntityTag=O SentimentClass=Neutral]
# [Text=deposition CharacterOffsetBegin=545 CharacterOffsetEnd=555 PartOfSpeech=NN Lemma=deposition NamedEntityTag=O SentimentClass=Neutral]
# [Text=in CharacterOffsetBegin=556 CharacterOffsetEnd=558 PartOfSpeech=IN Lemma=in NamedEntityTag=O SentimentClass=Neutral]
# [Text=the CharacterOffsetBegin=559 CharacterOffsetEnd=562 PartOfSpeech=DT Lemma=the NamedEntityTag=O SentimentClass=Neutral]
# [Text=kidney CharacterOffsetBegin=563 CharacterOffsetEnd=569 PartOfSpeech=NN Lemma=kidney NamedEntityTag=O SentimentClass=Neutral]
# [Text=was CharacterOffsetBegin=570 CharacterOffsetEnd=573 PartOfSpeech=VBD Lemma=be NamedEntityTag=O SentimentClass=Neutral]
# [Text=used CharacterOffsetBegin=574 CharacterOffsetEnd=578 PartOfSpeech=VBN Lemma=use NamedEntityTag=O SentimentClass=Neutral]
# [Text=. CharacterOffsetBegin=578 CharacterOffsetEnd=579 PartOfSpeech=. Lemma=. NamedEntityTag=O SentimentClass=Neutral]
# (ROOT
#   (S
#     (NP
#       (NP (DT A) (JJ murine) (NN model) (NN system))
#       (SBAR
#         (WHPP (IN in)
#           (WHNP (WDT which)))
#         (S
#           (NP
#             (NP
#               (NP
#                 (NP (NN cyclosporin) (NN A))
#                 (PRN (-LRB- -LRB-)
#                   (NP (NN CsA))
#                   (-RRB- -RRB-)))
#               (NN treatment))
#             (PP (IN for)
#               (NP (DT a) (JJ specified) (NN period))))
#           (VP (VBD caused)
#             (NP (JJ interstitial) (NN matrix) (NN deposition))
#             (PP (IN in)
#               (NP (DT the) (NN kidney)))))))
#     (VP (VBD was)
#       (VP (VBN used)))
#     (. .)))
#
# root(ROOT-0, used-25)
# det(system-4, A-1)
# amod(system-4, murine-2)
# compound(system-4, model-3)
# nmod:in(caused-17, system-4)
# nsubjpass(used-25, system-4)
# case(which-6, in-5)
# ref(system-4, which-6)
# compound(A-8, cyclosporin-7)
# compound(treatment-12, A-8)
# punct(CsA-10, -LRB--9)
# appos(A-8, CsA-10)
# punct(CsA-10, -RRB--11)
# nsubj(caused-17, treatment-12)
# case(period-16, for-13)
# det(period-16, a-14)
# amod(period-16, specified-15)
# nmod:for(treatment-12, period-16)
# acl:relcl(system-4, caused-17)
# amod(deposition-20, interstitial-18)
# compound(deposition-20, matrix-19)
# dobj(caused-17, deposition-20)
# case(kidney-23, in-21)
# det(kidney-23, the-22)
# nmod:in(caused-17, kidney-23)
# auxpass(used-25, was-24)
# punct(used-25, .-26)
#
# Sentence #5 (15 tokens, sentiment: Negative):
# CsA was then discontinued, and experimental procedures were initiated to investigate matrix degradation.
# [Text=CsA CharacterOffsetBegin=580 CharacterOffsetEnd=583 PartOfSpeech=NN Lemma=csa NamedEntityTag=O SentimentClass=Neutral]
# [Text=was CharacterOffsetBegin=584 CharacterOffsetEnd=587 PartOfSpeech=VBD Lemma=be NamedEntityTag=O SentimentClass=Neutral]
# [Text=then CharacterOffsetBegin=588 CharacterOffsetEnd=592 PartOfSpeech=RB Lemma=then NamedEntityTag=O SentimentClass=Neutral]
# [Text=discontinued CharacterOffsetBegin=593 CharacterOffsetEnd=605 PartOfSpeech=VBN Lemma=discontinue NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=605 CharacterOffsetEnd=606 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=and CharacterOffsetBegin=607 CharacterOffsetEnd=610 PartOfSpeech=CC Lemma=and NamedEntityTag=O SentimentClass=Neutral]
# [Text=experimental CharacterOffsetBegin=611 CharacterOffsetEnd=623 PartOfSpeech=JJ Lemma=experimental NamedEntityTag=O SentimentClass=Neutral]
# [Text=procedures CharacterOffsetBegin=624 CharacterOffsetEnd=634 PartOfSpeech=NNS Lemma=procedure NamedEntityTag=O SentimentClass=Neutral]
# [Text=were CharacterOffsetBegin=635 CharacterOffsetEnd=639 PartOfSpeech=VBD Lemma=be NamedEntityTag=O SentimentClass=Neutral]
# [Text=initiated CharacterOffsetBegin=640 CharacterOffsetEnd=649 PartOfSpeech=VBN Lemma=initiate NamedEntityTag=O SentimentClass=Neutral]
# [Text=to CharacterOffsetBegin=650 CharacterOffsetEnd=652 PartOfSpeech=TO Lemma=to NamedEntityTag=O SentimentClass=Neutral]
# [Text=investigate CharacterOffsetBegin=653 CharacterOffsetEnd=664 PartOfSpeech=VB Lemma=investigate NamedEntityTag=O SentimentClass=Neutral]
# [Text=matrix CharacterOffsetBegin=665 CharacterOffsetEnd=671 PartOfSpeech=NN Lemma=matrix NamedEntityTag=O SentimentClass=Neutral]
# [Text=degradation CharacterOffsetBegin=672 CharacterOffsetEnd=683 PartOfSpeech=NN Lemma=degradation NamedEntityTag=O SentimentClass=Neutral]
# [Text=. CharacterOffsetBegin=683 CharacterOffsetEnd=684 PartOfSpeech=. Lemma=. NamedEntityTag=O SentimentClass=Neutral]
# (ROOT
#   (S
#     (S
#       (NP (NN CsA))
#       (VP (VBD was)
#         (VP
#           (ADVP (RB then))
#           (VBN discontinued))))
#     (, ,)
#     (CC and)
#     (S
#       (NP (JJ experimental) (NNS procedures))
#       (VP (VBD were)
#         (VP (VBN initiated)
#           (S
#             (VP (TO to)
#               (VP (VB investigate)
#                 (NP (NN matrix) (NN degradation))))))))
#     (. .)))
#
# root(ROOT-0, discontinued-4)
# nsubjpass(discontinued-4, CsA-1)
# auxpass(discontinued-4, was-2)
# advmod(discontinued-4, then-3)
# punct(discontinued-4, ,-5)
# cc(discontinued-4, and-6)
# amod(procedures-8, experimental-7)
# nsubjpass(initiated-10, procedures-8)
# nsubj:xsubj(investigate-12, procedures-8)
# auxpass(initiated-10, were-9)
# conj:and(discontinued-4, initiated-10)
# mark(investigate-12, to-11)
# xcomp(initiated-10, investigate-12)
# compound(degradation-14, matrix-13)
# dobj(investigate-12, degradation-14)
# punct(discontinued-4, .-15)
#
# Sentence #6 (33 tokens, sentiment: Negative):
# Benazepril, an ACEi, facilitated matrix degradation via the bradykinin (BK) B2 receptor on tubular epithelial cells in the kidney, whereas CGP-48933, an ARB, did not.
# [Text=Benazepril CharacterOffsetBegin=685 CharacterOffsetEnd=695 PartOfSpeech=NNP Lemma=Benazepril NamedEntityTag=PERSON SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=695 CharacterOffsetEnd=696 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=an CharacterOffsetBegin=697 CharacterOffsetEnd=699 PartOfSpeech=DT Lemma=a NamedEntityTag=O SentimentClass=Neutral]
# [Text=ACEi CharacterOffsetBegin=700 CharacterOffsetEnd=704 PartOfSpeech=NN Lemma=acei NamedEntityTag=MISC SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=704 CharacterOffsetEnd=705 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=facilitated CharacterOffsetBegin=706 CharacterOffsetEnd=717 PartOfSpeech=VBD Lemma=facilitate NamedEntityTag=O SentimentClass=Neutral]
# [Text=matrix CharacterOffsetBegin=718 CharacterOffsetEnd=724 PartOfSpeech=NN Lemma=matrix NamedEntityTag=O SentimentClass=Neutral]
# [Text=degradation CharacterOffsetBegin=725 CharacterOffsetEnd=736 PartOfSpeech=NN Lemma=degradation NamedEntityTag=O SentimentClass=Neutral]
# [Text=via CharacterOffsetBegin=737 CharacterOffsetEnd=740 PartOfSpeech=IN Lemma=via NamedEntityTag=O SentimentClass=Neutral]
# [Text=the CharacterOffsetBegin=741 CharacterOffsetEnd=744 PartOfSpeech=DT Lemma=the NamedEntityTag=O SentimentClass=Neutral]
# [Text=bradykinin CharacterOffsetBegin=745 CharacterOffsetEnd=755 PartOfSpeech=NN Lemma=bradykinin NamedEntityTag=O SentimentClass=Neutral]
# [Text=-LRB- CharacterOffsetBegin=756 CharacterOffsetEnd=757 PartOfSpeech=-LRB- Lemma=-lrb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=BK CharacterOffsetBegin=757 CharacterOffsetEnd=759 PartOfSpeech=NN Lemma=bk NamedEntityTag=O SentimentClass=Neutral]
# [Text=-RRB- CharacterOffsetBegin=759 CharacterOffsetEnd=760 PartOfSpeech=-RRB- Lemma=-rrb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=B2 CharacterOffsetBegin=761 CharacterOffsetEnd=763 PartOfSpeech=NN Lemma=b2 NamedEntityTag=O SentimentClass=Neutral]
# [Text=receptor CharacterOffsetBegin=764 CharacterOffsetEnd=772 PartOfSpeech=NN Lemma=receptor NamedEntityTag=O SentimentClass=Neutral]
# [Text=on CharacterOffsetBegin=773 CharacterOffsetEnd=775 PartOfSpeech=IN Lemma=on NamedEntityTag=O SentimentClass=Neutral]
# [Text=tubular CharacterOffsetBegin=776 CharacterOffsetEnd=783 PartOfSpeech=JJ Lemma=tubular NamedEntityTag=O SentimentClass=Neutral]
# [Text=epithelial CharacterOffsetBegin=784 CharacterOffsetEnd=794 PartOfSpeech=JJ Lemma=epithelial NamedEntityTag=O SentimentClass=Neutral]
# [Text=cells CharacterOffsetBegin=795 CharacterOffsetEnd=800 PartOfSpeech=NNS Lemma=cell NamedEntityTag=O SentimentClass=Neutral]
# [Text=in CharacterOffsetBegin=801 CharacterOffsetEnd=803 PartOfSpeech=IN Lemma=in NamedEntityTag=O SentimentClass=Neutral]
# [Text=the CharacterOffsetBegin=804 CharacterOffsetEnd=807 PartOfSpeech=DT Lemma=the NamedEntityTag=O SentimentClass=Neutral]
# [Text=kidney CharacterOffsetBegin=808 CharacterOffsetEnd=814 PartOfSpeech=NN Lemma=kidney NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=814 CharacterOffsetEnd=815 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=whereas CharacterOffsetBegin=816 CharacterOffsetEnd=823 PartOfSpeech=IN Lemma=whereas NamedEntityTag=O SentimentClass=Neutral]
# [Text=CGP-48933 CharacterOffsetBegin=824 CharacterOffsetEnd=833 PartOfSpeech=NN Lemma=cgp-48933 NamedEntityTag=MISC SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=833 CharacterOffsetEnd=834 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=an CharacterOffsetBegin=835 CharacterOffsetEnd=837 PartOfSpeech=DT Lemma=a NamedEntityTag=O SentimentClass=Neutral]
# [Text=ARB CharacterOffsetBegin=838 CharacterOffsetEnd=841 PartOfSpeech=NN Lemma=arb NamedEntityTag=MISC SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=841 CharacterOffsetEnd=842 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=did CharacterOffsetBegin=843 CharacterOffsetEnd=846 PartOfSpeech=VBD Lemma=do NamedEntityTag=O SentimentClass=Neutral]
# [Text=not CharacterOffsetBegin=847 CharacterOffsetEnd=850 PartOfSpeech=RB Lemma=not NamedEntityTag=O SentimentClass=Negative]
# [Text=. CharacterOffsetBegin=850 CharacterOffsetEnd=851 PartOfSpeech=. Lemma=. NamedEntityTag=O SentimentClass=Neutral]
# (ROOT
#   (S
#     (NP
#       (NP (NNP Benazepril))
#       (, ,)
#       (NP (DT an) (NN ACEi))
#       (, ,))
#     (VP (VBD facilitated)
#       (NP
#         (NP (NN matrix) (NN degradation))
#         (PP (IN via)
#           (NP (DT the) (NN bradykinin)))
#         (PRN (-LRB- -LRB-)
#           (NP (NN BK))
#           (-RRB- -RRB-))
#         (NP
#           (NP (NN B2) (NN receptor))
#           (PP (IN on)
#             (NP
#               (NP (JJ tubular) (JJ epithelial) (NNS cells))
#               (PP (IN in)
#                 (NP
#                   (NP (DT the) (NN kidney))
#                   (, ,)
#                   (SBAR (IN whereas)
#                     (S
#                       (NP
#                         (NP (NN CGP-48933))
#                         (, ,)
#                         (NP (DT an) (NN ARB))
#                         (, ,))
#                       (VP (VBD did) (RB not)))))))))))
#     (. .)))
#
# root(ROOT-0, facilitated-6)
# nsubj(facilitated-6, Benazepril-1)
# punct(Benazepril-1, ,-2)
# det(ACEi-4, an-3)
# appos(Benazepril-1, ACEi-4)
# punct(Benazepril-1, ,-5)
# compound(degradation-8, matrix-7)
# dobj(facilitated-6, degradation-8)
# case(bradykinin-11, via-9)
# det(bradykinin-11, the-10)
# nmod:via(degradation-8, bradykinin-11)
# punct(BK-13, -LRB--12)
# appos(degradation-8, BK-13)
# punct(BK-13, -RRB--14)
# compound(receptor-16, B2-15)
# dep(degradation-8, receptor-16)
# case(cells-20, on-17)
# amod(cells-20, tubular-18)
# amod(cells-20, epithelial-19)
# nmod:on(receptor-16, cells-20)
# case(kidney-23, in-21)
# det(kidney-23, the-22)
# nmod:in(cells-20, kidney-23)
# punct(kidney-23, ,-24)
# mark(did-31, whereas-25)
# nsubj(did-31, CGP-48933-26)
# punct(CGP-48933-26, ,-27)
# det(ARB-29, an-28)
# appos(CGP-48933-26, ARB-29)
# punct(CGP-48933-26, ,-30)
# acl:relcl(kidney-23, did-31)
# neg(did-31, not-32)
# punct(facilitated-6, .-33)
#
# Sentence #7 (43 tokens, sentiment: Very negative):
# In this murine model of CsA nephropathy under ACE blockade, plasminogen activator inhibitor-1 (PAI-1) expression was decreased in tubular epithelial cells, possibly leading to conversion of plasminogen to plasmin by plasminogen activator and subsequent activation of matrix metalloproteinases.
# [Text=In CharacterOffsetBegin=852 CharacterOffsetEnd=854 PartOfSpeech=IN Lemma=in NamedEntityTag=O SentimentClass=Neutral]
# [Text=this CharacterOffsetBegin=855 CharacterOffsetEnd=859 PartOfSpeech=DT Lemma=this NamedEntityTag=O SentimentClass=Neutral]
# [Text=murine CharacterOffsetBegin=860 CharacterOffsetEnd=866 PartOfSpeech=JJ Lemma=murine NamedEntityTag=O SentimentClass=Neutral]
# [Text=model CharacterOffsetBegin=867 CharacterOffsetEnd=872 PartOfSpeech=NN Lemma=model NamedEntityTag=O SentimentClass=Positive]
# [Text=of CharacterOffsetBegin=873 CharacterOffsetEnd=875 PartOfSpeech=IN Lemma=of NamedEntityTag=O SentimentClass=Neutral]
# [Text=CsA CharacterOffsetBegin=876 CharacterOffsetEnd=879 PartOfSpeech=NN Lemma=csa NamedEntityTag=O SentimentClass=Neutral]
# [Text=nephropathy CharacterOffsetBegin=880 CharacterOffsetEnd=891 PartOfSpeech=NN Lemma=nephropathy NamedEntityTag=O SentimentClass=Neutral]
# [Text=under CharacterOffsetBegin=892 CharacterOffsetEnd=897 PartOfSpeech=IN Lemma=under NamedEntityTag=O SentimentClass=Neutral]
# [Text=ACE CharacterOffsetBegin=898 CharacterOffsetEnd=901 PartOfSpeech=NN Lemma=ace NamedEntityTag=O SentimentClass=Neutral]
# [Text=blockade CharacterOffsetBegin=902 CharacterOffsetEnd=910 PartOfSpeech=NN Lemma=blockade NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=910 CharacterOffsetEnd=911 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=plasminogen CharacterOffsetBegin=912 CharacterOffsetEnd=923 PartOfSpeech=NN Lemma=plasminogen NamedEntityTag=O SentimentClass=Neutral]
# [Text=activator CharacterOffsetBegin=924 CharacterOffsetEnd=933 PartOfSpeech=NN Lemma=activator NamedEntityTag=O SentimentClass=Neutral]
# [Text=inhibitor-1 CharacterOffsetBegin=934 CharacterOffsetEnd=945 PartOfSpeech=NN Lemma=inhibitor-1 NamedEntityTag=O SentimentClass=Neutral]
# [Text=-LRB- CharacterOffsetBegin=946 CharacterOffsetEnd=947 PartOfSpeech=-LRB- Lemma=-lrb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=PAI-1 CharacterOffsetBegin=947 CharacterOffsetEnd=952 PartOfSpeech=NN Lemma=pai-1 NamedEntityTag=O SentimentClass=Neutral]
# [Text=-RRB- CharacterOffsetBegin=952 CharacterOffsetEnd=953 PartOfSpeech=-RRB- Lemma=-rrb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=expression CharacterOffsetBegin=954 CharacterOffsetEnd=964 PartOfSpeech=NN Lemma=expression NamedEntityTag=O SentimentClass=Neutral]
# [Text=was CharacterOffsetBegin=965 CharacterOffsetEnd=968 PartOfSpeech=VBD Lemma=be NamedEntityTag=O SentimentClass=Neutral]
# [Text=decreased CharacterOffsetBegin=969 CharacterOffsetEnd=978 PartOfSpeech=VBN Lemma=decrease NamedEntityTag=O SentimentClass=Neutral]
# [Text=in CharacterOffsetBegin=979 CharacterOffsetEnd=981 PartOfSpeech=IN Lemma=in NamedEntityTag=O SentimentClass=Neutral]
# [Text=tubular CharacterOffsetBegin=982 CharacterOffsetEnd=989 PartOfSpeech=JJ Lemma=tubular NamedEntityTag=O SentimentClass=Neutral]
# [Text=epithelial CharacterOffsetBegin=990 CharacterOffsetEnd=1000 PartOfSpeech=JJ Lemma=epithelial NamedEntityTag=O SentimentClass=Neutral]
# [Text=cells CharacterOffsetBegin=1001 CharacterOffsetEnd=1006 PartOfSpeech=NNS Lemma=cell NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=1006 CharacterOffsetEnd=1007 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=possibly CharacterOffsetBegin=1008 CharacterOffsetEnd=1016 PartOfSpeech=RB Lemma=possibly NamedEntityTag=O SentimentClass=Neutral]
# [Text=leading CharacterOffsetBegin=1017 CharacterOffsetEnd=1024 PartOfSpeech=VBG Lemma=lead NamedEntityTag=O SentimentClass=Neutral]
# [Text=to CharacterOffsetBegin=1025 CharacterOffsetEnd=1027 PartOfSpeech=TO Lemma=to NamedEntityTag=O SentimentClass=Neutral]
# [Text=conversion CharacterOffsetBegin=1028 CharacterOffsetEnd=1038 PartOfSpeech=NN Lemma=conversion NamedEntityTag=O SentimentClass=Neutral]
# [Text=of CharacterOffsetBegin=1039 CharacterOffsetEnd=1041 PartOfSpeech=IN Lemma=of NamedEntityTag=O SentimentClass=Neutral]
# [Text=plasminogen CharacterOffsetBegin=1042 CharacterOffsetEnd=1053 PartOfSpeech=NN Lemma=plasminogen NamedEntityTag=O SentimentClass=Neutral]
# [Text=to CharacterOffsetBegin=1054 CharacterOffsetEnd=1056 PartOfSpeech=TO Lemma=to NamedEntityTag=O SentimentClass=Neutral]
# [Text=plasmin CharacterOffsetBegin=1057 CharacterOffsetEnd=1064 PartOfSpeech=NN Lemma=plasmin NamedEntityTag=O SentimentClass=Neutral]
# [Text=by CharacterOffsetBegin=1065 CharacterOffsetEnd=1067 PartOfSpeech=IN Lemma=by NamedEntityTag=O SentimentClass=Neutral]
# [Text=plasminogen CharacterOffsetBegin=1068 CharacterOffsetEnd=1079 PartOfSpeech=NN Lemma=plasminogen NamedEntityTag=O SentimentClass=Neutral]
# [Text=activator CharacterOffsetBegin=1080 CharacterOffsetEnd=1089 PartOfSpeech=NN Lemma=activator NamedEntityTag=O SentimentClass=Neutral]
# [Text=and CharacterOffsetBegin=1090 CharacterOffsetEnd=1093 PartOfSpeech=CC Lemma=and NamedEntityTag=O SentimentClass=Neutral]
# [Text=subsequent CharacterOffsetBegin=1094 CharacterOffsetEnd=1104 PartOfSpeech=JJ Lemma=subsequent NamedEntityTag=O SentimentClass=Neutral]
# [Text=activation CharacterOffsetBegin=1105 CharacterOffsetEnd=1115 PartOfSpeech=NN Lemma=activation NamedEntityTag=O SentimentClass=Neutral]
# [Text=of CharacterOffsetBegin=1116 CharacterOffsetEnd=1118 PartOfSpeech=IN Lemma=of NamedEntityTag=O SentimentClass=Neutral]
# [Text=matrix CharacterOffsetBegin=1119 CharacterOffsetEnd=1125 PartOfSpeech=NN Lemma=matrix NamedEntityTag=O SentimentClass=Neutral]
# [Text=metalloproteinases CharacterOffsetBegin=1126 CharacterOffsetEnd=1144 PartOfSpeech=NNS Lemma=metalloproteinase NamedEntityTag=O SentimentClass=Neutral]
# [Text=. CharacterOffsetBegin=1144 CharacterOffsetEnd=1145 PartOfSpeech=. Lemma=. NamedEntityTag=O SentimentClass=Neutral]
# (ROOT
#   (S
#     (PP (IN In)
#       (NP
#         (NP (DT this) (JJ murine) (NN model))
#         (PP (IN of)
#           (NP
#             (NP (NN CsA) (NN nephropathy))
#             (PP (IN under)
#               (NP
#                 (NP (NN ACE) (NN blockade))
#                 (, ,)
#                 (NP
#                   (NP (NN plasminogen) (NN activator) (NN inhibitor-1))
#                   (PRN (-LRB- -LRB-)
#                     (NP (NN PAI-1))
#                     (-RRB- -RRB-)))))))))
#     (NP (NN expression))
#     (VP (VBD was)
#       (VP (VBN decreased)
#         (PP (IN in)
#           (NP (JJ tubular) (JJ epithelial) (NNS cells)))
#         (, ,)
#         (S
#           (ADVP (RB possibly))
#           (VP (VBG leading)
#             (PP (TO to)
#               (NP
#                 (NP (NN conversion))
#                 (PP (IN of)
#                   (NP (NN plasminogen)))))
#             (PP (TO to)
#               (NP
#                 (NP
#                   (NP (NN plasmin))
#                   (PP (IN by)
#                     (NP (NN plasminogen) (NN activator))))
#                 (CC and)
#                 (NP
#                   (NP (JJ subsequent) (NN activation))
#                   (PP (IN of)
#                     (NP (NN matrix) (NNS metalloproteinases))))))))))
#     (. .)))
#
# root(ROOT-0, decreased-20)
# case(model-4, In-1)
# det(model-4, this-2)
# amod(model-4, murine-3)
# nmod:in(decreased-20, model-4)
# case(nephropathy-7, of-5)
# compound(nephropathy-7, CsA-6)
# nmod:of(model-4, nephropathy-7)
# case(blockade-10, under-8)
# compound(blockade-10, ACE-9)
# nmod:under(nephropathy-7, blockade-10)
# punct(blockade-10, ,-11)
# compound(inhibitor-1-14, plasminogen-12)
# compound(inhibitor-1-14, activator-13)
# appos(blockade-10, inhibitor-1-14)
# punct(PAI-1-16, -LRB--15)
# appos(inhibitor-1-14, PAI-1-16)
# punct(PAI-1-16, -RRB--17)
# nsubjpass(decreased-20, expression-18)
# auxpass(decreased-20, was-19)
# case(cells-24, in-21)
# amod(cells-24, tubular-22)
# amod(cells-24, epithelial-23)
# nmod:in(decreased-20, cells-24)
# punct(decreased-20, ,-25)
# advmod(leading-27, possibly-26)
# xcomp(decreased-20, leading-27)
# case(conversion-29, to-28)
# nmod:to(leading-27, conversion-29)
# case(plasminogen-31, of-30)
# nmod:of(conversion-29, plasminogen-31)
# case(plasmin-33, to-32)
# nmod:to(leading-27, plasmin-33)
# case(activator-36, by-34)
# compound(activator-36, plasminogen-35)
# nmod:by(plasmin-33, activator-36)
# cc(plasmin-33, and-37)
# amod(activation-39, subsequent-38)
# nmod:to(leading-27, activation-39)
# conj:and(plasmin-33, activation-39)
# case(metalloproteinases-42, of-40)
# compound(metalloproteinases-42, matrix-41)
# nmod:of(activation-39, metalloproteinases-42)
# punct(decreased-20, .-43)
#
# Sentence #8 (24 tokens, sentiment: Negative):
# These findings were confirmed in this study by measurements of plasmin activity, collagenolytic activity, and matrix metalloproteinase activities in the kidneys.
# [Text=These CharacterOffsetBegin=1146 CharacterOffsetEnd=1151 PartOfSpeech=DT Lemma=these NamedEntityTag=O SentimentClass=Neutral]
# [Text=findings CharacterOffsetBegin=1152 CharacterOffsetEnd=1160 PartOfSpeech=NNS Lemma=finding NamedEntityTag=O SentimentClass=Neutral]
# [Text=were CharacterOffsetBegin=1161 CharacterOffsetEnd=1165 PartOfSpeech=VBD Lemma=be NamedEntityTag=O SentimentClass=Neutral]
# [Text=confirmed CharacterOffsetBegin=1166 CharacterOffsetEnd=1175 PartOfSpeech=VBN Lemma=confirm NamedEntityTag=O SentimentClass=Neutral]
# [Text=in CharacterOffsetBegin=1176 CharacterOffsetEnd=1178 PartOfSpeech=IN Lemma=in NamedEntityTag=O SentimentClass=Neutral]
# [Text=this CharacterOffsetBegin=1179 CharacterOffsetEnd=1183 PartOfSpeech=DT Lemma=this NamedEntityTag=O SentimentClass=Neutral]
# [Text=study CharacterOffsetBegin=1184 CharacterOffsetEnd=1189 PartOfSpeech=NN Lemma=study NamedEntityTag=O SentimentClass=Neutral]
# [Text=by CharacterOffsetBegin=1190 CharacterOffsetEnd=1192 PartOfSpeech=IN Lemma=by NamedEntityTag=O SentimentClass=Neutral]
# [Text=measurements CharacterOffsetBegin=1193 CharacterOffsetEnd=1205 PartOfSpeech=NNS Lemma=measurement NamedEntityTag=O SentimentClass=Neutral]
# [Text=of CharacterOffsetBegin=1206 CharacterOffsetEnd=1208 PartOfSpeech=IN Lemma=of NamedEntityTag=O SentimentClass=Neutral]
# [Text=plasmin CharacterOffsetBegin=1209 CharacterOffsetEnd=1216 PartOfSpeech=JJ Lemma=plasmin NamedEntityTag=O SentimentClass=Neutral]
# [Text=activity CharacterOffsetBegin=1217 CharacterOffsetEnd=1225 PartOfSpeech=NN Lemma=activity NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=1225 CharacterOffsetEnd=1226 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=collagenolytic CharacterOffsetBegin=1227 CharacterOffsetEnd=1241 PartOfSpeech=JJ Lemma=collagenolytic NamedEntityTag=O SentimentClass=Neutral]
# [Text=activity CharacterOffsetBegin=1242 CharacterOffsetEnd=1250 PartOfSpeech=NN Lemma=activity NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=1250 CharacterOffsetEnd=1251 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=and CharacterOffsetBegin=1252 CharacterOffsetEnd=1255 PartOfSpeech=CC Lemma=and NamedEntityTag=O SentimentClass=Neutral]
# [Text=matrix CharacterOffsetBegin=1256 CharacterOffsetEnd=1262 PartOfSpeech=NN Lemma=matrix NamedEntityTag=O SentimentClass=Neutral]
# [Text=metalloproteinase CharacterOffsetBegin=1263 CharacterOffsetEnd=1280 PartOfSpeech=NN Lemma=metalloproteinase NamedEntityTag=O SentimentClass=Neutral]
# [Text=activities CharacterOffsetBegin=1281 CharacterOffsetEnd=1291 PartOfSpeech=NNS Lemma=activity NamedEntityTag=O SentimentClass=Neutral]
# [Text=in CharacterOffsetBegin=1292 CharacterOffsetEnd=1294 PartOfSpeech=IN Lemma=in NamedEntityTag=O SentimentClass=Neutral]
# [Text=the CharacterOffsetBegin=1295 CharacterOffsetEnd=1298 PartOfSpeech=DT Lemma=the NamedEntityTag=O SentimentClass=Neutral]
# [Text=kidneys CharacterOffsetBegin=1299 CharacterOffsetEnd=1306 PartOfSpeech=NNS Lemma=kidney NamedEntityTag=O SentimentClass=Neutral]
# [Text=. CharacterOffsetBegin=1306 CharacterOffsetEnd=1307 PartOfSpeech=. Lemma=. NamedEntityTag=O SentimentClass=Neutral]
# (ROOT
#   (S
#     (NP (DT These) (NNS findings))
#     (VP (VBD were)
#       (VP (VBN confirmed)
#         (PP (IN in)
#           (NP (DT this) (NN study)))
#         (PP (IN by)
#           (NP
#             (NP (NNS measurements))
#             (PP (IN of)
#               (NP
#                 (NP (JJ plasmin) (NN activity))
#                 (, ,)
#                 (NP (JJ collagenolytic) (NN activity))
#                 (, ,)
#                 (CC and)
#                 (NP
#                   (NP (NN matrix) (NN metalloproteinase) (NNS activities))
#                   (PP (IN in)
#                     (NP (DT the) (NNS kidneys))))))))))
#     (. .)))
#
# root(ROOT-0, confirmed-4)
# det(findings-2, These-1)
# nsubjpass(confirmed-4, findings-2)
# auxpass(confirmed-4, were-3)
# case(study-7, in-5)
# det(study-7, this-6)
# nmod:in(confirmed-4, study-7)
# case(measurements-9, by-8)
# nmod:agent(confirmed-4, measurements-9)
# case(activity-12, of-10)
# amod(activity-12, plasmin-11)
# nmod:of(measurements-9, activity-12)
# punct(activity-12, ,-13)
# amod(activity-15, collagenolytic-14)
# nmod:of(measurements-9, activity-15)
# conj:and(activity-12, activity-15)
# punct(activity-12, ,-16)
# cc(activity-12, and-17)
# compound(activities-20, matrix-18)
# compound(activities-20, metalloproteinase-19)
# nmod:of(measurements-9, activities-20)
# conj:and(activity-12, activities-20)
# case(kidneys-23, in-21)
# det(kidneys-23, the-22)
# nmod:in(activities-20, kidneys-23)
# punct(confirmed-4, .-24)
#
# Sentence #9 (14 tokens, sentiment: Negative):
# In tubular epithelial cells stimulated in vitro, BK suppressed PAI-1 gene expression.
# [Text=In CharacterOffsetBegin=1308 CharacterOffsetEnd=1310 PartOfSpeech=IN Lemma=in NamedEntityTag=O SentimentClass=Neutral]
# [Text=tubular CharacterOffsetBegin=1311 CharacterOffsetEnd=1318 PartOfSpeech=JJ Lemma=tubular NamedEntityTag=O SentimentClass=Neutral]
# [Text=epithelial CharacterOffsetBegin=1319 CharacterOffsetEnd=1329 PartOfSpeech=JJ Lemma=epithelial NamedEntityTag=O SentimentClass=Neutral]
# [Text=cells CharacterOffsetBegin=1330 CharacterOffsetEnd=1335 PartOfSpeech=NNS Lemma=cell NamedEntityTag=O SentimentClass=Neutral]
# [Text=stimulated CharacterOffsetBegin=1336 CharacterOffsetEnd=1346 PartOfSpeech=VBN Lemma=stimulate NamedEntityTag=O SentimentClass=Neutral]
# [Text=in CharacterOffsetBegin=1347 CharacterOffsetEnd=1349 PartOfSpeech=FW Lemma=in NamedEntityTag=O SentimentClass=Neutral]
# [Text=vitro CharacterOffsetBegin=1350 CharacterOffsetEnd=1355 PartOfSpeech=FW Lemma=vitro NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=1355 CharacterOffsetEnd=1356 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=BK CharacterOffsetBegin=1357 CharacterOffsetEnd=1359 PartOfSpeech=NN Lemma=bk NamedEntityTag=LOCATION SentimentClass=Neutral]
# [Text=suppressed CharacterOffsetBegin=1360 CharacterOffsetEnd=1370 PartOfSpeech=VBD Lemma=suppress NamedEntityTag=O SentimentClass=Neutral]
# [Text=PAI-1 CharacterOffsetBegin=1371 CharacterOffsetEnd=1376 PartOfSpeech=NN Lemma=pai-1 NamedEntityTag=O SentimentClass=Neutral]
# [Text=gene CharacterOffsetBegin=1377 CharacterOffsetEnd=1381 PartOfSpeech=NN Lemma=gene NamedEntityTag=O SentimentClass=Neutral]
# [Text=expression CharacterOffsetBegin=1382 CharacterOffsetEnd=1392 PartOfSpeech=NN Lemma=expression NamedEntityTag=O SentimentClass=Neutral]
# [Text=. CharacterOffsetBegin=1392 CharacterOffsetEnd=1393 PartOfSpeech=. Lemma=. NamedEntityTag=O SentimentClass=Neutral]
# (ROOT
#   (S
#     (PP (IN In)
#       (NP
#         (NP (JJ tubular) (JJ epithelial) (NNS cells))
#         (VP (VBN stimulated)
#           (ADVP (FW in) (FW vitro)))))
#     (, ,)
#     (NP (NN BK))
#     (VP (VBD suppressed)
#       (NP (NN PAI-1) (NN gene) (NN expression)))
#     (. .)))
#
# root(ROOT-0, suppressed-10)
# case(cells-4, In-1)
# amod(cells-4, tubular-2)
# amod(cells-4, epithelial-3)
# nmod:in(suppressed-10, cells-4)
# acl(cells-4, stimulated-5)
# compound(vitro-7, in-6)
# advmod(stimulated-5, vitro-7)
# punct(suppressed-10, ,-8)
# nsubj(suppressed-10, BK-9)
# compound(expression-13, PAI-1-11)
# compound(expression-13, gene-12)
# dobj(suppressed-10, expression-13)
# punct(suppressed-10, .-14)
#
# Sentence #10 (29 tokens, sentiment: Negative):
# All of these results suggest that ACEi can decrease PAI-1 expression via BK, thereby facilitating matrix degradation via activation of degradative enzymes to reduce interstitial matrix deposition.
# [Text=All CharacterOffsetBegin=1394 CharacterOffsetEnd=1397 PartOfSpeech=DT Lemma=all NamedEntityTag=O SentimentClass=Neutral]
# [Text=of CharacterOffsetBegin=1398 CharacterOffsetEnd=1400 PartOfSpeech=IN Lemma=of NamedEntityTag=O SentimentClass=Neutral]
# [Text=these CharacterOffsetBegin=1401 CharacterOffsetEnd=1406 PartOfSpeech=DT Lemma=these NamedEntityTag=O SentimentClass=Neutral]
# [Text=results CharacterOffsetBegin=1407 CharacterOffsetEnd=1414 PartOfSpeech=NNS Lemma=result NamedEntityTag=O SentimentClass=Neutral]
# [Text=suggest CharacterOffsetBegin=1415 CharacterOffsetEnd=1422 PartOfSpeech=VBP Lemma=suggest NamedEntityTag=O SentimentClass=Neutral]
# [Text=that CharacterOffsetBegin=1423 CharacterOffsetEnd=1427 PartOfSpeech=IN Lemma=that NamedEntityTag=O SentimentClass=Neutral]
# [Text=ACEi CharacterOffsetBegin=1428 CharacterOffsetEnd=1432 PartOfSpeech=NNS Lemma=aceus NamedEntityTag=O SentimentClass=Neutral]
# [Text=can CharacterOffsetBegin=1433 CharacterOffsetEnd=1436 PartOfSpeech=MD Lemma=can NamedEntityTag=O SentimentClass=Neutral]
# [Text=decrease CharacterOffsetBegin=1437 CharacterOffsetEnd=1445 PartOfSpeech=VB Lemma=decrease NamedEntityTag=O SentimentClass=Neutral]
# [Text=PAI-1 CharacterOffsetBegin=1446 CharacterOffsetEnd=1451 PartOfSpeech=NN Lemma=pai-1 NamedEntityTag=O SentimentClass=Neutral]
# [Text=expression CharacterOffsetBegin=1452 CharacterOffsetEnd=1462 PartOfSpeech=NN Lemma=expression NamedEntityTag=O SentimentClass=Neutral]
# [Text=via CharacterOffsetBegin=1463 CharacterOffsetEnd=1466 PartOfSpeech=IN Lemma=via NamedEntityTag=O SentimentClass=Neutral]
# [Text=BK CharacterOffsetBegin=1467 CharacterOffsetEnd=1469 PartOfSpeech=NNP Lemma=BK NamedEntityTag=LOCATION SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=1469 CharacterOffsetEnd=1470 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=thereby CharacterOffsetBegin=1471 CharacterOffsetEnd=1478 PartOfSpeech=RB Lemma=thereby NamedEntityTag=O SentimentClass=Neutral]
# [Text=facilitating CharacterOffsetBegin=1479 CharacterOffsetEnd=1491 PartOfSpeech=VBG Lemma=facilitate NamedEntityTag=O SentimentClass=Neutral]
# [Text=matrix CharacterOffsetBegin=1492 CharacterOffsetEnd=1498 PartOfSpeech=NN Lemma=matrix NamedEntityTag=O SentimentClass=Neutral]
# [Text=degradation CharacterOffsetBegin=1499 CharacterOffsetEnd=1510 PartOfSpeech=NN Lemma=degradation NamedEntityTag=O SentimentClass=Neutral]
# [Text=via CharacterOffsetBegin=1511 CharacterOffsetEnd=1514 PartOfSpeech=IN Lemma=via NamedEntityTag=O SentimentClass=Neutral]
# [Text=activation CharacterOffsetBegin=1515 CharacterOffsetEnd=1525 PartOfSpeech=NN Lemma=activation NamedEntityTag=O SentimentClass=Neutral]
# [Text=of CharacterOffsetBegin=1526 CharacterOffsetEnd=1528 PartOfSpeech=IN Lemma=of NamedEntityTag=O SentimentClass=Neutral]
# [Text=degradative CharacterOffsetBegin=1529 CharacterOffsetEnd=1540 PartOfSpeech=JJ Lemma=degradative NamedEntityTag=O SentimentClass=Neutral]
# [Text=enzymes CharacterOffsetBegin=1541 CharacterOffsetEnd=1548 PartOfSpeech=NNS Lemma=enzyme NamedEntityTag=O SentimentClass=Neutral]
# [Text=to CharacterOffsetBegin=1549 CharacterOffsetEnd=1551 PartOfSpeech=TO Lemma=to NamedEntityTag=O SentimentClass=Neutral]
# [Text=reduce CharacterOffsetBegin=1552 CharacterOffsetEnd=1558 PartOfSpeech=VB Lemma=reduce NamedEntityTag=O SentimentClass=Neutral]
# [Text=interstitial CharacterOffsetBegin=1559 CharacterOffsetEnd=1571 PartOfSpeech=JJ Lemma=interstitial NamedEntityTag=O SentimentClass=Neutral]
# [Text=matrix CharacterOffsetBegin=1572 CharacterOffsetEnd=1578 PartOfSpeech=NN Lemma=matrix NamedEntityTag=O SentimentClass=Neutral]
# [Text=deposition CharacterOffsetBegin=1579 CharacterOffsetEnd=1589 PartOfSpeech=NN Lemma=deposition NamedEntityTag=O SentimentClass=Neutral]
# [Text=. CharacterOffsetBegin=1589 CharacterOffsetEnd=1590 PartOfSpeech=. Lemma=. NamedEntityTag=O SentimentClass=Neutral]
# (ROOT
#   (S
#     (NP
#       (NP (DT All))
#       (PP (IN of)
# ...
# 	(57,15,[15,24]) -> (56,27,[27,32]), that is: "P < 0.001 versus placebo , P < 0.01" -> "P < 0.001 versus placebo"
# Coreference set:
# 	(56,46,[45,47]) -> (56,43,[42,44]), that is: "-13.2 mmHg" -> "-11.1 mmHg"
# Coreference set:
# 	(151,2,[1,3]) -> (57,2,[1,3]), that is: "Combination therapy" -> "Combination therapy"
# Coreference set:
# 	(57,8,[7,29]) -> (78,2,[1,3]), that is: "SBP/DBP values -LRB- -28.3 / -20.5 mmHg ; P < 0.001 versus placebo , P < 0.01 versus benazepril and amlodipine -RRB-" -> "Placebo values"
# Coreference set:
# 	(59,16,[16,17]) -> (58,14,[14,15]), that is: "0.05" -> "0.05"
# 	(60,19,[19,20]) -> (58,14,[14,15]), that is: "0.05" -> "0.05"
# 	(60,34,[34,35]) -> (58,14,[14,15]), that is: "0.05" -> "0.05"
# Coreference set:
# 	(58,17,[17,18]) -> (58,2,[1,3]), that is: "it" -> "Benazepril monotherapy"
# Coreference set:
# 	(58,10,[9,15]) -> (58,10,[9,11]), that is: "-8.4 IU/ml , P < 0.05" -> "-8.4 IU/ml"
# 	(58,12,[12,14]) -> (58,10,[9,11]), that is: "P <" -> "-8.4 IU/ml"
# 	(59,14,[14,16]) -> (58,10,[9,11]), that is: "P <" -> "-8.4 IU/ml"
# 	(60,17,[17,19]) -> (58,10,[9,11]), that is: "P <" -> "-8.4 IU/ml"
# 	(60,32,[32,34]) -> (58,10,[9,11]), that is: "P <" -> "-8.4 IU/ml"
# Coreference set:
# 	(59,15,[15,16]) -> (58,13,[13,14]), that is: "<" -> "<"
# 	(60,18,[18,19]) -> (58,13,[13,14]), that is: "<" -> "<"
# 	(60,33,[33,34]) -> (58,13,[13,14]), that is: "<" -> "<"
# 	(158,64,[64,65]) -> (58,13,[13,14]), that is: "<" -> "<"
# Coreference set:
# 	(59,9,[8,10]) -> (58,22,[21,27]), that is: "t-PA activity" -> "t-PA activity -LRB- +0.02 IU/ml -RRB-"
# Coreference set:
# 	(59,19,[19,20]) -> (59,2,[1,3]), that is: "it" -> "Amlodipine monotherapy"
# Coreference set:
# 	(61,8,[8,9]) -> (60,3,[1,4]), that is: "its" -> "The amlodipine/benazepril combination"
# Coreference set:
# 	(62,1,[1,2]) -> (61,17,[17,22]), that is: "Cats" -> "cats using a pharmacokinetic/pharmacodynamic model"
# Coreference set:
# 	(68,13,[13,14]) -> (63,18,[18,19]), that is: "1.0" -> "1.0"
# Coreference set:
# 	(64,6,[5,20]) -> (64,3,[1,4]), that is: "plasma concentrations of benazepril and benazeprilat , and recovery of radioactivity in faeces and urine" -> "The pharmacokinetic endpoints"
# 	(64,6,[5,11]) -> (64,3,[1,4]), that is: "plasma concentrations of benazepril and benazeprilat" -> "The pharmacokinetic endpoints"
# 	(70,17,[15,18]) -> (64,3,[1,4]), that is: "plasma benazeprilat concentrations" -> "The pharmacokinetic endpoints"
# Coreference set:
# 	(65,7,[5,12]) -> (65,3,[1,4]), that is: "plasma angiotensin-converting enzyme -LRB- ACE -RRB- activity" -> "The pharmacodynamic endpoint"
# Coreference set:
# 	(70,4,[3,5]) -> (66,12,[10,27]), that is: "the model" -> "a single-compartment model with a volume equal to the blood space -LRB- Vc = 0.093 L/kg -RRB-"
# Coreference set:
# 	(67,3,[2,4]) -> (66,20,[18,21]), that is: "this space" -> "the blood space"
# Coreference set:
# 	(71,12,[12,13]) -> (68,18,[18,19]), that is: "0.125" -> "0.125"
# Coreference set:
# 	(68,22,[22,39]) -> (68,9,[7,21]), that is: "elimination being principally biliary -LRB- approximately 85 % -RRB- rather than urinary -LRB- approximately 15 % -RRB-" -> "the central compartment -LRB- t1/2 approximately 1.0 h ; Cl approximately 0.125 L/kg/h -RRB-"
# Coreference set:
# 	(69,7,[7,20]) -> (69,3,[3,6]), that is: "long-lasting -LRB- t1/2 16-23 h -RRB- due to high affinity binding of benazeprilat" -> "inhibition of ACE"
# Coreference set:
# 	(69,28,[28,32]) -> (69,26,[24,27]), that is: "IC50 approximately 4.3 mmol/L" -> "approximately 3.5 mmol/L"
# 	(69,31,[29,32]) -> (69,26,[24,27]), that is: "approximately 4.3 mmol/L" -> "approximately 3.5 mmol/L"
# Coreference set:
# 	(74,17,[17,20]) -> (71,8,[8,17]), that is: "benazepril once daily" -> "benazepril -LRB- e.g. above 0.125 mg/kg q24 h -RRB-"
# Coreference set:
# 	(136,56,[55,57]) -> (71,21,[18,33]), that is: "ACE inhibition" -> "only small incremental inhibition of ACE -LRB- either peak effect or duration of action -RRB-"
# Coreference set:
# 	(72,1,[1,4]) -> (72,5,[5,9]), that is: "Albuminuria and hypertension" -> "predictors of poor renal"
# 	(72,5,[5,15]) -> (72,5,[5,9]), that is: "predictors of poor renal and cardiovascular outcome in diabetic patients" -> "predictors of poor renal"
# Coreference set:
# 	(75,3,[3,4]) -> (73,42,[42,43]), that is: "I" -> "I"
# 	(84,18,[18,19]) -> (73,42,[42,43]), that is: "I" -> "I"
# 	(138,11,[11,12]) -> (73,42,[42,43]), that is: "I" -> "I"
# Coreference set:
# 	(74,37,[37,38]) -> (74,21,[21,22]), that is: "80" -> "80"
# 	(169,22,[22,23]) -> (74,21,[21,22]), that is: "80" -> "80"
# Coreference set:
# 	(74,22,[21,27]) -> (74,15,[14,20]), that is: "80 mg of valsartan once daily" -> "20 mg of benazepril once daily"
# 	(74,30,[29,41]) -> (74,15,[14,20]), that is: "the combination of 20 mg of benazepril and 80 mg of valsartan" -> "20 mg of benazepril once daily"
# 	(74,33,[32,41]) -> (74,15,[14,20]), that is: "20 mg of benazepril and 80 mg of valsartan" -> "20 mg of benazepril once daily"
# 	(74,33,[32,36]) -> (74,15,[14,20]), that is: "20 mg of benazepril" -> "20 mg of benazepril once daily"
# 	(74,38,[37,41]) -> (74,15,[14,20]), that is: "80 mg of valsartan" -> "20 mg of benazepril once daily"
# Coreference set:
# 	(84,20,[18,21]) -> (75,5,[1,8]), that is: "I diabetic patients" -> "Twenty type I diabetic patients with DN"
# Coreference set:
# 	(79,12,[12,15]) -> (76,9,[9,16]), that is: "albuminuria and BP" -> "albuminuria , 24-h BP , and GFR"
# Coreference set:
# 	(78,61,[61,62]) -> (78,39,[39,40]), that is: "2" -> "2"
# Coreference set:
# 	(81,40,[40,41]) -> (78,54,[54,55]), that is: "7" -> "7"
# 	(81,59,[59,60]) -> (78,54,[54,55]), that is: "7" -> "7"
# Coreference set:
# 	(78,26,[24,31]) -> (78,32,[32,36]), that is: "BP -LSB- mean -LRB- SEM -RRB- -RSB-" -> "144 -LRB- 4 -RRB-"
# 	(78,46,[46,50]) -> (78,32,[32,36]), that is: "mean -LRB- SEM -RRB-" -> "144 -LRB- 4 -RRB-"
# Coreference set:
# 	(87,10,[10,11]) -> (81,63,[61,64]), that is: "10" -> "4 to 10"
# 	(89,3,[3,4]) -> (81,63,[61,64]), that is: "10" -> "4 to 10"
# Coreference set:
# 	(169,24,[24,25]) -> (85,7,[7,8]), that is: "102" -> "102"
# Coreference set:
# 	(111,5,[4,6]) -> (87,2,[1,3]), that is: "blood pressure" -> "Blood pressure"
# 	(111,7,[7,14]) -> (87,2,[1,3]), that is: "status of taking Benazepril and side effects" -> "Blood pressure"
# Coreference set:
# 	(97,6,[6,11]) -> (94,10,[10,19]), that is: "trandolapril , moexipril and imidapril" -> "trandolapril , moexipril , spirapril , temocapril and imidapril"
# 	(100,12,[12,15]) -> (94,10,[10,19]), that is: "trandolapril or moexipril" -> "trandolapril , moexipril , spirapril , temocapril and imidapril"
# Coreference set:
# 	(97,8,[8,11]) -> (94,12,[12,19]), that is: "moexipril and imidapril" -> "moexipril , spirapril , temocapril and imidapril"
# 	(98,4,[4,7]) -> (94,12,[12,19]), that is: "moexipril and temocapril" -> "moexipril , spirapril , temocapril and imidapril"
# Coreference set:
# 	(96,1,[1,2]) -> (95,13,[10,14]), that is: "They" -> "a carboxyl functional groups"
# Coreference set:
# 	(99,20,[20,21]) -> (99,8,[8,9]), that is: "meals" -> "meals"
# Coreference set:
# 	(102,4,[2,18]) -> (106,2,[1,3]), that is: "six ACE inhibitors -LRB- captopril , enalapril , fosinopril , lisinopril , quinapril and ramipril -RRB-" -> "ACE inhibitors"
# 	(133,22,[21,23]) -> (106,2,[1,3]), that is: "ACE inhibitors" -> "ACE inhibitors"
# Coreference set:
# 	(105,14,[14,17]) -> (102,8,[8,17]), that is: "enalapril and lisinopril" -> "enalapril , fosinopril , lisinopril , quinapril and ramipril"
# 	(122,14,[14,17]) -> (102,8,[8,17]), that is: "enalapril and lisinopril" -> "enalapril , fosinopril , lisinopril , quinapril and ramipril"
# Coreference set:
# 	(104,15,[15,18]) -> (167,1,[1,2]), that is: "diuretics and beta-blockers" -> "Diuretics"
# Coreference set:
# 	(107,6,[3,13]) -> (107,1,[1,2]), that is: "the only ACE inhibitor that exhibits a linear dose-response curve" -> "Lisinopril"
# 	(130,7,[4,8]) -> (107,1,[1,2]), that is: "the only ACE inhibitor" -> "Lisinopril"
# Coreference set:
# 	(112,4,[3,5]) -> (110,5,[1,10]), that is: "the patients" -> "1 831 essential hypertensive patients aged 35 to 75"
# Coreference set:
# 	(113,19,[18,20]) -> (110,20,[19,21]), that is: "18 months" -> "18 months"
# Coreference set:
# 	(116,8,[7,9]) -> (111,13,[12,14]), that is: "side effects" -> "side effects"
# Coreference set:
# 	(117,17,[17,18]) -> (114,7,[7,10]), that is: "them" -> "SBP and DBP"
# Coreference set:
# 	(122,30,[30,31]) -> (117,4,[4,5]), that is: "first" -> "first"
# Coreference set:
# 	(119,1,[1,7]) -> (119,13,[8,21]), that is: "Captopril , enalapril , and lisinopril" -> "angiotensin-converting enzyme -LRB- ACE -RRB- inhibitors widely prescribed for hypertension and heart failure"
# 	(166,26,[24,27]) -> (119,13,[8,21]), that is: "angiotensin-converting enzyme inhibitors" -> "angiotensin-converting enzyme -LRB- ACE -RRB- inhibitors widely prescribed for hypertension and heart failure"
# Coreference set:
# 	(125,3,[2,4]) -> (120,17,[15,18]), that is: "the rash" -> "pitiryasis rosea-like rash"
# Coreference set:
# 	(122,21,[20,22]) -> (121,17,[16,18]), that is: "patch tests" -> "patch tests"
# 	(131,21,[20,22]) -> (121,17,[16,18]), that is: "patch tests" -> "patch tests"
# 	(132,6,[5,7]) -> (121,17,[16,18]), that is: "patch tests" -> "patch tests"
# 	(133,2,[1,3]) -> (121,17,[16,18]), that is: "Patch tests" -> "patch tests"
# Coreference set:
# 	(125,12,[11,13]) -> (122,8,[4,17]), that is: "the reaction" -> "a cutaneous immune adverse reaction to captopril with tolerance to enalapril and lisinopril"
# Coreference set:
# 	(124,5,[5,6]) -> (123,4,[1,5]), that is: "she" -> "A 71-year-old nonatopic woman"
# 	(125,6,[6,7]) -> (123,4,[1,5]), that is: "she" -> "A 71-year-old nonatopic woman"
# Coreference set:
# 	(146,20,[20,21]) -> (124,12,[12,13]), that is: "50" -> "50"
# Coreference set:
# 	(155,4,[4,5]) -> (124,17,[17,18]), that is: "5" -> "5"
# 	(156,10,[10,11]) -> (124,17,[17,18]), that is: "5" -> "5"
# 	(157,24,[24,25]) -> (124,17,[17,18]), that is: "5" -> "5"
# 	(157,38,[38,39]) -> (124,17,[17,18]), that is: "5" -> "5"
# 	(158,31,[31,32]) -> (124,17,[17,18]), that is: "5" -> "5"
# 	(158,52,[52,53]) -> (124,17,[17,18]), that is: "5" -> "5"
# 	(159,22,[22,23]) -> (124,17,[17,18]), that is: "5" -> "5"
# 	(160,2,[2,3]) -> (124,17,[17,18]), that is: "5" -> "5"
# 	(160,10,[10,11]) -> (124,17,[17,18]), that is: "5" -> "5"
# Coreference set:
# 	(128,5,[5,13]) -> (129,8,[7,9]), that is: "captopril at 1 % and 10 % concentrations" -> "only captopril"
# Coreference set:
# 	(132,3,[2,4]) -> (129,2,[1,3]), that is: "our patient" -> "The patient"
# Coreference set:
# 	(132,24,[22,25]) -> (130,11,[9,12]), that is: "the sulfhydryl group" -> "a sulfhydryl group"
# Coreference set:
# 	(138,10,[10,12]) -> (139,8,[7,9]), that is: "TGFbetaR I" -> "TGFbetaR I"
# Coreference set:
# 	(141,1,[1,24]) -> (144,2,[1,5]), that is: "Effect of SKI , a herbal preparation for lowering adverse Qi , despelling turbidness , supplementing Qi and activating circulation , and Benazepril" -> "The effect of SKI"
# Coreference set:
# 	(141,3,[3,4]) -> (141,7,[5,21]), that is: "SKI" -> "a herbal preparation for lowering adverse Qi , despelling turbidness , supplementing Qi and activating circulation"
# 	(141,7,[5,24]) -> (141,7,[5,21]), that is: "a herbal preparation for lowering adverse Qi , despelling turbidness , supplementing Qi and activating circulation , and Benazepril" -> "a herbal preparation for lowering adverse Qi , despelling turbidness , supplementing Qi and activating circulation"
# Coreference set:
# 	(141,11,[10,12]) -> (141,17,[17,18]), that is: "adverse Qi" -> "Qi"
# Coreference set:
# 	(144,11,[11,12]) -> (142,14,[14,15]), that is: "ECM" -> "ECM"
# Coreference set:
# 	(145,23,[19,27]) -> (150,7,[5,8]), that is: "the chemical and enzymatic hydrolysis of benazepril hydrochloride" -> "the enzymatic hydrolysis"
# Coreference set:
# 	(146,63,[63,64]) -> (146,36,[36,37]), that is: "7.4" -> "7.4"
# Coreference set:
# 	(146,67,[67,68]) -> (146,41,[41,42]), that is: "37" -> "37"
# Coreference set:
# 	(149,9,[7,10]) -> (146,6,[4,10]), that is: "the acidic hydrolysis" -> "the acidic hydrolysis of benazepril hydrochloride"
# Coreference set:
# 	(147,9,[9,10]) -> (146,83,[83,84]), that is: "their" -> "enzymatic"
# Coreference set:
# 	(148,32,[32,33]) -> (148,25,[25,26]), that is: "-7" -> "-7"
# Coreference set:
# 	(148,14,[13,20]) -> (148,21,[21,22]), that is: "detection limits for benazepril hydrochloride and benazeprilat" -> "13.0"
# 	(148,21,[21,35]) -> (148,21,[21,22]), that is: "13.0 x 10 -LRB- -7 -RRB- and 9.0 x 10 -LRB- -7 -RRB- M" -> "13.0"
# 	(148,21,[21,29]) -> (148,21,[21,22]), that is: "13.0 x 10 -LRB- -7 -RRB- and 9.0" -> "13.0"
# Coreference set:
# 	(150,16,[15,17]) -> (149,5,[3,10]), that is: "the data" -> "the kinetic data of the acidic hydrolysis"
# Coreference set:
# 	(152,2,[1,3]) -> (152,7,[4,15]), that is: "Calcium antagonists" -> "highly effective antihypertensive drugs in a broad range of demographic groups"
# 	(165,8,[7,9]) -> (152,7,[4,15]), that is: "antihypertensive drugs" -> "highly effective antihypertensive drugs in a broad range of demographic groups"
# Coreference set:
# 	(161,9,[7,10]) -> (153,14,[12,15]), that is: "lower extremity edema" -> "lower extremity edema"
# 	(163,36,[34,37]) -> (153,14,[12,15]), that is: "lower extremity edema" -> "lower extremity edema"
# 	(164,10,[8,11]) -> (153,14,[12,15]), that is: "lower extremity edema" -> "lower extremity edema"
# Coreference set:
# 	(156,1,[1,2]) -> (155,2,[1,3]), that is: "They" -> "Forty-seven patients"
# Coreference set:
# 	(158,37,[37,38]) -> (156,15,[15,16]), that is: "25" -> "25"
# 	(161,2,[2,3]) -> (156,15,[15,16]), that is: "25" -> "25"
# Coreference set:
# 	(156,11,[8,33]) -> (158,38,[37,39]), that is: "an additional 5 mg of amlodipine , 25 mg of hydrochlorothiazide -LRB- HCTZ -RRB- , or 20 mg of benazepril for an additional 6 weeks" -> "25 mg"
# Coreference set:
# 	(157,39,[38,42]) -> (156,11,[8,14]), that is: "5 mg of amlodipine" -> "an additional 5 mg of amlodipine"
# 	(160,3,[2,6]) -> (156,11,[8,14]), that is: "5 mg of amlodipine" -> "an additional 5 mg of amlodipine"
# 	(160,11,[10,14]) -> (156,11,[8,14]), that is: "5 mg of amlodipine" -> "an additional 5 mg of amlodipine"
# Coreference set:
# 	(161,3,[2,6]) -> (156,16,[15,22]), that is: "25 mg of HCTZ" -> "25 mg of hydrochlorothiazide -LRB- HCTZ -RRB-"
# Coreference set:
# 	(158,59,[58,60]) -> (156,25,[24,33]), that is: "20 mg" -> "20 mg of benazepril for an additional 6 weeks"
# Coreference set:
# 	(158,67,[67,69]) -> (158,65,[65,66]), that is: "group 3" -> ".0167"
# Coreference set:
# 	(158,20,[17,21]) -> (158,22,[22,23]), that is: "the 10-mg amlodipine group" -> "-9.9"
# 	(158,35,[35,41]) -> (158,22,[22,23]), that is: "HCTZ -LRB- 25 mg -RRB- group" -> "-9.9"
# Coreference set:
# 	(158,32,[31,33]) -> (158,29,[28,34]), that is: "5 mg" -> "the amlodipine -LRB- 5 mg -RRB-"
# 	(158,50,[49,55]) -> (158,29,[28,34]), that is: "the amlodipine -LRB- 5 mg -RRB-" -> "the amlodipine -LRB- 5 mg -RRB-"
# 	(158,53,[52,54]) -> (158,29,[28,34]), that is: "5 mg" -> "the amlodipine -LRB- 5 mg -RRB-"
# Coreference set:
# 	(162,4,[3,5]) -> (159,18,[7,21]), that is: "water displacement" -> "at least a 10 % increase in lower extremity edema water displacement in response"
# Coreference set:
# 	(160,25,[24,26]) -> (160,30,[28,31]), that is: "+58.0 mL" -> "0.6 % change"
# Coreference set:
# 	(161,21,[21,24]) -> (161,19,[19,24]), that is: "n = 4" -> "change , n = 4"
# 	(162,11,[11,16]) -> (161,19,[19,24]), that is: "change , n = 8" -> "change , n = 4"
# 	(162,13,[13,16]) -> (161,19,[19,24]), that is: "n = 8" -> "change , n = 4"
# Coreference set:
# 	(169,1,[1,8]) -> (169,12,[9,31]), that is: "Propranolol , furosemide , amlodipine and atenolol" -> "the least expensive drugs used , with annual drug acquisition costs of Rs 80 , 102 , 182 and 318 , respectively"
# Coreference set:
# 	(170,42,[39,43]) -> (169,19,[16,29]), that is: "annual drug acquisition costs" -> "annual drug acquisition costs of Rs 80 , 102 , 182 and 318"
# Coreference set:
# 	(170,1,[1,31]) -> (170,35,[32,43]), that is: "Benazepril -LRB- Rs 1778 -RRB- , diltiazem SR -LRB- Rs 1777 -RRB- , lisinopril -LRB- Rs 1660 -RRB- , prazosin -LRB- Rs 1416 -RRB- and losartan -LRB- Rs 1365 -RRB-" -> "the most expensive drugs in terms of annual drug acquisition costs"

# %% [markdown]
# ## Sentiment Experiment with 50 Sentences

# %%
# !head -50 data/FilteredSentences.txt > data/Filtered50.txt

# %%
# %%timeit
# !java -cp "*" -Xmx2g edu.stanford.nlp.pipeline.StanfordCoreNLP -annotators tokenize,ssplit,pos,lemma,ner,parse,dcoref,sentiment -file data/Filtered50.txt -outputFormat text
# Out:
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator pos
# [main] INFO edu.stanford.nlp.tagger.maxent.MaxentTagger - Loading POS tagger from edu/stanford/nlp/models/pos-tagger/english-left3words/english-left3words-distsim.tagger ... done [1.2 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [1.8 sec].
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [1.8 sec].
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.8 sec].
# [main] INFO edu.stanford.nlp.time.JollyDayHolidays - Initializing JollyDayHoliday for SUTime from classpath edu/stanford/nlp/models/sutime/jollyday/Holidays_sutime.xml as sutime.binder.1.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ... done [0.4 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator dcoref
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator sentiment
#
# Processing file /Users/lisabarcelo/Desktop/W266/food_drug_interaction/parsing/data/Filtered50.txt ... writing to /Users/lisabarcelo/Desktop/W266/food_drug_interaction/parsing/Filtered50.txt.out
# Annotating file /Users/lisabarcelo/Desktop/W266/food_drug_interaction/parsing/data/Filtered50.txt ... done [245.5 sec].
#
# Annotation pipeline timing information:
# TokenizerAnnotator: 0.1 sec.
# WordsToSentencesAnnotator: 0.0 sec.
# POSTaggerAnnotator: 0.3 sec.
# MorphaAnnotator: 0.1 sec.
# NERCombinerAnnotator: 3.8 sec.
# ParserAnnotator: 223.7 sec.
# DeterministicCorefAnnotator: 17.3 sec.
# SentimentAnnotator: 0.2 sec.
# TOTAL: 245.5 sec. for 2143 tokens at 8.7 tokens/sec.
# Pipeline setup: 9.9 sec.
# Total time for StanfordCoreNLP pipeline: 255.5 sec.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator pos
# [main] INFO edu.stanford.nlp.tagger.maxent.MaxentTagger - Loading POS tagger from edu/stanford/nlp/models/pos-tagger/english-left3words/english-left3words-distsim.tagger ... done [1.2 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [1.8 sec].
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [1.7 sec].
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.8 sec].
# [main] INFO edu.stanford.nlp.time.JollyDayHolidays - Initializing JollyDayHoliday for SUTime from classpath edu/stanford/nlp/models/sutime/jollyday/Holidays_sutime.xml as sutime.binder.1.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ... done [0.4 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator dcoref
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator sentiment
#
# Processing file /Users/lisabarcelo/Desktop/W266/food_drug_interaction/parsing/data/Filtered50.txt ... writing to /Users/lisabarcelo/Desktop/W266/food_drug_interaction/parsing/Filtered50.txt.out
# Annotating file /Users/lisabarcelo/Desktop/W266/food_drug_interaction/parsing/data/Filtered50.txt ... done [262.0 sec].
#
# Annotation pipeline timing information:
# TokenizerAnnotator: 0.1 sec.
# WordsToSentencesAnnotator: 0.0 sec.
# POSTaggerAnnotator: 0.3 sec.
# MorphaAnnotator: 0.1 sec.
# NERCombinerAnnotator: 3.9 sec.
# ParserAnnotator: 243.6 sec.
# DeterministicCorefAnnotator: 13.6 sec.
# SentimentAnnotator: 0.4 sec.
# TOTAL: 262.0 sec. for 2143 tokens at 8.2 tokens/sec.
# Pipeline setup: 9.4 sec.
# Total time for StanfordCoreNLP pipeline: 271.6 sec.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator pos
# [main] INFO edu.stanford.nlp.tagger.maxent.MaxentTagger - Loading POS tagger from edu/stanford/nlp/models/pos-tagger/english-left3words/english-left3words-distsim.tagger ... done [1.2 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [1.8 sec].
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [1.8 sec].
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.7 sec].
# [main] INFO edu.stanford.nlp.time.JollyDayHolidays - Initializing JollyDayHoliday for SUTime from classpath edu/stanford/nlp/models/sutime/jollyday/Holidays_sutime.xml as sutime.binder.1.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ... done [0.3 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator dcoref
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator sentiment
#
# Processing file /Users/lisabarcelo/Desktop/W266/food_drug_interaction/parsing/data/Filtered50.txt ... writing to /Users/lisabarcelo/Desktop/W266/food_drug_interaction/parsing/Filtered50.txt.out
# Annotating file /Users/lisabarcelo/Desktop/W266/food_drug_interaction/parsing/data/Filtered50.txt ... done [266.3 sec].
#
# Annotation pipeline timing information:
# TokenizerAnnotator: 0.1 sec.
# WordsToSentencesAnnotator: 0.0 sec.
# POSTaggerAnnotator: 0.3 sec.
# MorphaAnnotator: 0.1 sec.
# NERCombinerAnnotator: 3.8 sec.
# ParserAnnotator: 247.6 sec.
# DeterministicCorefAnnotator: 14.1 sec.
# SentimentAnnotator: 0.3 sec.
# TOTAL: 266.3 sec. for 2143 tokens at 8.0 tokens/sec.
# Pipeline setup: 9.5 sec.
# Total time for StanfordCoreNLP pipeline: 275.9 sec.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator pos
# [main] INFO edu.stanford.nlp.tagger.maxent.MaxentTagger - Loading POS tagger from edu/stanford/nlp/models/pos-tagger/english-left3words/english-left3words-distsim.tagger ... done [1.2 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [1.8 sec].
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [1.7 sec].
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.8 sec].
# [main] INFO edu.stanford.nlp.time.JollyDayHolidays - Initializing JollyDayHoliday for SUTime from classpath edu/stanford/nlp/models/sutime/jollyday/Holidays_sutime.xml as sutime.binder.1.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ... done [0.6 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator dcoref
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator sentiment
#
# Processing file /Users/lisabarcelo/Desktop/W266/food_drug_interaction/parsing/data/Filtered50.txt ... writing to /Users/lisabarcelo/Desktop/W266/food_drug_interaction/parsing/Filtered50.txt.out
# Annotating file /Users/lisabarcelo/Desktop/W266/food_drug_interaction/parsing/data/Filtered50.txt ... done [270.1 sec].
#
# Annotation pipeline timing information:
# TokenizerAnnotator: 0.1 sec.
# WordsToSentencesAnnotator: 0.0 sec.
# POSTaggerAnnotator: 0.3 sec.
# MorphaAnnotator: 0.1 sec.
# NERCombinerAnnotator: 4.1 sec.
# ParserAnnotator: 251.2 sec.
# DeterministicCorefAnnotator: 13.9 sec.
# SentimentAnnotator: 0.3 sec.
# TOTAL: 270.1 sec. for 2143 tokens at 7.9 tokens/sec.
# Pipeline setup: 10.7 sec.
# Total time for StanfordCoreNLP pipeline: 280.9 sec.
# 1 loop, best of 3: 4min 32s per loop

# %%
# !head Filtered50.txt.out
# Out:
# Sentence #1 (34 tokens, sentiment: Negative):
# [u'casein', u'whey']in this study, we examined the separated caseins and whey proteins of goat milk for the presence of ACEI inhibitory peptides.
# [Text=-LSB- CharacterOffsetBegin=0 CharacterOffsetEnd=1 PartOfSpeech=-LRB- Lemma=-lsb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=u CharacterOffsetBegin=1 CharacterOffsetEnd=2 PartOfSpeech=FW Lemma=u NamedEntityTag=O SentimentClass=Neutral]
# [Text=` CharacterOffsetBegin=2 CharacterOffsetEnd=3 PartOfSpeech=`` Lemma=` NamedEntityTag=O SentimentClass=Neutral]
# [Text=casein CharacterOffsetBegin=3 CharacterOffsetEnd=9 PartOfSpeech=NN Lemma=casein NamedEntityTag=O SentimentClass=Neutral]
# [Text=' CharacterOffsetBegin=9 CharacterOffsetEnd=10 PartOfSpeech='' Lemma=' NamedEntityTag=O SentimentClass=Neutral]
# [Text=, CharacterOffsetBegin=10 CharacterOffsetEnd=11 PartOfSpeech=, Lemma=, NamedEntityTag=O SentimentClass=Neutral]
# [Text=u CharacterOffsetBegin=12 CharacterOffsetEnd=13 PartOfSpeech=FW Lemma=u NamedEntityTag=O SentimentClass=Neutral]
# [Text=` CharacterOffsetBegin=13 CharacterOffsetEnd=14 PartOfSpeech=`` Lemma=` NamedEntityTag=O SentimentClass=Neutral]

# %%
co_occurrence_dict = defaultdict(list)

for line in open('Filtered50.txt.out').readlines():
    if 'Sentence #' in line:
        sentence = str(line.strip('\n')).split(" ")[1]
        sentiment = str(line.strip('\n')).split(":")[1]
        sentiment = re.sub("\d+","",re.sub(r'[^\w\s]','',sentiment))
    elif line[0:5] == '[Text':
        word = str(line.split("=")[1]).split(" ")[0].lower()
        pos = str(line.split("=")[4]).split(" ")[0]
        co_occurrence_dict[(sentiment, sentence)].append(word)

# %%
#Example of one of the entries in the dictionary

from itertools import islice
import  pprint
def take(n, iterable):
    "Return first n items of the iterable as a list"
    return list(islice(iterable, n))

n_items = take(1, co_occurrence_dict.iteritems())
pp = pprint.PrettyPrinter(depth=6)
pp.pprint(n_items)
# Out:
# [((' Very negative', '#27'),
#   ['-lsb-',
#    'u',
#    '`',
#    'barley',
#    "'",
#    '-rsb-',
#    'papain',
#    'was',
#    'the',
#    'enzyme',
#    'of',
#    'choice',
#    ',',
#    'based',
#    'on',
#    'in',
#    'silico',
#    'analysis',
#    ',',
#    'for',
#    'experimental',
#    'hydrolysis',
#    'of',
#    'barley',
#    'protein',
#    'concentrate',
#    ',',
#    'which',
#    'was',
#    'performed',
#    'at',
#    'the',
#    'enzyme',
#    "'s",
#    'optimum',
#    'conditions',
#    '-lrb-',
#    '60',
#    'unkc',
#    ',',
#    'ph',
#    '6.0',
#    '-rrb-',
#    'for',
#    '24',
#    'h.',
#    'the',
#    'generated',
#    'hydrolysate',
#    'was',
#    'subjected',
#    'to',
#    'molecular',
#    'weight',
#    'cut-off',
#    '-lrb-',
#    'mwco',
#    '-rrb-',
#    'filtration',
#    ',',
#    'following',
#    'which',
#    'the',
#    'non-ultrafiltered',
#    'hydrolysate',
#    '-lrb-',
#    'nufh',
#    '-rrb-',
#    ',',
#    'and',
#    'the',
#    'generated',
#    '3',
#    'kda',
#    'and',
#    '10',
#    'kda',
#    'mwco',
#    'filtrates',
#    'were',
#    'assessed',
#    'for',
#    'their',
#    'in',
#    'vitro',
#    'acei-i',
#    'inhibitory',
#    'activities',
#    '.'])]

# %%
#Assuming these are the key words we are curious about.
search_phrase = ['barley','acei-i']

#Searching through the dictionary
for k,v in co_occurrence_dict.iteritems():
#     if any(k in search_phrase for k in v):
    if all(k in v for k in search_phrase):
        #print k, v
        print "There is a", k[0], "relationship between ", search_phrase, ".\nLiterature: ", " ".join([i for i in v])
# Out:
# There is a  Very negative relationship between  ['barley', 'acei-i'] .
# Literature:  -lsb- u ` barley ' -rsb- papain was the enzyme of choice , based on in silico analysis , for experimental hydrolysis of barley protein concentrate , which was performed at the enzyme 's optimum conditions -lrb- 60 unkc , ph 6.0 -rrb- for 24 h. the generated hydrolysate was subjected to molecular weight cut-off -lrb- mwco -rrb- filtration , following which the non-ultrafiltered hydrolysate -lrb- nufh -rrb- , and the generated 3 kda and 10 kda mwco filtrates were assessed for their in vitro acei-i inhibitory activities .
# There is a  Negative relationship between  ['barley', 'acei-i'] .
# Literature:  -lsb- u ` barley ' -rsb- our current work utilised in silico methodologies and peptide databases as tools for predicting release of acei-i inhibitory peptides from barley proteins .
# There is a  Very negative relationship between  ['barley', 'acei-i'] .
# Literature:  -lsb- u ` barley ' -rsb- the 3 kda filtrate -lrb- 1 mg/ml -rrb- , that demonstrated highest acei-i inhibitory activity of 70.37 % , was characterised in terms of its peptidic composition using mass spectrometry and 1882 peptides derived from 61 barley proteins were identified , amongst which 15 peptides were selected for chemical synthesis based on their predicted acei-i inhibitory properties .

# %% [markdown]
# ## EXPERIMENT ENDING

# %% [markdown]
# ## Experimenting with Different Models
#
# Per instructions at <https://nlp.stanford.edu/software/nndep.shtml>
#
# I opened up the `stanford-corenlp-3.8.0.jar` file and added all the folders inside the `edu/stanford/nlp/` folder!

# %%
# !java edu.stanford.nlp.parser.nndep.DependencyParser -model edu/stanford/nlp/models/parser/nndep/PTB_CoNLL_params.txt.gz -textFile KeywordSentences.txt -outFile KeywordSentences_output.txt
# Out:
# Loading depparse model file: edu/stanford/nlp/models/parser/nndep/PTB_CoNLL_params.txt.gz ...
# ###################
# #Transitions: 35
# #Labels: 17
# ROOTLABEL: ROOT
# PreComputed 100000, Elapsed Time: 1.664 (s)
# Initializing dependency parser ... done [2.6 sec].
# Loading POS tagger from edu/stanford/nlp/models/pos-tagger/english-left3words/english-left3words-distsim.tagger ... done [0.9 sec].
# Tagging completed in 1.09 sec.
# Parsed 12 sentences in 0.52 seconds (23.30 sents/sec).

# %%
# !head KeywordSentences_output.txt
# Out:
# VMOD(is-11, RAAS-1)
# P(RAAS-1, ,-2)
# NMOD(target-6, a-3)
# NMOD(target-6, major-4)
# NMOD(target-6, pharmacological-5)
# APPO(RAAS-1, target-6)
# NMOD(target-6, in-7)
# NMOD(medicine-9, cardiovascular-8)
# PMOD(in-7, medicine-9)
# P(RAAS-1, ,-10)

# %%
# !java edu.stanford.nlp.parser.nndep.DependencyParser -model edu/stanford/nlp/models/parser/nndep/english_UD.gz -textFile KeywordSentences.txt -outFile KeywordSentences_output.txt
# Out:
# Loading depparse model file: edu/stanford/nlp/models/parser/nndep/english_UD.gz ...
# ###################
# #Transitions: 81
# #Labels: 40
# ROOTLABEL: root
# PreComputed 99996, Elapsed Time: 12.48 (s)
# Initializing dependency parser ... done [13.8 sec].
# Loading POS tagger from edu/stanford/nlp/models/pos-tagger/english-left3words/english-left3words-distsim.tagger ... done [2.2 sec].
# Tagging completed in 2.43 sec.
# Parsed 12 sentences in 0.68 seconds (17.67 sents/sec).

# %%
# !head KeywordSentences_output.txt
# Out:
# nsubjpass(inhibited-12, RAAS-1)
# punct(RAAS-1, ,-2)
# det(target-6, a-3)
# amod(target-6, major-4)
# amod(target-6, pharmacological-5)
# appos(RAAS-1, target-6)
# case(medicine-9, in-7)
# amod(medicine-9, cardiovascular-8)
# nmod(target-6, medicine-9)
# punct(RAAS-1, ,-10)

# %% [markdown]
# ## Hypothesis testing....
#
# I found an example abstract <https://www.ncbi.nlm.nih.gov/pubmed/28702139> that pretty clearly makes a connection between an ACEI and liver toxicity and side effects.... now I want to see if we could pull out any interactions.

# %%
# !echo "Aim: Angiotensin-converting enzyme inhibitors (ACEIs) are commonly used to treat hypertension. Although generally well tolerated, the adverse effects of ACEIs include hypotension, cough, acute kidney injury and hyperkalemia. Rare reports of ACEI-induced hepatotoxicity have been described, most notably a cholestatic pattern of injury related to captopril. A 67-year-old male presented to the emergency department with a three-week history of jaundice, pruritis and weakness. Eight weeks before, he began taking ramipril and clopidogrel. His past medical history was significant for previous acute cholestatic liver injury approximately 20 years earlier, which was attributed to methimazole. Abnormal blood work demonstrated aspartate aminotransferase (AST) 47 U/L, alanine aminotransferase (ALT) 46 U/L, total bilirubin 230 µmol/L, direct bilirubin 176 µmol/L, and alkaline phosphatase (ALP) 470 U/L. Abdominal ultrasound and magnetic resonance cholangiopancreatography showed no bile duct obstruction. Further work-up was negative for infectious, autoimmune, or other causes. Percutaneous liver biopsy showed marked cholestasis. With discontinuation of ramipril, the patient demonstrated prolonged cholestasis with partial biochemical improvement and was discharged after six weeks in hospital. This case represents the first described cross reactivity between ramipril and methimazole, illustrating the complex and poorly understood nature of DILI. Despite the relatively few instances of ACEI-induced liver hepatotoxicity, consideration should be given to discontinuation of ramipril in situations of unknown liver damage." > sample_sentence.txt

# %%
# !head sample_sentence.txt
# Out:
# Aim: Angiotensin-converting enzyme inhibitors (ACEIs) are commonly used to treat hypertension. Although generally well tolerated, the adverse effects of ACEIs include hypotension, cough, acute kidney injury and hyperkalemia. Rare reports of ACEI-induced hepatotoxicity have been described, most notably a cholestatic pattern of injury related to captopril. A 67-year-old male presented to the emergency department with a three-week history of jaundice, pruritis and weakness. Eight weeks before, he began taking ramipril and clopidogrel. His past medical history was significant for previous acute cholestatic liver injury approximately 20 years earlier, which was attributed to methimazole. Abnormal blood work demonstrated aspartate aminotransferase (AST) 47 U/L, alanine aminotransferase (ALT) 46 U/L, total bilirubin 230 µmol/L, direct bilirubin 176 µmol/L, and alkaline phosphatase (ALP) 470 U/L. Abdominal ultrasound and magnetic resonance cholangiopancreatography showed no bile duct obstruction. Further work-up was negative for infectious, autoimmune, or other causes. Percutaneous liver biopsy showed marked cholestasis. With discontinuation of ramipril, the patient demonstrated prolonged cholestasis with partial biochemical improvement and was discharged after six weeks in hospital. This case represents the first described cross reactivity between ramipril and methimazole, illustrating the complex and poorly understood nature of DILI. Despite the relatively few instances of ACEI-induced liver hepatotoxicity, consideration should be given to discontinuation of ramipril in situations of unknown liver damage.

# %% [markdown]
# ## Wanting to check Sentiment Analysis
#
# What if I grouped all the words together based on the sentiment of the sentence they're found in, and then allowed us to search for a couple of key words, and then the sentiment analysis would determine the relationship between the two items: compound and drug, compound and organ, organ and drug, etc?

# %% [markdown]
# ### Running a parser and annotator to get the sentiment...

# %%
# !java -cp "*" -Xmx2g edu.stanford.nlp.pipeline.StanfordCoreNLP -annotators tokenize,ssplit,pos,lemma,ner,parse,dcoref,sentiment -file sample_sentence.txt -outputFormat text
# Out:
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator pos
# [main] INFO edu.stanford.nlp.tagger.maxent.MaxentTagger - Loading POS tagger from edu/stanford/nlp/models/pos-tagger/english-left3words/english-left3words-distsim.tagger ... done [1.2 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [1.8 sec].
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [1.7 sec].
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.8 sec].
# [main] INFO edu.stanford.nlp.time.JollyDayHolidays - Initializing JollyDayHoliday for SUTime from classpath edu/stanford/nlp/models/sutime/jollyday/Holidays_sutime.xml as sutime.binder.1.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ... done [0.6 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator dcoref
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator sentiment
#
# Processing file /Users/lisabarcelo/Desktop/W266/food_drug_interaction/parsing/sample_sentence.txt ... writing to /Users/lisabarcelo/Desktop/W266/food_drug_interaction/parsing/sample_sentence.txt.out
# Annotating file /Users/lisabarcelo/Desktop/W266/food_drug_interaction/parsing/sample_sentence.txt ... done [8.0 sec].
#
# Annotation pipeline timing information:
# TokenizerAnnotator: 0.1 sec.
# WordsToSentencesAnnotator: 0.0 sec.
# POSTaggerAnnotator: 0.1 sec.
# MorphaAnnotator: 0.1 sec.
# NERCombinerAnnotator: 4.2 sec.
# ParserAnnotator: 3.0 sec.
# DeterministicCorefAnnotator: 0.4 sec.
# SentimentAnnotator: 0.1 sec.
# TOTAL: 8.0 sec. for 255 tokens at 32.0 tokens/sec.
# Pipeline setup: 11.2 sec.
# Total time for StanfordCoreNLP pipeline: 19.2 sec.

# %% [markdown]
# ### We can take a look at the output...
#
# It's pretty messy, so I just wanted to pull out the important stuff.

# %%
# !cat sample_sentence.txt.out

# %% [markdown]
# ### Made a little dictionary that would group words by sentiment, and assign the appropriate sentiment to them.

# %%
co_occurrence_dict = defaultdict(list)

for line in open('sample_sentence.txt.out').readlines():
    if 'Sentence #' in line:
        sentence = str(line.strip('\n')).split(" ")[1]
        sentiment = str(line.strip('\n')).split(":")[1]
        sentiment = re.sub("\d+","",re.sub(r'[^\w\s]','',sentiment))
    elif line[0] == '[':
        word = str(line.split("=")[1]).split(" ")[0].lower()
        pos = str(line.split("=")[4]).split(" ")[0]
        co_occurrence_dict[(sentiment, sentence)].append(word)

# %%
#Example of one of the entries in the dictionary

from itertools import islice
import  pprint
def take(n, iterable):
    "Return first n items of the iterable as a list"
    return list(islice(iterable, n))

n_items = take(1, co_occurrence_dict.iteritems())
pp = pprint.PrettyPrinter(depth=6)
pp.pprint(n_items)
# Out:
# [((' Negative', '#10'),
#   ['percutaneous', 'liver', 'biopsy', 'showed', 'marked', 'cholestasis', '.'])]

# %% [markdown]
# ### This could be a way that we search our dictionary to find the relationship between the words.
# Look at a few key words, and see what results. Notice the different types of searches we could do. `if any...` vs `if all...`!

# %%
#Assuming these are the key words we are curious about.
search_phrase = ['ramipril','liver']

#Searching through the dictionary
for k,v in co_occurrence_dict.iteritems():
#     if any(k in search_phrase for k in v):
    if all(k in v for k in search_phrase):
        #print k, v
        print "There is a", k[0], "relationship between ", search_phrase, ".\nLiterature: ", " ".join([i for i in v])
# Out:
# There is a  Negative relationship between  ['ramipril', 'liver'] .
# Literature:  despite the relatively few instances of acei-induced liver hepatotoxicity , consideration should be given to discontinuation of ramipril in situations of unknown liver damage .

# %% [markdown]
# ## POS Tagging and Caching
#
# Another way of looking at it... We could just group the words together by POS tag? Not sure if this could be more helpful.

# %%
# !java edu.stanford.nlp.parser.nndep.DependencyParser -model edu/stanford/nlp/models/parser/nndep/PTB_CoNLL_params.txt.gz -textFile sample_sentence.txt -outFile sample_sentence_output.txt
# Out:
# Loading depparse model file: edu/stanford/nlp/models/parser/nndep/PTB_CoNLL_params.txt.gz ...
# ###################
# #Transitions: 35
# #Labels: 17
# ROOTLABEL: ROOT
# PreComputed 100000, Elapsed Time: 1.804 (s)
# Initializing dependency parser ... done [2.8 sec].
# Loading POS tagger from edu/stanford/nlp/models/pos-tagger/english-left3words/english-left3words-distsim.tagger ... done [0.7 sec].
# Tagging completed in 0.90 sec.
# Parsed 13 sentences in 0.48 seconds (27.31 sents/sec).

# %%
# !cat sample_sentence_output.txt
# Out:
# root(ROOT-0, Aim-1)
# P(Aim-1, :-2)
# NMOD(inhibitors-5, Angiotensin-converting-3)
# NMOD(inhibitors-5, enzyme-4)
# VMOD(are-9, inhibitors-5)
# NMOD(-RRB--8, -LRB--6)
# NMOD(-RRB--8, ACEIs-7)
# APPO(inhibitors-5, -RRB--8)
# NMOD(Aim-1, are-9)
# VMOD(are-9, commonly-10)
# VC(are-9, used-11)
# VMOD(used-11, to-12)
# IM(to-12, treat-13)
# VMOD(treat-13, hypertension-14)
# P(Aim-1, .-15)
#
# VMOD(include-11, Although-1)
# VMOD(tolerated-4, generally-2)
# AMOD(generally-2, well-3)
# SUB(Although-1, tolerated-4)
# P(include-11, ,-5)
# NMOD(effects-8, the-6)
# NMOD(effects-8, adverse-7)
# VMOD(include-11, effects-8)
# NMOD(effects-8, of-9)
# PMOD(of-9, ACEIs-10)
# root(ROOT-0, include-11)
# VMOD(include-11, hypotension-12)
# P(hypotension-12, ,-13)
# COORD(hypotension-12, cough-14)
# P(cough-14, ,-15)
# NMOD(injury-18, acute-16)
# NMOD(injury-18, kidney-17)
# COORD(cough-14, injury-18)
# COORD(injury-18, and-19)
# CONJ(and-19, hyperkalemia-20)
# P(include-11, .-21)
#
# NMOD(reports-2, Rare-1)
# VMOD(have-6, reports-2)
# NMOD(reports-2, of-3)
# NMOD(hepatotoxicity-5, ACEI-induced-4)
# PMOD(of-3, hepatotoxicity-5)
# root(ROOT-0, have-6)
# VC(have-6, been-7)
# VC(been-7, described-8)
# P(described-8, ,-9)
# AMOD(notably-11, most-10)
# NMOD(pattern-14, notably-11)
# NMOD(pattern-14, a-12)
# NMOD(pattern-14, cholestatic-13)
# VMOD(described-8, pattern-14)
# NMOD(pattern-14, of-15)
# PMOD(of-15, injury-16)
# APPO(injury-16, related-17)
# AMOD(related-17, to-18)
# PMOD(to-18, captopril-19)
# P(have-6, .-20)
#
# NMOD(male-3, A-1)
# NMOD(male-3, 67-year-old-2)
# root(ROOT-0, male-3)
# APPO(male-3, presented-4)
# VMOD(presented-4, to-5)
# NMOD(department-8, the-6)
# NMOD(department-8, emergency-7)
# PMOD(to-5, department-8)
# VMOD(presented-4, with-9)
# NMOD(history-12, a-10)
# NMOD(history-12, three-week-11)
# PMOD(with-9, history-12)
# NMOD(history-12, of-13)
# PMOD(of-13, jaundice-14)
# P(jaundice-14, ,-15)
# COORD(jaundice-14, pruritis-16)
# COORD(pruritis-16, and-17)
# CONJ(and-17, weakness-18)
# P(male-3, .-19)
#
# NMOD(weeks-2, Eight-1)
# AMOD(before-3, weeks-2)
# VMOD(began-6, before-3)
# P(began-6, ,-4)
# VMOD(began-6, he-5)
# root(ROOT-0, began-6)
# VMOD(began-6, taking-7)
# VMOD(taking-7, ramipril-8)
# COORD(ramipril-8, and-9)
# CONJ(and-9, clopidogrel-10)
# P(began-6, .-11)
#
# NMOD(history-4, His-1)
# NMOD(history-4, past-2)
# NMOD(history-4, medical-3)
# VMOD(was-5, history-4)
# root(ROOT-0, was-5)
# VMOD(was-5, significant-6)
# AMOD(significant-6, for-7)
# NMOD(injury-12, previous-8)
# NMOD(injury-12, acute-9)
# NMOD(injury-12, cholestatic-10)
# NMOD(injury-12, liver-11)
# PMOD(for-7, injury-12)
# NMOD(years-15, approximately-13)
# DEP(approximately-13, 20-14)
# AMOD(earlier-16, years-15)
# VMOD(was-5, earlier-16)
# P(was-5, ,-17)
# VMOD(was-19, which-18)
# VMOD(was-5, was-19)
# VC(was-19, attributed-20)
# VMOD(attributed-20, to-21)
# PMOD(to-21, methimazole-22)
# P(was-5, .-23)
#
# NMOD(work-3, Abnormal-1)
# NMOD(work-3, blood-2)
# VMOD(demonstrated-4, work-3)
# root(ROOT-0, demonstrated-4)
# NMOD(aminotransferase-6, aspartate-5)
# VMOD(demonstrated-4, aminotransferase-6)
# NMOD(aminotransferase-6, -LRB--7)
# COORD(-LRB--7, AST-8)
# COORD(AST-8, -RRB--9)
# NMOD(U/L-11, 47-10)
# COORD(-RRB--9, U/L-11)
# P(U/L-11, ,-12)
# NMOD(aminotransferase-14, alanine-13)
# COORD(U/L-11, aminotransferase-14)
# COORD(aminotransferase-14, -LRB--15)
# COORD(-LRB--15, ALT-16)
# COORD(ALT-16, -RRB--17)
# NMOD(U/L-19, 46-18)
# COORD(-RRB--17, U/L-19)
# P(U/L-19, ,-20)
# NMOD(µmol-24, total-21)
# NMOD(µmol-24, bilirubin-22)
# NMOD(µmol-24, 230-23)
# COORD(U/L-19, µmol-24)
# P(µmol-24, /-25)
# COORD(µmol-24, L-26)
# P(L-26, ,-27)
# COORD(L-26, direct-28)
# VMOD(direct-28, bilirubin-29)
# NMOD(µmol-31, 176-30)
# APPO(bilirubin-29, µmol-31)
# P(µmol-31, /-32)
# NMOD(U/L-42, L-33)
# P(L-33, ,-34)
# COORD(L-33, and-35)
# NMOD(phosphatase-37, alkaline-36)
# CONJ(and-35, phosphatase-37)
# NMOD(U/L-42, -LRB--38)
# NMOD(U/L-42, ALP-39)
# NMOD(U/L-42, -RRB--40)
# NMOD(U/L-42, 470-41)
# APPO(µmol-31, U/L-42)
# P(demonstrated-4, .-43)
#
# NMOD(ultrasound-2, Abdominal-1)
# VMOD(showed-7, ultrasound-2)
# COORD(ultrasound-2, and-3)
# NMOD(cholangiopancreatography-6, magnetic-4)
# NMOD(cholangiopancreatography-6, resonance-5)
# CONJ(and-3, cholangiopancreatography-6)
# root(ROOT-0, showed-7)
# NMOD(obstruction-11, no-8)
# NMOD(obstruction-11, bile-9)
# NMOD(obstruction-11, duct-10)
# VMOD(showed-7, obstruction-11)
# P(showed-7, .-12)
#
# NMOD(work-up-2, Further-1)
# VMOD(was-3, work-up-2)
# root(ROOT-0, was-3)
# VMOD(was-3, negative-4)
# VMOD(was-3, for-5)
# NMOD(autoimmune-8, infectious-6)
# P(autoimmune-8, ,-7)
# PMOD(for-5, autoimmune-8)
# P(autoimmune-8, ,-9)
# COORD(autoimmune-8, or-10)
# NMOD(causes-12, other-11)
# CONJ(or-10, causes-12)
# P(was-3, .-13)
#
# NMOD(biopsy-3, Percutaneous-1)
# NMOD(biopsy-3, liver-2)
# VMOD(showed-4, biopsy-3)
# root(ROOT-0, showed-4)
# NMOD(cholestasis-6, marked-5)
# VMOD(showed-4, cholestasis-6)
# P(showed-4, .-7)
#
# root(ROOT-0, With-1)
# PMOD(With-1, discontinuation-2)
# NMOD(discontinuation-2, of-3)
# PMOD(of-3, ramipril-4)
# P(ramipril-4, ,-5)
# NMOD(patient-7, the-6)
# VMOD(demonstrated-8, patient-7)
# NMOD(ramipril-4, demonstrated-8)
# NMOD(cholestasis-10, prolonged-9)
# VMOD(demonstrated-8, cholestasis-10)
# VMOD(demonstrated-8, with-11)
# NMOD(improvement-14, partial-12)
# NMOD(improvement-14, biochemical-13)
# PMOD(with-11, improvement-14)
# COORD(demonstrated-8, and-15)
# CONJ(and-15, was-16)
# VC(was-16, discharged-17)
# VMOD(discharged-17, after-18)
# NMOD(weeks-20, six-19)
# PMOD(after-18, weeks-20)
# NMOD(weeks-20, in-21)
# PMOD(in-21, hospital-22)
# P(With-1, .-23)
#
# NMOD(case-2, This-1)
# VMOD(represents-3, case-2)
# root(ROOT-0, represents-3)
# VMOD(represents-3, the-4)
# APPO(the-4, first-5)
# APPO(first-5, described-6)
# NMOD(reactivity-8, cross-7)
# VMOD(described-6, reactivity-8)
# NMOD(reactivity-8, between-9)
# PMOD(between-9, ramipril-10)
# COORD(ramipril-10, and-11)
# CONJ(and-11, methimazole-12)
# P(described-6, ,-13)
# VMOD(described-6, illustrating-14)
# NMOD(complex-16, the-15)
# VMOD(illustrating-14, complex-16)
# COORD(complex-16, and-17)
# AMOD(understood-19, poorly-18)
# CONJ(and-17, understood-19)
# APPO(complex-16, nature-20)
# NMOD(nature-20, of-21)
# PMOD(of-21, DILI-22)
# P(represents-3, .-23)
#
# VMOD(should-12, Despite-1)
# NMOD(instances-5, the-2)
# AMOD(few-4, relatively-3)
# NMOD(instances-5, few-4)
# PMOD(Despite-1, instances-5)
# NMOD(instances-5, of-6)
# NMOD(hepatotoxicity-9, ACEI-induced-7)
# NMOD(hepatotoxicity-9, liver-8)
# PMOD(of-6, hepatotoxicity-9)
# P(should-12, ,-10)
# VMOD(should-12, consideration-11)
# root(ROOT-0, should-12)
# VC(should-12, be-13)
# VC(be-13, given-14)
# VMOD(given-14, to-15)
# PMOD(to-15, discontinuation-16)
# NMOD(discontinuation-16, of-17)
# PMOD(of-17, ramipril-18)
# NMOD(discontinuation-16, in-19)
# PMOD(in-19, situations-20)
# NMOD(situations-20, of-21)
# NMOD(damage-24, unknown-22)
# NMOD(damage-24, liver-23)
# PMOD(of-21, damage-24)
# P(should-12, .-25)

# %%
POS_dict = defaultdict(list)
words_dict = defaultdict(list)
for line in open('sample_sentence_output.txt').readlines():
    pos = line.split("(")[0]
    try:
        word_1, word_2 = str(line.split("(")[1]).split(",")[0], str(line.split("(")[1]).split(",")[1]
        word_1 = re.sub("\d+","",re.sub(r'[^\w\s]','',word_1))
        word_2 = re.sub("\d+","",re.sub(r'[^\w\s]','',word_2))
        
        #Dictionary of words and their parts of speech?
        words_dict[str(word_1).strip(' \n')].append(str(pos).strip('\n'))
        words_dict[str(word_2).strip(' \n')].append(str(pos).strip('\n'))
        
        #Dictionary of POS with corresponding words?
        POS_dict[str(pos)].append(((str(word_1).strip('\n')),str(word_2).strip('\n')))
        
    except:
        next

print POS_dict.keys()
print words_dict.keys()
# Out:
# ['VC', 'SUB', 'VMOD', 'PMOD', 'DEP', 'NMOD', 'AMOD', 'APPO', 'P', 'IM', 'COORD', 'CONJ', 'root']
# ['', 'Percutaneous', 'partial', 'magnetic', 'years', 'obstruction', 'aspartate', 'DILI', 'causes', 'before', 'His', 'situations', 'cholestasis', 'reactivity', 'improvement', 'to', 'enzyme', 'complex', 'Although', 'Despite', 'weeks', 'include', 'pruritis', 'ACEIinduced', 'emergency', 'represents', 'weakness', 'biopsy', 'L', 'Aim', 'effects', 'mol', 'damage', 'acute', 'jaundice', 'presented', 'should', 'prolonged', 'methimazole', 'Further', 'alanine', 'illustrating', 'ramipril', 'direct', 'related', 'past', 'understood', 'are', 'instances', 'for', 'poorly', 'pattern', 'inhibitors', 'Eight', 'phosphatase', 'between', 'previous', 'ROOT', 'demonstrated', 'be', 'after', 'patient', 'nature', 'This', 'alkaline', 'notably', 'cholestatic', 'cough', 'discharged', 'LRB', 'of', 'taking', 'Abnormal', 'attributed', 'UL', 'discontinuation', 'resonance', 'or', 'first', 'Abdominal', 'hepatotoxicity', 'duct', 'marked', 'negative', 'ultrasound', 'been', 'consideration', 'total', 'workup', 'given', 'described', 'AST', 'aminotransferase', 'unknown', 'hospital', 'RRB', 'approximately', 'few', 'treat', 'injury', 'was', 'tolerated', 'Rare', 'threeweek', 'with', 'he', 'case', 'bile', 'hypotension', 'showed', 'work', 'infectious', 'yearold', 'biochemical', 'ALT', 'male', 'ALP', 'history', 'and', 'autoimmune', 'hypertension', 'commonly', 'have', 'in', 'captopril', 'kidney', 'clopidogrel', 'no', 'bilirubin', 'began', 'six', 'generally', 'cross', 'adverse', 'hyperkalemia', 'other', 'which', 'department', 'relatively', 'With', 'A', 'used', 'cholangiopancreatography', 'earlier', 'most', 'blood', 'significant', 'a', 'Angiotensinconverting', 'ACEIs', 'medical', 'well', 'reports', 'the', 'liver']
