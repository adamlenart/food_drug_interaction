# %% [markdown]
# # Data Filtering : Food-drug Interaction Project

# %% [markdown]
# ## Drug: Statin
# ## Food: common food

# %% [markdown]
# # Step 1: Load food names or compounds into a list of unique items

# %%
import pandas as pd
import numpy as np
import json
import pickle
import json
import jellyfish

# UTF-8 support
import codecs

# To use PubMed API
import pubmed.utils as pb

# Split abstracts to sentences
from nltk.tokenize import sent_tokenize

import random


from collections import defaultdict
import re

# %% [markdown]
# ### Functions for Step 1

# %%
def replaceNonASCII(text):
    ''' Replace all non ASCII characters by 'unk'
        This is to deal with Unicode encode/decode bug when using PySpark
    '''
    if text is not None:
        return ''.join([i if ord(i) < 128 else 'unk' for i in text])

    
def list_loader(data):
    ''' Load pickle file
        Returns keys of the loaded dictionary as a set
    '''
    test = pickle.load(open( data , "rb"))
    foodlist = []
    for food in test.keys():
        food = replaceNonASCII(food.decode('utf-8').lower())
        foodlist.append(food)
        
    return set(foodlist)  # Will work with a set rather than a list. Faster search for later (hash)

# %% [markdown]
# ### Using Adam's pickle file (food common name as sample)

# %% [markdown]
# For pickling the data from foodb.ca database, see Adam's notebook **compound_food_id.ipynb**
#
# As a first test, we will use only the food common name (not scientific name) only. Compounds names will be added once this test passes.

# %%
# food_common.pickle: Dictionary with common English food names as keys, compounds as values
test = pickle.load(open( "data/food_common.pickle", "rb"))

# %%
# Quick peek at the loaded data
for i, item in enumerate(test.iteritems()):
    if i == 0:
        print 'food name'
        print '-'*10
    print '{0}'.format(item[0])
    if i == 10: break
# Out:
# food name
# ----------
# Oregon yampah
# Okra
# Black mulberry
# Avocado
# Parsley
# Elderberry
# Sugar
# Sweet bay
# Common bean
# Fig
# Lard

# %%
foodlist = list_loader('data/food_common.pickle')

# %%
i = 0
for food in foodlist:
    print food
    i += 1
    if i > 5:
        break
# Out:
# atlantic pollock
# mixed nuts
# rose hip
# black mulberry
# pheasant
# whiting

# %% [markdown]
# # Step 2: Create list of words for drug keyword

# %%
drug_options = ['statin', 'statins', 'HMG-CoA reductase inhibitors', 'HMG-CoA reductase inhibitor', 
                'HMG-CoA reductase-inhibitors',  'HMG-CoA reductase-inhibitor',
                'HMG-CoA-reductase-inhibitors',  'HMG-CoA-reductase-inhibitor',
                'HMGA reductase inhibitors', 'HMGA reductase inhibitor',
                'HMG-CoA reductase', 'HMG-CoA-reductase', 'HMG CoA reductase',
                '(HMG-CoA) reductase inhibitors', '(HMG-CoA) reductase inhibitor', '(HMG-CoA) reductase',
                'hydroxy-methylglutaryl-coenzyme A reductase', '(HMG-CoA reductase)',
                'atorvastatin', 'fluvastatin', 'lovastatin', 'pitavastatin', 
                'pravastatin', 'rosuvastatin', 'simvastatin',
                'atorvastatins', 'fluvastatins', 'lovastatins', 'pitavastatins', 
                'pravastatins', 'rosuvastatins', 'simvastatins']

# %% [markdown]
# # Step 3: Filter sentences from abstract with drug keyword and food names

# %% [markdown]
# Note: Test with only the abstracts' first json file. Once works, we can add all 100 remaining files.

# %%
import pyspark
from pyspark import SparkContext
sc = SparkContext()

# %% [markdown]
# ### Functions for Step 3

# %%
name = ['pbabstract1.json']
data_list = []
for jsonfile in name:
    with open('statins_pbabstract/'+jsonfile, "r") as data_file:
        data = json.load(data_file)
        values = [replaceNonASCII(value) for value in data.values()]
        data_list.extend(values)

# %%
print data_list[:2]
# Out:
# [u'Clinically stable patients who underwent DES implantation 12 months previously and received aspirin monotherapy were randomly assigned to receive either high-intensity (40mg atorvastatin, n = 1000) or low-intensity (20mg pravastatin, n = 1000) statin treatment. The primary endpoint was adverse clinical events at 12-month follow-up (a composite of all death, myocardial infarction, revascularization, stent thrombosis, stroke, renal deterioration, intervention for peripheral artery disease, and admission for cardiac events).', u'The primary endpoint at 12-month follow-up occurred in 25 patients (2.5%) receiving high-intensity statin treatment and in 40 patients (4.1%) receiving low-intensity statin treatment (HR, 0.58; 95%CI, 0.36-0.92; P = .018). This difference was mainly driven by a lower rate of cardiac death (0 vs 0.4%, P = .025) and nontarget vessel myocardial infarction (0.1 vs 0.7%, P = .033) in the high-intensity statin treatment group.']

# %%
name = []
for jsonfile in name:
    with codecs.open(statins_pbabstract/jsonfile,"r","utf-8") as data_file:
        data = json.load(data_file)
        values = [replaceNonASCII(value) for value in data.values()]
        data_list.extend(values)
            
    return data_list

# %%
def abstract_loader(name):
    ''' Loads abstracts from json files in provided list
    '''
    data_list = []
    for jsonfile in name:
        with codecs.open('statins_pbabstract/'+jsonfile,"r","utf-8") as data_file:  # Note: changed directory of data!
            data = json.load(data_file)
            values = [replaceNonASCII(value) for value in data.values()]
            data_list.extend(values)
            
    return data_list


def splitSentences(abstract):
    sentences = sent_tokenize(abstract)
    return sentences


def find_ngrams(sentence, n):
    ''' Return list of ngrams from a sentence
    '''
    words_list = sentence.split()
    ngrams = zip(*[words_list[i:] for i in range(n)])
    #return [''.join([unicode(w)+' ' for w in ngram if type(w)==unicode]).strip() for ngram in ngrams]
    return [''.join([w+' ' for w in ngram]).strip() for ngram in ngrams]


#######################
# Method 1 - NOT USED #
#######################

# NOT USED since will return True if finds a food name within a word in the sentence
# E.g.: "pie" food name and "therapies" word in sentence: return True since "pie" in "therapies"
#def includeFoodCmpd(sentence, fdlist):
#    if any(word in sentence for word in fdlist):
#        return True
#    else:
#        return False


###################################
# Method 2 - solution to method 2 #
###################################

def includeDrug(sentence, dglist, limit, verbose=False):
    ''' Calculates the Jaro Wrinkler distance between drug name and ngrams in the sentence.
        Returns True if distance > limit
    '''
    result = False
    for drug in dglist:
        n = min(5, len(drug.split()))  # Assuming max as 5-gram        
        sentence_ngrams = find_ngrams(sentence, n)  # Note: punctuation at end of sentence will be included with
                                                # last word. For now ok, since the JW will still be > limit
        for ngram in sentence_ngrams:
            # Note: when using jaro_winkler, need to convert into unicode format
            ngram_distance = jellyfish.jaro_winkler(u"{}".format(drug.lower()), u"{}".format(ngram.lower()))
            if verbose:
                print drug, ngram, ngram_distance
            if ngram_distance > limit:  
                result = True
                break

    return result



def includeFoodCmpd(sentence, fdlist, limit, verbose=False):
    ''' Calculates the Jaro Wrinkler distance between food name and ngrams in the sentence.
        Returns True if distance > 0.95
    '''
    result = False
    for food in fdlist:
        n = min(3, len(food.split()))  # Assuming max as trigram        
        sentence_ngrams = find_ngrams(sentence, n)  # Note: punctuation at end of sentence will be included with
                                                # last word. For now ok, since the JW will still be > 0.95
        for ngram in sentence_ngrams:
            # Note: when using jaro_winkler, need to convert into unicode format
            ngram_distance = jellyfish.jaro_winkler(food.lower(), u"{}".format(ngram.lower()))
            if verbose:
                print food, ngram, ngram_distance
            if ngram_distance >= limit:  
                result = True
                break

    return result


def findFood(sentence, foods):
    ''' Returns the food names found in the sentence based on string distance method
    '''
    
    food = []

    # If using string distance method:
    for f in foods:
        n = min(3, len(f.split()))  # Assuming max as trigram        
        sentence_ngrams = find_ngrams(sentence, n)  # Note: punctuation at end of sentence will be included with
                                                # last word. For now ok, since the JW will still be > 0.95
        for ngram in sentence_ngrams:
            # Note: when using jaro_winkler, need to convert into unicode format
            if jellyfish.jaro_winkler(f.lower(), u"{}".format(ngram.lower())) > 0.95:
                food.append(f)
            
    return food


# Not used since we will use the string distance for filtering
def findFoodItems(sentence, foods):
    for item in foods:
        if item in sentence:
            print item
            
def is_relevant(sentence, irrelevant_list, fdlist):
    ''' Filter sentences with only relevant food words
    '''
    foods = findFood(sentence, fdlist)
    if any(word in foods for word in irrelevant_list):
        return False
    else:
        return True

# %%
# Test find_ngrams:
string = u"We are working hard on 266 project baseline"
find_ngrams(string, 3)
# Out:
# [u'We are working',
#  u'are working hard',
#  u'working hard on',
#  u'hard on 266',
#  u'on 266 project',
#  u'266 project baseline']

# %%
# Testing includeFoodCmpd function
ss = u'Panda is eating a pie'
testlist = [u"hello",u"pie"]
includeFoodCmpd(ss, testlist, 0.98, verbose=True)
# Out:
# hello Panda 0.0
# hello is 0.0
# hello eating 0.455555555556
# hello a 0.0
# hello pie 0.511111111111
# pie Panda 0.511111111111
# pie is 0.0
# pie eating 0.5
# pie a 0.0
# pie pie 1.0
# True

# %%
# Testing includeDrug function
ss = u'Panda is eating a pie'
testlist = [u"hello",u"pie"]
includeDrug(ss, testlist, 0.99, verbose=True)
# Out:
# hello Panda 0.0
# hello is 0.0
# hello eating 0.455555555556
# hello a 0.0
# hello pie 0.511111111111
# pie Panda 0.511111111111
# pie is 0.0
# pie eating 0.5
# pie a 0.0
# pie pie 1.0
# True

# %%
# Load all abstracts - there are 414 json files from PubMed
filename_list = []
for i in xrange(1, 415):
    filename_temp = "pbabstract" + str(i)+ ".json"
    filename_list.append(filename_temp)

abstract = abstract_loader(filename_list)

# %%
abstractRDD = sc.parallelize(abstract)\
                .filter(lambda a: a is not None)  #Some lines were empty: need to filter out
abstractRDD.take(2)
# Out:
# [u'Clinically stable patients who underwent DES implantation 12 months previously and received aspirin monotherapy were randomly assigned to receive either high-intensity (40mg atorvastatin, n = 1000) or low-intensity (20mg pravastatin, n = 1000) statin treatment. The primary endpoint was adverse clinical events at 12-month follow-up (a composite of all death, myocardial infarction, revascularization, stent thrombosis, stroke, renal deterioration, intervention for peripheral artery disease, and admission for cardiac events).',
#  u'The primary endpoint at 12-month follow-up occurred in 25 patients (2.5%) receiving high-intensity statin treatment and in 40 patients (4.1%) receiving low-intensity statin treatment (HR, 0.58; 95%CI, 0.36-0.92; P = .018). This difference was mainly driven by a lower rate of cardiac death (0 vs 0.4%, P = .025) and nontarget vessel myocardial infarction (0.1 vs 0.7%, P = .033) in the high-intensity statin treatment group.']

# %%
# Note: tried to braodcast the foodlist but got an error message when used it in below filter
# "TypeError: 'Broadcast' object is not iterable".... any idea why?
# foodlist_bcast = sc.broadcast(foodlist)

# %%
# If substituting drugs related words by "ACEI" then filter
#drugkeyword = "ACEI"

#sentences = abstractRDD.flatMap(splitSentences) \
#                       .map(lambda a: pb.ace_substitutor(a, drugkeyword)) \
#                       .filter(lambda a: drugkeyword in a)\
#                       .filter(lambda a: includeFoodCmpd(a, foodlist, 0.98))

#%%time
#filtered_sentences = sentences.collect()
### results:
### CPU times: user 71.2 ms, sys: 30.3 ms, total: 101 ms
### Wall time: 21min 30s

#len(filtered_sentences) -> 938

# %%
sentences = abstractRDD.flatMap(splitSentences) \
                       .filter(lambda a: includeDrug(a, drug_options , 0.99))\
                       .filter(lambda a: includeFoodCmpd(a, foodlist, 0.98))

# %%
sentences.take(2)
# Out:
# [u'18 samples of red yeast rice powder and 18 samples of lovastatin were collected.',
#  u'In this study, we demonstrate the efficacy of topical statin treatment in reducing scar in our validated rabbit ear scar model.']

# %%
# %%time
filtered_sentences = sentences.collect()
# Out:
# CPU times: user 113 ms, sys: 52.4 ms, total: 166 ms
# Wall time: 38min 26s

# %%
len(filtered_sentences)
# Out:
# 835

# %%
# Save filtered sentences containing drug and food name in textfile
#with open("data/FilteredSentences_ACEI_commonFood.txt", "w") as outcomes:
#    for sentence in filtered_sentences:
#        food = findFood(sentence, foodlist)
#        outcomes.writelines(str(food) + sentence + "\n")

# %%
# Delete some sentences with irrelevant food names
irrelevant = ['date', 'rabbit', 'shortening', 'arepas', 'water', 'cocktail']

relevant_sentences = sc.parallelize(filtered_sentences)\
                       .filter(lambda a: is_relevant(a, irrelevant, foodlist))\
                       .collect()

# %%
len(relevant_sentences)
# Out:
# 370

# %%
with open("data/FilteredSentences_Statin_commonFood_clean.txt", "w") as outcomes:
    for sentence in relevant_sentences:
        food = findFood(sentence, foodlist)
        outcomes.writelines(str(food) + sentence + "\n")

# %% [markdown]
# ## Step 4: Classify sentences as positive or negative based on a sentiment lexicon

# %% [markdown]
# There are 467 sentences containing both ACE Inhibitor drug and a food name from Step 2. They will be labeled and then compared to the 2 baseline models classification for model evaluation.

# %% [markdown]
# ## BASELINE 1: 50/50 coin flip classification

# %% [markdown]
# Our first model is to simply classify the interaction between drug and food in the sentence as positive, negative or neutral based on equal probability of 1/3 in each class.
#
# Evaluation metrics: the labels of 100 randomly chosen sentences from outcomes in step 2 (i.e. sentences with drug and food names) will be compared with the random labels from baseline model.

# %%
classification = [(random.choice(["positive", "negative", "neutral"]), sentence) for sentence in relevant_sentences]

# %% [markdown]
# # -------------- SECTION BELOW HAS NOT BEEN UPDATED --------------

# %% [markdown]
# ## BASELINE 2: Sentiment lexicon

# %% [markdown]
# Sentiment lexicon used is the Harvard General Inquirer (http://www.wjh.harvard.edu/~inquirer/spreadsheet_guide.htm). It contains 1,915 positive words and 2,291 negative words and is free for research use.

# %%
db_sentiment = pd.read_csv("data/inquirerbasic.csv", encoding = 'utf8')
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (63,108,109,110,176) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
db_sentiment.head()
# Out:
#          Entry Source Positiv  Negativ Pstv Affil  Ngtv Hostile Strong Power  \
# 0            A  H4Lvd     NaN      NaN  NaN   NaN   NaN     NaN    NaN   NaN
# 1      ABANDON  H4Lvd     NaN  Negativ  NaN   NaN  Ngtv     NaN    NaN   NaN
# 2  ABANDONMENT     H4     NaN  Negativ  NaN   NaN   NaN     NaN    NaN   NaN
# 3        ABATE  H4Lvd     NaN  Negativ  NaN   NaN   NaN     NaN    NaN   NaN
# 4    ABATEMENT    Lvd     NaN      NaN  NaN   NaN   NaN     NaN    NaN   NaN
#
#                          ...                         Anomie NegAff PosAff  \
# 0                        ...                            NaN    NaN    NaN
# 1                        ...                            NaN    NaN    NaN
# 2                        ...                            NaN    NaN    NaN
# 3                        ...                            NaN    NaN    NaN
# 4                        ...                            NaN    NaN    NaN
#
#   SureLw   If NotLw TimeSpc FormLw  Othtags  \
# 0    NaN  NaN   NaN     NaN    NaN  DET ART
# 1    NaN  NaN   NaN     NaN    NaN     SUPV
# 2    NaN  NaN   NaN     NaN    NaN     Noun
# 3    NaN  NaN   NaN     NaN    NaN     SUPV
# 4    NaN  NaN   NaN     NaN    NaN     Noun
#
#                                              Defined
# 0  | article: Indefinite singular article--some o...
# 1                                                  |
# 2                                                  |
# 3                                                  |
# 4                                                NaN
#
# [5 rows x 186 columns]

# %%
# Look at all data fields available
for column in db_sentiment.columns:
    print column
# Out:
# Entry
# Source
# Positiv
# Negativ
# Pstv
# Affil
# Ngtv
# Hostile
# Strong
# Power
# Weak
# Submit
# Active
# Passive
# Pleasur
# Pain
# Feel
# Arousal
# EMOT
# Virtue
# Vice
# Ovrst
# Undrst
# Academ
# Doctrin
# Econ@
# Exch
# ECON
# Exprsv
# Legal
# Milit
# Polit@
# POLIT
# Relig
# Role
# COLL
# Work
# Ritual
# SocRel
# Race
# Kin@
# MALE
# Female
# Nonadlt
# HU
# ANI
# PLACE
# Social
# Region
# Route
# Aquatic
# Land
# Sky
# Object
# Tool
# Food
# Vehicle
# BldgPt
# ComnObj
# NatObj
# BodyPt
# ComForm
# COM
# Say
# Need
# Goal
# Try
# Means
# Persist
# Complet
# Fail
# NatrPro
# Begin
# Vary
# Increas
# Decreas
# Finish
# Stay
# Rise
# Exert
# Fetch
# Travel
# Fall
# Think
# Know
# Causal
# Ought
# Perceiv
# Compare
# Eval@
# EVAL
# Solve
# Abs@
# ABS
# Quality
# Quan
# NUMB
# ORD
# CARD
# FREQ
# DIST
# Time@
# TIME
# Space
# POS
# DIM
# Rel
# COLOR
# Self
# Our
# You
# Name
# Yes
# No
# Negate
# Intrj
# IAV
# DAV
# SV
# IPadj
# IndAdj
# PowGain
# PowLoss
# PowEnds
# PowAren
# PowCon
# PowCoop
# PowAuPt
# PowPt
# PowDoct
# PowAuth
# PowOth
# PowTot
# RcEthic
# RcRelig
# RcGain
# RcLoss
# RcEnds
# RcTot
# RspGain
# RspLoss
# RspOth
# RspTot
# AffGain
# AffLoss
# AffPt
# AffOth
# AffTot
# WltPt
# WltTran
# WltOth
# WltTot
# WlbGain
# WlbLoss
# WlbPhys
# WlbPsyc
# WlbPt
# WlbTot
# EnlGain
# EnlLoss
# EnlEnds
# EnlPt
# EnlOth
# EnlTot
# SklAsth
# SklPt
# SklOth
# SklTot
# TrnGain
# TrnLoss
# TranLw
# MeansLw
# EndsLw
# ArenaLw
# PtLw
# Nation
# Anomie
# NegAff
# PosAff
# SureLw
# If
# NotLw
# TimeSpc
# FormLw
# Othtags
# Defined

# %% [markdown]
# **Note:** some columns seem quite interesting for analysing relationship other than simply positive or negative sentiment (e.g. "causal", etc.). For the baseline, we will only use the "positive" and "negative" columns

# %%
# Filter only the words labeled positive or negative
positive = db_sentiment[db_sentiment.Positiv == "Positiv"].Entry.map(lambda x: x.lower()).tolist()
negative = db_sentiment[db_sentiment.Negativ == "Negativ"].Entry.map(lambda x: x.lower()).tolist()

# %%
positive[:4]
# Out:
# [u'abide', u'ability', u'able', u'abound']

# %%
negative[:4]
# Out:
# [u'abandon', u'abandonment', u'abate', u'abdicate']

# %%
# Transform list into sets for faster search
positive = set(positive)
negative = set(negative)

# %% [markdown]
# Below is an attempt to classify whether a sentence is positive or negative.
# Note the main weaknesses:
# 1. It is "positively" biased for now since looks at the positive words first and if it finds it, then it immediately returns positive. Thus, it may not look at the entire sentence in case of both positive or negative words.
# 2. Negation of a positive word is not taken into account

# %%
def includeSentiment(sentence, poslist, neglist): 
    ''' Classify sentence as positive or negative based on first word found
        in the lexicon
    '''
    if any(word in sentence for word in poslist):
        return ("positive", sentence)
    elif any(word in sentence for word in neglist):
        return ("negative", sentence)
    else:
        return ("neutral", sentence)

# %%
# Add sentiment as key in the RDD

filtered_sentencesRDD = sc.parallelize(filtered_sentences)
sentiments = filtered_sentencesRDD.map(lambda a: includeSentiment(a, positive, negative))

# %%
# Peek at 2 first lines
sentiments.take(2)
# Out:
# [('positive',
#   u'in this study, we examined the separated caseins and whey proteins of goat milk for the presence of ACEI inhibitory peptides.'),
#  ('positive',
#   u'digestion of isolated whey proteins and caseins of goat milk by gastric pepsin generated soluble hydrolysates exhibiting significant inhibition of ACEI compared to weak inhibition by undigested proteins.')]

# %%
# Create 2 lists of filtered sentences: one positive list and one negative list
pos_sentiments = sentiments.lookup("positive")
neg_sentiments = sentiments.lookup("negative")

# %%
# Examples of sentences with positive sentiment lexicon
pos_sentiments[:10]
# Out:
# [u'in this study, we examined the separated caseins and whey proteins of goat milk for the presence of ACEI inhibitory peptides.',
#  u'digestion of isolated whey proteins and caseins of goat milk by gastric pepsin generated soluble hydrolysates exhibiting significant inhibition of ACEI compared to weak inhibition by undigested proteins.',
#  u'the peptides from whey and caseins exert significant ACEI inhibitory activities comparable to that of captopril, an antihypertensive drug, exhibiting ic50 values of 4.45unkunkm and 4.27unkunkm, respectively.',
#  u'the results introduce, for the first time, new potent ACEI-inhibitory peptides that can be released by gastric pepsin of goat milk whey and caseins and thus may pave the way for their candidacy as anti-hypertensive bioactive peptides and prevention of associated disorders.',
#  u'ACEI use between 1 january 2003 and the index date were determined by the date of hospitalization for acute pancreatitis among the cases.',
#  u'compared to hydrolysates from whey protein, where the inhibitory effect can almost exclusively be attributed to ile-trp, the ACEI inhibition by plant protein hydrolysates is caused by a variety of peptides, in particular tyrosine-containing peptides.',
#  u'the annual rate of adverse events related to ACEI (ie, the number of reported cases of adverse events per 1000 patients receiving an ACEI) was calculated from data captured on the date the events were first reported for the 5 years before and 5 years after the revocation of the pa constraint.',
#  u'these findings suggest a therapeutic potential for mas and/or at2 receptor activation and ACEI inhibition in restoring endothelial function impaired by elevated dietary salt intake or other pathological conditions.',
#  u'casein haplotype significantly influenced the antioxidative and ACEI-inhibitory capacities of digested casein.',
#  u'in particular, bb-a(2)a(1)-aa casein and bb-a(1)a(1)-aa casein showed the highest ACEI-inhibitory capacity, bb-a(2)a(2)-aa casein showed the highest antioxidant capacity, whereas bb-a(2)a(2)-bb casein showed the lowest biological capacity.']

# %%
# Examples of sentences with negative sentiment lexicon
neg_sentiments[:2]
# Out:
# [u'the late-eluting fraction (f4) of either whey or caseins exhibited greater ACEI inhibition.',
#  u'we investigated the molecular mechanisms involved in the ACEI (ACEI) inhibition by (-)-epigallocatechin-3-gallate (egcg), a major tea catechin.']

# %%
def findSentiment(sentence, sentiment, poslist, neglist):
    '''Print out the lexicon word that classified the sentence as positive or negative
    '''
    if sentiment == "positive":
        lexicon = poslist
    else:
        lexicon = neglist
    for word in lexicon:
        # Note: had to use this "try/except" since there was an unicode ascii error... any ways
        # to fix this without this try/except? if left the same, then we won't be able to see
        # some sentiment word in some sentences.
        try:
            if word in sentence:
                print word
        except:
            next

# %%
s5 = u"digestion of isolated whey proteins and caseins of goat milk by gastric pepsin generated soluble hydrolysates exhibiting significant inhibition of ACEI compared to weak inhibition by undigested proteins"
print findFood(s5, foodlist)
findSentiment(s5, "positive", positive, negative)
# Out:
# [u'casein', u'whey']
# pro
# generate
# significant

# %%
s6 = u"the late-eluting fraction (f4) of either whey or caseins exhibited greater ACEI inhibition"
print findFood(s6, foodlist)
findSentiment(s6, "negative", positive, negative)
# Out:
# [u'casein', u'whey']
# inhibit
# inhibition

# %%
def findTags(sentence, sentiment, foods, poslist, neglist, limit):
    ''' Returns the tags of the sentence 
        Both lexicon word that classified the sentence as positive or negative and food name
    '''
    
    sent = []
    food = []
    
    if sentiment == "positive":
        lexicon = poslist
    else:
        lexicon = neglist
    for word in lexicon:
        # Note: had to use this "try/except" since there was an unicode ascii error... any ways
        # to fix this without this try/except? if left the same, then we won't be able to see
        # some sentiment word in some sentences.
        try:
            if word in sentence:
                sent.append(word)
        except:
            next
            
    # If using simple test of if food name "in" sentence method
    #for f in foods:
    #    if f in sentence:
    #        food.append(f)
    
    # If using string distance method:
    for f in foods:
        n = min(3, len(f.split()))  # Assuming max as trigram        
        sentence_ngrams = find_ngrams(sentence, n)  # Note: punctuation at end of sentence will be included with
                                                # last word. For now ok, since the JW will still be > 0.95
        for ngram in sentence_ngrams:
            # Note: when using jaro_winkler, need to convert into unicode format
            if jellyfish.jaro_winkler(f.lower(), u"{}".format(ngram.lower())) > limit:
                food.append(f)

            
    return [sent, food, sentence]

# %%
# Save results in a text file
# Note: this could have been also done in Spark! But felt lazy to code... feel free to try!

# %%
with open("data/Positive.txt", "w") as pos:
    for sentence in pos_sentiments:
        tags = findTags(sentence, "positive", foodlist, positive, negative, 0.95)
        pos.writelines(str(tags)+ "\n")

# %%
with open("data/Negative.txt", "w") as pos:
    for sentence in pos_sentiments:
        tags = findTags(sentence, "negative", foodlist, positive, negative, 0.95)
        pos.writelines(str(tags)+ "\n")

# %% [markdown]
# **Final Notes**
# 1. In our baseline, some words like "date" that appear in a sentence will be interpreted as the fruit "date" instead of a calendar date and thus, will be filtered as outputs sentences. This can only be solved if we take into account the context of the sentence and we will need ML to model this!
# 2. Sentiment analysis need a major improvement: only basing on the positive and negative words without how the food and drug are connected through these words is not a good model.

# %% [markdown]
# ## BELOW: Latest Update as of 8-4-2017 [Lisa B]

# %% [markdown]
# ## Sentiment Classifier Using Stanford Model

# %% [markdown]
# #### First import the sentences, and then run the sentiment analysis on them via command line

# %%
# !head data/FilteredSentences_Statin_commonFood_clean.txt
# Out:
# [u'rice']18 samples of red yeast rice powder and 18 samples of lovastatin were collected.
# [u'rice']: Purpose: Red yeast rice (RYR) supplementation has become a popular alternative to statin therapy in treating hypercholesterolemia.
# [u'rice']We examined whether FDA's manufacturing standards led to standard concentrations of the statin monacolin K in red yeast rice supplements.
# [u'rice']Red yeast rice contains a fungus (Monascus purpureus), which was utilized in the original production of lovastatin (MEVACOR, Merck & Co, Whitehouse Station, NJ), the first marketed pharmaceutical statin, and is chemically identical to such product.
# [u'oyster mushroom', u'rice', u'mushrooms']Matrix effect-free UHPLC-MS/MS method was developed and validated for the determination of cholesterol-lowering lovastatin in food samples represented by Pu-erh tea, oyster mushroom, and red yeast rice.
# [u'rice']Suitability of the resulting MISPE-UHPLC-MS/MS procedure for real sample analysis was verified by the determination of lovastatin in one dietary supplement based on the red yeast rice with a given amount of the target analyte.
# [u'gelatin']Analysis of spectra of fluvastatin (Flu), gelatin (Gel), and Flu with Gel complex using a Fourier transform-infrared spectrometer indicates that Flu was bound to Gel through a bond involving the carboxyl and amino groups.
# [u'oat']We examined the economic impact of daily intake of unk3 g of oat unk-glucan in primary prevention of CHD in patients receiving statins or no pharmacologic treatment.
# [u'oat', u'oat']A decision model was developed to compare costs and outcomes associated with lowering cholesterol levels with no pharmacologic treatment and normal diet, no pharmacologic treatment plus unk3 g/d of oat unk-glucan, and statin therapy plus unk3 g/d of oat unk-glucan.
# [u'salt', u'oat']Apolipoprotein-E-deficient mice were fed for 24unkweeks either high-fat/cholesterol diet alone (control, HFC) or high-fat/cholesterol in conjunction with one of three dietary interventions, as follows: plant sterol ester (PSE), oat unk-glucan (OBG) and bile salt hydrolase-active Lactobacillus reuteri APC 2587 (BSH), or the drug atorvastatin (STAT).

# %% [markdown]
# # Testing with PCFG Model*
#
# *notice I made a change to the lexparser file to allow for more memory

# %%
# !cat ./lexparser.sh
# Out:
# #!/usr/bin/env bash
# #
# # Runs the English PCFG parser on one or more files, printing trees only
#
# if [ ! $# -ge 1 ]; then
#   echo Usage: `basename $0` 'file(s)'
#   echo
#   exit
# fi
#
# scriptdir=`dirname $0`
#
# java -mx500m -cp "$scriptdir/*:" edu.stanford.nlp.parser.lexparser.LexicalizedParser \
#  -outputFormat "penn,typedDependencies" edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz $*

# %%
# %%timeit
! ./lexparser.sh  data/FilteredSentences_Statin_commonFood_clean.txt
# Out:
# [main] INFO edu.stanford.nlp.parser.lexparser.LexicalizedParser - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ... done [0.8 sec].
# Parsing file: data/FilteredSentences_Statin_commonFood_clean.txt
# Parsing [sent. 1 len. 21]: -LSB- u ` rice ' -RSB- 18 samples of red yeast rice powder and 18 samples of lovastatin were collected .
# (ROOT
#   (S
#     (S
#       (NP (JJ -LSB-) (NN u) (`` `) (NN rice) ('' '))
#       (VP (VBZ -RSB-)
#         (NP
#           (NP (CD 18) (NNS samples))
#           (PP (IN of)
#             (NP (JJ red) (NN yeast) (NN rice) (NN powder))))))
#     (CC and)
#     (S
#       (NP
#         (NP (CD 18) (NNS samples))
#         (PP (IN of)
#           (NP (NN lovastatin))))
#       (VP (VBD were)
#         (VP (VBN collected))))
#     (. .)))
#
# amod(rice-4, -LSB--1)
# compound(rice-4, u-2)
# nsubj(-RSB--6, rice-4)
# root(ROOT-0, -RSB--6)
# nummod(samples-8, 18-7)
# dobj(-RSB--6, samples-8)
# case(powder-13, of-9)
# amod(powder-13, red-10)
# compound(powder-13, yeast-11)
# compound(powder-13, rice-12)
# nmod:of(samples-8, powder-13)
# cc(-RSB--6, and-14)
# nummod(samples-16, 18-15)
# nsubjpass(collected-20, samples-16)
# case(lovastatin-18, of-17)
# nmod:of(samples-16, lovastatin-18)
# auxpass(collected-20, were-19)
# conj:and(-RSB--6, collected-20)
#
# Parsing [sent. 2 len. 28]: -LSB- u ` rice ' -RSB- : Purpose : Red yeast rice -LRB- RYR -RRB- supplementation has become a popular alternative to statin therapy in treating hypercholesterolemia .
# (ROOT
#   (NP
#     (NP (JJ -LSB-) (NN u) (`` `) (NN rice) ('' ') (NN -RSB-))
#     (: :)
#     (NP
#       (NP (NNP Purpose))
#       (: :)
#       (NP
#         (NP (JJ Red) (NN yeast) (NN rice))
#         (PRN (-LRB- -LRB-)
#           (NP (NNP RYR))
#           (-RRB- -RRB-))
#         (SBAR
#           (S
#             (NP (NN supplementation))
#             (VP (VBZ has)
#               (VP (VBN become)
#                 (NP (DT a) (JJ popular) (NN alternative))
#                 (S
#                   (VP (TO to)
#                     (VP (VB statin)
#                       (NP (NN therapy))
#                       (PP (IN in)
#                         (S
#                           (VP (VBG treating)
#                             (NP (NN hypercholesterolemia))))))))))))))
#     (. .)))
#
# amod(-RSB--6, -LSB--1)
# compound(-RSB--6, u-2)
# compound(-RSB--6, rice-4)
# root(ROOT-0, -RSB--6)
# dep(-RSB--6, Purpose-8)
# amod(rice-12, Red-10)
# compound(rice-12, yeast-11)
# dep(Purpose-8, rice-12)
# appos(rice-12, RYR-14)
# nsubj(become-18, supplementation-16)
# aux(become-18, has-17)
# acl:relcl(rice-12, become-18)
# det(alternative-21, a-19)
# amod(alternative-21, popular-20)
# xcomp(become-18, alternative-21)
# mark(statin-23, to-22)
# advcl(become-18, statin-23)
# dobj(statin-23, therapy-24)
# mark(treating-26, in-25)
# advcl(statin-23, treating-26)
# dobj(treating-26, hypercholesterolemia-27)
#
# Parsing [sent. 3 len. 28]: -LSB- u ` rice ' -RSB- We examined whether FDA 's manufacturing standards led to standard concentrations of the statin monacolin K in red yeast rice supplements .
# (ROOT
#   (S
#     (NP (JJ -LSB-) (NN u) (`` `) (NN rice) ('' '))
#     (VP (VBD -RSB-)
#       (SBAR
#         (S
#           (NP (PRP We))
#           (VP (VBD examined)
#             (SBAR (IN whether)
#               (S
#                 (NP
#                   (NP (NNP FDA) (POS 's))
#                   (VBG manufacturing) (NNS standards))
#                 (VP (VBD led)
#                   (PP (TO to)
#                     (NP
#                       (NP (JJ standard) (NNS concentrations))
#                       (PP (IN of)
#                         (NP (DT the) (NN statin) (NN monacolin) (NN K)))))
#                   (PP (IN in)
#                     (NP (JJ red) (NN yeast) (NN rice) (NNS supplements))))))))))
#     (. .)))
#
# amod(rice-4, -LSB--1)
# compound(rice-4, u-2)
# nsubj(-RSB--6, rice-4)
# root(ROOT-0, -RSB--6)
# nsubj(examined-8, We-7)
# ccomp(-RSB--6, examined-8)
# mark(led-14, whether-9)
# nmod:poss(standards-13, FDA-10)
# case(FDA-10, 's-11)
# amod(standards-13, manufacturing-12)
# nsubj(led-14, standards-13)
# ccomp(examined-8, led-14)
# case(concentrations-17, to-15)
# amod(concentrations-17, standard-16)
# nmod:to(led-14, concentrations-17)
# case(K-22, of-18)
# det(K-22, the-19)
# compound(K-22, statin-20)
# compound(K-22, monacolin-21)
# nmod:of(concentrations-17, K-22)
# case(supplements-27, in-23)
# amod(supplements-27, red-24)
# compound(supplements-27, yeast-25)
# compound(supplements-27, rice-26)
# nmod:in(led-14, supplements-27)
#
# Parsing [sent. 4 len. 53]: -LSB- u ` rice ' -RSB- Red yeast rice contains a fungus -LRB- Monascus purpureus -RRB- , which was utilized in the original production of lovastatin -LRB- MEVACOR , Merck & Co , Whitehouse Station , NJ -RRB- , the first marketed pharmaceutical statin , and is chemically identical to such product .
# (ROOT
#   (SINV
#     (S
#       (NP (JJ -LSB-) (NN u) (`` `) (NN rice) ('' '))
#       (VP (VBZ -RSB-)
#         (NP (JJ Red) (NN yeast) (NN rice))))
#     (VP (VBZ contains))
#     (NP
#       (NP (DT a) (NN fungus))
#       (PRN (-LRB- -LRB-)
#         (NP (NNP Monascus) (NNS purpureus))
#         (-RRB- -RRB-))
#       (, ,)
#       (SBAR
#         (WHNP (WDT which))
#         (S
#           (VP
#             (VP (VBD was)
#               (VP (VBN utilized)
#                 (PP (IN in)
#                   (NP
#                     (NP
#                       (NP (DT the) (JJ original) (NN production))
#                       (PP (IN of)
#                         (NP (NN lovastatin))))
#                     (PRN (-LRB- -LRB-)
#                       (NP
#                         (NP (NNP MEVACOR) (, ,) (NNP Merck)
#                           (CC &)
#                           (NNP Co))
#                         (, ,)
#                         (NP (NNP Whitehouse) (NNP Station))
#                         (, ,)
#                         (NP (NNP NJ)))
#                       (-RRB- -RRB-))
#                     (, ,)
#                     (NP (DT the) (JJ first) (JJ marketed) (JJ pharmaceutical) (NN statin))
#                     (, ,)))))
#             (CC and)
#             (VP (VBZ is)
#               (ADVP (RB chemically))
#               (ADJP (JJ identical)
#                 (PP (TO to)
#                   (NP (JJ such) (NN product)))))))))
#     (. .)))
#
# amod(rice-4, -LSB--1)
# compound(rice-4, u-2)
# nsubj(-RSB--6, rice-4)
# dep(contains-10, -RSB--6)
# amod(rice-9, Red-7)
# compound(rice-9, yeast-8)
# dobj(-RSB--6, rice-9)
# root(ROOT-0, contains-10)
# det(fungus-12, a-11)
# nsubj(contains-10, fungus-12)
# nsubjpass(utilized-20, fungus-12)
# nsubj(identical-49, fungus-12)
# compound(purpureus-15, Monascus-14)
# appos(fungus-12, purpureus-15)
# ref(fungus-12, which-18)
# auxpass(utilized-20, was-19)
# acl:relcl(fungus-12, utilized-20)
# case(production-24, in-21)
# det(production-24, the-22)
# amod(production-24, original-23)
# nmod:in(utilized-20, production-24)
# case(lovastatin-26, of-25)
# nmod:of(production-24, lovastatin-26)
# dep(production-24, MEVACOR-28)
# dep(production-24, Merck-30)
# conj:&(MEVACOR-28, Merck-30)
# cc(MEVACOR-28, &-31)
# dep(production-24, Co-32)
# conj:&(MEVACOR-28, Co-32)
# compound(Station-35, Whitehouse-34)
# appos(MEVACOR-28, Station-35)
# appos(MEVACOR-28, NJ-37)
# det(statin-44, the-40)
# amod(statin-44, first-41)
# amod(statin-44, marketed-42)
# amod(statin-44, pharmaceutical-43)
# appos(production-24, statin-44)
# cc(utilized-20, and-46)
# cop(identical-49, is-47)
# advmod(identical-49, chemically-48)
# acl:relcl(fungus-12, identical-49)
# conj:and(utilized-20, identical-49)
# case(product-52, to-50)
# amod(product-52, such-51)
# nmod:to(identical-49, product-52)
#
# Parsing [sent. 5 len. 47]: -LSB- u ` oyster mushroom ' , u ` rice ' , u ` mushrooms ' -RSB- Matrix effect-free UHPLC-MS/MS method was developed and validated for the determination of cholesterol-lowering lovastatin in food samples represented by Pu-erh tea , oyster mushroom , and red yeast rice .
# (ROOT
#   (S
#     (NP
#       (NP (JJ -LSB-) (NN u) (`` `) (NN oyster) (NN mushroom) ('' '))
#       (, ,)
#       (NP (NN u) (`` `) (NN rice) ('' '))
#       (, ,))
#     (VP (VBP u) (`` `)
#       (NP
#         (NP
#           (NP (NNS mushrooms) (POS '))
#           (NNP -RSB-) (NNP Matrix))
#         (SBAR
#           (S
#             (NP (JJ effect-free) (JJ UHPLC-MS/MS) (NN method))
#             (VP (VBD was)
#               (VP (VBN developed)
#                 (CC and)
#                 (VBN validated)
#                 (PP (IN for)
#                   (NP
#                     (NP (DT the) (NN determination))
#                     (PP (IN of)
#                       (NP (JJ cholesterol-lowering) (NN lovastatin))))))))))
#       (PP (IN in)
#         (NP
#           (NP (NN food) (NNS samples))
#           (VP (VBN represented)
#             (PP (IN by)
#               (NP
#                 (NP (JJ Pu-erh) (NN tea))
#                 (, ,)
#                 (NP (NN oyster) (NN mushroom))
#                 (, ,)
#                 (CC and)
#                 (NP (JJ red) (NN yeast) (NN rice))))))))
#     (. .)))
#
# amod(mushroom-5, -LSB--1)
# compound(mushroom-5, u-2)
# compound(mushroom-5, oyster-4)
# nsubj(u-13, mushroom-5)
# compound(rice-10, u-8)
# appos(mushroom-5, rice-10)
# root(ROOT-0, u-13)
# nmod:poss(Matrix-18, mushrooms-15)
# case(mushrooms-15, '-16)
# compound(Matrix-18, -RSB--17)
# dobj(u-13, Matrix-18)
# amod(method-21, effect-free-19)
# amod(method-21, UHPLC-MS/MS-20)
# nsubjpass(developed-23, method-21)
# nsubjpass(validated-25, method-21)
# auxpass(developed-23, was-22)
# acl:relcl(Matrix-18, developed-23)
# cc(developed-23, and-24)
# acl:relcl(Matrix-18, validated-25)
# conj:and(developed-23, validated-25)
# case(determination-28, for-26)
# det(determination-28, the-27)
# nmod:for(developed-23, determination-28)
# case(lovastatin-31, of-29)
# amod(lovastatin-31, cholesterol-lowering-30)
# nmod:of(determination-28, lovastatin-31)
# case(samples-34, in-32)
# compound(samples-34, food-33)
# nmod:in(u-13, samples-34)
# acl(samples-34, represented-35)
# case(tea-38, by-36)
# amod(tea-38, Pu-erh-37)
# nmod:by(represented-35, tea-38)
# compound(mushroom-41, oyster-40)
# nmod:by(represented-35, mushroom-41)
# conj:and(tea-38, mushroom-41)
# cc(tea-38, and-43)
# amod(rice-46, red-44)
# compound(rice-46, yeast-45)
# nmod:by(represented-35, rice-46)
# conj:and(tea-38, rice-46)
#
# Parsing [sent. 6 len. 42]: -LSB- u ` rice ' -RSB- Suitability of the resulting MISPE-UHPLC-MS/MS procedure for real sample analysis was verified by the determination of lovastatin in one dietary supplement based on the red yeast rice with a given amount of the target analyte .
# (ROOT
#   (S
#     (NP (JJ -LSB-) (NN u) (`` `) (NN rice) ('' '))
#     (VP (VBD -RSB-)
#       (SBAR
#         (S
#           (NP
#             (NP (NNP Suitability))
#             (PP (IN of)
#               (NP
#                 (NP (DT the) (VBG resulting) (NNP MISPE-UHPLC-MS/MS) (NN procedure))
#                 (PP (IN for)
#                   (NP (JJ real) (NN sample) (NN analysis))))))
#           (VP (VBD was)
#             (VP (VBN verified)
#               (PP (IN by)
#                 (NP
#                   (NP (DT the) (NN determination))
#                   (PP (IN of)
#                     (NP (NN lovastatin)))))
#               (PP (IN in)
#                 (NP
#                   (NP (CD one) (JJ dietary) (NN supplement))
#                   (VP (VBN based)
#                     (PP (IN on)
#                       (NP (DT the) (JJ red) (NN yeast) (NN rice)))
#                     (PP (IN with)
#                       (NP
#                         (NP (DT a) (VBN given) (NN amount))
#                         (PP (IN of)
#                           (NP (DT the) (NN target) (NN analyte)))))))))))))
#     (. .)))
#
# amod(rice-4, -LSB--1)
# compound(rice-4, u-2)
# nsubj(-RSB--6, rice-4)
# root(ROOT-0, -RSB--6)
# nsubjpass(verified-18, Suitability-7)
# case(procedure-12, of-8)
# det(procedure-12, the-9)
# amod(procedure-12, resulting-10)
# compound(procedure-12, MISPE-UHPLC-MS/MS-11)
# nmod:of(Suitability-7, procedure-12)
# case(analysis-16, for-13)
# amod(analysis-16, real-14)
# compound(analysis-16, sample-15)
# nmod:for(procedure-12, analysis-16)
# auxpass(verified-18, was-17)
# ccomp(-RSB--6, verified-18)
# case(determination-21, by-19)
# det(determination-21, the-20)
# nmod:by(verified-18, determination-21)
# case(lovastatin-23, of-22)
# nmod:of(determination-21, lovastatin-23)
# case(supplement-27, in-24)
# nummod(supplement-27, one-25)
# amod(supplement-27, dietary-26)
# nmod:in(verified-18, supplement-27)
# acl(supplement-27, based-28)
# case(rice-33, on-29)
# det(rice-33, the-30)
# amod(rice-33, red-31)
# compound(rice-33, yeast-32)
# nmod:on(based-28, rice-33)
# case(amount-37, with-34)
# det(amount-37, a-35)
# amod(amount-37, given-36)
# nmod:with(based-28, amount-37)
# case(analyte-41, of-38)
# det(analyte-41, the-39)
# compound(analyte-41, target-40)
# nmod:of(amount-37, analyte-41)
#
# Parsing [sent. 7 len. 47]: -LSB- u ` gelatin ' -RSB- Analysis of spectra of fluvastatin -LRB- Flu -RRB- , gelatin -LRB- Gel -RRB- , and Flu with Gel complex using a Fourier transform-infrared spectrometer indicates that Flu was bound to Gel through a bond involving the carboxyl and amino groups .
# (ROOT
#   (S
#     (NP (JJ -LSB-) (NN u) (`` `) (NN gelatin) ('' '))
#     (VP (VBD -RSB-)
#       (NP
#         (NP
#           (NP (NNP Analysis))
#           (PP (IN of)
#             (NP
#               (NP
#                 (NP (NN spectra))
#                 (PP (IN of)
#                   (NP (NN fluvastatin))))
#               (PRN (-LRB- -LRB-)
#                 (NP (NNP Flu))
#                 (-RRB- -RRB-))
#               (, ,)
#               (NP
#                 (NP (NN gelatin))
#                 (PRN (-LRB- -LRB-)
#                   (NP (NNP Gel))
#                   (-RRB- -RRB-)))
#               (, ,))))
#         (CC and)
#         (NP
#           (NP (NNP Flu))
#           (PP (IN with)
#             (NP (NNP Gel) (NN complex)))))
#       (S
#         (VP (VBG using)
#           (SBAR
#             (S
#               (NP (DT a) (NNP Fourier) (JJ transform-infrared) (NN spectrometer))
#               (VP (VBZ indicates)
#                 (SBAR (IN that)
#                   (S
#                     (NP (NNP Flu))
#                     (VP (VBD was)
#                       (VP (VBN bound)
#                         (S
#                           (VP (TO to)
#                             (VP (VB Gel)
#                               (PP (IN through)
#                                 (NP
#                                   (NP (DT a) (NN bond))
#                                   (PP (VBG involving)
#                                     (NP
#                                       (NP (DT the) (NN carboxyl))
#                                       (CC and)
#                                       (NP (JJ amino) (NNS groups)))))))))))))))))))
#     (. .)))
#
# amod(gelatin-4, -LSB--1)
# compound(gelatin-4, u-2)
# nsubj(-RSB--6, gelatin-4)
# root(ROOT-0, -RSB--6)
# dobj(-RSB--6, Analysis-7)
# case(spectra-9, of-8)
# nmod:of(Analysis-7, spectra-9)
# case(fluvastatin-11, of-10)
# nmod:of(spectra-9, fluvastatin-11)
# appos(spectra-9, Flu-13)
# appos(spectra-9, gelatin-16)
# appos(gelatin-16, Gel-18)
# cc(Analysis-7, and-21)
# dobj(-RSB--6, Flu-22)
# conj:and(Analysis-7, Flu-22)
# case(complex-25, with-23)
# compound(complex-25, Gel-24)
# nmod:with(Flu-22, complex-25)
# xcomp(-RSB--6, using-26)
# det(spectrometer-30, a-27)
# compound(spectrometer-30, Fourier-28)
# amod(spectrometer-30, transform-infrared-29)
# nsubj(indicates-31, spectrometer-30)
# ccomp(using-26, indicates-31)
# mark(bound-35, that-32)
# nsubjpass(bound-35, Flu-33)
# nsubj:xsubj(Gel-37, Flu-33)
# auxpass(bound-35, was-34)
# ccomp(indicates-31, bound-35)
# mark(Gel-37, to-36)
# xcomp(bound-35, Gel-37)
# case(bond-40, through-38)
# det(bond-40, a-39)
# nmod:through(Gel-37, bond-40)
# case(carboxyl-43, involving-41)
# det(carboxyl-43, the-42)
# nmod:involving(bond-40, carboxyl-43)
# cc(carboxyl-43, and-44)
# amod(groups-46, amino-45)
# nmod:involving(bond-40, groups-46)
# conj:and(carboxyl-43, groups-46)
#
# Parsing [sent. 8 len. 34]: -LSB- u ` oat ' -RSB- We examined the economic impact of daily intake of unk3 g of oat unk-glucan in primary prevention of CHD in patients receiving statins or no pharmacologic treatment .
# (ROOT
#   (S
#     (NP (JJ -LSB-) (NN u) (`` `) (NN oat) ('' '))
#     (VP (VBD -RSB-)
#       (SBAR
#         (S
#           (NP (PRP We))
#           (VP (VBD examined)
#             (NP
#               (NP (DT the) (JJ economic) (NN impact))
#               (PP (IN of)
#                 (NP
#                   (NP (JJ daily) (NN intake))
#                   (PP (IN of)
#                     (NP
#                       (NP (JJ unk3) (NN g))
#                       (PP (IN of)
#                         (NP
#                           (NP (NN oat) (NN unk-glucan))
#                           (PP (IN in)
#                             (NP
#                               (NP (JJ primary) (NN prevention))
#                               (PP (IN of)
#                                 (NP (NNP CHD))))))))))))
#             (PP (IN in)
#               (NP
#                 (NP (NNS patients))
#                 (VP (VBG receiving)
#                   (NP
#                     (NP (NNS statins))
#                     (CC or)
#                     (NP (DT no) (JJ pharmacologic) (NN treatment))))))))))
#     (. .)))
#
# amod(oat-4, -LSB--1)
# compound(oat-4, u-2)
# nsubj(-RSB--6, oat-4)
# root(ROOT-0, -RSB--6)
# nsubj(examined-8, We-7)
# ccomp(-RSB--6, examined-8)
# det(impact-11, the-9)
# amod(impact-11, economic-10)
# dobj(examined-8, impact-11)
# case(intake-14, of-12)
# amod(intake-14, daily-13)
# nmod:of(impact-11, intake-14)
# case(g-17, of-15)
# amod(g-17, unk3-16)
# nmod:of(intake-14, g-17)
# case(unk-glucan-20, of-18)
# compound(unk-glucan-20, oat-19)
# nmod:of(g-17, unk-glucan-20)
# case(prevention-23, in-21)
# amod(prevention-23, primary-22)
# nmod:in(unk-glucan-20, prevention-23)
# case(CHD-25, of-24)
# nmod:of(prevention-23, CHD-25)
# case(patients-27, in-26)
# nmod:in(examined-8, patients-27)
# acl(patients-27, receiving-28)
# dobj(receiving-28, statins-29)
# cc(statins-29, or-30)
# neg(treatment-33, no-31)
# amod(treatment-33, pharmacologic-32)
# dobj(receiving-28, treatment-33)
# conj:or(statins-29, treatment-33)
#
# Parsing [sent. 9 len. 54]: -LSB- u ` oat ' , u ` oat ' -RSB- A decision model was developed to compare costs and outcomes associated with lowering cholesterol levels with no pharmacologic treatment and normal diet , no pharmacologic treatment plus unk3 g/d of oat unk-glucan , and statin therapy plus unk3 g/d of oat unk-glucan .
# (ROOT
#   (S
#     (NP
#       (NP (JJ -LSB-) (NN u) (`` `) (NN oat) ('' '))
#       (, ,)
#       (NP
#         (NP (NN u) (`` `) (NN oat) ('' ') (NNS -RSB-))
#         (NP (DT A) (NN decision) (NN model))))
#     (VP (VBD was)
#       (VP (VBN developed)
#         (S
#           (VP (TO to)
#             (VP (VB compare)
#               (NP
#                 (NP
#                   (NP (NNS costs)
#                     (CC and)
#                     (NNS outcomes))
#                   (VP (VBN associated)
#                     (PP (IN with)
#                       (S
#                         (VP (VBG lowering)
#                           (NP (NN cholesterol) (NNS levels))
#                           (PP (IN with)
#                             (NP
#                               (NP (DT no) (JJ pharmacologic) (NN treatment))
#                               (CC and)
#                               (NP (JJ normal) (NN diet)))))))))
#                 (, ,)
#                 (NP
#                   (NP (DT no) (JJ pharmacologic) (NN treatment))
#                   (PP (CC plus)
#                     (NP
#                       (NP (JJ unk3) (NN g/d))
#                       (PP (IN of)
#                         (NP (NN oat) (NN unk-glucan))))))
#                 (, ,)
#                 (CC and)
#                 (NP
#                   (NP (NN statin) (NN therapy))
#                   (PP (CC plus)
#                     (NP
#                       (NP (JJ unk3) (NN g/d))
#                       (PP (IN of)
#                         (NP (NN oat) (NN unk-glucan))))))))))))
#     (. .)))
#
# amod(oat-4, -LSB--1)
# compound(oat-4, u-2)
# nsubjpass(developed-16, oat-4)
# nsubj:xsubj(compare-18, oat-4)
# compound(-RSB--11, u-7)
# compound(-RSB--11, oat-9)
# appos(oat-4, -RSB--11)
# det(model-14, A-12)
# compound(model-14, decision-13)
# dep(-RSB--11, model-14)
# auxpass(developed-16, was-15)
# root(ROOT-0, developed-16)
# mark(compare-18, to-17)
# xcomp(developed-16, compare-18)
# dobj(compare-18, costs-19)
# cc(costs-19, and-20)
# dobj(compare-18, outcomes-21)
# conj:and(costs-19, outcomes-21)
# acl(costs-19, associated-22)
# mark(lowering-24, with-23)
# advcl(associated-22, lowering-24)
# compound(levels-26, cholesterol-25)
# dobj(lowering-24, levels-26)
# case(treatment-30, with-27)
# neg(treatment-30, no-28)
# amod(treatment-30, pharmacologic-29)
# nmod:with(lowering-24, treatment-30)
# cc(treatment-30, and-31)
# amod(diet-33, normal-32)
# nmod:with(lowering-24, diet-33)
# conj:and(treatment-30, diet-33)
# neg(treatment-37, no-35)
# amod(treatment-37, pharmacologic-36)
# dobj(compare-18, treatment-37)
# conj:and(costs-19, treatment-37)
# case(g/d-40, plus-38)
# amod(g/d-40, unk3-39)
# nmod:plus(treatment-37, g/d-40)
# case(unk-glucan-43, of-41)
# compound(unk-glucan-43, oat-42)
# nmod:of(g/d-40, unk-glucan-43)
# cc(costs-19, and-45)
# compound(therapy-47, statin-46)
# dobj(compare-18, therapy-47)
# conj:and(costs-19, therapy-47)
# case(g/d-50, plus-48)
# amod(g/d-50, unk3-49)
# nmod:plus(therapy-47, g/d-50)
# case(unk-glucan-53, of-51)
# compound(unk-glucan-53, oat-52)
# nmod:of(g/d-50, unk-glucan-53)
#
# Parsing [sent. 10 len. 72]: -LSB- u ` salt ' , u ` oat ' -RSB- Apolipoprotein-E-deficient mice were fed for 24unkweeks either high-fat/cholesterol diet alone -LRB- control , HFC -RRB- or high-fat/cholesterol in conjunction with one of three dietary interventions , as follows : plant sterol ester -LRB- PSE -RRB- , oat unk-glucan -LRB- OBG -RRB- and bile salt hydrolase-active Lactobacillus reuteri APC 2587 -LRB- BSH -RRB- , or the drug atorvastatin -LRB- STAT -RRB- .
# (ROOT
#   (S
#     (NP
#       (NP (JJ -LSB-) (NN u) (`` `) (NN salt) ('' '))
#       (, ,)
#       (NP
#         (NP (NN u) (`` `) (NN oat) ('' '))
#         (NP (JJ -RSB-) (JJ Apolipoprotein-E-deficient) (NNS mice))))
#     (VP (VBD were)
#       (VP
#         (VP (VBN fed)
#           (PP (IN for)
#             (S
#               (VP (VBG 24unkweeks)
#                 (NP (DT either) (JJ high-fat/cholesterol) (NN diet))
#                 (ADVP (RB alone))
#                 (PRN (-LRB- -LRB-)
#                   (NP (NN control))
#                   (, ,)
#                   (NP (NNP HFC))
#                   (-RRB- -RRB-))))))
#         (CC or)
#         (VP (VBN high-fat/cholesterol)
#           (PP (IN in)
#             (NP (NN conjunction))))
#         (PP (IN with)
#           (NP
#             (NP
#               (NP (CD one))
#               (PP (IN of)
#                 (NP
#                   (NP (CD three) (JJ dietary) (NNS interventions))
#                   (, ,)
#                   (SBAR (IN as)
#                     (S
#                       (VP (VBZ follows)))))))
#             (: :)
#             (NP
#               (NP
#                 (NP (NN plant) (JJ sterol) (NN ester))
#                 (PRN (-LRB- -LRB-)
#                   (NP (NNP PSE))
#                   (-RRB- -RRB-)))
#               (, ,)
#               (NP
#                 (NP (NN oat) (NN unk-glucan))
#                 (PRN (-LRB- -LRB-)
#                   (NP (NNP OBG))
#                   (-RRB- -RRB-)))
#               (CC and)
#               (NP
#                 (NP (JJ bile) (NN salt) (NN hydrolase-active) (NN Lactobacillus) (NNS reuteri))
#                 (NP
#                   (NP (NNP APC) (CD 2587))
#                   (PRN (-LRB- -LRB-)
#                     (NP (NNP BSH))
#                     (-RRB- -RRB-)))))
#             (, ,)
#             (CC or)
#             (NP
#               (NP (DT the) (NN drug) (NN atorvastatin))
#               (PRN (-LRB- -LRB-)
#                 (NP (NNP STAT))
#                 (-RRB- -RRB-)))))))
#     (. .)))
#
# amod(salt-4, -LSB--1)
# compound(salt-4, u-2)
# nsubjpass(fed-15, salt-4)
# nsubjpass(high-fat/cholesterol-28, salt-4)
# compound(oat-9, u-7)
# appos(salt-4, oat-9)
# amod(mice-13, -RSB--11)
# amod(mice-13, Apolipoprotein-E-deficient-12)
# dep(oat-9, mice-13)
# auxpass(fed-15, were-14)
# root(ROOT-0, fed-15)
# mark(24unkweeks-17, for-16)
# advcl(fed-15, 24unkweeks-17)
# det(diet-20, either-18)
# amod(diet-20, high-fat/cholesterol-19)
# dobj(24unkweeks-17, diet-20)
# advmod(24unkweeks-17, alone-21)
# dep(24unkweeks-17, control-23)
# dep(control-23, HFC-25)
# cc(fed-15, or-27)
# conj:or(fed-15, high-fat/cholesterol-28)
# case(conjunction-30, in-29)
# nmod:in(high-fat/cholesterol-28, conjunction-30)
# case(one-32, with-31)
# nmod:with(fed-15, one-32)
# case(interventions-36, of-33)
# nummod(interventions-36, three-34)
# amod(interventions-36, dietary-35)
# nmod:of(one-32, interventions-36)
# mark(follows-39, as-38)
# dep(interventions-36, follows-39)
# compound(ester-43, plant-41)
# amod(ester-43, sterol-42)
# nmod:with(fed-15, ester-43)
# conj:or(one-32, ester-43)
# appos(ester-43, PSE-45)
# compound(unk-glucan-49, oat-48)
# conj:or(one-32, unk-glucan-49)
# conj:and(ester-43, unk-glucan-49)
# appos(unk-glucan-49, OBG-51)
# cc(ester-43, and-53)
# amod(reuteri-58, bile-54)
# compound(reuteri-58, salt-55)
# compound(reuteri-58, hydrolase-active-56)
# compound(reuteri-58, Lactobacillus-57)
# conj:or(one-32, reuteri-58)
# conj:and(ester-43, reuteri-58)
# dep(reuteri-58, APC-59)
# nummod(APC-59, 2587-60)
# appos(APC-59, BSH-62)
# cc(one-32, or-65)
# det(atorvastatin-68, the-66)
# compound(atorvastatin-68, drug-67)
# nmod:with(fed-15, atorvastatin-68)
# conj:or(one-32, atorvastatin-68)
# appos(atorvastatin-68, STAT-70)
#
# Parsing [sent. 11 len. 44]: -LSB- u ` salt ' -RSB- Veterans within the Salt Lake City Veterans Affairs -LRB- VA -RRB- Medical Center initiating statin therapy from October 2008 to December 2011 were randomized in a pragmatic design to receive either an educational mailer or usual care .
# (ROOT
#   (S
#     (NP (JJ -LSB-) (NN u) (`` `) (NN salt) ('' '))
#     (VP (VBD -RSB-)
#       (SBAR
#         (S
#           (NP
#             (NP (NNP Veterans))
#             (PP (IN within)
#               (NP
#                 (NP (DT the)
#                   (ADJP (NNP Salt) (NNP Lake))
#                   (NNP City) (NNP Veterans) (NNP Affairs)
#                   (PRN (-LRB- -LRB-)
#                     (NP (NNP VA))
#                     (-RRB- -RRB-))
#                   (NNP Medical) (NNP Center) (NNP initiating) (NN statin) (NN therapy))
#                 (PP (IN from)
#                   (NP (NNP October) (CD 2008)))
#                 (PP (TO to)
#                   (NP (NNP December) (CD 2011))))))
#           (VP (VBD were)
#             (VP (VBN randomized)
#               (PP (IN in)
#                 (NP (DT a) (JJ pragmatic) (NN design)))
#               (S
#                 (VP (TO to)
#                   (VP (VB receive)
#                     (NP (CC either)
#                       (NP (DT an) (JJ educational) (NN mailer))
#                       (CC or)
#                       (NP (JJ usual) (NN care)))))))))))
#     (. .)))
#
# amod(salt-4, -LSB--1)
# compound(salt-4, u-2)
# nsubj(-RSB--6, salt-4)
# root(ROOT-0, -RSB--6)
# nsubjpass(randomized-30, Veterans-7)
# nsubj:xsubj(receive-36, Veterans-7)
# case(therapy-22, within-8)
# det(therapy-22, the-9)
# amod(Lake-11, Salt-10)
# amod(therapy-22, Lake-11)
# compound(therapy-22, City-12)
# compound(therapy-22, Veterans-13)
# compound(therapy-22, Affairs-14)
# appos(therapy-22, VA-16)
# compound(therapy-22, Medical-18)
# compound(therapy-22, Center-19)
# compound(therapy-22, initiating-20)
# compound(therapy-22, statin-21)
# nmod:within(Veterans-7, therapy-22)
# case(October-24, from-23)
# nmod:from(therapy-22, October-24)
# nummod(October-24, 2008-25)
# case(December-27, to-26)
# nmod:to(therapy-22, December-27)
# nummod(December-27, 2011-28)
# auxpass(randomized-30, were-29)
# ccomp(-RSB--6, randomized-30)
# case(design-34, in-31)
# det(design-34, a-32)
# amod(design-34, pragmatic-33)
# nmod:in(randomized-30, design-34)
# mark(receive-36, to-35)
# xcomp(randomized-30, receive-36)
# cc:preconj(mailer-40, either-37)
# det(mailer-40, an-38)
# amod(mailer-40, educational-39)
# dobj(receive-36, mailer-40)
# cc(mailer-40, or-41)
# amod(care-43, usual-42)
# dobj(receive-36, care-43)
# conj:or(mailer-40, care-43)
#
# Parsing [sent. 12 len. 48]: -LSB- u ` citrus ' -RSB- Herein , we investigated the chemopreventive effects of nobiletin -LRB- NBT , a citrus polymethoxyflavone -RRB- and atorvastatin -LRB- ATST , a lipid-lowering drug -RRB- in colon cancer cells/macrophages and an azoxymethane -LRB- AOM -RRB- - induced colon carcinogenesis rat model .
# (ROOT
#   (S
#     (S
#       (VP (VBG -LSB-)
#         (NP
#           (NP (JJ u) (`` `) (NNS citrus) (POS '))
#           (NNP -RSB-) (NNP Herein))))
#     (, ,)
#     (NP (PRP we))
#     (VP (VBD investigated)
#       (NP
#         (NP (DT the) (JJ chemopreventive) (NNS effects))
#         (PP (IN of)
#           (NP
#             (NP (NN nobiletin))
#             (PRN (-LRB- -LRB-)
#               (NP (NNP NBT))
#               (, ,)
#               (NP (DT a) (JJ citrus) (NN polymethoxyflavone))
#               (-RRB- -RRB-))
#             (CC and)
#             (NP (NN atorvastatin))
#             (PRN (-LRB- -LRB-)
#               (NP (NNP ATST))
#               (, ,)
#               (NP (DT a) (JJ lipid-lowering) (NN drug))
#               (-RRB- -RRB-)))))
#       (PP (IN in)
#         (NP
#           (NP (NN colon) (NN cancer) (NNS cells/macrophages))
#           (CC and)
#           (NP
#             (NP (DT an) (NN azoxymethane))
#             (PRN (-LRB- -LRB-)
#               (NP (NNP AOM))
#               (-RRB- -RRB-)))))
#       (: -)
#       (S
#         (NP (JJ induced) (NN colon) (NNS carcinogenesis))
#         (VP (VB rat)
#           (NP (NN model)))))
#     (. .)))
#
# advcl(investigated-10, -LSB--1)
# amod(citrus-4, u-2)
# nmod:poss(Herein-7, citrus-4)
# case(citrus-4, '-5)
# compound(Herein-7, -RSB--6)
# dobj(-LSB--1, Herein-7)
# nsubj(investigated-10, we-9)
# root(ROOT-0, investigated-10)
# det(effects-13, the-11)
# amod(effects-13, chemopreventive-12)
# dobj(investigated-10, effects-13)
# case(nobiletin-15, of-14)
# nmod:of(effects-13, nobiletin-15)
# appos(nobiletin-15, NBT-17)
# det(polymethoxyflavone-21, a-19)
# amod(polymethoxyflavone-21, citrus-20)
# dep(NBT-17, polymethoxyflavone-21)
# cc(nobiletin-15, and-23)
# nmod:of(effects-13, atorvastatin-24)
# conj:and(nobiletin-15, atorvastatin-24)
# appos(nobiletin-15, ATST-26)
# det(drug-30, a-28)
# amod(drug-30, lipid-lowering-29)
# dep(ATST-26, drug-30)
# case(cells/macrophages-35, in-32)
# compound(cells/macrophages-35, colon-33)
# compound(cells/macrophages-35, cancer-34)
# nmod:in(investigated-10, cells/macrophages-35)
# cc(cells/macrophages-35, and-36)
# det(azoxymethane-38, an-37)
# nmod:in(investigated-10, azoxymethane-38)
# conj:and(cells/macrophages-35, azoxymethane-38)
# appos(azoxymethane-38, AOM-40)
# amod(carcinogenesis-45, induced-43)
# compound(carcinogenesis-45, colon-44)
# nsubj(rat-46, carcinogenesis-45)
# parataxis(investigated-10, rat-46)
# dobj(rat-46, model-47)
#
# Parsing [sent. 13 len. 51]: -LSB- u ` bean ' -RSB- The ovariectomized groups were administered orally daily with -LRB- 1 -RRB- lovastatin 11 mg/kg/day alone ; -LRB- 2 -RRB- tocotrienol derived from annatto bean -LRB- annatto tocotrienol -RRB- 60 mg/kg/day alone ; -LRB- 3 -RRB- lovastatin 11 mg/kg/day , and annatto tocotrienol 60 mg/kg/day .
# (ROOT
#   (S
#     (S
#       (NP (JJ -LSB-) (NN u) (`` `) (NN bean) ('' '))
#       (VP (VBD -RSB-)
#         (SBAR
#           (S
#             (NP (DT The) (JJ ovariectomized) (NNS groups))
#             (VP (VBD were)
#               (VP (VBN administered)
#                 (ADJP (RB orally) (JJ daily))
#                 (PP (IN with)
#                   (NP
#                     (PRN (-LRB- -LRB-)
#                       (NP (CD 1))
#                       (-RRB- -RRB-))
#                     (NN lovastatin))
#                   (ADVP
#                     (NP (CD 11) (NN mg/kg/day))
#                     (RB alone)))))))))
#     (: ;)
#     (S
#       (LST (-LRB- -LRB-) (LS 2) (-RRB- -RRB-))
#       (NP (NN tocotrienol))
#       (VP (VBD derived)
#         (PP (IN from)
#           (NP
#             (NP (NN annatto) (NN bean))
#             (PRN (-LRB- -LRB-)
#               (NP (NN annatto) (NN tocotrienol))
#               (-RRB- -RRB-)))
#           (ADVP
#             (NP (CD 60) (NN mg/kg/day))
#             (RB alone)))))
#     (: ;)
#     (S
#       (LST (-LRB- -LRB-) (LS 3) (-RRB- -RRB-))
#       (NP (NN lovastatin) (CD 11))
#       (VP (VBP mg/kg/day)))
#     (, ,)
#     (CC and)
#     (S
#       (NP (NN annatto))
#       (VP (VBP tocotrienol)
#         (NP (CD 60))
#         (ADVP (RB mg/kg/day))))
#     (. .)))
#
# amod(bean-4, -LSB--1)
# compound(bean-4, u-2)
# nsubj(-RSB--6, bean-4)
# root(ROOT-0, -RSB--6)
# det(groups-9, The-7)
# amod(groups-9, ovariectomized-8)
# nsubjpass(administered-11, groups-9)
# auxpass(administered-11, were-10)
# ccomp(-RSB--6, administered-11)
# advmod(daily-13, orally-12)
# xcomp(administered-11, daily-13)
# case(lovastatin-18, with-14)
# appos(lovastatin-18, 1-16)
# nmod:with(administered-11, lovastatin-18)
# nummod(mg/kg/day-20, 11-19)
# nmod:npmod(alone-21, mg/kg/day-20)
# advmod(lovastatin-18, alone-21)
# dep(derived-27, 2-24)
# nsubj(derived-27, tocotrienol-26)
# conj:and(-RSB--6, derived-27)
# case(bean-30, from-28)
# compound(bean-30, annatto-29)
# nmod:from(derived-27, bean-30)
# compound(tocotrienol-33, annatto-32)
# appos(bean-30, tocotrienol-33)
# nummod(mg/kg/day-36, 60-35)
# nmod:npmod(alone-37, mg/kg/day-36)
# advmod(bean-30, alone-37)
# dep(mg/kg/day-44, 3-40)
# nsubj(mg/kg/day-44, lovastatin-42)
# nummod(lovastatin-42, 11-43)
# conj:and(-RSB--6, mg/kg/day-44)
# cc(-RSB--6, and-46)
# nsubj(tocotrienol-48, annatto-47)
# conj:and(-RSB--6, tocotrienol-48)
# dobj(tocotrienol-48, 60-49)
# advmod(tocotrienol-48, mg/kg/day-50)
#
# Parsing [sent. 14 len. 73]: -LSB- u ` spread ' -RSB- Patients were randomized into four groups for a 6-week treatment : the control -LRB- CT -RRB- group remained on the same statin therapy , the ezetimibe -LRB- EZ -RRB- group received 10unkmg/day of ezetimibe , the plant sterol -LRB- PS -RRB- group received spread enriched with 2unkg of plant sterols , and the ezetimibe + PS -LRB- EZ+PS -RRB- group received 10unkmg/day EZ +2 unkg PS .
# (ROOT
#   (S
#     (NP
#       (NP
#         (NP (JJ -LSB-) (NN u))
#         (`` `)
#         (S
#           (S
#             (NP
#               (NP (NN spread) (POS '))
#               (NNP -RSB-) (NNPS Patients))
#             (VP (VBD were)
#               (VP (VBN randomized)
#                 (PP (IN into)
#                   (NP
#                     (NP (CD four) (NNS groups))
#                     (PP (IN for)
#                       (NP (DT a) (JJ 6-week) (NN treatment))))))))
#           (: :)
#           (S
#             (NP
#               (NP (DT the) (NN control)
#                 (PRN (-LRB- -LRB-)
#                   (NP (NNP CT))
#                   (-RRB- -RRB-))
#                 (NN group))
#               (VP (VBN remained)
#                 (PP (IN on)
#                   (NP
#                     (NP (DT the) (JJ same) (NN statin) (NN therapy))
#                     (, ,)
#                     (NP (DT the) (NN ezetimibe))
#                     (PRN (-LRB- -LRB-)
#                       (NP (NNP EZ))
#                       (-RRB- -RRB-))
#                     (NP (NN group))))))
#             (VP (VBD received)
#               (NP
#                 (NP (NNS 10unkmg/day))
#                 (PP (IN of)
#                   (NP (NN ezetimibe)))))))
#         (, ,)
#         (NP
#           (NP (DT the) (NN plant) (NN sterol))
#           (PRN (-LRB- -LRB-)
#             (NP (NNP PS))
#             (-RRB- -RRB-))
#           (SBAR
#             (S
#               (NP (NN group))
#               (VP (VBD received)
#                 (NP
#                   (NP (NN spread))
#                   (VP (VBN enriched)
#                     (PP (IN with)
#                       (NP
#                         (NP (NNS 2unkg))
#                         (PP (IN of)
#                           (NP (NN plant) (NNS sterols)))))))))))
#         (, ,))
#       (CC and)
#       (NP (DT the)
#         (ADJP (JJ ezetimibe) (JJ +))
#         (NNP PS)
#         (PRN (-LRB- -LRB-)
#           (NP (NNP EZ+PS))
#           (-RRB- -RRB-))
#         (NN group)))
#     (VP (VBD received)
#       (NP
#         (NP (CD 10unkmg/day) (NNP EZ) (CD +2))
#         (VP (VBG unkg)
#           (NP (NNP PS)))))
#     (. .)))
#
# amod(u-2, -LSB--1)
# nsubj(received-67, u-2)
# nmod:poss(Patients-7, spread-4)
# case(spread-4, '-5)
# compound(Patients-7, -RSB--6)
# nsubjpass(randomized-9, Patients-7)
# auxpass(randomized-9, were-8)
# dep(u-2, randomized-9)
# case(groups-12, into-10)
# nummod(groups-12, four-11)
# nmod:into(randomized-9, groups-12)
# case(treatment-16, for-13)
# det(treatment-16, a-14)
# amod(treatment-16, 6-week-15)
# nmod:for(groups-12, treatment-16)
# det(group-23, the-18)
# compound(group-23, control-19)
# appos(group-23, CT-21)
# nsubj(received-37, group-23)
# acl(group-23, remained-24)
# case(therapy-29, on-25)
# det(therapy-29, the-26)
# amod(therapy-29, same-27)
# compound(therapy-29, statin-28)
# nmod:on(remained-24, therapy-29)
# det(ezetimibe-32, the-31)
# appos(therapy-29, ezetimibe-32)
# appos(therapy-29, EZ-34)
# dep(therapy-29, group-36)
# parataxis(randomized-9, received-37)
# dobj(received-37, 10unkmg/day-38)
# case(ezetimibe-40, of-39)
# nmod:of(10unkmg/day-38, ezetimibe-40)
# det(sterol-44, the-42)
# compound(sterol-44, plant-43)
# appos(u-2, sterol-44)
# appos(sterol-44, PS-46)
# nsubj(received-49, group-48)
# acl:relcl(sterol-44, received-49)
# dobj(received-49, spread-50)
# acl(spread-50, enriched-51)
# case(2unkg-53, with-52)
# nmod:with(enriched-51, 2unkg-53)
# case(sterols-56, of-54)
# compound(sterols-56, plant-55)
# nmod:of(2unkg-53, sterols-56)
# cc(u-2, and-58)
# det(group-66, the-59)
# amod(+-61, ezetimibe-60)
# amod(group-66, +-61)
# compound(group-66, PS-62)
# appos(group-66, EZ+PS-64)
# conj:and(u-2, group-66)
# nsubj(received-67, group-66)
# root(ROOT-0, received-67)
# nummod(EZ-69, 10unkmg/day-68)
# dobj(received-67, EZ-69)
# nummod(EZ-69, +2-70)
# acl(EZ-69, unkg-71)
# dobj(unkg-71, PS-72)
#
# Parsing [sent. 15 len. 26]: -LSB- u ` casein ' -RSB- Atorvastatin treatment increased serum alanine aminotransferase -LRB- ALT -RRB- and aspartate aminotransferase -LRB- AST -RRB- in casein injection mice .
# (ROOT
#   (S
#     (NP (JJ -LSB-) (NN u) (`` `) (NN casein) ('' '))
#     (VP (VBZ -RSB-)
#       (NP
#         (NP
#           (NP (NNP Atorvastatin) (NN treatment) (VBD increased) (JJ serum) (NN alanine) (NNS aminotransferase))
#           (PRN (-LRB- -LRB-)
#             (NP (NNP ALT))
#             (-RRB- -RRB-)))
#         (CC and)
#         (NP
#           (NP
#             (NP (JJ aspartate) (NN aminotransferase))
#             (PRN (-LRB- -LRB-)
#               (NP (NNP AST))
#               (-RRB- -RRB-)))
#           (PP (IN in)
#             (NP (JJ casein) (NN injection) (NNS mice))))))
#     (. .)))
#
# amod(casein-4, -LSB--1)
# compound(casein-4, u-2)
# nsubj(-RSB--6, casein-4)
# root(ROOT-0, -RSB--6)
# compound(aminotransferase-12, Atorvastatin-7)
# compound(aminotransferase-12, treatment-8)
# amod(aminotransferase-12, increased-9)
# amod(aminotransferase-12, serum-10)
# compound(aminotransferase-12, alanine-11)
# dobj(-RSB--6, aminotransferase-12)
# appos(aminotransferase-12, ALT-14)
# cc(aminotransferase-12, and-16)
# amod(aminotransferase-18, aspartate-17)
# dobj(-RSB--6, aminotransferase-18)
# conj:and(aminotransferase-12, aminotransferase-18)
# appos(aminotransferase-18, AST-20)
# case(mice-25, in-22)
# amod(mice-25, casein-23)
# compound(mice-25, injection-24)
# nmod:in(aminotransferase-18, mice-25)
#
# Parsing [sent. 16 len. 36]: -LSB- u ` casein ' -RSB- Moreover , atorvastatin treatment exacerbated hepatic steatosis , inflammation and fibrosis , as well as increased hepatic reactive oxygen species -LRB- ROS -RRB- and malondialdehyde in casein injection mice .
# (ROOT
#   (S
#     (S
#       (NP (JJ -LSB-) (NN u) (`` `) (NN casein) ('' '))
#       (VP (VBZ -RSB-)
#         (ADVP (RB Moreover))))
#     (, ,)
#     (NP (NN atorvastatin) (NN treatment))
#     (VP (VBD exacerbated)
#       (NP
#         (NP
#           (NP (JJ hepatic) (NNS steatosis))
#           (, ,)
#           (NP (NN inflammation))
#           (CC and)
#           (NP (NN fibrosis)))
#         (, ,)
#         (CONJP (RB as) (RB well) (IN as))
#         (NP
#           (NP (VBN increased) (JJ hepatic) (JJ reactive) (NN oxygen) (NNS species))
#           (PRN (-LRB- -LRB-)
#             (NP (NNP ROS))
#             (-RRB- -RRB-)))
#         (CC and)
#         (NP
#           (NP (NN malondialdehyde))
#           (PP (IN in)
#             (NP (JJ casein) (NN injection) (NNS mice))))))
#     (. .)))
#
# amod(casein-4, -LSB--1)
# compound(casein-4, u-2)
# nsubj(-RSB--6, casein-4)
# ccomp(exacerbated-11, -RSB--6)
# advmod(-RSB--6, Moreover-7)
# compound(treatment-10, atorvastatin-9)
# nsubj(exacerbated-11, treatment-10)
# root(ROOT-0, exacerbated-11)
# amod(steatosis-13, hepatic-12)
# dobj(exacerbated-11, steatosis-13)
# dobj(exacerbated-11, inflammation-15)
# conj:and(steatosis-13, inflammation-15)
# cc(steatosis-13, and-16)
# dobj(exacerbated-11, fibrosis-17)
# conj:and(steatosis-13, fibrosis-17)
# cc(steatosis-13, as-19)
# mwe(as-19, well-20)
# mwe(as-19, as-21)
# amod(species-26, increased-22)
# amod(species-26, hepatic-23)
# amod(species-26, reactive-24)
# compound(species-26, oxygen-25)
# dobj(exacerbated-11, species-26)
# conj:and(steatosis-13, species-26)
# appos(species-26, ROS-28)
# cc(steatosis-13, and-30)
# dobj(exacerbated-11, malondialdehyde-31)
# conj:and(steatosis-13, malondialdehyde-31)
# case(mice-35, in-32)
# amod(mice-35, casein-33)
# compound(mice-35, injection-34)
# nmod:in(malondialdehyde-31, mice-35)
#
# Parsing [sent. 17 len. 41]: -LSB- u ` olive ' -RSB- Herein , we evaluated the effect of lovastatin and orlistat on polyp development and ER expression in ApcMin / + mice , in order to confirm previous data obtained with unkunk3-PUFAs and olive oil .
# (ROOT
#   (S
#     (S
#       (NP (JJ -LSB-) (NN u) (`` `) (NN olive) ('' '))
#       (VP (VBZ -RSB-)
#         (NP (NNP Herein))))
#     (, ,)
#     (NP (PRP we))
#     (VP (VBN evaluated)
#       (NP
#         (NP (DT the) (NN effect))
#         (PP (IN of)
#           (NP (NN lovastatin)
#             (CC and)
#             (NN orlistat))))
#       (PP (IN on)
#         (NP
#           (NP (NN polyp) (NN development)
#             (CC and)
#             (NN ER) (NN expression))
#           (PP (IN in)
#             (NP (NNP ApcMin) (NNP /) (NNP +) (NNS mice)))))
#       (, ,)
#       (SBAR (IN in) (NN order)
#         (S
#           (VP (TO to)
#             (VP (VB confirm)
#               (NP
#                 (NP (JJ previous) (NNS data))
#                 (VP (VBN obtained)
#                   (PP (IN with)
#                     (NP
#                       (ADJP (JJ unkunk3-PUFAs)
#                         (CC and)
#                         (JJ olive))
#                       (NN oil))))))))))
#     (. .)))
#
# amod(olive-4, -LSB--1)
# compound(olive-4, u-2)
# nsubj(-RSB--6, olive-4)
# ccomp(evaluated-10, -RSB--6)
# dobj(-RSB--6, Herein-7)
# nsubj(evaluated-10, we-9)
# root(ROOT-0, evaluated-10)
# det(effect-12, the-11)
# dobj(evaluated-10, effect-12)
# case(lovastatin-14, of-13)
# nmod:of(effect-12, lovastatin-14)
# cc(lovastatin-14, and-15)
# nmod:of(effect-12, orlistat-16)
# conj:and(lovastatin-14, orlistat-16)
# case(development-19, on-17)
# compound(development-19, polyp-18)
# nmod:on(evaluated-10, development-19)
# cc(development-19, and-20)
# compound(expression-22, ER-21)
# nmod:on(evaluated-10, expression-22)
# conj:and(development-19, expression-22)
# case(mice-27, in-23)
# compound(mice-27, ApcMin-24)
# compound(mice-27, /-25)
# compound(mice-27, +-26)
# nmod:in(development-19, mice-27)
# mark(confirm-32, in-29)
# mwe(in-29, order-30)
# mark(confirm-32, to-31)
# advcl(evaluated-10, confirm-32)
# amod(data-34, previous-33)
# dobj(confirm-32, data-34)
# acl(data-34, obtained-35)
# case(oil-40, with-36)
# amod(oil-40, unkunk3-PUFAs-37)
# cc(unkunk3-PUFAs-37, and-38)
# conj:and(unkunk3-PUFAs-37, olive-39)
# amod(oil-40, olive-39)
# nmod:with(obtained-35, oil-40)
#
# Parsing [sent. 18 len. 103]: -LSB- u ` rice ' -RSB- Then , the following lipid-lowering treatments were added in order to improve the ezetimibe low density lipoprotein cholesterol -LRB- LDL-C -RRB- lowering efficacy , based on clinical judgment : fenofibrate 145unkmg , rosuvastatin 5unkmg 1 tablet/week , rosuvastatin 5unkmg 2 tablets/week , red yeast rice -LRB- standardized in monacolin K 3unkmg -RRB- + berberine 500unkmg , berberine 500unkmg b.i.d. , phytosterols 900unkmgunk + unkpsyllium fiber 3.5 unkg b.i.d. -LSB- u ` gelatin ' -RSB- The present study was performed to determine whether simvastatin improves bone regeneration when combined with calcium silicate/gypsum and gelatin -LRB- CS-GEL -RRB- .
# (ROOT
#   (S
#     (S
#       (NP (JJ -LSB-) (NN u) (`` `) (NN rice) ('' '))
#       (VP (VBD -RSB-)
#         (SBAR
#           (S
#             (ADVP (RB Then))
#             (, ,)
#             (NP (DT the) (JJ following) (JJ lipid-lowering) (NNS treatments))
#             (VP (VBD were)
#               (VP (VBN added)
#                 (PP (IN in)
#                   (NP (NN order)))
#                 (S
#                   (VP (TO to)
#                     (VP (VB improve)
#                       (NP
#                         (NP (DT the)
#                           (ADJP (JJ ezetimibe) (JJ low))
#                           (NN density) (NN lipoprotein) (NN cholesterol))
#                         (PRN (-LRB- -LRB-)
#                           (NP (NNP LDL-C))
#                           (-RRB- -RRB-)))
#                       (S
#                         (VP (VBG lowering)
#                           (ADVP (RB efficacy))))
#                       (, ,)
#                       (PP (VBN based)
#                         (PP (IN on)
#                           (NP (JJ clinical) (NN judgment)))))))))))))
#     (: :)
#     (S
#       (NP
#         (NP (JJ fenofibrate) (NNS 145unkmg))
#         (, ,)
#         (NP (JJ rosuvastatin) (JJ 5unkmg) (CD 1) (NN tablet/week))
#         (, ,)
#         (NP
#           (NP (NN rosuvastatin) (NNS 5unkmg))
#           (NP (CD 2) (NN tablets/week)))
#         (, ,)
#         (NP
#           (NP (JJ red) (NN yeast) (NN rice))
#           (PRN (-LRB- -LRB-)
#             (NP
#               (NP (JJ standardized))
#               (PP (IN in)
#                 (NP (JJ monacolin) (NNP K) (NNS 3unkmg))))
#             (-RRB- -RRB-))
#           (NP (JJ +) (NN berberine) (NNS 500unkmg)))
#         (, ,)
#         (NP (JJ berberine) (JJ 500unkmg) (NN b.i.d.))
#         (, ,))
#       (VP (VBZ phytosterols)
#         (NP
#           (NP (JJ 900unkmgunk) (JJ +) (NN unkpsyllium) (NN fiber))
#           (SBAR
#             (S
#               (NP (CD 3.5) (JJ unkg) (NNP b.i.d.) (NNP -LSB-) (NN u) (`` `) (NN gelatin) ('' '))
#               (VP (VBD -RSB-)
#                 (SBAR
#                   (S
#                     (NP (DT The) (JJ present) (NN study))
#                     (VP (VBD was)
#                       (VP (VBN performed)
#                         (S
#                           (VP (TO to)
#                             (VP (VB determine)
#                               (SBAR (IN whether)
#                                 (S
#                                   (NP (NN simvastatin))
#                                   (VP (VBZ improves)
#                                     (NP (NN bone) (NN regeneration))
#                                     (SBAR
#                                       (WHADVP (WRB when))
#                                       (S
#                                         (VP (VBN combined)
#                                           (PP (IN with)
#                                             (NP (NN calcium) (NN silicate/gypsum)
#                                               (CC and)
#                                               (NN gelatin)))
#                                           (PRN (-LRB- -LRB-)
#                                             (NP (NNP CS-GEL))
#                                             (-RRB- -RRB-)))))))))))))))))))))
#     (. .)))
#
# amod(rice-4, -LSB--1)
# compound(rice-4, u-2)
# nsubj(-RSB--6, rice-4)
# root(ROOT-0, -RSB--6)
# advmod(added-14, Then-7)
# det(treatments-12, the-9)
# amod(treatments-12, following-10)
# amod(treatments-12, lipid-lowering-11)
# nsubjpass(added-14, treatments-12)
# nsubj:xsubj(improve-18, treatments-12)
# auxpass(added-14, were-13)
# ccomp(-RSB--6, added-14)
# advcl(added-14, in-15)
# mwe(in-15, order-16)
# mark(improve-18, to-17)
# xcomp(added-14, improve-18)
# det(cholesterol-24, the-19)
# amod(low-21, ezetimibe-20)
# amod(cholesterol-24, low-21)
# compound(cholesterol-24, density-22)
# compound(cholesterol-24, lipoprotein-23)
# dobj(improve-18, cholesterol-24)
# appos(cholesterol-24, LDL-C-26)
# xcomp(improve-18, lowering-28)
# advmod(lowering-28, efficacy-29)
# case(judgment-34, based-31)
# mwe(based-31, on-32)
# amod(judgment-34, clinical-33)
# advcl(improve-18, judgment-34)
# amod(145unkmg-37, fenofibrate-36)
# nsubj(phytosterols-67, 145unkmg-37)
# amod(tablet/week-42, rosuvastatin-39)
# amod(tablet/week-42, 5unkmg-40)
# nummod(tablet/week-42, 1-41)
# appos(145unkmg-37, tablet/week-42)
# compound(5unkmg-45, rosuvastatin-44)
# appos(145unkmg-37, 5unkmg-45)
# nummod(tablets/week-47, 2-46)
# dep(5unkmg-45, tablets/week-47)
# ...
# (ROOT
#   (NP
#     (NP (JJ -LSB-) (NN u) (`` `) (NN spirit) ('' '))
#     (, ,)
#     (NP (NN u) (`` `) (NN spirit) ('' '))
#     (, ,)
#     (S
#       (S
#         (VP (VB u)
#           (NP
#             (NP (`` `) (NN spirit) ('' ') (NNS -RSB-))
#             (SBAR
#               (S
#                 (NP
#                   (NP (DT The) (NN sequence))
#                   (PP (IN of)
#                     (NP
#                       (NP (NN effect))
#                       (PP (IN of)
#                         (NP (NNS statins))))))
#                 (VP (VBZ is)
#                   (SBAR (IN as)
#                     (S
#                       (VP (VBZ follows))))))))))
#       (: :)
#       (S
#         (VP
#           (VP (VBG blocking)
#             (PP (IN of)
#               (NP
#                 (NP (NN synthesis))
#                 (PP (IN in)
#                   (NP (NNS hepatocytes))))))
#           (CC and)
#           (VP (VBG decreasing)
#             (PP (IN of)
#               (NP
#                 (NP (NN content))
#                 (PP (IN of)
#                   (NP
#                     (NP
#                       (NP
#                         (NP (JJ unesterified) (NN cholesterol) (NN spirit))
#                         (PP (IN in)
#                           (NP (NN blood) (NN plasma))))
#                       (: ;)
#                       (NP
#                         (NP (NN activation))
#                         (PP (IN of)
#                           (NP
#                             (NP (NNS hydrolysis))
#                             (PP (IN of)
#                               (NP
#                                 (NP (NNPS triglycerides))
#                                 (PP (IN in)
#                                   (NP
#                                     (NP
#                                       (ADJP (JJ palmitic)
#                                         (CC and)
#                                         (JJ oleic))
#                                       (NNS lipoproteins))
#                                     (PP (IN of)
#                                       (NP
#                                         (ADJP (RB very) (JJ low))
#                                         (NN density))))))))))
#                       (: ;)
#                       (NP
#                         (NP (NN formation))
#                         (PP (IN of)
#                           (NP
#                             (NP (JJ ligand) (NNS lipoproteins))
#                             (PP (IN of)
#                               (NP
#                                 (ADJP (RB very) (JJ low))
#                                 (NN density)))))))
#                     (CC and)
#                     (NP
#                       (NP (PRP$ their) (NN absorption))
#                       (PP (IN by)
#                         (NP (NNS cells))))))))
#             (PP (IN by)
#               (NP
#                 (NP (NN force))
#                 (PP (IN of)
#                   (NP (JJ apoB-100) (NNS endocytosis))))))))
#       (: ;)
#       (S
#         (VP (VBG decreasing)
#           (PP (IN in)
#             (NP
#               (NP (NN blood))
#               (PP (IN of)
#                 (NP
#                   (NP (NN content))
#                   (PP (IN of)
#                     (NP (JJ polyenoic) (NN fatty) (NNS acids))))))))))
#     (, ,)
#     (NP
#       (NP
#         (NP (NN equimolar))
#         (VP (VBN esterified)
#           (PP (IN by)
#             (NP (NN cholesterol) (NN spirit)))))
#       (, ,)
#       (NP
#         (NP (NNS polyethers))
#         (PP (IN of)
#           (NP (NN cholesterol) (NN spirit))))
#       (CC and)
#       (NP
#         (NP (VBG decreasing))
#         (PP (IN of)
#           (NP (NN level)))
#         (PP (IN of)
#           (NP (NN cholesterol) (NNS spirit-lipoproteins)))
#         (PP (IN of)
#           (NP
#             (ADJP (RB very) (JJ low))
#             (NN density)))))
#     (. .)))
#
# amod(spirit-4, -LSB--1)
# compound(spirit-4, u-2)
# root(ROOT-0, spirit-4)
# compound(spirit-9, u-7)
# appos(spirit-4, spirit-9)
# dep(spirit-4, u-12)
# compound(-RSB--16, spirit-14)
# dobj(u-12, -RSB--16)
# det(sequence-18, The-17)
# nsubj(is-23, sequence-18)
# case(effect-20, of-19)
# nmod:of(sequence-18, effect-20)
# case(statins-22, of-21)
# nmod:of(effect-20, statins-22)
# acl:relcl(-RSB--16, is-23)
# mark(follows-25, as-24)
# advcl(is-23, follows-25)
# parataxis(u-12, blocking-27)
# case(synthesis-29, of-28)
# nmod:of(blocking-27, synthesis-29)
# case(hepatocytes-31, in-30)
# nmod:in(synthesis-29, hepatocytes-31)
# cc(blocking-27, and-32)
# parataxis(u-12, decreasing-33)
# conj:and(blocking-27, decreasing-33)
# case(content-35, of-34)
# nmod:of(decreasing-33, content-35)
# case(spirit-39, of-36)
# amod(spirit-39, unesterified-37)
# compound(spirit-39, cholesterol-38)
# nmod:of(content-35, spirit-39)
# case(plasma-42, in-40)
# compound(plasma-42, blood-41)
# nmod:in(spirit-39, plasma-42)
# dep(spirit-39, activation-44)
# case(hydrolysis-46, of-45)
# nmod:of(activation-44, hydrolysis-46)
# case(triglycerides-48, of-47)
# nmod:of(hydrolysis-46, triglycerides-48)
# case(lipoproteins-53, in-49)
# amod(lipoproteins-53, palmitic-50)
# cc(palmitic-50, and-51)
# conj:and(palmitic-50, oleic-52)
# amod(lipoproteins-53, oleic-52)
# nmod:in(triglycerides-48, lipoproteins-53)
# case(density-57, of-54)
# advmod(low-56, very-55)
# amod(density-57, low-56)
# nmod:of(lipoproteins-53, density-57)
# dep(spirit-39, formation-59)
# case(lipoproteins-62, of-60)
# amod(lipoproteins-62, ligand-61)
# nmod:of(formation-59, lipoproteins-62)
# case(density-66, of-63)
# advmod(low-65, very-64)
# amod(density-66, low-65)
# nmod:of(lipoproteins-62, density-66)
# cc(spirit-39, and-67)
# nmod:poss(absorption-69, their-68)
# nmod:of(content-35, absorption-69)
# conj:and(spirit-39, absorption-69)
# case(cells-71, by-70)
# nmod:by(absorption-69, cells-71)
# case(force-73, by-72)
# nmod:by(decreasing-33, force-73)
# case(endocytosis-76, of-74)
# amod(endocytosis-76, apoB-100-75)
# nmod:of(force-73, endocytosis-76)
# parataxis(u-12, decreasing-78)
# case(blood-80, in-79)
# nmod:in(decreasing-78, blood-80)
# case(content-82, of-81)
# nmod:of(blood-80, content-82)
# case(acids-86, of-83)
# amod(acids-86, polyenoic-84)
# compound(acids-86, fatty-85)
# nmod:of(content-82, acids-86)
# appos(spirit-4, equimolar-88)
# acl(equimolar-88, esterified-89)
# case(spirit-92, by-90)
# compound(spirit-92, cholesterol-91)
# nmod:by(esterified-89, spirit-92)
# appos(spirit-4, polyethers-94)
# conj:and(equimolar-88, polyethers-94)
# case(spirit-97, of-95)
# compound(spirit-97, cholesterol-96)
# nmod:of(polyethers-94, spirit-97)
# cc(equimolar-88, and-98)
# appos(spirit-4, decreasing-99)
# conj:and(equimolar-88, decreasing-99)
# case(level-101, of-100)
# nmod:of(decreasing-99, level-101)
# case(spirit-lipoproteins-104, of-102)
# compound(spirit-lipoproteins-104, cholesterol-103)
# nmod:of(decreasing-99, spirit-lipoproteins-104)
# case(density-108, of-105)
# advmod(low-107, very-106)
# amod(density-108, low-107)
# nmod:of(decreasing-99, density-108)
#
# Parsing [sent. 43 len. 57]: -LSB- u ` coconut ' -RSB- To assess these effects , 15-week-old stroke-prone spontaneously hypertensive rats -LRB- SHRSPs -RRB- were divided into four groups -LRB- n = 6 , each -RRB- : alpha-tocopherol -LRB- AT -RRB- , lovastatin -LRB- LoV -RRB- , alpha-tocopherol + lovastatin -LRB- AT + LoV -RRB- , and control -LRB- C -RRB- .
# (ROOT
#   (S
#     (S
#       (NP (JJ -LSB-) (NN u) (`` `) (NN coconut) ('' '))
#       (VP (VBZ -RSB-)
#         (S
#           (VP (TO To)
#             (VP (VB assess)
#               (NP (DT these) (NNS effects)))))))
#     (, ,)
#     (NP
#       (NP (JJ 15-week-old) (JJ stroke-prone) (JJ spontaneously) (NN hypertensive) (NNS rats))
#       (PRN (-LRB- -LRB-)
#         (NP (NNP SHRSPs))
#         (-RRB- -RRB-)))
#     (VP (VBD were)
#       (VP (VBN divided)
#         (PP (IN into)
#           (NP
#             (NP
#               (NP (CD four) (NNS groups))
#               (PRN (-LRB- -LRB-)
#                 (VP (VBN n)
#                   (S
#                     (VP (SYM =)
#                       (NP (CD 6))))
#                   (, ,)
#                   (S
#                     (NP (DT each))))
#                 (-RRB- -RRB-)))
#             (: :)
#             (NP
#               (NP
#                 (NP (NN alpha-tocopherol))
#                 (PRN (-LRB- -LRB-)
#                   (NP (NNP AT))
#                   (-RRB- -RRB-)))
#               (, ,)
#               (NP
#                 (NP (NN lovastatin))
#                 (PRN (-LRB- -LRB-)
#                   (NP (NNP LoV))
#                   (-RRB- -RRB-)))
#               (, ,)
#               (NP
#                 (NP (JJ alpha-tocopherol) (VBG +) (NN lovastatin))
#                 (PRN (-LRB- -LRB-)
#                   (NP (NNP AT) (NNP +) (NNP LoV))
#                   (-RRB- -RRB-)))
#               (, ,)
#               (CC and)
#               (NP
#                 (NP (NN control))
#                 (PRN (-LRB- -LRB-)
#                   (NP (NNP C))
#                   (-RRB- -RRB-))))))))
#     (. .)))
#
# amod(coconut-4, -LSB--1)
# compound(coconut-4, u-2)
# nsubj(-RSB--6, coconut-4)
# nsubj:xsubj(assess-8, coconut-4)
# ccomp(divided-21, -RSB--6)
# mark(assess-8, To-7)
# xcomp(-RSB--6, assess-8)
# det(effects-10, these-9)
# dobj(assess-8, effects-10)
# amod(rats-16, 15-week-old-12)
# amod(rats-16, stroke-prone-13)
# amod(rats-16, spontaneously-14)
# compound(rats-16, hypertensive-15)
# nsubjpass(divided-21, rats-16)
# appos(rats-16, SHRSPs-18)
# auxpass(divided-21, were-20)
# root(ROOT-0, divided-21)
# case(groups-24, into-22)
# nummod(groups-24, four-23)
# nmod:into(divided-21, groups-24)
# dep(groups-24, n-26)
# dep(6-28, =-27)
# ccomp(n-26, 6-28)
# xcomp(n-26, each-30)
# dep(groups-24, alpha-tocopherol-33)
# appos(alpha-tocopherol-33, AT-35)
# dep(groups-24, lovastatin-38)
# conj:and(alpha-tocopherol-33, lovastatin-38)
# appos(lovastatin-38, LoV-40)
# amod(lovastatin-45, alpha-tocopherol-43)
# amod(lovastatin-45, +-44)
# dep(groups-24, lovastatin-45)
# conj:and(alpha-tocopherol-33, lovastatin-45)
# compound(LoV-49, AT-47)
# compound(LoV-49, +-48)
# appos(lovastatin-45, LoV-49)
# cc(alpha-tocopherol-33, and-52)
# dep(groups-24, control-53)
# conj:and(alpha-tocopherol-33, control-53)
# appos(control-53, C-55)
#
# Parsing [sent. 44 len. 32]: We administered 120 IU of alpha-tocopherol diluted in 0.1 ml of coconut oil , whereas the dose of lovastatin was administered at a ratio of 1 mg/kg of rat body weight .
# (ROOT
#   (S
#     (NP (PRP We))
#     (VP (VBN administered)
#       (NP
#         (NP (CD 120) (NN IU))
#         (PP (IN of)
#           (NP (JJ alpha-tocopherol) (NNS diluted))))
#       (PP (IN in)
#         (NP
#           (NP (CD 0.1) (NN ml))
#           (PP (IN of)
#             (NP (JJ coconut) (NN oil)))))
#       (, ,)
#       (SBAR (IN whereas)
#         (S
#           (NP
#             (NP (DT the) (NN dose))
#             (PP (IN of)
#               (NP (NN lovastatin))))
#           (VP (VBD was)
#             (VP (VBN administered)
#               (PP (IN at)
#                 (NP
#                   (NP (DT a) (NN ratio))
#                   (PP (IN of)
#                     (NP
#                       (NP (CD 1) (NN mg/kg))
#                       (PP (IN of)
#                         (NP (NN rat) (NN body) (NN weight))))))))))))
#     (. .)))
#
# nsubj(administered-2, We-1)
# root(ROOT-0, administered-2)
# nummod(IU-4, 120-3)
# dobj(administered-2, IU-4)
# case(diluted-7, of-5)
# amod(diluted-7, alpha-tocopherol-6)
# nmod:of(IU-4, diluted-7)
# case(ml-10, in-8)
# nummod(ml-10, 0.1-9)
# nmod:in(administered-2, ml-10)
# case(oil-13, of-11)
# amod(oil-13, coconut-12)
# nmod:of(ml-10, oil-13)
# mark(administered-21, whereas-15)
# det(dose-17, the-16)
# nsubjpass(administered-21, dose-17)
# case(lovastatin-19, of-18)
# nmod:of(dose-17, lovastatin-19)
# auxpass(administered-21, was-20)
# advcl(administered-2, administered-21)
# case(ratio-24, at-22)
# det(ratio-24, a-23)
# nmod:at(administered-21, ratio-24)
# case(mg/kg-27, of-25)
# nummod(mg/kg-27, 1-26)
# nmod:of(ratio-24, mg/kg-27)
# case(weight-31, of-28)
# compound(weight-31, rat-29)
# compound(weight-31, body-30)
# nmod:of(mg/kg-27, weight-31)
#
# Parsing [sent. 45 len. 12]: -LSB- u ` cinnamon ' -RSB- Cinnamon and statin were held .
# (ROOT
#   (S
#     (NP
#       (NP (NNP -LSB-) (NNP u) (`` `) (NNP cinnamon) ('' ') (NNP -RSB-) (NNP Cinnamon))
#       (CC and)
#       (NP (NN statin)))
#     (VP (VBD were)
#       (VP (VBN held)))
#     (. .)))
#
# compound(Cinnamon-7, -LSB--1)
# compound(Cinnamon-7, u-2)
# compound(Cinnamon-7, cinnamon-4)
# compound(Cinnamon-7, -RSB--6)
# nsubjpass(held-11, Cinnamon-7)
# cc(Cinnamon-7, and-8)
# conj:and(Cinnamon-7, statin-9)
# nsubjpass(held-11, statin-9)
# auxpass(held-11, were-10)
# root(ROOT-0, held-11)
#
# Parsing [sent. 46 len. 23]: -LSB- u ` cinnamon ' -RSB- A combination of cinnamon supplement and statin can cause hepatitis , and it should be discouraged .
# (ROOT
#   (S
#     (S
#       (NP (NNP -LSB-) (NNP u) (`` `) (NNP cinnamon) ('' '))
#       (VP (VBD -RSB-)
#         (SBAR
#           (S
#             (NP
#               (NP (DT A) (NN combination))
#               (PP (IN of)
#                 (NP (JJ cinnamon) (NN supplement)
#                   (CC and)
#                   (NN statin))))
#             (VP (MD can)
#               (VP (VB cause)
#                 (NP (NN hepatitis))))))))
#     (, ,)
#     (CC and)
#     (S
#       (NP (PRP it))
#       (VP (MD should)
#         (VP (VB be)
#           (VP (VBN discouraged)))))
#     (. .)))
#
# compound(cinnamon-4, -LSB--1)
# compound(cinnamon-4, u-2)
# nsubj(-RSB--6, cinnamon-4)
# root(ROOT-0, -RSB--6)
# det(combination-8, A-7)
# nsubj(cause-15, combination-8)
# case(supplement-11, of-9)
# amod(supplement-11, cinnamon-10)
# nmod:of(combination-8, supplement-11)
# cc(supplement-11, and-12)
# nmod:of(combination-8, statin-13)
# conj:and(supplement-11, statin-13)
# aux(cause-15, can-14)
# ccomp(-RSB--6, cause-15)
# dobj(cause-15, hepatitis-16)
# cc(-RSB--6, and-18)
# nsubjpass(discouraged-22, it-19)
# aux(discouraged-22, should-20)
# auxpass(discouraged-22, be-21)
# conj:and(-RSB--6, discouraged-22)
#
# Parsing [sent. 47 len. 136]: -LSB- u ` spirit ' , u ` spirit ' -RSB- The effect of statins occur in several stages : 1 -RRB- inhibition in hepatocytes of synthesis of functionally specific pool of spirit cholesterol , polar mono-layer of lipoproteins of very low density ; 2 -RRB- activation of hydrolysis of triglycerides in lipoproteins of very low density , formation of apoE/B -100 - ligand and absorption of lipoproteins of very low density by insulin-depended cells ; 3 -RRB- decreasing of content of and spirit cholesterol-lipoproteins of very low density in blood plasma ; 4 -RRB- activation of hydrolysis of triglycerides in lipoproteins of low density , formation of apoB-100-ligand and absorption of lipoproteins of low density by insulin-independent cells ; 5 -RRB- decreasing of level of and increasing of content of lipoproteins of high density .
#
# *******************************************************
# ***  WARNING!! OUT OF MEMORY! THERE WAS NOT ENOUGH  ***
# ***  MEMORY TO RUN ALL PARSERS.  EITHER GIVE THE    ***
# ***  JVM MORE MEMORY, SET THE MAXIMUM SENTENCE      ***
# ***  LENGTH WITH -maxLength, OR PERHAPS YOU ARE     ***
# ***  HAPPY TO HAVE THE PARSER FALL BACK TO USING    ***
# ***  A SIMPLER PARSER FOR VERY LONG SENTENCES.      ***
# *******************************************************
#
# Sentence has no parse using PCFG grammar (or no PCFG fallback).  Skipping...
# Exception in thread "main" edu.stanford.nlp.parser.common.NoSuchParseException
# 	at edu.stanford.nlp.parser.lexparser.LexicalizedParserQuery.getBestParse(LexicalizedParserQuery.java:404)
# 	at edu.stanford.nlp.parser.lexparser.LexicalizedParserQuery.getBestParse(LexicalizedParserQuery.java:376)
# 	at edu.stanford.nlp.parser.lexparser.ParseFiles.processResults(ParseFiles.java:272)
# 	at edu.stanford.nlp.parser.lexparser.ParseFiles.parseFiles(ParseFiles.java:216)
# 	at edu.stanford.nlp.parser.lexparser.ParseFiles.parseFiles(ParseFiles.java:75)
# 	at edu.stanford.nlp.parser.lexparser.LexicalizedParser.main(LexicalizedParser.java:1517)
# 1 loop, best of 3: 1min 8s per loop

# %% [markdown]
# ### Command Line Parser

# %%
# !java -cp "*" -Xmx2g edu.stanford.nlp.pipeline.StanfordCoreNLP \
-annotators tokenize,ssplit,pos,lemma,ner,parse,dcoref,sentiment \
-file data/FilteredSentences_Statin_commonFood_clean.txt \
-outputFormat text
# Out:
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator pos
# [main] INFO edu.stanford.nlp.tagger.maxent.MaxentTagger - Loading POS tagger from edu/stanford/nlp/models/pos-tagger/english-left3words/english-left3words-distsim.tagger ... done [1.4 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [1.9 sec].
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [2.6 sec].
# [main] INFO edu.stanford.nlp.ie.AbstractSequenceClassifier - Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.9 sec].
# [main] INFO edu.stanford.nlp.time.JollyDayHolidays - Initializing JollyDayHoliday for SUTime from classpath edu/stanford/nlp/models/sutime/jollyday/Holidays_sutime.xml as sutime.binder.1.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ... done [0.4 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator dcoref
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator sentiment
#
# Processing file /Users/lisabarcelo/Desktop/W266/food_drug_interaction/parsing/data/FilteredSentences_Statin_commonFood_clean.txt ... writing to /Users/lisabarcelo/Desktop/W266/food_drug_interaction/parsing/FilteredSentences_Statin_commonFood_clean.txt.out
# Annotating file /Users/lisabarcelo/Desktop/W266/food_drug_interaction/parsing/data/FilteredSentences_Statin_commonFood_clean.txt ... done [3247.4 sec].
#
# Annotation pipeline timing information:
# TokenizerAnnotator: 0.2 sec.
# WordsToSentencesAnnotator: 0.0 sec.
# POSTaggerAnnotator: 1.4 sec.
# MorphaAnnotator: 0.1 sec.
# NERCombinerAnnotator: 11.8 sec.
# ParserAnnotator: 2960.3 sec.
# DeterministicCorefAnnotator: 271.7 sec.
# SentimentAnnotator: 1.8 sec.
# TOTAL: 3247.4 sec. for 16671 tokens at 5.1 tokens/sec.
# Pipeline setup: 11.5 sec.
# Total time for StanfordCoreNLP pipeline: 3259.6 sec.

# %% [markdown]
# ## Let's see a few sentences:

# %%
# !head FilteredSentences_Statin_commonFood_clean.txt.out
# Out:
# Sentence #1 (21 tokens, sentiment: Negative):
# [u'rice']18 samples of red yeast rice powder and 18 samples of lovastatin were collected.
# [Text=-LSB- CharacterOffsetBegin=0 CharacterOffsetEnd=1 PartOfSpeech=-LRB- Lemma=-lsb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=u CharacterOffsetBegin=1 CharacterOffsetEnd=2 PartOfSpeech=FW Lemma=u NamedEntityTag=O SentimentClass=Neutral]
# [Text=` CharacterOffsetBegin=2 CharacterOffsetEnd=3 PartOfSpeech=`` Lemma=` NamedEntityTag=O SentimentClass=Neutral]
# [Text=rice CharacterOffsetBegin=3 CharacterOffsetEnd=7 PartOfSpeech=NN Lemma=rice NamedEntityTag=O SentimentClass=Neutral]
# [Text=' CharacterOffsetBegin=7 CharacterOffsetEnd=8 PartOfSpeech='' Lemma=' NamedEntityTag=O SentimentClass=Neutral]
# [Text=-RSB- CharacterOffsetBegin=8 CharacterOffsetEnd=9 PartOfSpeech=-RRB- Lemma=-rsb- NamedEntityTag=O SentimentClass=Neutral]
# [Text=18 CharacterOffsetBegin=9 CharacterOffsetEnd=11 PartOfSpeech=CD Lemma=18 NamedEntityTag=NUMBER NormalizedNamedEntityTag=18.0 SentimentClass=Neutral]
# [Text=samples CharacterOffsetBegin=12 CharacterOffsetEnd=19 PartOfSpeech=NNS Lemma=sample NamedEntityTag=O SentimentClass=Neutral]

# %% [markdown]
# ## Creating Dictionaries

# %%
co_occurrence_dict = defaultdict(list)

for line in open('FilteredSentences_Statin_commonFood_clean.txt.out').readlines():
    if 'Sentence #' in line:
        sentence = str(line.strip('\n')).split(" ")[1]
        sentiment = str(line.strip('\n')).split(":")[1]
        sentiment = re.sub("\d+","",re.sub(r'[^\w\s]','',sentiment))
    elif line[0:5] == '[Text':
        word = str(line.split("=")[1]).split(" ")[0].lower()
        pos = str(line.split("=")[4]).split(" ")[0]
        co_occurrence_dict[(sentiment, sentence)].append(word)

# %% [markdown]
# ## Creating Dictionary for Visualization

# %%
foodlist = list_loader('data/food_common.pickle')

# %%
treeData = defaultdict(list)

treeData["name"] =  "Statins"
treeData["parent"] = "null"

#making tiny child dictionary
treeData_b = defaultdict(list)
treeData_b["name"] =  "Negative"
treeData_b["parent"] = "Statins"

treeData_c = defaultdict(list)
treeData_c["name"] =  "Very Negative"
treeData_c["parent"] = "Statins"


for k, v in co_occurrence_dict.iteritems():
    sentiment = str(k[0]).strip(" ")
        #Negative branch
    if sentiment == 'Negative':
        for vv in v:
            if vv in foodlist:
                if vv in set([treeData_b["children"][i]["name"] for i in range(len(treeData_b["children"]))]):
                    pass
                else:
                    treeData_b["children"].append({"parent":sentiment,
                        "name":vv})

    elif sentiment == 'Very negative':        
        for vv in v:
            if vv in foodlist:
                if vv in set([treeData_c["children"][i]["name"] for i in range(len(treeData_c["children"]))]):
                    pass
                else:
                    treeData_c["children"].append({"parent":sentiment,
                        "name":vv})
    else:
        next
        
    #Adding all children dictionaries
treeData["children"].append(treeData_b)
treeData["children"].append(treeData_c)

        
treeData
# Out:
# defaultdict(list,
#             {'children': [defaultdict(list,
#                           {'children': [{'name': 'rice', 'parent': 'Negative'},
#                             {'name': 'grapefruit', 'parent': 'Negative'},
#                             {'name': 'spread', 'parent': 'Negative'},
#                             {'name': 'gelatin', 'parent': 'Negative'},
#                             {'name': 'eggs', 'parent': 'Negative'},
#                             {'name': 'pomegranate', 'parent': 'Negative'},
#                             {'name': 'coffee', 'parent': 'Negative'},
#                             {'name': 'margarine', 'parent': 'Negative'},
#                             {'name': 'olive', 'parent': 'Negative'},
#                             {'name': 'sunflower', 'parent': 'Negative'},
#                             {'name': 'casein', 'parent': 'Negative'},
#                             {'name': 'tea', 'parent': 'Negative'},
#                             {'name': 'opossum', 'parent': 'Negative'},
#                             {'name': 'salt', 'parent': 'Negative'},
#                             {'name': 'agar', 'parent': 'Negative'},
#                             {'name': 'chickpea', 'parent': 'Negative'},
#                             {'name': 'spirit', 'parent': 'Negative'},
#                             {'name': 'wheat', 'parent': 'Negative'},
#                             {'name': 'ginger', 'parent': 'Negative'},
#                             {'name': 'shrimp', 'parent': 'Negative'},
#                             {'name': 'citrus', 'parent': 'Negative'},
#                             {'name': 'fenugreek', 'parent': 'Negative'},
#                             {'name': 'fruits', 'parent': 'Negative'},
#                             {'name': 'oat', 'parent': 'Negative'},
#                             {'name': 'arepa', 'parent': 'Negative'},
#                             {'name': 'radish', 'parent': 'Negative'},
#                             {'name': 'coconut', 'parent': 'Negative'},
#                             {'name': 'water', 'parent': 'Negative'},
#                             {'name': 'buffalo', 'parent': 'Negative'},
#                             {'name': 'garlic', 'parent': 'Negative'},
#                             {'name': 'cabbage', 'parent': 'Negative'},
#                             {'name': 'cinnamon', 'parent': 'Negative'},
#                             {'name': 'millet', 'parent': 'Negative'},
#                             {'name': 'eggplant', 'parent': 'Negative'},
#                             {'name': 'flaxseed', 'parent': 'Negative'},
#                             {'name': 'sugar', 'parent': 'Negative'},
#                             {'name': 'cream', 'parent': 'Negative'},
#                             {'name': 'mushrooms', 'parent': 'Negative'},
#                             {'name': 'pectin', 'parent': 'Negative'},
#                             {'name': 'bean', 'parent': 'Negative'},
#                             {'name': 'dripping', 'parent': 'Negative'},
#                             {'name': 'pie', 'parent': 'Negative'},
#                             {'name': 'apple', 'parent': 'Negative'},
#                             {'name': 'quail', 'parent': 'Negative'},
#                             {'name': 'yogurt', 'parent': 'Negative'},
#                             {'name': 'sake', 'parent': 'Negative'},
#                             {'name': 'crustaceans', 'parent': 'Negative'},
#                             {'name': 'flatfish', 'parent': 'Negative'},
#                             {'name': 'corn', 'parent': 'Negative'},
#                             {'name': 'pulses', 'parent': 'Negative'},
#                             {'name': 'lime', 'parent': 'Negative'}],
#                            'name': 'Negative',
#                            'parent': 'Statins'}),
#               defaultdict(list,
#                           {'children': [{'name': 'rice',
#                              'parent': 'Very negative'},
#                             {'name': 'wheat', 'parent': 'Very negative'},
#                             {'name': 'tea', 'parent': 'Very negative'},
#                             {'name': 'almond', 'parent': 'Very negative'},
#                             {'name': 'barley', 'parent': 'Very negative'},
#                             {'name': 'eggplant', 'parent': 'Very negative'},
#                             {'name': 'okra', 'parent': 'Very negative'},
#                             {'name': 'banana', 'parent': 'Very negative'},
#                             {'name': 'corn', 'parent': 'Very negative'},
#                             {'name': 'spread', 'parent': 'Very negative'},
#                             {'name': 'grapefruit', 'parent': 'Very negative'},
#                             {'name': 'pomegranate', 'parent': 'Very negative'},
#                             {'name': 'citrus', 'parent': 'Very negative'},
#                             {'name': 'fruits', 'parent': 'Very negative'},
#                             {'name': 'spirit', 'parent': 'Very negative'},
#                             {'name': 'agar', 'parent': 'Very negative'},
#                             {'name': 'chives', 'parent': 'Very negative'},
#                             {'name': 'garlic', 'parent': 'Very negative'},
#                             {'name': 'arepa', 'parent': 'Very negative'},
#                             {'name': 'quail', 'parent': 'Very negative'},
#                             {'name': 'peanut', 'parent': 'Very negative'},
#                             {'name': 'coconut', 'parent': 'Very negative'},
#                             {'name': 'margarine', 'parent': 'Very negative'},
#                             {'name': 'mushrooms', 'parent': 'Very negative'},
#                             {'name': 'salt', 'parent': 'Very negative'},
#                             {'name': 'flaxseed', 'parent': 'Very negative'},
#                             {'name': 'honey', 'parent': 'Very negative'},
#                             {'name': 'sugar', 'parent': 'Very negative'},
#                             {'name': 'spirulina', 'parent': 'Very negative'},
#                             {'name': 'olive', 'parent': 'Very negative'},
#                             {'name': 'pectin', 'parent': 'Very negative'},
#                             {'name': 'gelatin', 'parent': 'Very negative'},
#                             {'name': 'liquor', 'parent': 'Very negative'},
#                             {'name': 'bean', 'parent': 'Very negative'}],
#                            'name': 'Very Negative',
#                            'parent': 'Statins'})],
#              'name': 'Statins',
#              'parent': 'null'})
